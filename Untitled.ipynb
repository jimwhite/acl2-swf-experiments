# %%
(include-book "acl2s/top" :dir :system)
# Out:
# ACL2 Warning [Compiled file] in ( INCLUDE-BOOK "acl2s/ccg/ccg" ...):
# Unable to load compiled file for book
#   /home/acl2/books/acl2s/ccg/ccg.lisp
# because the compiled file does not exist.  See :DOC include-book.
# Here is the sequence of books with loads of compiled or expansion files
# that have led down to the printing of this message, where the load
# for each is halted during the load for the next:
#
#   /home/acl2/books/acl2s/top.lisp
#   /home/acl2/books/acl2s/base-theory.lisp
#   /home/acl2/books/acl2s/properties.lisp
#
#
# TTAG NOTE (for included book): Adding ttag :EV-FNCALL-W-OK from book /home/acl2/books/acl2s/cgen/type.
#
# TTAG NOTE (for included book): Adding ttag :EV-FNCALL-W-OK from book /home/acl2/books/acl2s/cgen/utilities.
#
# TTAG NOTE (for included book): Adding ttag :EV-FNCALL-W-OK from book /home/acl2/books/acl2s/defdata/tau-characterization.
#
# ...

# %%
(in-package "ACL2S")
# Out:
#  "ACL2S"
