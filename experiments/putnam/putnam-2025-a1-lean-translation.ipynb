# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; putnam-2025-a1-lean-translation.lisp
# ;;;
# ;;; Direct translation of Lean4 Putnam 2025 A1 proof to ACL2.
# ;;;
# ;;; Source:
# ;;;   https://github.com/project-numina/Numina-Putnam2025/blob/main/NuminaPutnam2025/putnam_2025_a1.lean
# ;;;
# ;;; The Lean4 theorem statement is:
# ;;;   {k | ¬ (2 * m k + 1).Coprime (2 * n k + 1)}.Finite
# ;;;
# ;;; ACL2 formulation:
# ;;;   For any K, count-bad(m0, n0, K) < D(0) = |m0 - n0|
# ;;;   i.e., the set of "bad" indices has strictly fewer than |m0 - n0| elements.
# ;;;
# ;;; Translation from Lean4 by Jim White and GitHub Copilot (Opus 4.5) with assistance by Perplexity.
# ;;; Date: January 2026
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
(in-package "ACL2")
# Out:
#  "ACL2"

# %%
;; For dm::gcd and dm::divides
(include-book "projects/numbers/euclid" :dir :system)
# Out:
# Summary
# Form:  ( INCLUDE-BOOK "projects/numbers/euclid" ...)
# Rules: NIL
# Time:  0.06 seconds (prove: 0.00, print: 0.00, other: 0.06)
#  "/home/acl2/books/projects/numbers/euclid.lisp"

# %%
;; For arithmetic
(include-book "arithmetic-5/top" :dir :system)
# Out:
# ACL2 Observation in NON-LINEAR-ARITHMETIC:  To turn on non-linear arithmetic,
# execute :
#
# (SET-DEFAULT-HINTS '((NONLINEARP-DEFAULT-HINT STABLE-UNDER-SIMPLIFICATIONP
#                                               HIST PSPV)))
#
# or :
#
# (SET-DEFAULT-HINTS
#      '((NONLINEARP-DEFAULT-HINT++ ID
#                                   STABLE-UNDER-SIMPLIFICATIONP HIST NIL)))
#
# See the README for more about non-linear arithmetic and general information
# about using this library.
#
# Summary
# Form:  ( INCLUDE-BOOK "arithmetic-5/top" ...)
# Rules: NIL
# Time:  0.10 seconds (prove: 0.00, print: 0.00, other: 0.10)
#  "/home/acl2/books/arithmetic-5/top.lisp"

# %%
;; For evenp-times (product of odd numbers is odd)
(include-book "projects/numbers/eisenstein" :dir :system)
# Out:
# Summary
# Form:  ( INCLUDE-BOOK "projects/numbers/eisenstein" ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  "/home/acl2/books/projects/numbers/eisenstein.lisp"

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; BRIDGE LEMMAS: Connecting dm::divides to integerp
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; These derive from the definition of dm::divides and dm::gcd-divides

# %%
;; dm::divides means the quotient is an integer (from definition)
(defthm divides-means-integerp-quotient
  (implies (dm::divides d a)
           (integerp (/ a d)))
  :hints (("Goal" :in-theory (enable dm::divides))))
# Out:
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM DIVIDES-MEANS-INTEGERP-QUOTIENT ...)
# Rules: ((:DEFINITION DM::DIVIDES))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  31
#  DIVIDES-MEANS-INTEGERP-QUOTIENT

# %%
;; gcd(a,b) divides a when a is nonzero (instance of dm::gcd-divides)
(defthm gcd-divides-first
  (implies (and (integerp a) (integerp b) (not (equal a 0)))
           (dm::divides (dm::gcd a b) a))
  :hints (("Goal" :use ((:instance dm::gcd-divides (x a) (y b))))))
# Out:
# Goal'
#
# Q.E.D.
#
# The storage of GCD-DIVIDES-FIRST depends upon the :type-prescription
# rule DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM GCD-DIVIDES-FIRST ...)
# Rules: ((:TYPE-PRESCRIPTION DM::DIVIDES))
# Hint-events: ((:USE DM::GCD-DIVIDES))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  GCD-DIVIDES-FIRST

# %%
;; Combining: a/gcd(a,b) is an integer
(defthm quotient-by-gcd-integerp
  (implies (and (integerp a) (integerp b) (not (equal a 0)))
           (integerp (/ a (dm::gcd a b))))
  :hints (("Goal" :use ((:instance gcd-divides-first)
                        (:instance divides-means-integerp-quotient 
                                   (d (dm::gcd a b)))))))
# Out:
# ACL2 Warning [Use] in ( DEFTHM QUOTIENT-BY-GCD-INTEGERP ...):  It is
# unusual to :USE the formula of an enabled :REWRITE or :DEFINITION rule,
# so you may want to consider disabling (:REWRITE GCD-DIVIDES-FIRST)
# and (:REWRITE DIVIDES-MEANS-INTEGERP-QUOTIENT) in the hint provided
# for Goal.  See :DOC using-enabled-rules.
#
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM QUOTIENT-BY-GCD-INTEGERP ...)
# Rules: NIL
# Hint-events: ((:USE DIVIDES-MEANS-INTEGERP-QUOTIENT)
#               (:USE GCD-DIVIDES-FIRST))
# Warnings:  Use
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  QUOTIENT-BY-GCD-INTEGERP

# %%
;; gcd is positive when inputs are positive (instance of dm::gcd-pos)
(defthm gcd-posp
  (implies (and (posp a) (posp b))
           (posp (dm::gcd a b)))
  :hints (("Goal" :use ((:instance dm::gcd-pos (x a) (y b)))))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM GCD-POSP ...):  Our heuristics choose
# (DM::GCD A B) as the :TYPED-TERM.
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of GCD-POSP depends upon the :compound-recognizer rule
# POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM GCD-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION =)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION DM::GCD))
# Hint-events: ((:USE DM::GCD-POS))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  211
#  GCD-POSP

# %%
;; a/gcd(a,b) is positive when a is positive
(defthm quotient-by-gcd-posp
  (implies (and (posp a) (posp b))
           (posp (/ a (dm::gcd a b))))
  :hints (("Goal" :use ((:instance quotient-by-gcd-integerp)
                        (:instance gcd-posp))))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM QUOTIENT-BY-GCD-POSP ...):  Our heuristics
# choose (* A (/ (DM::GCD A B))) as the :TYPED-TERM.
#
# ACL2 Warning [Use] in ( DEFTHM QUOTIENT-BY-GCD-POSP ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE QUOTIENT-BY-GCD-INTEGERP)
# in the hint provided for Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of QUOTIENT-BY-GCD-POSP depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM QUOTIENT-BY-GCD-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION GCD-POSP))
# Hint-events: ((:USE GCD-POSP)
#               (:USE QUOTIENT-BY-GCD-INTEGERP))
# Warnings:  Use
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  231
#  QUOTIENT-BY-GCD-POSP

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; PART 1: ODD-PART FUNCTION
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; Lean4: let oddPart : ℕ → ℕ := fun n => n / 2 ^ n.factorization 2

# %%
(defun odd-part (n)
  "Remove all factors of 2 from n. Returns n if n is odd, n/2^k where k is maximal."
  (declare (xargs :guard (natp n)
                  :measure (nfix n)))
  (if (or (zp n) (not (integerp (/ n 2))))
      n
    (odd-part (/ n 2))))
# Out:
# For the admission of ODD-PART we will use the relation O< (which is
# known to be well-founded on the domain recognized by O-P) and the measure
# (NFIX N).  The non-trivial part of the measure conjecture is
#
# Goal
# (AND (O-P (NFIX N))
#      (IMPLIES (NOT (OR (ZP N) (NOT (INTEGERP (* N 1/2)))))
#               (O< (NFIX (* N 1/2)) (NFIX N)))).
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# That completes the proof of the measure theorem for ODD-PART.  Thus,
# we admit this function under the principle of definition.  We observe
# that the type of ODD-PART is described by the theorem
# (OR (AND (INTEGERP (ODD-PART N)) (< 0 (ODD-PART N))) (EQUAL (ODD-PART N) N)).
# We used the :compound-recognizer rule ZP-COMPOUND-RECOGNIZER and primitive
# type reasoning.
#
# Computing the guard conjecture for ODD-PART....
#
# The guard conjecture for ODD-PART is trivial to prove, given the :compound-
# recognizer rules NATP-COMPOUND-RECOGNIZER and ZP-COMPOUND-RECOGNIZER
# and primitive type reasoning.  ODD-PART is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN ODD-PART ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NFIX)
#         (:DEFINITION NOT)
#         (:DEFINITION O-FINP)
#         (:DEFINITION O-P)
#         (:DEFINITION O<)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* a (/ a))|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(< x (/ y)) with (< 0 y)|)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-<))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  167
#  ODD-PART

# %%
;; Basic properties
(defthm odd-part-posp
  (implies (posp n)
           (posp (odd-part n)))
  :rule-classes (:rewrite :type-prescription))
# Out:
# ACL2 Observation in ( DEFTHM ODD-PART-POSP ...):  Our heuristics choose
# (ODD-PART N) as the :TYPED-TERM.
#
# ACL2 Warning [Non-rec] in ( DEFTHM ODD-PART-POSP ...):  A :REWRITE
# rule generated from ODD-PART-POSP will be triggered only by terms containing
# the function symbol POSP, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of ODD-PART-POSP depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER and the :type-prescription rule POSP.
#
# Summary
# Form:  ( DEFTHM ODD-PART-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION ODD-PART)
#         (:TYPE-PRESCRIPTION POSP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  ODD-PART-POSP

# %%
(defthm odd-part-leq
  (implies (posp n)
           (<= (odd-part n) n))
  :rule-classes :linear)
# Out:
# Goal'
#
# ([ A key checkpoint:
#
# Goal'
# (IMPLIES (AND (INTEGERP N) (< 0 N))
#          (<= (ODD-PART N) N))
#
# *1 (Goal') is pushed for proof by induction.
#
# ])
#
# Perhaps we can prove *1 by induction.  One induction scheme is suggested
# by this conjecture.
#
# We will induct according to a scheme suggested by (ODD-PART N).
#
# This suggestion was produced using the :induction rule ODD-PART.  If
# we let (:P N) denote *1 above then the induction scheme we'll use is
# (AND (IMPLIES (AND (NOT (OR (ZP N) (NOT (INTEGERP (* N 1/2)))))
#                    (:P (* N 1/2)))
#               (:P N))
#      (IMPLIES (OR (ZP N) (NOT (INTEGERP (* N 1/2))))
#               (:P N))).
# This induction is justified by the same argument used to admit ODD-PART.
# When applied to the goal at hand the above induction scheme produces
# three nontautological subgoals.
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/1
#
# *1 is COMPLETED!
# Thus key checkpoint Goal' is COMPLETED!
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ODD-PART-LEQ ...)
# Rules: ((:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NOT)
#         (:DEFINITION ODD-PART)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION ODD-PART)
#         (:REWRITE |(* a (/ a))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(< x (/ y)) with (< 0 y)|)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-<))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  436
#  ODD-PART-LEQ

# %%
(defthm odd-part-of-1
  (equal (odd-part 1) 1))
# Out:
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ODD-PART-OF-1 ...)
# Rules: ((:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART ODD-PART))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  4
#  ODD-PART-OF-1

# %%
(defthm odd-part-odd
  (implies (and (posp n) (not (integerp (/ n 2))))
           (equal (odd-part n) n)))
# Out:
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ODD-PART-ODD ...)
# Rules: ((:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NOT)
#         (:DEFINITION ODD-PART)
#         (:DEFINITION POSP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* y x)|))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  136
#  ODD-PART-ODD

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; PART 2: SEQUENCE DEFINITION
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; Lean4:
# ;;;   (hm : ∀ k : ℕ, m (k + 1) = ((2 * m k + 1) / (2 * n k + 1) : ℚ).num)
# ;;;   (hn : ∀ k : ℕ, n (k + 1) = ((2 * m k + 1) / (2 * n k + 1) : ℚ).den)
# ;;;
# ;;; The rational p/q reduced to lowest terms has:
# ;;;   numerator = p / gcd(p,q)
# ;;;   denominator = q / gcd(p,q)

# %%
;; Coerce to positive integer, defaulting to 1
(defun pos-fix (x)
  (if (posp x) x 1))
# Out:
# Since POS-FIX is non-recursive, its admission is trivial.  We observe
# that the type of POS-FIX is described by the theorem
# (AND (INTEGERP (POS-FIX X)) (< 0 (POS-FIX X))).  We used the :compound-
# recognizer rule POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFUN POS-FIX ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  POS-FIX

# %%
(defun next-mn (m n)
  "Given (m, n), return (m', n') where m'/n' = (2m+1)/(2n+1) reduced to lowest terms.
   Coerces non-positive inputs to 1."
  (let* ((m (pos-fix m))
         (n (pos-fix n))
         (a (+ 1 (* 2 m)))
         (b (+ 1 (* 2 n)))
         (g (dm::gcd a b)))
    (cons (/ a g) (/ b g))))
# Out:
# Since NEXT-MN is non-recursive, its admission is trivial.  We observe
# that the type of NEXT-MN is described by the theorem
# (AND (CONSP (NEXT-MN M N)) (NOT (TRUE-LISTP (NEXT-MN M N)))).  We used
# the :compound-recognizer rule POSP-COMPOUND-RECOGNIZER, primitive type
# reasoning and the :type-prescription rules GCD-POSP and POS-FIX.
#
# Summary
# Form:  ( DEFUN NEXT-MN ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION POS-FIX))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  NEXT-MN

# %%
(defun mn-seq (m0 n0 k)
  "Return (m_k . n_k) for the sequence starting at (m0, n0).
   Coerces non-positive m0/n0 to 1, non-natural k to 0."
  (declare (xargs :measure (nfix k)))
  (let ((m0 (pos-fix m0))
        (n0 (pos-fix n0)))
    (if (zp k)
        (cons m0 n0)
      (let ((prev (mn-seq m0 n0 (1- k))))
        (next-mn (car prev) (cdr prev))))))
# Out:
# For the admission of MN-SEQ we will use the relation O< (which is known
# to be well-founded on the domain recognized by O-P) and the measure
# (NFIX K).  The non-trivial part of the measure conjecture is
#
# Goal
# (AND (O-P (NFIX K))
#      (IMPLIES (NOT (ZP K))
#               (O< (NFIX (+ -1 K)) (NFIX K)))).
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# That completes the proof of the measure theorem for MN-SEQ.  Thus,
# we admit this function under the principle of definition.  We observe
# that the type of MN-SEQ is described by the theorem
# (AND (CONSP (MN-SEQ M0 N0 K)) (NOT (TRUE-LISTP (MN-SEQ M0 N0 K)))).
# We used primitive type reasoning and the :type-prescription rules NEXT-MN
# and POS-FIX.
#
# Summary
# Form:  ( DEFUN MN-SEQ ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NFIX)
#         (:DEFINITION O-FINP)
#         (:DEFINITION O-P)
#         (:DEFINITION O<)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE SIMPLIFY-SUMS-<)
#         (:TYPE-PRESCRIPTION NEXT-MN)
#         (:TYPE-PRESCRIPTION POS-FIX))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  130
#  MN-SEQ

# %%
(defun m-k (m0 n0 k) (car (mn-seq m0 n0 k)))
(defun n-k (m0 n0 k) (cdr (mn-seq m0 n0 k)))
# Out:
# Since M-K is non-recursive, its admission is trivial.  We could deduce
# no constraints on the type of M-K.
#
# Summary
# Form:  ( DEFUN M-K ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  M-K
#
# Since N-K is non-recursive, its admission is trivial.  We observe that
# the type of N-K is described by the theorem (NOT (TRUE-LISTP (N-K M0 N0 K))).
# We used primitive type reasoning and the :type-prescription rule MN-SEQ.
#
# Summary
# Form:  ( DEFUN N-K ...)
# Rules: ((:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION MN-SEQ))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  N-K

# %%
;; 2m+1 is positive when m is positive
(defthm two-m-plus-one-posp
  (implies (posp m)
           (posp (+ 1 (* 2 m))))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM TWO-M-PLUS-ONE-POSP ...):  Our heuristics
# choose (+ 1 (* 2 M)) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of TWO-M-PLUS-ONE-POSP depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM TWO-M-PLUS-ONE-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TWO-M-PLUS-ONE-POSP

# %%
;; next-mn returns positive car
(defthm next-mn-car-posp
  (posp (car (next-mn m n)))
  :hints (("Goal" :in-theory (enable next-mn)
                  :use ((:instance quotient-by-gcd-posp
                                   (a (+ 1 (* 2 (pos-fix m))))
                                   (b (+ 1 (* 2 (pos-fix n))))))))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM NEXT-MN-CAR-POSP ...):  Our heuristics
# choose (CAR (NEXT-MN M N)) as the :TYPED-TERM.
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of NEXT-MN-CAR-POSP depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM NEXT-MN-CAR-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NEXT-MN)
#         (:DEFINITION NOT)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART DM::GCD)
#         (:EXECUTABLE-COUNTERPART POSP)
#         (:EXECUTABLE-COUNTERPART UNARY-/)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* (+ x y) z)|)
#         (:REWRITE |(* (if a b c) x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ x (if a b c))|)
#         (:REWRITE |(< x (/ y)) with (< 0 y)|)
#         (:REWRITE |(< x (if a b c))|)
#         (:REWRITE CAR-CONS)
#         (:REWRITE SIMPLIFY-TERMS-SUCH-AS-0-<-AX+BX-RATIONAL-COMMON)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION QUOTIENT-BY-GCD-POSP)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE QUOTIENT-BY-GCD-POSP))
# Time:  0.03 seconds (prove: 0.02, print: 0.00, other: 0.01)
# Prover steps counted:  916
#  NEXT-MN-CAR-POSP

# %%
;; next-mn returns positive cdr
(defthm next-mn-cdr-posp
  (posp (cdr (next-mn m n)))
  :hints (("Goal" :in-theory (enable next-mn)
                  :use ((:instance quotient-by-gcd-posp
                                   (a (+ 1 (* 2 (pos-fix n))))
                                   (b (+ 1 (* 2 (pos-fix m)))))
                        (:instance dm::gcd-commutative
                                   (x (+ 1 (* 2 (pos-fix m))))
                                   (y (+ 1 (* 2 (pos-fix n))))))))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM NEXT-MN-CDR-POSP ...):  Our heuristics
# choose (CDR (NEXT-MN M N)) as the :TYPED-TERM.
# Goal'
# Goal''
#
# Splitter note (see :DOC splitter) for Goal'' (5 subgoals).
#   if-intro: ((:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE |(* (if a b c) x)|)
#              (:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE |(< x (if a b c))|))
#
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# The storage of NEXT-MN-CDR-POSP depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM NEXT-MN-CDR-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NEXT-MN)
#         (:DEFINITION NOT)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART DM::GCD)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART POSP)
#         (:EXECUTABLE-COUNTERPART UNARY-/)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* (+ x y) z)|)
#         (:REWRITE |(* (if a b c) x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ x (if a b c))|)
#         (:REWRITE |(< x (/ y)) with (< 0 y)|)
#         (:REWRITE |(< x (if a b c))|)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DEFAULT-LESS-THAN-2)
#         (:REWRITE SIMPLIFY-TERMS-SUCH-AS-0-<-AX+BX-RATIONAL-COMMON)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE DM::GCD-COMMUTATIVE)
#               (:USE QUOTIENT-BY-GCD-POSP))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE |(* (if a b c) x)|)
#              (:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE |(< x (if a b c))|))
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Prover steps counted:  2625
#  NEXT-MN-CDR-POSP

# %%
;; mn-seq returns a pair of positive integers (proved by simultaneous induction)
(defthm mn-seq-posp-pair
  (and (posp (car (mn-seq m0 n0 k)))
       (posp (cdr (mn-seq m0 n0 k))))
  :hints (("Goal" :induct (mn-seq m0 n0 k)
                  :in-theory (enable mn-seq next-mn))
          ("Subgoal *1/2" 
           :use ((:instance quotient-by-gcd-posp
                            (a (+ 1 (* 2 (car (mn-seq (pos-fix m0) (pos-fix n0) (1- k))))))
                            (b (+ 1 (* 2 (cdr (mn-seq (pos-fix m0) (pos-fix n0) (1- k)))))))
                 (:instance quotient-by-gcd-posp
                            (a (+ 1 (* 2 (cdr (mn-seq (pos-fix m0) (pos-fix n0) (1- k))))))
                            (b (+ 1 (* 2 (car (mn-seq (pos-fix m0) (pos-fix n0) (1- k)))))))
                 (:instance dm::gcd-commutative
                            (x (+ 1 (* 2 (car (mn-seq (pos-fix m0) (pos-fix n0) (1- k))))))
                            (y (+ 1 (* 2 (cdr (mn-seq (pos-fix m0) (pos-fix n0) (1- k))))))))))
  :rule-classes ((:type-prescription :corollary (posp (car (mn-seq m0 n0 k))))
                 (:type-prescription :corollary (posp (cdr (mn-seq m0 n0 k))))))
# Out:
# ACL2 Observation in ( DEFTHM MN-SEQ-POSP-PAIR ...):  Our heuristics
# choose (CAR (MN-SEQ M0 N0 K)) as the :TYPED-TERM.
#
# ACL2 Observation in ( DEFTHM MN-SEQ-POSP-PAIR ...):  Our heuristics
# choose (CDR (MN-SEQ M0 N0 K)) as the :TYPED-TERM.
#
# *1 (the initial Goal, a key checkpoint) is pushed for proof by induction.
#
# We have been told to use induction.  One induction scheme is suggested
# by the induction hint.
#
# We will induct according to a scheme suggested by (MN-SEQ M0 N0 K).
#
# This suggestion was produced using the :induction rule MN-SEQ.  If
# we let (:P K M0 N0) denote *1 above then the induction scheme we'll
# use is
# (AND (IMPLIES (AND (NOT (ZP K))
#                    (:P (+ -1 K) (POS-FIX M0) (POS-FIX N0)))
#               (:P K M0 N0))
#      (IMPLIES (ZP K) (:P K M0 N0))).
# This induction is justified by the same argument used to admit MN-SEQ.
# Note, however, that the unmeasured variables M0 and N0 are being instantiated.
# When applied to the goal at hand the above induction scheme produces
# two nontautological subgoals.
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
#
# Splitter note (see :DOC splitter) for Subgoal *1/2'' (18 subgoals).
#   if-intro: ((:DEFINITION MN-SEQ)
#              (:DEFINITION POS-FIX)
#              (:DEFINITION POSP))
#
# Subgoal *1/2.18
# Subgoal *1/2.18'
# Subgoal *1/2.17
# Subgoal *1/2.17'
# Subgoal *1/2.17''
# Subgoal *1/2.16
# Subgoal *1/2.16'
# Subgoal *1/2.15
# Subgoal *1/2.15'
# Subgoal *1/2.15''
# Subgoal *1/2.14
# Subgoal *1/2.14'
# Subgoal *1/2.13
# Subgoal *1/2.13'
# Subgoal *1/2.13''
# Subgoal *1/2.12
# Subgoal *1/2.12'
# Subgoal *1/2.11
# Subgoal *1/2.11'
# Subgoal *1/2.11''
# Subgoal *1/2.10
# Subgoal *1/2.10'
#
# Splitter note (see :DOC splitter) for Subgoal *1/2.10' (2 subgoals).
#   if-intro: ((:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ (if a b c) x)|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE DEFAULT-DIVIDE)
#              (:REWRITE DEFAULT-LESS-THAN-2)
#              (:REWRITE DEFAULT-TIMES-1)
#              (:REWRITE DEFAULT-TIMES-2))
#
# Subgoal *1/2.10.2
# Subgoal *1/2.10.1
# Subgoal *1/2.9
# Subgoal *1/2.9'
# Subgoal *1/2.8
# Subgoal *1/2.8'
#
# Splitter note (see :DOC splitter) for Subgoal *1/2.8' (2 subgoals).
#   if-intro: ((:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ (if a b c) x)|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE DEFAULT-DIVIDE)
#              (:REWRITE DEFAULT-LESS-THAN-2)
#              (:REWRITE DEFAULT-TIMES-1)
#              (:REWRITE DEFAULT-TIMES-2))
#
# Subgoal *1/2.8.2
# Subgoal *1/2.8.1
# Subgoal *1/2.7
# Subgoal *1/2.7'
# Subgoal *1/2.6
# Subgoal *1/2.6'
#
# Splitter note (see :DOC splitter) for Subgoal *1/2.6' (4 subgoals).
#   if-intro: ((:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ (if a b c) x)|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE DEFAULT-DIVIDE)
#              (:REWRITE DEFAULT-LESS-THAN-2)
#              (:REWRITE DEFAULT-TIMES-1)
#              (:REWRITE DEFAULT-TIMES-2))
#
# Subgoal *1/2.6.4
# Subgoal *1/2.6.3
# Subgoal *1/2.6.2
# Subgoal *1/2.6.1
# Subgoal *1/2.5
# Subgoal *1/2.5'
# Subgoal *1/2.4
# Subgoal *1/2.4'
#
# Splitter note (see :DOC splitter) for Subgoal *1/2.4' (2 subgoals).
#   if-intro: ((:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ (if a b c) x)|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE DEFAULT-DIVIDE)
#              (:REWRITE DEFAULT-LESS-THAN-2)
#              (:REWRITE DEFAULT-TIMES-1)
#              (:REWRITE DEFAULT-TIMES-2))
#
# Subgoal *1/2.4.2
# Subgoal *1/2.4.1
# Subgoal *1/2.3
# Subgoal *1/2.3'
# Subgoal *1/2.2
# Subgoal *1/2.2'
#
# Splitter note (see :DOC splitter) for Subgoal *1/2.2' (2 subgoals).
#   if-intro: ((:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ (if a b c) x)|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE DEFAULT-DIVIDE)
#              (:REWRITE DEFAULT-LESS-THAN-2)
#              (:REWRITE DEFAULT-TIMES-1)
#              (:REWRITE DEFAULT-TIMES-2))
#
# Subgoal *1/2.2.2
# Subgoal *1/2.2.1
# Subgoal *1/2.1
# Subgoal *1/2.1'
# Subgoal *1/1
#
# *1 is COMPLETED!
# Thus key checkpoint Goal is COMPLETED!
#
# Q.E.D.
#
# The storage of MN-SEQ-POSP-PAIR depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM MN-SEQ-POSP-PAIR ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION MN-SEQ)
#         (:DEFINITION NEXT-MN)
#         (:DEFINITION NOT)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART DM::GCD)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART POSP)
#         (:EXECUTABLE-COUNTERPART UNARY-/)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION MN-SEQ)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* (+ x y) z)|)
#         (:REWRITE |(* 0 x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ (if a b c) x)|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ c (+ d x))|)
#         (:REWRITE |(+ x (if a b c))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(< x (/ y)) with (< 0 y)|)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DEFAULT-DIVIDE)
#         (:REWRITE DEFAULT-LESS-THAN-2)
#         (:REWRITE DEFAULT-TIMES-1)
#         (:REWRITE DEFAULT-TIMES-2)
#         (:REWRITE REDUCE-ADDITIVE-CONSTANT-<)
#         (:REWRITE SIMPLIFY-TERMS-SUCH-AS-0-<-AX+BX-RATIONAL-COMMON)
#         (:TYPE-PRESCRIPTION DM::GCD)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE DM::GCD-COMMUTATIVE)
#               (:USE QUOTIENT-BY-GCD-POSP))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION MN-SEQ)
#              (:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ (if a b c) x)|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE DEFAULT-DIVIDE)
#              (:REWRITE DEFAULT-LESS-THAN-2)
#              (:REWRITE DEFAULT-TIMES-1)
#              (:REWRITE DEFAULT-TIMES-2))
# Time:  5.34 seconds (prove: 5.34, print: 0.00, other: 0.00)
# Prover steps counted:  584406
#  MN-SEQ-POSP-PAIR

# %%
;; Accessor type rules (derived from mn-seq-posp-pair)
(defthm m-k-posp
  (posp (m-k m0 n0 k))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM M-K-POSP ...):  Our heuristics choose
# (M-K M0 N0 K) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of M-K-POSP depends upon the :compound-recognizer rule
# POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM M-K-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION M-K)
#         (:DEFINITION POSP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  25
#  M-K-POSP

# %%
(defthm n-k-posp
  (posp (n-k m0 n0 k))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM N-K-POSP ...):  Our heuristics choose
# (N-K M0 N0 K) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of N-K-POSP depends upon the :compound-recognizer rule
# POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM N-K-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION N-K)
#         (:DEFINITION POSP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  25
#  N-K-POSP

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; PART 3: GCD AND DIFFERENCE FUNCTIONS
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; Lean4:
# ;;;   let D : ℕ → ℕ := fun k => if m k ≥ n k then m k - n k else n k - m k
# ;;;   let g : ℕ → ℕ := fun k => (2 * m k + 1).gcd (2 * n k + 1)

# %%
(defun g-k (m0 n0 k)
  "g(k) = gcd(2*m_k + 1, 2*n_k + 1)"
  (let ((m (m-k m0 n0 k))
        (n (n-k m0 n0 k)))
    (dm::gcd (+ 1 (* 2 m)) (+ 1 (* 2 n)))))
# Out:
# Since G-K is non-recursive, its admission is trivial.  We observe that
# the type of G-K is described by the theorem
# (AND (INTEGERP (G-K M0 N0 K)) (< 0 (G-K M0 N0 K))).  We used the :compound-
# recognizer rule POSP-COMPOUND-RECOGNIZER, primitive type reasoning
# and the :type-prescription rules GCD-POSP, M-K-POSP, N-K-POSP and
# TWO-M-PLUS-ONE-POSP.
#
# Summary
# Form:  ( DEFUN G-K ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION M-K-POSP)
#         (:TYPE-PRESCRIPTION N-K-POSP)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  G-K

# %%
(defun D-k (m0 n0 k)
  "D(k) = |m_k - n_k|"
  (abs (- (m-k m0 n0 k) (n-k m0 n0 k))))
# Out:
# Since D-K is non-recursive, its admission is trivial.  We observe that
# the type of D-K is described by the theorem
# (NOT (AND (RATIONALP (D-K M0 N0 K)) (< (D-K M0 N0 K) 0))).  We used
# the :type-prescription rule ABS.
#
# Summary
# Form:  ( DEFUN D-K ...)
# Rules: ((:TYPE-PRESCRIPTION ABS))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  D-K

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; PART 4: PRODUCT OF GCDs
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; Lean4: (Finset.range K).prod g
# ;;; This is the product g(0) * g(1) * ... * g(K-1)

# %%
(defun prod-g (m0 n0 k)
  "Product of g(0), g(1), ..., g(k-1). Empty product (k=0) is 1."
  (declare (xargs :measure (nfix k)))
  (if (zp k)
      1
    (* (g-k m0 n0 (1- k)) (prod-g m0 n0 (1- k)))))
# Out:
# For the admission of PROD-G we will use the relation O< (which is known
# to be well-founded on the domain recognized by O-P) and the measure
# (NFIX K).  The non-trivial part of the measure conjecture is
#
# Goal
# (AND (O-P (NFIX K))
#      (IMPLIES (NOT (ZP K))
#               (O< (NFIX (+ -1 K)) (NFIX K)))).
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# That completes the proof of the measure theorem for PROD-G.  Thus,
# we admit this function under the principle of definition.  We observe
# that the type of PROD-G is described by the theorem
# (AND (INTEGERP (PROD-G M0 N0 K)) (< 0 (PROD-G M0 N0 K))).  We used
# primitive type reasoning and the :type-prescription rule G-K.
#
# Summary
# Form:  ( DEFUN PROD-G ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NFIX)
#         (:DEFINITION O-FINP)
#         (:DEFINITION O-P)
#         (:DEFINITION O<)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE SIMPLIFY-SUMS-<)
#         (:TYPE-PRESCRIPTION G-K))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  130
#  PROD-G

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; PART 5: KEY LEMMAS FROM LEAN4 (PROVEN)
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %% [raw]
# ;; Helper lemmas for recurrence proofs

# %%
;; g-k in terms of mn-seq
(defthm g-k-expand
  (equal (g-k m0 n0 k)
         (dm::gcd (+ 1 (* 2 (car (mn-seq m0 n0 k))))
                  (+ 1 (* 2 (cdr (mn-seq m0 n0 k))))))
  :hints (("Goal" :in-theory (enable g-k m-k n-k))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM G-K-EXPAND ...):  A :REWRITE rule
# generated from G-K-EXPAND will be triggered only by terms containing
# the function symbol G-K, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM G-K-EXPAND ...)
# Rules: ((:DEFINITION G-K)
#         (:DEFINITION M-K)
#         (:DEFINITION N-K)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  554
#  G-K-EXPAND

# %%
;; mn-seq at k+1 in terms of next-mn at k
(defthm mn-seq-step
  (implies (natp k)
           (equal (mn-seq m0 n0 (+ 1 k))
                  (next-mn (car (mn-seq m0 n0 k))
                           (cdr (mn-seq m0 n0 k)))))
  :hints (("Goal" :in-theory (enable mn-seq)
                  :expand ((mn-seq m0 n0 (+ 1 k))))))
# Out:
# Goal'
#
# Splitter note (see :DOC splitter) for Goal' (16 subgoals).
#   if-intro: ((:DEFINITION MN-SEQ)
#              (:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE CONS-EQUAL))
#
# Subgoal 16
#
# ([ A key checkpoint:
#
# Subgoal 16
# (IMPLIES (AND (INTEGERP K)
#               (<= 0 K)
#               (NOT (INTEGERP M0))
#               (NOT (INTEGERP N0)))
#          (EQUAL (+ (/ (DM::GCD (+ 1 (* 2 (CAR (MN-SEQ 1 1 K))))
#                                (+ 1 (* 2 (CDR (MN-SEQ 1 1 K))))))
#                    (* 2 (CAR (MN-SEQ 1 1 K))
#                       (/ (DM::GCD (+ 1 (* 2 (CAR (MN-SEQ 1 1 K))))
#                                   (+ 1 (* 2 (CDR (MN-SEQ 1 1 K))))))))
#                 (+ (/ (DM::GCD (+ 1 (* 2 (CAR (MN-SEQ M0 N0 K))))
#                                (+ 1 (* 2 (CDR (MN-SEQ M0 N0 K))))))
#                    (* 2 (CAR (MN-SEQ M0 N0 K))
#                       (/ (DM::GCD (+ 1 (* 2 (CAR (MN-SEQ M0 N0 K))))
#                                   (+ 1 (* 2 (CDR (MN-SEQ M0 N0 K))))))))))
#
# *1 (Subgoal 16) is pushed for proof by induction.
#
# ])
# Subgoal 15
#
# ([ A key checkpoint:
#
# Subgoal 15
# (IMPLIES (AND (INTEGERP K)
#               (<= 0 K)
#               (NOT (INTEGERP M0))
#               (NOT (INTEGERP N0)))
#          (EQUAL (+ (/ (DM::GCD (+ 1 (* 2 (CAR (MN-SEQ 1 1 K))))
#                                (+ 1 (* 2 (CDR (MN-SEQ 1 1 K))))))
#                    (* 2 (CDR (MN-SEQ 1 1 K))
#                       (/ (DM::GCD (+ 1 (* 2 (CAR (MN-SEQ 1 1 K))))
#                                   (+ 1 (* 2 (CDR (MN-SEQ 1 1 K))))))))
#                 (+ (/ (DM::GCD (+ 1 (* 2 (CAR (MN-SEQ M0 N0 K))))
#                                (+ 1 (* 2 (CDR (MN-SEQ M0 N0 K))))))
#                    (* 2 (CDR (MN-SEQ M0 N0 K))
#                       (/ (DM::GCD (+ 1 (* 2 (CAR (MN-SEQ M0 N0 K))))
#                                   (+ 1 (* 2 (CDR (MN-SEQ M0 N0 K))))))))))
#
# Normally we would attempt to prove Subgoal 15 by induction.  However,
# we prefer in this instance to focus on the original input conjecture
# rather than this simplified special case.  We therefore abandon our
# previous work on this conjecture and reassign the name *1 to the original
# conjecture.  (See :DOC otf-flg.)
#
# ])
#
# Perhaps we can prove *1 by induction.  Two induction schemes are suggested
# by this conjecture.  Subsumption reduces that number to one.
#
# We will induct according to a scheme suggested by (MN-SEQ M0 N0 K),
# while accommodating (MN-SEQ M0 N0 K).
#
# These suggestions were produced using the :induction rule MN-SEQ.
# If we let (:P K M0 N0) denote *1 above then the induction scheme we'll
# use is
# (AND (IMPLIES (AND (NOT (ZP K))
#                    (:P (+ -1 K) (POS-FIX M0) (POS-FIX N0)))
#               (:P K M0 N0))
#      (IMPLIES (ZP K) (:P K M0 N0))).
# This induction is justified by the same argument used to admit MN-SEQ.
# Note, however, that the unmeasured variables M0 and N0 are being instantiated.
# When applied to the goal at hand the above induction scheme produces
# two nontautological subgoals.
# Subgoal *1/2
# Subgoal *1/2'
#
# Splitter note (see :DOC splitter) for Subgoal *1/2' (81 subgoals).
#   if-intro: ((:DEFINITION MN-SEQ)
#              (:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE |(* (if a b c) x)|)
#              (:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ x (if a b c))|))
#
# Subgoal *1/2.81
# Subgoal *1/2.80
# Subgoal *1/2.79
# Subgoal *1/2.78
# Subgoal *1/2.77
# Subgoal *1/2.76
# Subgoal *1/2.75
# Subgoal *1/2.74
# Subgoal *1/2.73
# Subgoal *1/2.72
# Subgoal *1/2.71
# Subgoal *1/2.70
# Subgoal *1/2.69
# Subgoal *1/2.68
# Subgoal *1/2.67
# Subgoal *1/2.66
# Subgoal *1/2.65
# Subgoal *1/2.64
# Subgoal *1/2.63
# Subgoal *1/2.62
# Subgoal *1/2.61
# Subgoal *1/2.60
# Subgoal *1/2.59
# Subgoal *1/2.58
# Subgoal *1/2.57
# Subgoal *1/2.56
# Subgoal *1/2.55
# Subgoal *1/2.54
# Subgoal *1/2.53
# Subgoal *1/2.52
# Subgoal *1/2.51
# Subgoal *1/2.50
# Subgoal *1/2.49
# Subgoal *1/2.48
# Subgoal *1/2.47
# Subgoal *1/2.46
# Subgoal *1/2.45
# Subgoal *1/2.44
# Subgoal *1/2.43
# Subgoal *1/2.42
# Subgoal *1/2.41
# Subgoal *1/2.40
# Subgoal *1/2.39
# Subgoal *1/2.38
# Subgoal *1/2.37
# Subgoal *1/2.36
# Subgoal *1/2.35
# Subgoal *1/2.34
# Subgoal *1/2.33
# Subgoal *1/2.32
# Subgoal *1/2.31
# Subgoal *1/2.30
# Subgoal *1/2.29
# Subgoal *1/2.28
# Subgoal *1/2.27
# Subgoal *1/2.26
# Subgoal *1/2.25
# Subgoal *1/2.24
# Subgoal *1/2.23
# Subgoal *1/2.22
# Subgoal *1/2.21
# Subgoal *1/2.20
# Subgoal *1/2.19
# Subgoal *1/2.18
# Subgoal *1/2.17
# Subgoal *1/2.16
# Subgoal *1/2.15
# Subgoal *1/2.14
# Subgoal *1/2.13
# Subgoal *1/2.12
# Subgoal *1/2.11
# Subgoal *1/2.10
# Subgoal *1/2.9
# Subgoal *1/2.8
# Subgoal *1/2.7
# Subgoal *1/2.6
# Subgoal *1/2.5
# Subgoal *1/2.4
# Subgoal *1/2.3
# Subgoal *1/2.2
# Subgoal *1/2.1
# Subgoal *1/1
# Subgoal *1/1'
# Subgoal *1/1''
#
# Splitter note (see :DOC splitter) for Subgoal *1/1'' (9 subgoals).
#   if-intro: ((:DEFINITION MN-SEQ)
#              (:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ x (if a b c))|))
#
# Subgoal *1/1.9
# Subgoal *1/1.9'
# Subgoal *1/1.8
# Subgoal *1/1.7
# Subgoal *1/1.6
# Subgoal *1/1.5
# Subgoal *1/1.5'
# Subgoal *1/1.4
# Subgoal *1/1.3
# Subgoal *1/1.3'
# Subgoal *1/1.2
# Subgoal *1/1.1
# Subgoal *1/1.1'
#
# *1 is COMPLETED!
# Thus key checkpoint Goal is COMPLETED!
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM MN-SEQ-STEP ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION MN-SEQ)
#         (:DEFINITION NATP)
#         (:DEFINITION NEXT-MN)
#         (:DEFINITION NOT)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART DM::GCD)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART MN-SEQ)
#         (:EXECUTABLE-COUNTERPART NEXT-MN)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART POS-FIX)
#         (:EXECUTABLE-COUNTERPART POSP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:EXECUTABLE-COUNTERPART UNARY-/)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-LINEAR-EQUALITIES NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION MN-SEQ)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* (+ x y) z)|)
#         (:REWRITE |(* (if a b c) x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* c (* d x))|)
#         (:REWRITE |(* x (+ y z))|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ c (+ d x))|)
#         (:REWRITE |(+ x (* c x))|)
#         (:REWRITE |(+ x (if a b c))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(< x (/ y)) with (< 0 y)|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE CONS-EQUAL)
#         (:REWRITE DEFAULT-LESS-THAN-2)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE REDUCE-ADDITIVE-CONSTANT-<)
#         (:REWRITE REMOVE-WEAK-INEQUALITIES)
#         (:REWRITE SIMPLIFY-TERMS-SUCH-AS-0-<-AX+BX-RATIONAL-COMMON)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION MN-SEQ)
#              (:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE |(* (if a b c) x)|)
#              (:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(+ x (if a b c))|))
# Time:  9.52 seconds (prove: 9.51, print: 0.00, other: 0.00)
# Prover steps counted:  791955
#  MN-SEQ-STEP

# %%
;;; LEMMA 4 (Lean4: hD_rec): D(k+1) * g(k) = 2 * D(k)
;;; KEY RECURRENCE - PROVEN!
(defthm D-recurrence
  (implies (natp k)
           (equal (* (D-k m0 n0 (+ 1 k)) (g-k m0 n0 k))
                  (* 2 (D-k m0 n0 k))))
  :hints (("Goal" :in-theory (enable D-k m-k n-k g-k mn-seq next-mn))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM D-RECURRENCE ...):  A :REWRITE rule
# generated from D-RECURRENCE will be triggered only by terms containing
# the function symbols D-K and G-K, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
#
# ACL2 Warning [Subsume] in ( DEFTHM D-RECURRENCE ...):  The previously
# added rule |(* y x)| subsumes a newly proposed :REWRITE rule generated
# from D-RECURRENCE, in the sense that the old rule rewrites a more general
# target.  Because the new rule will be tried first, it may nonetheless
# find application.
#
# Goal'
#
# Splitter note (see :DOC splitter) for Goal' (2 subgoals).
#   if-intro: ((:DEFINITION ABS)
#              (:REWRITE |(* (if a b c) x)|)
#              (:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(equal (if a b c) x)|))
#
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM D-RECURRENCE ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NEXT-MN)
#         (:DEFINITION NOT)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* (+ x y) z)|)
#         (:REWRITE |(* (if a b c) x)|)
#         (:REWRITE |(* 0 x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* a (/ a))|)
#         (:REWRITE |(* x (+ y z))|)
#         (:REWRITE |(* x (- y))|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ (* c x) (* d x))|)
#         (:REWRITE |(+ (+ x y) z)|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (* c x))|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE |(equal (if a b c) x)|)
#         (:REWRITE BUBBLE-DOWN-+-BUBBLE-DOWN)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE MN-SEQ-STEP)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-EQUAL)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-<)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION ABS)
#              (:REWRITE |(* (if a b c) x)|)
#              (:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(equal (if a b c) x)|))
# Warnings:  Subsume and Non-rec
# Time:  0.04 seconds (prove: 0.03, print: 0.00, other: 0.01)
# Prover steps counted:  1972
#  D-RECURRENCE

# %%
;; Algebra helper for product formula
(defthm algebra-helper
  (implies (and (equal (* d-succ g) (* 2 d-prev))
                (equal (* d-prev pg) (* exp d0))
                (acl2-numberp d-succ)
                (acl2-numberp d-prev)
                (acl2-numberp d0)
                (acl2-numberp g)
                (acl2-numberp pg)
                (acl2-numberp exp))
           (equal (* d-succ g pg) (* 2 exp d0))))
# Out:
# ACL2 Warning [Free] in ( DEFTHM ALGEBRA-HELPER ...):  A :REWRITE rule
# generated from ALGEBRA-HELPER contains the free variables D-PREV, D0
# and EXP.  These variables will be chosen by searching for instances
# of (EQUAL (* D-SUCC G) (* 2 D-PREV)) and (EQUAL (* D-PREV PG) (* EXP D0))
# in the context of the term being rewritten.  This is generally a severe
# restriction on the applicability of a :REWRITE rule.  See :DOC free-
# variables.
#
#
# ACL2 Warning [Subsume] in ( DEFTHM ALGEBRA-HELPER ...):  The previously
# added rules |(* y (* x z))| and |(* y x)| subsume a newly proposed
# :REWRITE rule generated from ALGEBRA-HELPER, in the sense that the
# old rules rewrite more general targets.  Because the new rule will
# be tried first, it may nonetheless find application.
#
#
# Splitter note (see :DOC splitter) for Goal (1 subgoal).
#   case-split: ((:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-EQUAL))
#
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ALGEBRA-HELPER ...)
# Rules: ((:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART FORCE)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:EXECUTABLE-COUNTERPART UNARY-/)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* 0 x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* a (/ a))|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(/ (/ x))|)
#         (:REWRITE |(equal (/ x) c)|)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-EQUAL))
# Splitter rules (see :DOC splitter):
#   case-split: ((:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-EQUAL))
# Warnings:  Subsume and Free
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  469
#  ALGEBRA-HELPER

# %%
;;; LEMMA 5 (Lean4: hprod_formula): D(K) * prod-g(K) = 2^K * D(0)
;;; PROVEN!
(defthm product-formula
  (implies (natp k)
           (equal (* (D-k m0 n0 k) (prod-g m0 n0 k))
                  (* (expt 2 k) (D-k m0 n0 0))))
  :hints (("Goal" :induct (prod-g m0 n0 k)
                  :in-theory (e/d (prod-g)
                                  (D-k g-k mn-seq m-k n-k next-mn pos-fix D-recurrence)))
          ("Subgoal *1/2" 
           :use ((:instance D-recurrence (k (1- k)))
                 (:instance algebra-helper
                            (d-succ (D-k m0 n0 k))
                            (g (g-k m0 n0 (1- k)))
                            (d-prev (D-k m0 n0 (1- k)))
                            (pg (prod-g m0 n0 (1- k)))
                            (exp (expt 2 (1- k)))
                            (d0 (D-k m0 n0 0))))
           :in-theory (e/d (prod-g g-k-expand)
                           (D-k g-k mn-seq m-k n-k next-mn pos-fix D-recurrence algebra-helper)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM PRODUCT-FORMULA ...):  A :REWRITE
# rule generated from PRODUCT-FORMULA will be triggered only by terms
# containing the function symbol D-K, which has a non-recursive definition.
# Unless this definition is disabled, this rule is unlikely ever to be
# used.
#
#
# ACL2 Warning [Subsume] in ( DEFTHM PRODUCT-FORMULA ...):  The previously
# added rule |(* y x)| subsumes a newly proposed :REWRITE rule generated
# from PRODUCT-FORMULA, in the sense that the old rule rewrites a more
# general target.  Because the new rule will be tried first, it may nonetheless
# find application.
#
#
# *1 (the initial Goal, a key checkpoint) is pushed for proof by induction.
#
# We have been told to use induction.  One induction scheme is suggested
# by the induction hint.
#
# We will induct according to a scheme suggested by (PROD-G M0 N0 K).
#
# This suggestion was produced using the :induction rule PROD-G.  If
# we let (:P K M0 N0) denote *1 above then the induction scheme we'll
# use is
# (AND (IMPLIES (AND (NOT (ZP K)) (:P (+ -1 K) M0 N0))
#               (:P K M0 N0))
#      (IMPLIES (ZP K) (:P K M0 N0))).
# This induction is justified by the same argument used to admit PROD-G.
# When applied to the goal at hand the above induction scheme produces
# two nontautological subgoals.
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
#
# Splitter note (see :DOC splitter) for Subgoal *1/2'' (8 subgoals).
#   if-intro: ((:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(equal (if a b c) x)|)
#              (:REWRITE DEFAULT-TIMES-1)
#              (:REWRITE DEFAULT-TIMES-2))
#
# Subgoal *1/2.8
# Subgoal *1/2.7
# Subgoal *1/2.7'
# Subgoal *1/2.6
# Subgoal *1/2.6'
# Subgoal *1/2.5
# Subgoal *1/2.4
# Subgoal *1/2.3
# Subgoal *1/2.2
# Subgoal *1/2.1
# Subgoal *1/1
# Subgoal *1/1'
# Subgoal *1/1''
#
# *1 is COMPLETED!
# Thus key checkpoint Goal is COMPLETED!
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM PRODUCT-FORMULA ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION PROD-G)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART ACL2-NUMBERP)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART EXPT)
#         (:EXECUTABLE-COUNTERPART FIX)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART RATIONALP)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-LINEAR-EQUALITIES NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION PROD-G)
#         (:REWRITE |(* 0 x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* c (expt d n))|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ c (+ d x))|)
#         (:REWRITE |(equal (* x y) 0)|)
#         (:REWRITE |(equal (if a b c) x)|)
#         (:REWRITE BUBBLE-DOWN-*-MATCH-3)
#         (:REWRITE DEFAULT-TIMES-1)
#         (:REWRITE DEFAULT-TIMES-2)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE NORMALIZE-FACTORS-GATHER-EXPONENTS)
#         (:REWRITE REMOVE-WEAK-INEQUALITIES)
#         (:TYPE-PRESCRIPTION D-K)
#         (:TYPE-PRESCRIPTION EXPT-TYPE-PRESCRIPTION-INTEGERP-BASE)
#         (:TYPE-PRESCRIPTION EXPT-TYPE-PRESCRIPTION-NONNEGATIVE-BASE)
#         (:TYPE-PRESCRIPTION EXPT-TYPE-PRESCRIPTION-POSITIVE-BASE)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION PROD-G)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE ALGEBRA-HELPER)
#               (:USE D-RECURRENCE))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(equal (if a b c) x)|)
#              (:REWRITE DEFAULT-TIMES-1)
#              (:REWRITE DEFAULT-TIMES-2))
# Warnings:  Subsume and Non-rec
# Time:  0.05 seconds (prove: 0.04, print: 0.00, other: 0.01)
# Prover steps counted:  4571
#  PRODUCT-FORMULA

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; ODDNESS LEMMAS
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Definition of odd
(defun my-oddp (n)
  (and (integerp n)
       (not (integerp (/ n 2)))))
# Out:
# Since MY-ODDP is non-recursive, its admission is trivial.  We observe
# that the type of MY-ODDP is described by the theorem
# (OR (EQUAL (MY-ODDP N) T) (EQUAL (MY-ODDP N) NIL)).
#
# Summary
# Form:  ( DEFUN MY-ODDP ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MY-ODDP

# %%
;; 2k+1 is odd
(defthm two-k-plus-one-odd
  (implies (integerp k)
           (my-oddp (+ 1 (* 2 k))))
  :hints (("Goal" :in-theory (enable my-oddp))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM TWO-K-PLUS-ONE-ODD ...):  A :REWRITE
# rule generated from TWO-K-PLUS-ONE-ODD will be triggered only by terms
# containing the function symbol MY-ODDP, which has a non-recursive definition.
# Unless this definition is disabled, this rule is unlikely ever to be
# used.
#
#
# Q.E.D.
#
# The storage of TWO-K-PLUS-ONE-ODD depends upon the :type-prescription
# rule MY-ODDP.
#
# Summary
# Form:  ( DEFTHM TWO-K-PLUS-ONE-ODD ...)
# Rules: ((:DEFINITION MY-ODDP)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* a (/ a) b)|)
#         (:REWRITE |(* x (+ y z))|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:TYPE-PRESCRIPTION MY-ODDP))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  66
#  TWO-K-PLUS-ONE-ODD

# %%
;; If d is even and q is integer, then d*q is even
(defthm even-times-integer-is-even
  (implies (and (integerp (/ d 2))
                (integerp q))
           (integerp (/ (* d q) 2)))
  :hints (("Goal" :use ((:instance (:theorem (implies (integerp x) (integerp (* 2 x))))
                                   (x (* (/ d 2) q)))))))
# Out:
# Goal'
# Goal''
#
# Splitter note (see :DOC splitter) for Goal'' (2 subgoals).
#   if-intro: ((:REWRITE |(* x (if a b c))|)
#              (:REWRITE DEFAULT-TIMES-1))
#
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM EVEN-TIMES-INTEGER-IS-EVEN ...)
# Rules: ((:DEFINITION FIX)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART UNARY-/)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:META META-INTEGERP-CORRECT)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* a (/ a) b)|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE DEFAULT-TIMES-1)
#         (:REWRITE INTP-1)
#         (:REWRITE META-INTEGERP-UNHIDE-HIDE))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:REWRITE |(* x (if a b c))|)
#              (:REWRITE DEFAULT-TIMES-1))
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Prover steps counted:  566
#  EVEN-TIMES-INTEGER-IS-EVEN

# %%
;; A divisor of an odd number is odd
(defthm divisor-of-odd-is-odd
  (implies (and (my-oddp n)
                (dm::divides d n)
                (posp d))
           (my-oddp d))
  :hints (("Goal" :in-theory (enable my-oddp dm::divides)
                  :use ((:instance even-times-integer-is-even
                                   (q (/ n d)))))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM DIVISOR-OF-ODD-IS-ODD ...):  A :REWRITE
# rule generated from DIVISOR-OF-ODD-IS-ODD will be triggered only by
# terms containing the function symbol MY-ODDP, which has a non-recursive
# definition.  Unless this definition is disabled, this rule is unlikely
# ever to be used.
#
#
# ACL2 Warning [Free] in ( DEFTHM DIVISOR-OF-ODD-IS-ODD ...):  A :REWRITE
# rule generated from DIVISOR-OF-ODD-IS-ODD contains the free variable
# N.  This variable will be chosen by searching for an instance of (MY-ODDP N)
# in the context of the term being rewritten.  This is generally a severe
# restriction on the applicability of a :REWRITE rule.  See :DOC free-
# variables.
#
#
# ACL2 Warning [Non-rec] in ( DEFTHM DIVISOR-OF-ODD-IS-ODD ...):  As
# noted, we will instantiate the free variable, N, of a :REWRITE rule
# generated from DIVISOR-OF-ODD-IS-ODD, by searching for the hypothesis
# shown above.  However, this hypothesis mentions the function symbol
# MY-ODDP, which has a non-recursive definition.  Unless this definition
# is disabled, that function symbol is unlikely to occur in the conjecture
# being proved and hence the search for the required hypothesis will
# likely fail.
#
#
# ACL2 Warning [Use] in ( DEFTHM DIVISOR-OF-ODD-IS-ODD ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE EVEN-TIMES-INTEGER-IS-EVEN)
# in the hint provided for Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of DIVISOR-OF-ODD-IS-ODD depends upon the :type-prescription
# rule MY-ODDP.
#
# Summary
# Form:  ( DEFTHM DIVISOR-OF-ODD-IS-ODD ...)
# Rules: ((:DEFINITION DM::DIVIDES)
#         (:DEFINITION MY-ODDP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* a (/ a) b)|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:TYPE-PRESCRIPTION MY-ODDP))
# Hint-events: ((:USE EVEN-TIMES-INTEGER-IS-EVEN))
# Warnings:  Use, Free and Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Prover steps counted:  365
#  DIVISOR-OF-ODD-IS-ODD

# %%
;; gcd of two odd positive numbers is odd
(defthm gcd-of-odds-is-odd
  (implies (and (my-oddp a) (my-oddp b) (posp a) (posp b))
           (my-oddp (dm::gcd a b)))
  :hints (("Goal" :use ((:instance divisor-of-odd-is-odd
                                   (n a)
                                   (d (dm::gcd a b)))
                        (:instance dm::gcd-divides (x a) (y b))
                        (:instance dm::gcd-pos (x a) (y b))))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM GCD-OF-ODDS-IS-ODD ...):  A :REWRITE
# rule generated from GCD-OF-ODDS-IS-ODD will be triggered only by terms
# containing the function symbol MY-ODDP, which has a non-recursive definition.
# Unless this definition is disabled, this rule is unlikely ever to be
# used.
#
#
# ACL2 Warning [Use] in ( DEFTHM GCD-OF-ODDS-IS-ODD ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE DIVISOR-OF-ODD-IS-ODD)
# in the hint provided for Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of GCD-OF-ODDS-IS-ODD depends upon the :type-prescription
# rule MY-ODDP.
#
# Summary
# Form:  ( DEFTHM GCD-OF-ODDS-IS-ODD ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION =)
#         (:DEFINITION MY-ODDP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* y x)|)
#         (:REWRITE GCD-DIVIDES-FIRST)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MY-ODDP))
# Hint-events: ((:USE DIVISOR-OF-ODD-IS-ODD)
#               (:USE DM::GCD-DIVIDES)
#               (:USE DM::GCD-POS))
# Warnings:  Use and Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  694
#  GCD-OF-ODDS-IS-ODD

# %%
;;; LEMMA 2 (Lean4: hg_odd): g(k) is odd for all k - PROVEN!
(defthm g-k-is-odd
  (my-oddp (g-k m0 n0 k))
  :hints (("Goal" :in-theory (enable g-k m-k n-k)
                  :use ((:instance gcd-of-odds-is-odd
                                   (a (+ 1 (* 2 (car (mn-seq m0 n0 k)))))
                                   (b (+ 1 (* 2 (cdr (mn-seq m0 n0 k))))))))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM G-K-IS-ODD ...):  A :REWRITE rule
# generated from G-K-IS-ODD will be triggered only by terms containing
# the function symbols MY-ODDP and G-K, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
#
# ACL2 Warning [Use] in ( DEFTHM G-K-IS-ODD ...):  It is unusual to :USE
# the formula of an enabled :REWRITE or :DEFINITION rule, so you may
# want to consider disabling (:REWRITE GCD-OF-ODDS-IS-ODD) in the hint
# provided for Goal.  See :DOC using-enabled-rules.
#
# Goal'
#
# Q.E.D.
#
# The storage of G-K-IS-ODD depends upon the :type-prescription rule
# MY-ODDP.
#
# Summary
# Form:  ( DEFTHM G-K-IS-ODD ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE GCD-OF-ODDS-IS-ODD)
#         (:REWRITE TWO-K-PLUS-ONE-ODD)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION MY-ODDP)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE GCD-OF-ODDS-IS-ODD))
# Warnings:  Use and Non-rec
# Time:  0.03 seconds (prove: 0.02, print: 0.00, other: 0.01)
# Prover steps counted:  1201
#  G-K-IS-ODD

# %%
;; If n is odd and > 1, then n >= 3
(defthm odd-gt-1-means-geq-3
  (implies (and (my-oddp n) (> n 1))
           (>= n 3))
  :hints (("Goal" :in-theory (enable my-oddp))))
# Out:
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ODD-GT-1-MEANS-GEQ-3 ...)
# Rules: ((:DEFINITION MY-ODDP)
#         (:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:FAKE-RUNE-FOR-LINEAR-EQUALITIES NIL))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  71
#  ODD-GT-1-MEANS-GEQ-3

# %%
;; If g(k) > 1, then g(k) >= 3 (key for pigeonhole bound)
(defthm bad-g-geq-3
  (implies (> (g-k m0 n0 k) 1)
           (>= (g-k m0 n0 k) 3))
  :hints (("Goal" :use ((:instance g-k-is-odd)
                        (:instance odd-gt-1-means-geq-3 (n (g-k m0 n0 k)))))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM BAD-G-GEQ-3 ...):  A :REWRITE rule
# generated from BAD-G-GEQ-3 will be triggered only by terms containing
# the function symbol G-K, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
#
# ACL2 Warning [Use] in ( DEFTHM BAD-G-GEQ-3 ...):  It is unusual to
# :USE the formula of an enabled :REWRITE or :DEFINITION rule, so you
# may want to consider disabling (:REWRITE G-K-IS-ODD) and
# (:REWRITE ODD-GT-1-MEANS-GEQ-3) in the hint provided for Goal.  See
# :DOC using-enabled-rules.
#
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM BAD-G-GEQ-3 ...)
# Rules: NIL
# Hint-events: ((:USE G-K-IS-ODD)
#               (:USE ODD-GT-1-MEANS-GEQ-3))
# Warnings:  Use and Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  BAD-G-GEQ-3

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; DIVISIBILITY LEMMAS (using dm::divides-minus from euclid)
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; gcd divides difference (combines dm::divides-sum with dm::divides-minus)
(defthm gcd-divides-diff
  (implies (and (integerp a) (integerp b) (not (equal a 0)) (not (equal b 0)))
           (dm::divides (dm::gcd a b) (- a b)))
  :hints (("Goal" :use ((:instance dm::gcd-divides (x a) (y b))
                        (:instance dm::divides-minus 
                                   (x (dm::gcd a b))
                                   (y b))
                        (:instance dm::divides-sum
                                   (x (dm::gcd a b))
                                   (y a)
                                   (z (- b)))))))
# Out:
# Goal'
#
# Q.E.D.
#
# The storage of GCD-DIVIDES-DIFF depends upon the :type-prescription
# rule DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM GCD-DIVIDES-DIFF ...)
# Rules: ((:TYPE-PRESCRIPTION DM::DIVIDES))
# Hint-events: ((:USE DM::DIVIDES-MINUS)
#               (:USE DM::DIVIDES-SUM)
#               (:USE DM::GCD-DIVIDES))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  GCD-DIVIDES-DIFF

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; ODD-PART LEMMAS (needed for hoddPart_descent)
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Key fact: odd-part(n) = n when n is odd
(defthm odd-part-of-odd
  (implies (my-oddp n)
           (equal (odd-part n) n))
  :hints (("Goal" :in-theory (enable odd-part my-oddp))))
# Out:
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ODD-PART-OF-ODD ...)
# Rules: ((:DEFINITION MY-ODDP)
#         (:DEFINITION ODD-PART)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* y x)|))
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Prover steps counted:  92
#  ODD-PART-OF-ODD

# %%
;; odd-part(2*n) = odd-part(n)
(defthm odd-part-of-double
  (implies (posp n)
           (equal (odd-part (* 2 n)) (odd-part n)))
  :hints (("Goal" :in-theory (enable odd-part)
                  :expand ((odd-part (* 2 n))))))
# Out:
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ODD-PART-OF-DOUBLE ...)
# Rules: ((:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ODD-PART)
#         (:DEFINITION POSP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* a (/ a) b)|)
#         (:REWRITE |(* y x)|))
# Time:  0.02 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Prover steps counted:  881
#  ODD-PART-OF-DOUBLE

# %% [raw]
# ;; KEY LEMMA: odd-part(n/g) * g = odd-part(n) when g is odd and g|n
# ;; (This is hoddPart-descent-lemma-2 from the search results)
# ;; Proof idea: g is odd so doesn't affect factors of 2, only odd part

# %%
;; Helper: if g|n, then n/g is an integer
(defthm divides-implies-quotient-integerp
  (implies (and (posp g) (posp n)
                (dm::divides g n))
           (integerp (/ n g)))
  :hints (("Goal" :in-theory (enable dm::divides))))
# Out:
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM DIVIDES-IMPLIES-QUOTIENT-INTEGERP ...)
# Rules: ((:DEFINITION DM::DIVIDES)
#         (:DEFINITION POSP))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  53
#  DIVIDES-IMPLIES-QUOTIENT-INTEGERP

# %%
;; Helper: if g|n, then n/g is positive
(defthm divides-implies-quotient-posp
  (implies (and (posp g) (posp n)
                (dm::divides g n))
           (posp (/ n g)))
  :hints (("Goal" :in-theory (enable dm::divides))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM DIVIDES-IMPLIES-QUOTIENT-POSP ...):
# A :REWRITE rule generated from DIVIDES-IMPLIES-QUOTIENT-POSP will be
# triggered only by terms containing the function symbol POSP, which
# has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of DIVIDES-IMPLIES-QUOTIENT-POSP depends upon the :compound-
# recognizer rule POSP-COMPOUND-RECOGNIZER and the :type-prescription
# rule POSP.
#
# Summary
# Form:  ( DEFTHM DIVIDES-IMPLIES-QUOTIENT-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION DM::DIVIDES)
#         (:DEFINITION POSP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:TYPE-PRESCRIPTION POSP))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  53
#  DIVIDES-IMPLIES-QUOTIENT-POSP

# %%
;; Use dm::evenp-times: (evenp (* x y)) = (or (evenp x) (evenp y))
(defthm odd-times-odd-is-odd
  (implies (and (integerp m) (integerp n)
                (my-oddp m) (my-oddp n))
           (my-oddp (* m n)))
  :hints (("Goal" :in-theory (enable my-oddp)
                  :use (:instance dm::evenp-times (dm::x m) (dm::y n)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM ODD-TIMES-ODD-IS-ODD ...):  A :REWRITE
# rule generated from ODD-TIMES-ODD-IS-ODD will be triggered only by
# terms containing the function symbol MY-ODDP, which has a non-recursive
# definition.  Unless this definition is disabled, this rule is unlikely
# ever to be used.
#
#
# ACL2 Warning [Use] in ( DEFTHM ODD-TIMES-ODD-IS-ODD ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE DM::EVENP-TIMES) in the
# hint provided for Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of ODD-TIMES-ODD-IS-ODD depends upon the :type-prescription
# rule MY-ODDP.
#
# Summary
# Form:  ( DEFTHM ODD-TIMES-ODD-IS-ODD ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:DEFINITION EVENP)
#         (:DEFINITION IFF)
#         (:DEFINITION MY-ODDP)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:META META-INTEGERP-CORRECT)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(equal (if a b c) x)|)
#         (:REWRITE EQUAL-OF-PREDICATES-REWRITE)
#         (:REWRITE META-INTEGERP-UNHIDE-HIDE)
#         (:TYPE-PRESCRIPTION MY-ODDP))
# Hint-events: ((:USE DM::EVENP-TIMES))
# Warnings:  Use and Non-rec
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  363
#  ODD-TIMES-ODD-IS-ODD

# %%
;; If m is odd, then odd-part(m * n) = m * odd-part(n)
;; When we multiply by an odd number, we don't add factors of 2
(defthm odd-part-times-odd
  (implies (and (posp m) (posp n) (my-oddp m))
           (equal (odd-part (* m n))
                  (* m (odd-part n))))
  :hints (("Goal" :in-theory (enable odd-part my-oddp))))
# Out:
# Goal'
# Goal''
#
# ([ A key checkpoint:
#
# Goal''
# (IMPLIES (AND (INTEGERP M)
#               (< 0 M)
#               (INTEGERP N)
#               (< 0 N)
#               (NOT (INTEGERP (* 1/2 M))))
#          (EQUAL (ODD-PART (* M N))
#                 (* M (ODD-PART N))))
#
# *1 (Goal'') is pushed for proof by induction.
#
# ])
#
# Perhaps we can prove *1 by induction.  One induction scheme is suggested
# by this conjecture.
#
# We will induct according to a scheme suggested by (ODD-PART N).
#
# This suggestion was produced using the :induction rule ODD-PART.  If
# we let (:P M N) denote *1 above then the induction scheme we'll use
# is
# (AND (IMPLIES (AND (NOT (OR (ZP N) (NOT (INTEGERP (* N 1/2)))))
#                    (:P M (* N 1/2)))
#               (:P M N))
#      (IMPLIES (OR (ZP N) (NOT (INTEGERP (* N 1/2))))
#               (:P M N))).
# This induction is justified by the same argument used to admit ODD-PART.
# When applied to the goal at hand the above induction scheme produces
# three nontautological subgoals.
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/1
#
# *1 is COMPLETED!
# Thus key checkpoint Goal'' is COMPLETED!
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ODD-PART-TIMES-ODD ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION FIX)
#         (:DEFINITION MY-ODDP)
#         (:DEFINITION NOT)
#         (:DEFINITION ODD-PART)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION ODD-PART)
#         (:META META-INTEGERP-CORRECT)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* a (/ a) b)|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(equal (if a b c) x)|)
#         (:REWRITE INTP-1)
#         (:REWRITE META-INTEGERP-UNHIDE-HIDE)
#         (:REWRITE ODD-PART-OF-ODD)
#         (:REWRITE ODD-TIMES-ODD-IS-ODD)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-EQUAL)
#         (:REWRITE ZP-OPEN)
#         (:TYPE-PRESCRIPTION INTP-*)
#         (:TYPE-PRESCRIPTION ODD-PART)
#         (:TYPE-PRESCRIPTION ODD-PART-POSP))
# Time:  0.04 seconds (prove: 0.04, print: 0.00, other: 0.00)
# Prover steps counted:  4277
#  ODD-PART-TIMES-ODD

# %%
;; Main lemma: odd-part(n/g) * g = odd-part(n) when g is odd and g|n
(defthm odd-part-quotient-by-odd
  (implies (and (posp n) (posp g)
                (my-oddp g)
                (dm::divides g n))
           (equal (* g (odd-part (/ n g)))
                  (odd-part n)))
  :hints (("Goal" 
           :use ((:instance odd-part-times-odd 
                            (m g) 
                            (n (/ n g)))
                 (:instance divides-implies-quotient-posp
                            (g g) (n n)))
           :in-theory (disable odd-part-times-odd divides-implies-quotient-posp))))
# Out:
# ACL2 Warning [Subsume] in ( DEFTHM ODD-PART-QUOTIENT-BY-ODD ...):
# The previously added rule |(* y x)| subsumes a newly proposed :REWRITE
# rule generated from ODD-PART-QUOTIENT-BY-ODD, in the sense that the
# old rule rewrites a more general target.  Because the new rule will
# be tried first, it may nonetheless find application.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ODD-PART-QUOTIENT-BY-ODD ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION MY-ODDP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* a (/ a) b)|)
#         (:REWRITE |(* y x)|)
#         (:TYPE-PRESCRIPTION DM::DIVIDES))
# Hint-events: ((:USE DIVIDES-IMPLIES-QUOTIENT-POSP)
#               (:USE ODD-PART-TIMES-ODD))
# Warnings:  Subsume
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.01)
# Prover steps counted:  1062
#  ODD-PART-QUOTIENT-BY-ODD

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; DIVISIBILITY LEMMAS - g(k) DIVIDES D(k) (PROVEN!)
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; 2 does not divide an odd number
(defthm two-not-divides-odd
  (implies (my-oddp g)
           (not (dm::divides 2 g)))
  :hints (("Goal" :in-theory (enable my-oddp dm::divides))))
# Out:
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM TWO-NOT-DIVIDES-ODD ...)
# Rules: ((:DEFINITION DM::DIVIDES)
#         (:DEFINITION MY-ODDP)
#         (:DEFINITION NOT))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  42
#  TWO-NOT-DIVIDES-ODD

# %%
;; If g is odd and g | 2x, then g | x (key: odd*integer=even iff integer is even)
(defthm odd-divides-double-implies-divides
  (implies (and (posp g)
                (integerp x)
                (my-oddp g)
                (dm::divides g (* 2 x)))
           (dm::divides g x))
  :hints (("Goal" :in-theory (enable dm::divides my-oddp)
                  :use ((:instance dm::evenp-times
                                   (dm::x g)
                                   (dm::y (/ (* 2 x) g)))))))
# Out:
# ACL2 Warning [Use] in ( DEFTHM ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES ...):
# It is unusual to :USE the formula of an enabled :REWRITE or :DEFINITION
# rule, so you may want to consider disabling (:REWRITE DM::EVENP-TIMES)
# in the hint provided for Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES depends upon the
# :type-prescription rule DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES ...)
# Rules: ((:DEFINITION DM::DIVIDES)
#         (:DEFINITION EVENP)
#         (:DEFINITION MY-ODDP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:META META-INTEGERP-CORRECT)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* a (/ a) b)|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE META-INTEGERP-UNHIDE-HIDE)
#         (:TYPE-PRESCRIPTION DM::DIVIDES))
# Hint-events: ((:USE DM::EVENP-TIMES))
# Warnings:  Use
# Time:  0.03 seconds (prove: 0.02, print: 0.00, other: 0.01)
# Prover steps counted:  547
#  ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES

# %%
;; g(k) divides 2*(m(k) - n(k)) - follows from gcd-divides-diff
(defthm g-divides-twice-diff
  (implies (natp k)
           (dm::divides (g-k m0 n0 k)
                        (* 2 (- (m-k m0 n0 k) (n-k m0 n0 k)))))
  :hints (("Goal" :in-theory (enable g-k m-k n-k)
                  :use ((:instance gcd-divides-diff
                                   (a (+ 1 (* 2 (car (mn-seq m0 n0 k)))))
                                   (b (+ 1 (* 2 (cdr (mn-seq m0 n0 k))))))))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM G-DIVIDES-TWICE-DIFF ...):  A :REWRITE
# rule generated from G-DIVIDES-TWICE-DIFF will be triggered only by
# terms containing the function symbols G-K, M-K and N-K, which have
# non-recursive definitions.  Unless these definitions are disabled,
# this rule is unlikely ever to be used.
#
#
# ACL2 Warning [Use] in ( DEFTHM G-DIVIDES-TWICE-DIFF ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE GCD-DIVIDES-DIFF) in the
# hint provided for Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of G-DIVIDES-TWICE-DIFF depends upon the :type-prescription
# rule DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM G-DIVIDES-TWICE-DIFF ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION M-K)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* x (+ y z))|)
#         (:REWRITE |(* x (- y))|)
#         (:REWRITE |(+ (+ x y) z)|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ c (+ d x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(- (* c x))|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE G-K-EXPAND)
#         (:TYPE-PRESCRIPTION DM::DIVIDES)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE GCD-DIVIDES-DIFF))
# Warnings:  Use and Non-rec
# Time:  0.04 seconds (prove: 0.03, print: 0.00, other: 0.01)
# Prover steps counted:  2133
#  G-DIVIDES-TWICE-DIFF

# %%
;; g(k) divides (m(k) - n(k)) since g(k) is odd
(defthm g-divides-diff-raw
  (implies (natp k)
           (dm::divides (g-k m0 n0 k)
                        (- (m-k m0 n0 k) (n-k m0 n0 k))))
  :hints (("Goal" :use ((:instance g-divides-twice-diff)
                        (:instance odd-divides-double-implies-divides
                                   (g (g-k m0 n0 k))
                                   (x (- (m-k m0 n0 k) (n-k m0 n0 k))))
                        (:instance g-k-is-odd)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM G-DIVIDES-DIFF-RAW ...):  A :REWRITE
# rule generated from G-DIVIDES-DIFF-RAW will be triggered only by terms
# containing the function symbols G-K, M-K and N-K, which have non-recursive
# definitions.  Unless these definitions are disabled, this rule is unlikely
# ever to be used.
#
#
# ACL2 Warning [Use] in ( DEFTHM G-DIVIDES-DIFF-RAW ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE G-DIVIDES-TWICE-DIFF),
# (:REWRITE ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES) and (:REWRITE G-K-IS-ODD)
# in the hint provided for Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of G-DIVIDES-DIFF-RAW depends upon the :type-prescription
# rule DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM G-DIVIDES-DIFF-RAW ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION M-K)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* x (+ y z))|)
#         (:REWRITE |(* x (- y))|)
#         (:REWRITE |(- (* c x))|)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE G-K-IS-ODD)
#         (:REWRITE GCD-OF-ODDS-IS-ODD)
#         (:REWRITE ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES)
#         (:REWRITE TWO-K-PLUS-ONE-ODD)
#         (:TYPE-PRESCRIPTION DM::DIVIDES)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE G-DIVIDES-TWICE-DIFF)
#               (:USE G-K-IS-ODD)
#               (:USE ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES))
# Warnings:  Use and Non-rec
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Prover steps counted:  3226
#  G-DIVIDES-DIFF-RAW

# %%
;; If d | x then d | |x|
(defthm divides-abs
  (implies (dm::divides d x)
           (dm::divides d (abs x)))
  :hints (("Goal" :in-theory (enable dm::divides)
                  :cases ((>= x 0)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM DIVIDES-ABS ...):  A :REWRITE rule
# generated from DIVIDES-ABS will be triggered only by terms containing
# the function symbol ABS, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
#
# Q.E.D.
#
# The storage of DIVIDES-ABS depends upon the :type-prescription rule
# DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM DIVIDES-ABS ...)
# Rules: ((:DEFINITION ABS)
#         (:DEFINITION DM::DIVIDES)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (- x) y)|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE REMOVE-STRICT-INEQUALITIES)
#         (:REWRITE REMOVE-WEAK-INEQUALITIES)
#         (:TYPE-PRESCRIPTION DM::DIVIDES))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  311
#  DIVIDES-ABS

# %%
;;; LEMMA 3 (Lean4: hg_dvd_D): g(k) | D(k) - PROVEN!
(defthm g-divides-D
  (implies (natp k)
           (dm::divides (g-k m0 n0 k) (D-k m0 n0 k)))
  :hints (("Goal" :in-theory (enable D-k)
                  :use ((:instance g-divides-diff-raw)
                        (:instance divides-abs
                                   (d (g-k m0 n0 k))
                                   (x (- (m-k m0 n0 k) (n-k m0 n0 k))))))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM G-DIVIDES-D ...):  A :REWRITE rule
# generated from G-DIVIDES-D will be triggered only by terms containing
# the function symbols G-K and D-K, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
#
# ACL2 Warning [Use] in ( DEFTHM G-DIVIDES-D ...):  It is unusual to
# :USE the formula of an enabled :REWRITE or :DEFINITION rule, so you
# may want to consider disabling (:REWRITE G-DIVIDES-DIFF-RAW) and
# (:REWRITE DIVIDES-ABS) in the hint provided for Goal.  See :DOC using-
# enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of G-DIVIDES-D depends upon the :type-prescription rule
# DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM G-DIVIDES-D ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:TYPE-PRESCRIPTION DM::DIVIDES)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2))
# Hint-events: ((:USE DIVIDES-ABS)
#               (:USE G-DIVIDES-DIFF-RAW))
# Warnings:  Use and Non-rec
# Time:  0.04 seconds (prove: 0.03, print: 0.00, other: 0.01)
# Prover steps counted:  3283
#  G-DIVIDES-D

# %%
;; If g is odd and g | n, then g | odd-part(n)
(defthm odd-divides-odd-part
  (implies (and (posp n) (posp g)
                (my-oddp g)
                (dm::divides g n))
           (dm::divides g (odd-part n)))
  :hints (("Goal" :in-theory (enable dm::divides)
                  :use ((:instance odd-part-quotient-by-odd (n n) (g g))
                        (:instance divides-implies-quotient-posp)))))
# Out:
# ACL2 Warning [Use] in ( DEFTHM ODD-DIVIDES-ODD-PART ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE ODD-PART-QUOTIENT-BY-ODD)
# and (:REWRITE DIVIDES-IMPLIES-QUOTIENT-POSP) in the hint provided for
# Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Goal'5'
#
# Q.E.D.
#
# The storage of ODD-DIVIDES-ODD-PART depends upon the :type-prescription
# rule DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM ODD-DIVIDES-ODD-PART ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION DM::DIVIDES)
#         (:DEFINITION HIDE)
#         (:DEFINITION MY-ODDP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* a (/ a) b)|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(/ (/ x))|)
#         (:REWRITE |(< 0 (* x y)) rationalp (* x y)|)
#         (:TYPE-PRESCRIPTION DM::DIVIDES)
#         (:TYPE-PRESCRIPTION ODD-PART-POSP))
# Hint-events: ((:USE DIVIDES-IMPLIES-QUOTIENT-POSP)
#               (:USE ODD-PART-QUOTIENT-BY-ODD))
# Warnings:  Use
# Time:  0.04 seconds (prove: 0.04, print: 0.00, other: 0.00)
# Prover steps counted:  3203
#  ODD-DIVIDES-ODD-PART

# %%
;; g(k) | odd-part(D(k))
(defthm g-divides-odd-part-D
  (implies (and (natp k) (posp (D-k m0 n0 k)))
           (dm::divides (g-k m0 n0 k) (odd-part (D-k m0 n0 k))))
  :hints (("Goal" :use ((:instance odd-divides-odd-part
                                   (g (g-k m0 n0 k))
                                   (n (D-k m0 n0 k)))
                        (:instance g-divides-D)
                        (:instance g-k-is-odd)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM G-DIVIDES-ODD-PART-D ...):  A :REWRITE
# rule generated from G-DIVIDES-ODD-PART-D will be triggered only by
# terms containing the function symbols G-K and D-K, which have non-
# recursive definitions.  Unless these definitions are disabled, this
# rule is unlikely ever to be used.
#
#
# ACL2 Warning [Use] in ( DEFTHM G-DIVIDES-ODD-PART-D ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE ODD-DIVIDES-ODD-PART),
# (:REWRITE G-DIVIDES-D) and (:REWRITE G-K-IS-ODD) in the hint provided
# for Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of G-DIVIDES-ODD-PART-D depends upon the :type-prescription
# rule DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM G-DIVIDES-ODD-PART-D ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE |(< x (if a b c))|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE G-K-IS-ODD)
#         (:REWRITE GCD-OF-ODDS-IS-ODD)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE ODD-DIVIDES-ODD-PART)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:REWRITE TWO-K-PLUS-ONE-ODD)
#         (:TYPE-PRESCRIPTION DM::DIVIDES)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE G-DIVIDES-D)
#               (:USE G-K-IS-ODD)
#               (:USE ODD-DIVIDES-ODD-PART))
# Warnings:  Use and Non-rec
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  9545
#  G-DIVIDES-ODD-PART-D

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; REMAINING LEMMAS (TO BE PROVEN)
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %% [raw]
# ;;; LEMMA 1 (Lean4: hne): m_k ≠ n_k for all k
# ;;; (defthm mn-seq-distinct ...)

# %% [raw]
# ;;; LEMMA 6 (Lean4: hoddPart_descent):
# ;;;   odd-part(D(K)) * prod-g(K) = odd-part(D(0))
# ;;; Depends on: odd-part-quotient-by-odd

# %% [raw]
# ;;; LEMMA 7 (Lean4: hprod_bound): prod-g(K) ≤ D(0)
# ;;; Follows from hoddPart_descent since odd-part(D(K)) >= 1

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; PART 6: THE FINITENESS ARGUMENT SETUP
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;;
# ;;; The Lean4 proof uses a PIGEONHOLE ARGUMENT:
# ;;;
# ;;; 1. Assume the "bad" set S = {k | g(k) > 1} is infinite
# ;;;
# ;;; 2. Extract D(0)+1 elements from S (possible since S is infinite)
# ;;;    Let these be indices i_1, i_2, ..., i_{D(0)+1}
# ;;;
# ;;; 3. For each bad index i, g(i) ≥ 3 (since gcd of odds, and > 1)
# ;;;
# ;;; 4. So product of g over these indices is ≥ 3^{D(0)+1} > D(0)
# ;;;
# ;;; 5. But by the oddPart descent, ANY product of g values over
# ;;;    distinct indices is bounded by odd-part(D(0)) ≤ D(0)
# ;;;
# ;;; 6. Contradiction! So S must be finite.
# ;;;
# ;;; ACL2 APPROACH (constructive counting):
# ;;;
# ;;; We prove: count-bad(K) < D(0) for all K
# ;;;
# ;;; where count-bad(K) counts bad indices in {0, ..., K-1}.
# ;;; This directly shows the bad set has < D(0) elements.
# ;;;
# ;;; Key lemmas used:
# ;;; - prod-g(K) >= 3^(count-bad(K))  [each bad g >= 3]
# ;;; - prod-g(K) <= D(0)              [from hoddPart-descent]
# ;;; - 3^n > n for all n              [exponential grows faster]
# ;;;
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; LEMMA 6 SETUP: hoddPart_descent helpers
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; If g is odd and g | 2x, then g | x  
;; Since g is odd, gcd(g,2) = 1, so g | x
(defthm odd-divides-implies-divides-double
  (implies (and (posp g) (integerp x)
                (my-oddp g)
                (dm::divides g (* 2 x)))
           (dm::divides g x))
  :hints (("Goal" :use ((:instance dm::evenp-times (dm::x g) (dm::y (/ (* 2 x) g))))
                  :in-theory (enable dm::divides my-oddp))))
# Out:
# ACL2 Warning [Subsume] in ( DEFTHM ODD-DIVIDES-IMPLIES-DIVIDES-DOUBLE
# ...):  A newly proposed :REWRITE rule generated from
# ODD-DIVIDES-IMPLIES-DIVIDES-DOUBLE probably subsumes the previously
# added :REWRITE rule ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES, in the sense
# that the new rule will now probably be applied whenever the old rule
# would have been.
#
#
# ACL2 Warning [Subsume] in ( DEFTHM ODD-DIVIDES-IMPLIES-DIVIDES-DOUBLE
# ...):  The previously added rule ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES
# subsumes a newly proposed :REWRITE rule generated from
# ODD-DIVIDES-IMPLIES-DIVIDES-DOUBLE, in the sense that the old rule
# rewrites a more general target.  Because the new rule will be tried
# first, it may nonetheless find application.
#
#
# ACL2 Warning [Use] in ( DEFTHM ODD-DIVIDES-IMPLIES-DIVIDES-DOUBLE ...):
# It is unusual to :USE the formula of an enabled :REWRITE or :DEFINITION
# rule, so you may want to consider disabling (:REWRITE DM::EVENP-TIMES)
# in the hint provided for Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of ODD-DIVIDES-IMPLIES-DIVIDES-DOUBLE depends upon the
# :type-prescription rule DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM ODD-DIVIDES-IMPLIES-DIVIDES-DOUBLE ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION DM::DIVIDES)
#         (:DEFINITION EVENP)
#         (:DEFINITION MY-ODDP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:META META-INTEGERP-CORRECT)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* a (/ a) b)|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE META-INTEGERP-UNHIDE-HIDE)
#         (:REWRITE ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES)
#         (:TYPE-PRESCRIPTION DM::DIVIDES))
# Hint-events: ((:USE DM::EVENP-TIMES))
# Warnings:  Use and Subsume
# Time:  0.02 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  586
#  ODD-DIVIDES-IMPLIES-DIVIDES-DOUBLE

# %%
;; D(k+1) = 2 * D(k) / g(k) as an equation
;; Note: Only requires D(k) > 0 since pos-fix handles invalid inputs
(defthm D-recurrence-quotient
  (implies (and (natp k)
                (posp (D-k m0 n0 k)))
           (equal (D-k m0 n0 (1+ k))
                  (/ (* 2 (D-k m0 n0 k))
                     (g-k m0 n0 k))))
  :hints (("Goal" :use ((:instance D-recurrence)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM D-RECURRENCE-QUOTIENT ...):  A :REWRITE
# rule generated from D-RECURRENCE-QUOTIENT will be triggered only by
# terms containing the function symbol D-K, which has a non-recursive
# definition.  Unless this definition is disabled, this rule is unlikely
# ever to be used.
#
#
# ACL2 Warning [Use] in ( DEFTHM D-RECURRENCE-QUOTIENT ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE D-RECURRENCE) in the hint
# provided for Goal.  See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM D-RECURRENCE-QUOTIENT ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NEXT-MN)
#         (:DEFINITION NOT)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* (+ x y) z)|)
#         (:REWRITE |(* (- x) y)|)
#         (:REWRITE |(* (if a b c) x)|)
#         (:REWRITE |(* 0 x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* a (/ a))|)
#         (:REWRITE |(* x (+ y z))|)
#         (:REWRITE |(* x (- y))|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ (* c x) (* d x))|)
#         (:REWRITE |(+ (+ x y) z)|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (* c x))|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE |(< x (if a b c))|)
#         (:REWRITE |(equal (if a b c) x)|)
#         (:REWRITE BUBBLE-DOWN-+-BUBBLE-DOWN)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE MN-SEQ-STEP)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-EQUAL)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-<)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-EQUAL)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE D-RECURRENCE))
# Warnings:  Use and Non-rec
# Time:  0.14 seconds (prove: 0.14, print: 0.00, other: 0.00)
# Prover steps counted:  12009
#  D-RECURRENCE-QUOTIENT

# %%
;; g(k) | 2*D(k)
(defthm g-divides-2D
  (implies (natp k)
           (dm::divides (g-k m0 n0 k) (* 2 (D-k m0 n0 k))))
  :hints (("Goal" :use ((:instance g-divides-D))
           :in-theory (e/d (dm::divides) (g-divides-D)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM G-DIVIDES-2D ...):  A :REWRITE rule
# generated from G-DIVIDES-2D will be triggered only by terms containing
# the function symbols G-K and D-K, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of G-DIVIDES-2D depends upon the :type-prescription rule
# DM::DIVIDES.
#
# Summary
# Form:  ( DEFTHM G-DIVIDES-2D ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION DM::DIVIDES)
#         (:DEFINITION M-K)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* (+ x y) z)|)
#         (:REWRITE |(* (- x) y)|)
#         (:REWRITE |(* (if a b c) x)|)
#         (:REWRITE |(* c (* d x))|)
#         (:REWRITE |(* x (+ y z))|)
#         (:REWRITE |(* x (- y))|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (* c x))|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE GCD-OF-ODDS-IS-ODD)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE ODD-DIVIDES-IMPLIES-DIVIDES-DOUBLE)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:REWRITE TWO-K-PLUS-ONE-ODD)
#         (:TYPE-PRESCRIPTION DM::DIVIDES)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE G-DIVIDES-D))
# Warnings:  Non-rec
# Time:  0.04 seconds (prove: 0.03, print: 0.00, other: 0.01)
# Prover steps counted:  2325
#  G-DIVIDES-2D

# %%
;; 2*D(k) / g(k) is positive when D(k) > 0
;; Note: Only requires D(k) > 0 since pos-fix handles invalid inputs
(defthm two-D-over-g-posp
  (implies (and (natp k)
                (posp (D-k m0 n0 k)))
           (posp (/ (* 2 (D-k m0 n0 k)) (g-k m0 n0 k))))
  :hints (("Goal" :use ((:instance g-divides-2D)
                        (:instance divides-implies-quotient-posp
                                   (g (g-k m0 n0 k))
                                   (n (* 2 (D-k m0 n0 k))))))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM TWO-D-OVER-G-POSP ...):  A :REWRITE
# rule generated from TWO-D-OVER-G-POSP will be triggered only by terms
# containing the function symbols POSP, D-K and G-K, which have non-
# recursive definitions.  Unless these definitions are disabled, this
# rule is unlikely ever to be used.
#
#
# ACL2 Warning [Use] in ( DEFTHM TWO-D-OVER-G-POSP ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE G-DIVIDES-2D) and
# (:REWRITE DIVIDES-IMPLIES-QUOTIENT-POSP) in the hint provided for Goal.
# See :DOC using-enabled-rules.
#
# Goal'
# Goal''
#
# Splitter note (see :DOC splitter) for Goal'' (4 subgoals).
#   if-intro: ((:DEFINITION ABS)
#              (:DEFINITION POSP)
#              (:REWRITE |(* x (if a b c))|))
#
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# The storage of TWO-D-OVER-G-POSP depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER and the :type-prescription rule POSP.
#
# Summary
# Form:  ( DEFTHM TWO-D-OVER-G-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* (+ x y) z)|)
#         (:REWRITE |(* (- x) y)|)
#         (:REWRITE |(* 0 x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* a (/ a))|)
#         (:REWRITE |(* x (+ y z))|)
#         (:REWRITE |(* x (- y))|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ (* c x) (* d x))|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (* c x))|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE BUBBLE-DOWN-+-BUBBLE-DOWN)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-<)
#         (:TYPE-PRESCRIPTION DM::DIVIDES)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION POSP)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE DIVIDES-IMPLIES-QUOTIENT-POSP)
#               (:USE G-DIVIDES-2D))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION ABS)
#              (:DEFINITION POSP)
#              (:REWRITE |(* x (if a b c))|))
# Warnings:  Use and Non-rec
# Time:  0.12 seconds (prove: 0.12, print: 0.00, other: 0.00)
# Prover steps counted:  11321
#  TWO-D-OVER-G-POSP

# %%
;; odd-part(D(k+1)) * g(k) = odd-part(D(k))
;; Since D(k+1) = 2*D(k)/g(k) and g(k) is odd, we can use odd-part-quotient-by-odd
;; Note: Only requires D(k) > 0 since pos-fix handles invalid inputs
(defthm oddPart-single-step
  (implies (and (natp k)
                (posp (D-k m0 n0 k)))
           (equal (* (odd-part (D-k m0 n0 (1+ k)))
                     (g-k m0 n0 k))
                  (odd-part (D-k m0 n0 k))))
  :hints (("Goal" :use ((:instance D-recurrence-quotient)
                        (:instance odd-divides-implies-divides-double
                                   (g (g-k m0 n0 k))
                                   (x (D-k m0 n0 k)))
                        (:instance odd-part-times-odd
                                   (n (/ (* 2 (D-k m0 n0 k)) (g-k m0 n0 k)))
                                   (m (g-k m0 n0 k)))
                        (:instance two-D-over-g-posp)
                        (:instance g-k-is-odd)
                        (:instance g-divides-2D))
           :in-theory (disable D-recurrence-quotient odd-divides-implies-divides-double
                               odd-part-times-odd two-D-over-g-posp g-k-is-odd
                               g-divides-2D))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM ODDPART-SINGLE-STEP ...):  A :REWRITE
# rule generated from ODDPART-SINGLE-STEP will be triggered only by terms
# containing the function symbols D-K and G-K, which have non-recursive
# definitions.  Unless these definitions are disabled, this rule is unlikely
# ever to be used.
#
#
# ACL2 Warning [Subsume] in ( DEFTHM ODDPART-SINGLE-STEP ...):  The previously
# added rule |(* y x)| subsumes a newly proposed :REWRITE rule generated
# from ODDPART-SINGLE-STEP, in the sense that the old rule rewrites a
# more general target.  Because the new rule will be tried first, it
# may nonetheless find application.
#
# Goal'
# Goal''
#
# Splitter note (see :DOC splitter) for Goal'' (3 subgoals).
#   if-intro: ((:DEFINITION ABS)
#              (:DEFINITION NOT)
#              (:DEFINITION ODD-PART)
#              (:DEFINITION POSP)
#              (:REWRITE |(* (if a b c) x)|)
#              (:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(< x (if a b c))|)
#              (:REWRITE |(equal (if a b c) x)|)
#              (:REWRITE ZP-OPEN))
#
# Subgoal 3
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ODDPART-SINGLE-STEP ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION MY-ODDP)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NEXT-MN)
#         (:DEFINITION NOT)
#         (:DEFINITION ODD-PART)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART ABS)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART POSP)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (* x y) z)|)
#         (:REWRITE |(* (+ x y) z)|)
#         (:REWRITE |(* (- x) y)|)
#         (:REWRITE |(* (if a b c) x)|)
#         (:REWRITE |(* -1 x)|)
#         (:REWRITE |(* 0 x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* a (/ a) b)|)
#         (:REWRITE |(* a (/ a))|)
#         (:REWRITE |(* c (* d x))|)
#         (:REWRITE |(* x (+ y z))|)
#         (:REWRITE |(* x (- y))|)
#         (:REWRITE |(* x (if a b c))|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ (* c x) (* d x))|)
#         (:REWRITE |(+ (+ x y) z)|)
#         (:REWRITE |(+ (- x) (* c x))|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (* c x))|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE |(< x (if a b c))|)
#         (:REWRITE |(equal (if a b c) x)|)
#         (:REWRITE BUBBLE-DOWN-+-BUBBLE-DOWN)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DM::DIVIDES-0)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE GCD-OF-ODDS-IS-ODD)
#         (:REWRITE MN-SEQ-STEP)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE ODD-DIVIDES-DOUBLE-IMPLIES-DIVIDES)
#         (:REWRITE ODD-PART-OF-ODD)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-EQUAL)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-<)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-EQUAL)
#         (:REWRITE SIMPLIFY-SUMS-EQUAL)
#         (:REWRITE TWO-K-PLUS-ONE-ODD)
#         (:REWRITE ZP-OPEN)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION ODD-PART)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE D-RECURRENCE-QUOTIENT)
#               (:USE G-DIVIDES-2D)
#               (:USE G-K-IS-ODD)
#               (:USE ODD-DIVIDES-IMPLIES-DIVIDES-DOUBLE)
#               (:USE ODD-PART-TIMES-ODD)
#               (:USE TWO-D-OVER-G-POSP))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION ABS)
#              (:DEFINITION NOT)
#              (:DEFINITION ODD-PART)
#              (:DEFINITION POSP)
#              (:REWRITE |(* (if a b c) x)|)
#              (:REWRITE |(* x (if a b c))|)
#              (:REWRITE |(< x (if a b c))|)
#              (:REWRITE |(equal (if a b c) x)|)
#              (:REWRITE ZP-OPEN))
# Warnings:  Subsume and Non-rec
# Time:  2.74 seconds (prove: 2.74, print: 0.00, other: 0.01)
# Prover steps counted:  238881
#  ODDPART-SINGLE-STEP

# %%
;; odd-part of a positive integer is positive
(defthm odd-part-of-posp-is-posp
  (implies (posp n)
           (posp (odd-part n)))
  :hints (("Goal" :in-theory (enable odd-part)))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM ODD-PART-OF-POSP-IS-POSP ...):  Our heuristics
# choose (ODD-PART N) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of ODD-PART-OF-POSP-IS-POSP depends upon the :compound-
# recognizer rule POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM ODD-PART-OF-POSP-IS-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION ODD-PART-POSP))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  ODD-PART-OF-POSP-IS-POSP

# %%
;; D(k) type - always a nat due to abs
(defthm D-k-natp-helper
  (natp (D-k m0 n0 k))
  :hints (("Goal" :in-theory (enable D-k)))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM D-K-NATP-HELPER ...):  Our heuristics
# choose (D-K M0 N0 K) as the :TYPED-TERM.
# Subgoal 2
# Subgoal 1
# Subgoal 1'
#
# Q.E.D.
#
# The storage of D-K-NATP-HELPER depends upon the :compound-recognizer
# rule NATP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM D-K-NATP-HELPER ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE |(< (if a b c) x)|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2))
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Prover steps counted:  787
#  D-K-NATP-HELPER

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; LEMMA 6: hoddPart_descent - The Key Descent Formula
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Helper: D(k) > 0 implies D(k+1) > 0
;; Note: Only requires D(k) > 0 since pos-fix handles invalid inputs
(defthm D-k-posp-step
  (implies (and (natp k)
                (posp (D-k m0 n0 k)))
           (posp (D-k m0 n0 (1+ k))))
  :hints (("Goal" :use ((:instance D-recurrence-quotient)
                        (:instance two-D-over-g-posp)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM D-K-POSP-STEP ...):  A :REWRITE
# rule generated from D-K-POSP-STEP will be triggered only by terms containing
# the function symbols POSP and D-K, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
#
# ACL2 Warning [Use] in ( DEFTHM D-K-POSP-STEP ...):  It is unusual to
# :USE the formula of an enabled :REWRITE or :DEFINITION rule, so you
# may want to consider disabling (:REWRITE D-RECURRENCE-QUOTIENT) and
# (:REWRITE TWO-D-OVER-G-POSP) in the hint provided for Goal.  See :DOC
# using-enabled-rules.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of D-K-POSP-STEP depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER and the :type-prescription rule POSP.
#
# Summary
# Form:  ( DEFTHM D-K-POSP-STEP ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* (* x y) z)|)
#         (:TYPE-PRESCRIPTION D-K-NATP-HELPER)
#         (:TYPE-PRESCRIPTION G-K)
#         (:TYPE-PRESCRIPTION POSP))
# Hint-events: ((:USE D-RECURRENCE-QUOTIENT)
#               (:USE TWO-D-OVER-G-POSP))
# Warnings:  Use and Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  342
#  D-K-POSP-STEP

# %%
;; Helper induction scheme for nat induction
(defun nat-induct (k)
  (if (zp k)
      0
    (nat-induct (1- k))))
# Out:
# The admission of NAT-INDUCT is trivial, using the relation O< (which
# is known to be well-founded on the domain recognized by O-P) and the
# measure (ACL2-COUNT K).  We observe that the type of NAT-INDUCT is
# described by the theorem (EQUAL (NAT-INDUCT K) 0).
#
# Summary
# Form:  ( DEFUN NAT-INDUCT ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  NAT-INDUCT

# %%
;; LEMMA 6 (Lean4: hoddPart_descent):
;;   odd-part(D(K)) * prod-g(K) = odd-part(D(0))
;;
;; This is the key formula showing that the product of g values
;; equals the ratio of odd-parts, which bounds the product.
;; Note: Only requires D(0) > 0 since pos-fix handles invalid inputs
(defthm hoddPart-descent
  (implies (and (natp K)
                (posp (D-k m0 n0 0)))
           (equal (* (odd-part (D-k m0 n0 K))
                     (prod-g m0 n0 K))
                  (odd-part (D-k m0 n0 0))))
  :hints (("Goal" :induct (prod-g m0 n0 K)
                  :in-theory (e/d (prod-g) 
                                  (D-k g-k odd-part odd-part-quotient-by-odd)))
          ("Subgoal *1/2" 
           :use ((:instance oddPart-single-step (k (1- K)))))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM HODDPART-DESCENT ...):  A :REWRITE
# rule generated from HODDPART-DESCENT will be triggered only by terms
# containing the function symbol D-K, which has a non-recursive definition.
# Unless this definition is disabled, this rule is unlikely ever to be
# used.
#
#
# ACL2 Warning [Subsume] in ( DEFTHM HODDPART-DESCENT ...):  The previously
# added rule |(* y x)| subsumes a newly proposed :REWRITE rule generated
# from HODDPART-DESCENT, in the sense that the old rule rewrites a more
# general target.  Because the new rule will be tried first, it may nonetheless
# find application.
#
#
# *1 (the initial Goal, a key checkpoint) is pushed for proof by induction.
#
# We have been told to use induction.  One induction scheme is suggested
# by the induction hint.
#
# We will induct according to a scheme suggested by (PROD-G M0 N0 K).
#
# This suggestion was produced using the :induction rule PROD-G.  If
# we let (:P K M0 N0) denote *1 above then the induction scheme we'll
# use is
# (AND (IMPLIES (AND (NOT (ZP K)) (:P (+ -1 K) M0 N0))
#               (:P K M0 N0))
#      (IMPLIES (ZP K) (:P K M0 N0))).
# This induction is justified by the same argument used to admit PROD-G.
# When applied to the goal at hand the above induction scheme produces
# two nontautological subgoals.
# Subgoal *1/2
#
# ACL2 Warning [Use] in ( DEFTHM HODDPART-DESCENT ...):  It is unusual
# to :USE the formula of an enabled :REWRITE or :DEFINITION rule, so
# you may want to consider disabling (:REWRITE ODDPART-SINGLE-STEP) in
# the hint provided for Subgoal *1/2.  See :DOC using-enabled-rules.
#
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/2'''
# Subgoal *1/2'4'
# Subgoal *1/1
# Subgoal *1/1'
# Subgoal *1/1''
#
# *1 is COMPLETED!
# Thus key checkpoint Goal is COMPLETED!
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM HODDPART-DESCENT ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:DEFINITION PROD-G)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART ODD-PART)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-LINEAR-EQUALITIES NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION PROD-G)
#         (:REWRITE |(* 0 x)|)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ c (+ d x))|)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE REMOVE-WEAK-INEQUALITIES)
#         (:TYPE-PRESCRIPTION D-K-NATP-HELPER)
#         (:TYPE-PRESCRIPTION ODD-PART-OF-POSP-IS-POSP))
# Hint-events: ((:USE ODDPART-SINGLE-STEP))
# Warnings:  Use, Subsume and Non-rec
# Time:  0.06 seconds (prove: 0.05, print: 0.00, other: 0.01)
# Prover steps counted:  5847
#  HODDPART-DESCENT

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; LEMMA 6 COROLLARIES
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; odd-part is at most n (since odd-part divides n)
(defthm odd-part-leq-n
  (implies (posp n)
           (<= (odd-part n) n))
  :hints (("Goal" :in-theory (enable odd-part)))
  :rule-classes :linear)
# Out:
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ODD-PART-LEQ-N ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:LINEAR ODD-PART-LEQ)
#         (:TYPE-PRESCRIPTION ODD-PART-OF-POSP-IS-POSP))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  146
#  ODD-PART-LEQ-N

# %%
;; prod-g is positive
(defthm prod-g-posp
  (implies (natp K)
           (posp (prod-g m0 n0 K)))
  :hints (("Goal" :in-theory (enable prod-g)))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM PROD-G-POSP ...):  Our heuristics choose
# (PROD-G M0 N0 K) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of PROD-G-POSP depends upon the :compound-recognizer rule
# POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM PROD-G-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION PROD-G))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  PROD-G-POSP

# %%
;; D(k) is a natural number (integer >= 0)
(defthm D-k-natp
  (implies (and (natp k) (posp m0) (posp n0) (not (equal m0 n0)))
           (natp (D-k m0 n0 k)))
  :hints (("Goal" :in-theory (enable D-k))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM D-K-NATP ...):  A :REWRITE rule
# generated from D-K-NATP will be triggered only by terms containing
# the function symbols NATP and D-K, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
#
# Q.E.D.
#
# The storage of D-K-NATP depends upon the :compound-recognizer rule
# NATP-COMPOUND-RECOGNIZER and the :type-prescription rule D-K-NATP-HELPER.
#
# Summary
# Form:  ( DEFTHM D-K-NATP ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION D-K-NATP-HELPER))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  D-K-NATP

# %%
;; D(0) > 0 when m0 ≠ n0
(defthm D-k-0-when-distinct
  (implies (and (posp m0) (posp n0) (not (equal m0 n0)))
           (posp (D-k m0 n0 0)))
  :hints (("Goal" :in-theory (enable D-k))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM D-K-0-WHEN-DISTINCT ...):  A :REWRITE
# rule generated from D-K-0-WHEN-DISTINCT will be triggered only by terms
# containing the function symbols POSP and D-K, which have non-recursive
# definitions.  Unless these definitions are disabled, this rule is unlikely
# ever to be used.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of D-K-0-WHEN-DISTINCT depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER and the :type-prescription rule POSP.
#
# Summary
# Form:  ( DEFTHM D-K-0-WHEN-DISTINCT ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION MN-SEQ)
#         (:DEFINITION N-K)
#         (:DEFINITION NOT)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE |(< x (if a b c))|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:TYPE-PRESCRIPTION POSP))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Prover steps counted:  342
#  D-K-0-WHEN-DISTINCT

# %%
;; If x * y = z where y > 0 and z >= 1 and all are integers, then x >= 1
(defthm product-equals-bound
  (implies (and (posp y) (posp z)
                (equal (* x y) z)
                (integerp x))
           (posp x))
  :rule-classes nil)
# Out:
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM PRODUCT-EQUALS-BOUND ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  PRODUCT-EQUALS-BOUND

# %%
;; odd-part(D(K)) is positive when D(0) > 0
;; From hoddPart-descent: odd-part(D(K)) * prod-g(K) = odd-part(D(0))
;; prod-g(K) > 0, odd-part(D(0)) >= 1, so odd-part(D(K)) >= 1
(defthm odd-part-D-k-posp
  (implies (and (natp K)
                (posp (D-k m0 n0 0)))
           (posp (odd-part (D-k m0 n0 K))))
  :hints (("Goal" :use ((:instance hoddPart-descent)
                        (:instance product-equals-bound
                                   (x (odd-part (D-k m0 n0 K)))
                                   (y (prod-g m0 n0 K))
                                   (z (odd-part (D-k m0 n0 0))))
                        (:instance prod-g-posp)
                        (:instance odd-part-of-posp-is-posp
                                   (n (D-k m0 n0 0))))
           :in-theory (disable hoddPart-descent prod-g-posp odd-part-of-posp-is-posp))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM ODD-PART-D-K-POSP ...):  A :REWRITE
# rule generated from ODD-PART-D-K-POSP will be triggered only by terms
# containing the function symbols POSP and D-K, which have non-recursive
# definitions.  Unless these definitions are disabled, this rule is unlikely
# ever to be used.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# The storage of ODD-PART-D-K-POSP depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER and the :type-prescription rule POSP.
#
# Summary
# Form:  ( DEFTHM ODD-PART-D-K-POSP ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION D-K-NATP-HELPER)
#         (:TYPE-PRESCRIPTION ODD-PART)
#         (:TYPE-PRESCRIPTION ODD-PART-POSP)
#         (:TYPE-PRESCRIPTION POSP)
#         (:TYPE-PRESCRIPTION PROD-G))
# Hint-events: ((:USE HODDPART-DESCENT)
#               (:USE ODD-PART-OF-POSP-IS-POSP)
#               (:USE PROD-G-POSP)
#               (:USE PRODUCT-EQUALS-BOUND))
# Warnings:  Non-rec
# Time:  0.02 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Prover steps counted:  514
#  ODD-PART-D-K-POSP

# %%
;; D(k) > 0 for all k when D(0) > 0
;; Since odd-part(D(K)) >= 1 and D(K) >= odd-part(D(K)), we have D(K) >= 1
(defthm D-k-posp-all
  (implies (and (natp k)
                (posp (D-k m0 n0 0)))
           (posp (D-k m0 n0 k)))
  :hints (("Goal" :use ((:instance odd-part-D-k-posp (K k))
                        (:instance odd-part-leq-n (n (D-k m0 n0 k))))
           :in-theory (disable odd-part-D-k-posp odd-part-leq-n))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM D-K-POSP-ALL ...):  A :REWRITE rule
# generated from D-K-POSP-ALL will be triggered only by terms containing
# the function symbols POSP and D-K, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
# Goal'
# Goal''
#
# Splitter note (see :DOC splitter) for Goal'' (20 subgoals).
#   if-intro: ((:DEFINITION ABS)
#              (:DEFINITION MN-SEQ)
#              (:DEFINITION NOT)
#              (:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE |(+ (if a b c) x)|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE |(- (if a b c))|)
#              (:REWRITE |(< (if a b c) x)|)
#              (:REWRITE |(< x (if a b c))|))
#
# Subgoal 20
# Subgoal 20'
# Subgoal 19
# Subgoal 18
# Subgoal 18'
# Subgoal 17
# Subgoal 17'
# Subgoal 16
# Subgoal 15
# Subgoal 14
# Subgoal 14'
# Subgoal 13
# Subgoal 13'
# Subgoal 12
# Subgoal 11
# Subgoal 10
# Subgoal 10'
# Subgoal 9
# Subgoal 8
# Subgoal 8'
# Subgoal 7
# Subgoal 6
# Subgoal 6'
# Subgoal 5
# Subgoal 4
# Subgoal 4'
# Subgoal 3
# Subgoal 3'
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# The storage of D-K-POSP-ALL depends upon the :compound-recognizer rule
# POSP-COMPOUND-RECOGNIZER and the :type-prescription rule POSP.
#
# Summary
# Form:  ( DEFTHM D-K-POSP-ALL ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION MN-SEQ)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART ABS)
#         (:EXECUTABLE-COUNTERPART ACL2-NUMBERP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART ODD-PART)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-LINEAR-EQUALITIES NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* a (/ a))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ (if a b c) x)|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ c (+ d x))|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ x (if a b c))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE |(- (if a b c))|)
#         (:REWRITE |(< (if a b c) x)|)
#         (:REWRITE |(< x (/ y)) with (< 0 y)|)
#         (:REWRITE |(< x (if a b c))|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DEFAULT-LESS-THAN-1)
#         (:REWRITE DEFAULT-LESS-THAN-2)
#         (:REWRITE DEFAULT-PLUS-2)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:REWRITE REDUCE-ADDITIVE-CONSTANT-<)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-<)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION ODD-PART)
#         (:TYPE-PRESCRIPTION POSP))
# Hint-events: ((:USE ODD-PART-D-K-POSP)
#               (:USE ODD-PART-LEQ-N))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION ABS)
#              (:DEFINITION MN-SEQ)
#              (:DEFINITION NOT)
#              (:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE |(+ (if a b c) x)|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE |(- (if a b c))|)
#              (:REWRITE |(< (if a b c) x)|)
#              (:REWRITE |(< x (if a b c))|))
# Warnings:  Non-rec
# Time:  0.50 seconds (prove: 0.49, print: 0.00, other: 0.01)
# Prover steps counted:  84345
#  D-K-POSP-ALL

# %%
;; If a * b = c and a >= 1 and all positive, then b <= c
(defthm product-bound
  (implies (and (posp a) (posp b) (posp c)
                (equal (* a b) c))
           (<= b c))
  :rule-classes nil)
# Out:
# Goal'
# Goal''
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM PRODUCT-BOUND ...)
# Rules: ((:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* a (/ a))|)
#         (:REWRITE |(* y (* x z))|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(< 0 (* x y)) rationalp (* x y)|)
#         (:REWRITE |(< x (/ y)) with (< 0 y)|)
#         (:REWRITE SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-<))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  291
#  PRODUCT-BOUND

# %%
;; prod-g(K) <= odd-part(D(0))
(defthm prod-g-leq-odd-part-D0
  (implies (and (natp K)
                (posp (D-k m0 n0 0)))
           (<= (prod-g m0 n0 K) (odd-part (D-k m0 n0 0))))
  :hints (("Goal" :use ((:instance hoddPart-descent)
                        (:instance odd-part-D-k-posp)
                        (:instance prod-g-posp)
                        (:instance odd-part-of-posp-is-posp (n (D-k m0 n0 0)))
                        (:instance product-bound
                                   (a (odd-part (D-k m0 n0 K)))
                                   (b (prod-g m0 n0 K))
                                   (c (odd-part (D-k m0 n0 0)))))
           :in-theory (disable hoddPart-descent odd-part-D-k-posp prod-g-posp
                               odd-part-of-posp-is-posp))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM PROD-G-LEQ-ODD-PART-D0 ...):  A
# :REWRITE rule generated from PROD-G-LEQ-ODD-PART-D0 will be triggered
# only by terms containing the function symbol D-K, which has a non-
# recursive definition.  Unless this definition is disabled, this rule
# is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM PROD-G-LEQ-ODD-PART-D0 ...)
# Rules: NIL
# Hint-events: ((:USE HODDPART-DESCENT)
#               (:USE ODD-PART-D-K-POSP)
#               (:USE ODD-PART-OF-POSP-IS-POSP)
#               (:USE PROD-G-POSP)
#               (:USE PRODUCT-BOUND))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  PROD-G-LEQ-ODD-PART-D0

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; LEMMA 7: THE MAIN BOUND (Lean4: hprod_g_bound)
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; LEMMA 7 (final form): prod-g(K) <= D(0)
;; This is crucial for the finiteness argument!
(defthm prod-g-bound
  (implies (and (natp K)
                (posp (D-k m0 n0 0)))
           (<= (prod-g m0 n0 K) (D-k m0 n0 0)))
  :hints (("Goal" :use ((:instance prod-g-leq-odd-part-D0)
                        (:instance odd-part-leq-n (n (D-k m0 n0 0))))
           :in-theory (disable prod-g-leq-odd-part-D0 odd-part-leq-n))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM PROD-G-BOUND ...):  A :REWRITE rule
# generated from PROD-G-BOUND will be triggered only by terms containing
# the function symbol D-K, which has a non-recursive definition.  Unless
# this definition is disabled, this rule is unlikely ever to be used.
#
# Goal'
# Goal''
#
# Splitter note (see :DOC splitter) for Goal'' (6 subgoals).
#   if-intro: ((:DEFINITION ABS)
#              (:DEFINITION MN-SEQ)
#              (:DEFINITION NOT)
#              (:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE |(+ (if a b c) x)|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE |(- (if a b c))|)
#              (:REWRITE |(< (if a b c) x)|)
#              (:REWRITE |(< x (if a b c))|))
#
# Subgoal 6
# Subgoal 5
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM PROD-G-BOUND ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION MN-SEQ)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART ABS)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART POSP)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(+ (if a b c) x)|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ x (if a b c))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE |(- (if a b c))|)
#         (:REWRITE |(< (if a b c) x)|)
#         (:REWRITE |(< x (if a b c))|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:TYPE-PRESCRIPTION ODD-PART)
#         (:TYPE-PRESCRIPTION ODD-PART-OF-POSP-IS-POSP)
#         (:TYPE-PRESCRIPTION PROD-G)
#         (:TYPE-PRESCRIPTION PROD-G-POSP))
# Hint-events: ((:USE ODD-PART-LEQ-N)
#               (:USE PROD-G-LEQ-ODD-PART-D0))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION ABS)
#              (:DEFINITION MN-SEQ)
#              (:DEFINITION NOT)
#              (:DEFINITION POS-FIX)
#              (:DEFINITION POSP)
#              (:REWRITE |(+ (if a b c) x)|)
#              (:REWRITE |(+ x (if a b c))|)
#              (:REWRITE |(- (if a b c))|)
#              (:REWRITE |(< (if a b c) x)|)
#              (:REWRITE |(< x (if a b c))|))
# Warnings:  Non-rec
# Time:  0.09 seconds (prove: 0.08, print: 0.00, other: 0.01)
# Prover steps counted:  19967
#  PROD-G-BOUND

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; THE FINITENESS ARGUMENT (following Lean4 exactly)
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;;
# ;;; Lean4 proves: {k | ¬(2*m_k+1).Coprime(2*n_k+1)}.Finite
# ;;; via contradiction:
# ;;; 1. Assume infinitely many bad indices
# ;;; 2. Pick D(0)+1 distinct bad indices
# ;;; 3. Product of their g values >= 3^(D(0)+1) > D(0)
# ;;; 4. But prod-g for any set <= D(0)
# ;;; 5. Contradiction
# ;;;
# ;;; In ACL2, we formulate this as: count-bad(k) < D(0) for all k
# ;;; which means there are at most D(0)-1 bad indices total.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %%
;; Helper: 3^n > n for all n (Lean4: Nat.lt_pow_self)
(defun three-pow (n)
  (declare (xargs :guard (natp n)))
  (if (zp n) 1 (* 3 (three-pow (1- n)))))
# Out:
# The admission of THREE-POW is trivial, using the relation O< (which
# is known to be well-founded on the domain recognized by O-P) and the
# measure (ACL2-COUNT N).  We observe that the type of THREE-POW is described
# by the theorem (AND (INTEGERP (THREE-POW N)) (< 0 (THREE-POW N))).
# We used primitive type reasoning.
#
# Computing the guard conjecture for THREE-POW....
#
# The guard conjecture for THREE-POW is trivial to prove, given the :compound-
# recognizer rules NATP-COMPOUND-RECOGNIZER and ZP-COMPOUND-RECOGNIZER,
# primitive type reasoning and the :type-prescription rule THREE-POW.
# THREE-POW is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN THREE-POW ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION THREE-POW))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  THREE-POW

# %%
(defthm three-pow-positive
  (posp (three-pow n))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM THREE-POW-POSITIVE ...):  Our heuristics
# choose (THREE-POW N) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of THREE-POW-POSITIVE depends upon the :compound-recognizer
# rule POSP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM THREE-POW-POSITIVE ...)
# Rules: ((:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION THREE-POW))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  THREE-POW-POSITIVE

# %%
(defthm three-pow-gt-n
  (implies (natp n)
           (> (three-pow n) n))
  :hints (("Goal" :induct (three-pow n))))
# Out:
# *1 (the initial Goal, a key checkpoint) is pushed for proof by induction.
#
# We have been told to use induction.  One induction scheme is suggested
# by the induction hint.
#
# We will induct according to a scheme suggested by (THREE-POW N).
#
# This suggestion was produced using the :induction rule THREE-POW.
# If we let (:P N) denote *1 above then the induction scheme we'll use
# is
# (AND (IMPLIES (AND (NOT (ZP N)) (:P (+ -1 N)))
#               (:P N))
#      (IMPLIES (ZP N) (:P N))).
# This induction is justified by the same argument used to admit THREE-POW.
# When applied to the goal at hand the above induction scheme produces
# two nontautological subgoals.
# Subgoal *1/2
# Subgoal *1/2'
#
# Splitter note (see :DOC splitter) for Subgoal *1/2' (2 subgoals).
#   if-intro: ((:DEFINITION THREE-POW))
#
# Subgoal *1/2.2
# Subgoal *1/2.1
# Subgoal *1/1
#
# *1 is COMPLETED!
# Thus key checkpoint Goal is COMPLETED!
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM THREE-POW-GT-N ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:DEFINITION THREE-POW)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION THREE-POW)
#         (:REWRITE REMOVE-WEAK-INEQUALITIES)
#         (:TYPE-PRESCRIPTION THREE-POW-POSITIVE))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION THREE-POW))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  230
#  THREE-POW-GT-N

# %%
;; Number of bad indices (g > 1) in range 0..k-1
;; Lean4: This is implicit in the |indices| = D(0)+1 argument
(defun count-bad (m0 n0 k)
  (declare (xargs :measure (nfix k)))
  (if (zp k)
      0
    (+ (if (> (g-k m0 n0 (1- k)) 1) 1 0)
       (count-bad m0 n0 (1- k)))))
# Out:
# For the admission of COUNT-BAD we will use the relation O< (which is
# known to be well-founded on the domain recognized by O-P) and the measure
# (NFIX K).  The non-trivial part of the measure conjecture is
#
# Goal
# (AND (O-P (NFIX K))
#      (IMPLIES (NOT (ZP K))
#               (O< (NFIX (+ -1 K)) (NFIX K)))).
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# That completes the proof of the measure theorem for COUNT-BAD.  Thus,
# we admit this function under the principle of definition.  We observe
# that the type of COUNT-BAD is described by the theorem
# (AND (INTEGERP (COUNT-BAD M0 N0 K)) (<= 0 (COUNT-BAD M0 N0 K))).  We
# used primitive type reasoning.
#
# Summary
# Form:  ( DEFUN COUNT-BAD ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION NFIX)
#         (:DEFINITION O-FINP)
#         (:DEFINITION O-P)
#         (:DEFINITION O<)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE SIMPLIFY-SUMS-<))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  130
#  COUNT-BAD

# %%
(defthm count-bad-natp
  (natp (count-bad m0 n0 k))
  :rule-classes :type-prescription)
# Out:
# ACL2 Observation in ( DEFTHM COUNT-BAD-NATP ...):  Our heuristics choose
# (COUNT-BAD M0 N0 K) as the :TYPED-TERM.
#
# Q.E.D.
#
# The storage of COUNT-BAD-NATP depends upon the :compound-recognizer
# rule NATP-COMPOUND-RECOGNIZER.
#
# Summary
# Form:  ( DEFTHM COUNT-BAD-NATP ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:TYPE-PRESCRIPTION COUNT-BAD))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  COUNT-BAD-NATP

# %% [raw]
# ;; Key lemma: prod-g >= 3^(count-bad)
# ;; Lean4: hprod_ge using Finset.prod_le_prod and hg_ge3'
# ;; Each bad g(k) >= 3, so product of all g's >= 3^(# of bad indices)

# %%
;; Helper: if a <= b and 3 <= c and b,c positive, then 3*a <= c*b
(defthm product-inequality-helper
  (implies (and (<= a b)
                (<= 3 c)
                (posp b)
                (posp c)
                (natp a))
           (<= (* 3 a) (* b c)))
  :hints (("Goal" :nonlinearp t)))
# Out:
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM PRODUCT-INEQUALITY-HELPER ...)
# Rules: ((:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POSP)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |arith (* 1 x)|))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  203
#  PRODUCT-INEQUALITY-HELPER

# %%
(defthm prod-g-geq-three-pow-count-bad
  (implies (natp k)
           (>= (prod-g m0 n0 k) (three-pow (count-bad m0 n0 k))))
  :hints (("Goal" :induct (count-bad m0 n0 k)
                  :in-theory (enable prod-g count-bad))
          ("Subgoal *1/2" :use ((:instance bad-g-geq-3 (k (1- k)))
                                (:instance product-inequality-helper
                                           (a (three-pow (count-bad m0 n0 (1- k))))
                                           (b (prod-g m0 n0 (1- k)))
                                           (c (g-k m0 n0 (1- k)))))))
  :rule-classes :linear)
# Out:
# *1 (the initial Goal, a key checkpoint) is pushed for proof by induction.
#
# We have been told to use induction.  One induction scheme is suggested
# by the induction hint.
#
# We will induct according to a scheme suggested by (COUNT-BAD M0 N0 K).
#
# This suggestion was produced using the :induction rule COUNT-BAD.
# If we let (:P K M0 N0) denote *1 above then the induction scheme we'll
# use is
# (AND (IMPLIES (AND (NOT (ZP K)) (:P (+ -1 K) M0 N0))
#               (:P K M0 N0))
#      (IMPLIES (ZP K) (:P K M0 N0))).
# This induction is justified by the same argument used to admit COUNT-BAD.
# When applied to the goal at hand the above induction scheme produces
# two nontautological subgoals.
# Subgoal *1/2
#
# ACL2 Warning [Use] in ( DEFTHM PROD-G-GEQ-THREE-POW-COUNT-BAD ...):
# It is unusual to :USE the formula of an enabled :REWRITE or :DEFINITION
# rule, so you may want to consider disabling (:REWRITE BAD-G-GEQ-3)
# and (:REWRITE PRODUCT-INEQUALITY-HELPER) in the hint provided for Subgoal
# *1/2.  See :DOC using-enabled-rules.
#
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/2'''
# Subgoal *1/2'4'
# Subgoal *1/1
# Subgoal *1/1'
# Subgoal *1/1''
#
# *1 is COMPLETED!
# Thus key checkpoint Goal is COMPLETED!
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM PROD-G-GEQ-THREE-POW-COUNT-BAD ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER ZP-COMPOUND-RECOGNIZER)
#         (:DEFINITION COUNT-BAD)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION PROD-G)
#         (:DEFINITION SYNP)
#         (:DEFINITION THREE-POW)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART THREE-POW)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-LINEAR-EQUALITIES NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION COUNT-BAD)
#         (:REWRITE |(* 1 x)|)
#         (:REWRITE |(* y x)|)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ c (+ d x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE G-K-EXPAND)
#         (:REWRITE GCD-OF-ODDS-IS-ODD)
#         (:REWRITE ODD-GT-1-MEANS-GEQ-3)
#         (:REWRITE PRODUCT-INEQUALITY-HELPER)
#         (:REWRITE REMOVE-WEAK-INEQUALITIES)
#         (:REWRITE TWO-K-PLUS-ONE-ODD)
#         (:TYPE-PRESCRIPTION COUNT-BAD-NATP)
#         (:TYPE-PRESCRIPTION GCD-POSP)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 1)
#         (:TYPE-PRESCRIPTION MN-SEQ-POSP-PAIR . 2)
#         (:TYPE-PRESCRIPTION PROD-G-POSP)
#         (:TYPE-PRESCRIPTION THREE-POW-POSITIVE)
#         (:TYPE-PRESCRIPTION TWO-M-PLUS-ONE-POSP))
# Hint-events: ((:USE BAD-G-GEQ-3)
#               (:USE PRODUCT-INEQUALITY-HELPER))
# Warnings:  Use
# Time:  0.10 seconds (prove: 0.09, print: 0.00, other: 0.01)
# Prover steps counted:  9316
#  PROD-G-GEQ-THREE-POW-COUNT-BAD

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; MAIN THEOREM: PUTNAM 2025 A1
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;;
# ;;; Lean4's theorem:
# ;;;   theorem putnam_2025_a1 (m n : ℕ → ℕ)
# ;;;     (h0 : m 0 > 0 ∧ n 0 > 0 ∧ m 0 ≠ n 0)
# ;;;     (hm : ∀ k : ℕ, m (k + 1) = ((2 * m k + 1) / (2 * n k + 1) : ℚ).num)
# ;;;     (hn : ∀ k : ℕ, n (k + 1) = ((2 * m k + 1) / (2 * n k + 1) : ℚ).den):
# ;;;     {k | ¬ (2 * m k + 1).Coprime (2 * n k + 1)}.Finite
# ;;;
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %% [raw]
# ;;; LEAN4-MATCHING DEFINITIONS
# ;;; These mirror the Lean4 definitions exactly

# %%
;; Lean4: m, n : ℕ → ℕ  (the sequence functions)
;; In ACL2, m and n are functions of k (with m0, n0 as parameters)
(defmacro m (k) `(m-k m0 n0 ,k))
(defmacro n (k) `(n-k m0 n0 ,k))
# Out:
# Summary
# Form:  ( DEFMACRO M ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  M
#
# Summary
# Form:  ( DEFMACRO N ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  N

# %%
;; Lean4: (2 * m k + 1).Coprime (2 * n k + 1)
;; Coprime means gcd = 1
(defun coprime-p (a b)
  "True when gcd(a, b) = 1"
  (equal (dm::gcd a b) 1))
# Out:
# Since COPRIME-P is non-recursive, its admission is trivial.  We observe
# that the type of COPRIME-P is described by the theorem
# (OR (EQUAL (COPRIME-P A B) T) (EQUAL (COPRIME-P A B) NIL)).  We used
# primitive type reasoning.
#
# Summary
# Form:  ( DEFUN COPRIME-P ...)
# Rules: ((:FAKE-RUNE-FOR-TYPE-SET NIL))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  COPRIME-P

# %%
;; Lean4: ¬ (2 * m k + 1).Coprime (2 * n k + 1)
(defun not-coprime-at-k (m0 n0 k)
  "True when gcd(2*m_k+1, 2*n_k+1) ≠ 1, i.e., not coprime"
  (not (coprime-p (+ 1 (* 2 (m-k m0 n0 k)))
                  (+ 1 (* 2 (n-k m0 n0 k))))))
# Out:
# Since NOT-COPRIME-AT-K is non-recursive, its admission is trivial.
# We observe that the type of NOT-COPRIME-AT-K is described by the theorem
# (OR (EQUAL (NOT-COPRIME-AT-K M0 N0 K) T)
#     (EQUAL (NOT-COPRIME-AT-K M0 N0 K) NIL)).
#
# Summary
# Form:  ( DEFUN NOT-COPRIME-AT-K ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  NOT-COPRIME-AT-K

# %%
;; Lean4: {k | ¬ (2 * m k + 1).Coprime (2 * n k + 1)}
;; Count the number of k < K where 2*m_k+1 and 2*n_k+1 are NOT coprime
(defun count-if-not-coprime (m0 n0 K)
  "#{k < K | ¬ Coprime(2*m_k+1, 2*n_k+1)}"
  (count-bad m0 n0 K))
# Out:
# Since COUNT-IF-NOT-COPRIME is non-recursive, its admission is trivial.
# We observe that the type of COUNT-IF-NOT-COPRIME is described by the
# theorem
# (AND (INTEGERP (COUNT-IF-NOT-COPRIME M0 N0 K))
#      (<= 0 (COUNT-IF-NOT-COPRIME M0 N0 K))).
# We used the :type-prescription rule COUNT-BAD-NATP.
#
# Summary
# Form:  ( DEFUN COUNT-IF-NOT-COPRIME ...)
# Rules: ((:TYPE-PRESCRIPTION COUNT-BAD-NATP))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  COUNT-IF-NOT-COPRIME

# %% [raw]
# ;; Lean4: .Finite means the set has a finite upper bound
# ;; We express this as: for all K, |{k < K : ¬ Coprime}| < |m(0) - n(0)|

# %% [raw]
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;;; THEOREM: putnam_2025_a1
# ;;;
# ;;; Lean4:
# ;;;   theorem putnam_2025_a1 (m n : ℕ → ℕ)
# ;;;     (h0 : m 0 > 0 ∧ n 0 > 0 ∧ m 0 ≠ n 0)
# ;;;     (hm : ∀ k, m (k+1) = ((2*m k+1)/(2*n k+1) : ℚ).num)
# ;;;     (hn : ∀ k, n (k+1) = ((2*m k+1)/(2*n k+1) : ℚ).den):
# ;;;     {k | ¬ (2 * m k + 1).Coprime (2 * n k + 1)}.Finite
# ;;;
# ;;; ACL2 translation:
# ;;;   Given m0, n0 satisfying h0 (m0 > 0, n0 > 0, m0 ≠ n0),
# ;;;   with m, n defined by the recurrence (built into m-k, n-k),
# ;;;   the set {k | ¬ Coprime(2*m(k)+1, 2*n(k)+1)} is finite,
# ;;;   specifically: |{k < K : not coprime}| < |m0 - n0| for all K.
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;

# %% [raw]
# ;; Main theorem matching Lean4 structure:
# ;;   theorem putnam_2025_a1 (m n : ℕ → ℕ)
# ;;     (h0 : m 0 > 0 ∧ n 0 > 0 ∧ m 0 ≠ n 0)
# ;;     (hm : ∀ k, m (k+1) = ((2*m k+1)/(2*n k+1) : ℚ).num)
# ;;     (hn : ∀ k, n (k+1) = ((2*m k+1)/(2*n k+1) : ℚ).den):
# ;;     {k | ¬ (2 * m k + 1).Coprime (2 * n k + 1)}.Finite
# ;;
# ;; ACL2 formulation: The number of k where ¬ Coprime(2*m_k+1, 2*n_k+1)
# ;; is strictly bounded by |m0 - n0|, hence finite.

# %%
(defthm putnam_2025_a1
  (implies 
   ;; h0 : m 0 > 0 ∧ n 0 > 0 ∧ m 0 ≠ n 0
   (and (posp m0)                           ; m 0 > 0
        (posp n0)                           ; n 0 > 0
        (not (equal m0 n0))                 ; m 0 ≠ n 0
        (natp K))
   ;; {k | ¬ Coprime(2*m_k+1, 2*n_k+1)}.Finite
   ;; i.e., #{k < K : ¬ Coprime(2*m_k+1, 2*n_k+1)} < |m0 - n0|
   (< (count-if-not-coprime m0 n0 K)        ; #{k < K : gcd ≠ 1}
      (abs (- m0 n0))))                     ; |m(0) - n(0)|
  :hints (("Goal" :use ((:instance prod-g-geq-three-pow-count-bad (k K))
                        (:instance prod-g-bound)
                        (:instance three-pow-gt-n (n (count-bad m0 n0 K)))
                        (:instance D-k-0-when-distinct))
           :in-theory (e/d (D-k count-if-not-coprime) 
                           (prod-g-geq-three-pow-count-bad prod-g-bound
                            three-pow-gt-n D-k-0-when-distinct)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM PUTNAM_2025_A1 ...):  A :REWRITE
# rule generated from PUTNAM_2025_A1 will be triggered only by terms
# containing the function symbols COUNT-IF-NOT-COPRIME and ABS, which
# have non-recursive definitions.  Unless these definitions are disabled,
# this rule is unlikely ever to be used.
#
# Goal'
# Goal''
#
# Splitter note (see :DOC splitter) for Goal'' (2 subgoals).
#   if-intro: ((:DEFINITION ABS)
#              (:DEFINITION NOT)
#              (:DEFINITION POSP)
#              (:REWRITE |(< (if a b c) x)|)
#              (:REWRITE |(< x (if a b c))|))
#
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM PUTNAM_2025_A1 ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER POSP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ABS)
#         (:DEFINITION COUNT-IF-NOT-COPRIME)
#         (:DEFINITION D-K)
#         (:DEFINITION M-K)
#         (:DEFINITION MN-SEQ)
#         (:DEFINITION N-K)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION POS-FIX)
#         (:DEFINITION POSP)
#         (:DEFINITION SYNP)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE |(+ 0 x)|)
#         (:REWRITE |(+ x (- x))|)
#         (:REWRITE |(+ y (+ x z))|)
#         (:REWRITE |(+ y x)|)
#         (:REWRITE |(- (+ x y))|)
#         (:REWRITE |(- (- x))|)
#         (:REWRITE |(< (if a b c) x)|)
#         (:REWRITE |(< x (if a b c))|)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE NORMALIZE-ADDENDS)
#         (:REWRITE PREFER-POSITIVE-ADDENDS-<)
#         (:TYPE-PRESCRIPTION COUNT-BAD-NATP)
#         (:TYPE-PRESCRIPTION PROD-G-POSP)
#         (:TYPE-PRESCRIPTION THREE-POW-POSITIVE))
# Hint-events: ((:USE D-K-0-WHEN-DISTINCT)
#               (:USE PROD-G-BOUND)
#               (:USE PROD-G-GEQ-THREE-POW-COUNT-BAD)
#               (:USE THREE-POW-GT-N))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION ABS)
#              (:DEFINITION NOT)
#              (:DEFINITION POSP)
#              (:REWRITE |(< (if a b c) x)|)
#              (:REWRITE |(< x (if a b c))|))
# Warnings:  Non-rec
# Time:  0.06 seconds (prove: 0.05, print: 0.00, other: 0.01)
# Prover steps counted:  5847
#  PUTNAM_2025_A1
