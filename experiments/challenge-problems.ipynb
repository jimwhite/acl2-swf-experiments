# %%
(in-package "ACL2")
# Out:
#  "ACL2"

# %% [raw]
# ;; =============================================================================
# ;; Real Challenge Problems from Software Foundations (Early Chapters)
# ;; =============================================================================
# ;;
# ;; This file contains SWF exercises that are GENUINELY CHALLENGING in ACL2.
# ;; After auditing all 3-4 star exercises from SWF chapters 2-5, only these
# ;; require non-trivial effort in ACL2.
# ;;
# ;; Criteria for inclusion:
# ;; - Requires helper lemmas, careful induction, or theory control
# ;; - Not solved automatically by ACL2's built-in automation
# ;; - Can be properly expressed in ACL2 (no higher-order function issues)
# ;;
# ;; Excluded exercises:
# ;; - Bags/Interleaving: Trivial in ACL2 (see trivial-swf-exercises.lisp)
# ;; - Church Numerals: Can't encode properly without higher-order functions
# ;; - Currying: Can't state properly without lambdas in theorems
# ;;
# ;; LEGEND:
# ;; ✓ SWF - Theorem appears in Software Foundations
# ;; ⚠ ADAPTED - Based on SWF but modified for ACL2
# ;; ✗ INVENTED - Created for this file (may be helper lemma)
# ;; ★ - Difficulty rating (★☆☆☆ = easy, ★★★★ = hard)
# ;;
# ;; =============================================================================

# %% [raw]
# ;; =============================================================================
# ;; CHALLENGE 1: Binary Number System (★★★★ HARD)
# ;; =============================================================================
# ;; Source: Software Foundations, Induction chapter
# ;; Difficulty: HARD - Custom data type requires termination proofs
# ;;
# ;; Build a complete binary number system with conversion to/from naturals
# ;; and prove properties about normalization and arithmetic.
# ;;
# ;; Why this is hard:
# ;; - Custom recursive data type (not built-in like lists)
# ;; - Functions won't admit without measure hints
# ;; - Need to establish basic properties before proving main theorems
# ;; - Round-trip conversions require careful reasoning about normalization
# ;; =============================================================================

# %% [raw]
# ;; Binary numbers: either Zero, or a sequence of bits (least significant first)
# ;; Representation: Bin ::= Z | B0 Bin | B1 Bin
# ;; Examples: 0 = Z, 1 = (B1 . Z), 2 = (B0 B1 . Z), 3 = (B1 B1 . Z)
# ;;
# ;; This representation allows leading zeros: (B0 B0 B1 . Z) = 4
# ;; Normalization removes them: normalize((B0 B0 B1 . Z)) = (B1 . Z) = 2... wait that's wrong
# ;; Actually (B0 B1 . Z) = 2 because it's LSB first: bit_0 + 2*bit_1 = 0 + 2*1 = 2

# %%
(defun binp (x)
  "Recognizer for binary numbers"
  (declare (xargs :guard t))
  (if (atom x)
      (eq x 'Z)
    (and (consp x)
         (or (eq (car x) 'B0)
             (eq (car x) 'B1))
         (binp (cdr x)))))
# Out:
# The admission of BINP is trivial, using the relation O< (which is known
# to be well-founded on the domain recognized by O-P) and the measure
# (ACL2-COUNT X).  We observe that the type of BINP is described by the
# theorem (OR (EQUAL (BINP X) T) (EQUAL (BINP X) NIL)).  We used primitive
# type reasoning.
#
# Computing the guard conjecture for BINP....
#
# The guard conjecture for BINP is trivial to prove.  BINP is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN BINP ...)
# Rules: ((:FAKE-RUNE-FOR-TYPE-SET NIL))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  BINP

# %%
(defun bin-incr (b)
  "Increment a binary number"
  (declare (xargs :guard (binp b)))
  (if (eq b 'Z)
      '(B1 . Z)
    (let ((bit (car b))
          (rest (cdr b)))
      (if (eq bit 'B0)
          (cons 'B1 rest)
        (cons 'B0 (bin-incr rest))))))
# Out:
# For the admission of BIN-INCR we will use the relation O< (which is
# known to be well-founded on the domain recognized by O-P) and the measure
# (ACL2-COUNT B).  The non-trivial part of the measure conjecture is
#
# Goal
# (IMPLIES (AND (NOT (EQ B 'Z))
#               (NOT (EQ (CAR B) 'B0)))
#          (O< (ACL2-COUNT (CDR B))
#              (ACL2-COUNT B))).
# Goal'
# Goal''
# Subgoal 2
# Subgoal 2'
# Subgoal 2''
#
# ([ A key checkpoint:
#
# Goal''
# (IMPLIES (AND (NOT (EQUAL B 'Z))
#               (NOT (EQUAL (CAR B) 'B0)))
#          (< (ACL2-COUNT (CDR B)) (ACL2-COUNT B)))
#
# *1 (Subgoal 2'') is pushed for proof by induction:
# (IMPLIES (AND (EQUAL (ACL2-COUNT B) 0)
#               (NOT (CONSP B)))
#          (EQUAL B 'Z)).
# Subgoal 1
# Subgoal 1'
#
# ])
#
# Perhaps we can prove *1 by induction.  One induction scheme is suggested
# by this conjecture.
#
# We will induct according to a scheme suggested by (ACL2-COUNT B).
#
# This suggestion was produced using the :induction rule ACL2-COUNT.
# If we let (:P B) denote *1 above then the induction scheme we'll use
# is
# (AND (IMPLIES (AND (NOT (CONSP B))
#                    (NOT (RATIONALP B))
#                    (NOT (COMPLEX-RATIONALP B))
#                    (NOT (STRINGP B)))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (NOT (RATIONALP B))
#                    (NOT (COMPLEX-RATIONALP B))
#                    (STRINGP B))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (NOT (RATIONALP B))
#                    (COMPLEX-RATIONALP B)
#                    (:P (REALPART B))
#                    (:P (IMAGPART B)))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (RATIONALP B)
#                    (NOT (INTEGERP B)))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (RATIONALP B)
#                    (INTEGERP B))
#               (:P B))
#      (IMPLIES (AND (CONSP B)
#                    (:P (CAR B))
#                    (:P (CDR B)))
#               (:P B))).
# This induction is justified by the same argument used to admit ACL2-COUNT.
# When applied to the goal at hand the above induction scheme produces
# thirteen nontautological subgoals.
# Subgoal *1/13
# Subgoal *1/13'
# Subgoal *1/13''
#
# ([ A key checkpoint while proving *1 (descended from Goal''):
#
# Subgoal *1/13'
# (IMPLIES (AND (NOT (CONSP B))
#               (NOT (RATIONALP B))
#               (NOT (COMPLEX-RATIONALP B))
#               (NOT (STRINGP B)))
#          (EQUAL B 'Z))
#
# A goal of NIL, Subgoal *1/13'', has been generated!  Obviously, the
# proof attempt has failed.
#
# ])
#
#
# ACL2 Error in ( DEFUN BIN-INCR ...):  The proof of the measure conjecture
# for BIN-INCR has failed.
#
#
#
# Summary
# Form:  ( DEFUN BIN-INCR ...)
# Rules: ((:DEFINITION ACL2-COUNT)
#         (:DEFINITION EQ)
#         (:DEFINITION O-FINP)
#         (:DEFINITION O<)
#         (:ELIM CAR-CDR-ELIM)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART ACL2-COUNT)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-LINEAR-EQUALITIES NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION ACL2-COUNT)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DEFAULT-CAR)
#         (:REWRITE DEFAULT-CDR)
#         (:TYPE-PRESCRIPTION ACL2-COUNT))
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  1365
#
# ---
# The key checkpoint goals, below, may help you to debug this failure.
# See :DOC failure and see :DOC set-checkpoint-summary-limit.
# ---
#
# *** Key checkpoint at the top level: ***
#
# Goal''
# (IMPLIES (AND (NOT (EQUAL B 'Z))
#               (NOT (EQUAL (CAR B) 'B0)))
#          (< (ACL2-COUNT (CDR B)) (ACL2-COUNT B)))
#
# *** Key checkpoint under a top-level induction
#     before generating a goal of NIL (see :DOC nil-goal): ***
#
# Subgoal *1/13'
# (IMPLIES (AND (NOT (CONSP B))
#               (NOT (RATIONALP B))
#               (NOT (COMPLEX-RATIONALP B))
#               (NOT (STRINGP B)))
#          (EQUAL B 'Z))
#
# ACL2 Error [Failure] in ( DEFUN BIN-INCR ...):  The proof of the measure
# conjecture for BIN-INCR has failed.  See :DOC failure.
#
# ******** FAILED ********

# %%
(defun bin-to-nat (b)
  "Convert binary number to natural number"
  (declare (xargs :guard (binp b)))
  (if (eq b 'Z)
      0
    (let ((bit (car b))
          (rest (cdr b)))
      (+ (if (eq bit 'B1) 1 0)
         (* 2 (bin-to-nat rest))))))
# Out:
# For the admission of BIN-TO-NAT we will use the relation O< (which
# is known to be well-founded on the domain recognized by O-P) and the
# measure (ACL2-COUNT B).  The non-trivial part of the measure conjecture
# is
#
# Goal
# (IMPLIES (NOT (EQ B 'Z))
#          (O< (ACL2-COUNT (CDR B))
#              (ACL2-COUNT B))).
# Goal'
# Goal''
# Subgoal 2
# Subgoal 2'
# Subgoal 2''
#
# ([ A key checkpoint:
#
# Goal''
# (IMPLIES (NOT (EQUAL B 'Z))
#          (< (ACL2-COUNT (CDR B)) (ACL2-COUNT B)))
#
# *1 (Subgoal 2'') is pushed for proof by induction:
# (IMPLIES (AND (EQUAL (ACL2-COUNT B) 0)
#               (NOT (CONSP B)))
#          (EQUAL B 'Z)).
# Subgoal 1
# Subgoal 1'
#
# ])
#
# Perhaps we can prove *1 by induction.  One induction scheme is suggested
# by this conjecture.
#
# We will induct according to a scheme suggested by (ACL2-COUNT B).
#
# This suggestion was produced using the :induction rule ACL2-COUNT.
# If we let (:P B) denote *1 above then the induction scheme we'll use
# is
# (AND (IMPLIES (AND (NOT (CONSP B))
#                    (NOT (RATIONALP B))
#                    (NOT (COMPLEX-RATIONALP B))
#                    (NOT (STRINGP B)))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (NOT (RATIONALP B))
#                    (NOT (COMPLEX-RATIONALP B))
#                    (STRINGP B))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (NOT (RATIONALP B))
#                    (COMPLEX-RATIONALP B)
#                    (:P (REALPART B))
#                    (:P (IMAGPART B)))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (RATIONALP B)
#                    (NOT (INTEGERP B)))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (RATIONALP B)
#                    (INTEGERP B))
#               (:P B))
#      (IMPLIES (AND (CONSP B)
#                    (:P (CAR B))
#                    (:P (CDR B)))
#               (:P B))).
# This induction is justified by the same argument used to admit ACL2-COUNT.
# When applied to the goal at hand the above induction scheme produces
# thirteen nontautological subgoals.
# Subgoal *1/13
# Subgoal *1/13'
# Subgoal *1/13''
#
# ([ A key checkpoint while proving *1 (descended from Goal''):
#
# Subgoal *1/13'
# (IMPLIES (AND (NOT (CONSP B))
#               (NOT (RATIONALP B))
#               (NOT (COMPLEX-RATIONALP B))
#               (NOT (STRINGP B)))
#          (EQUAL B 'Z))
#
# A goal of NIL, Subgoal *1/13'', has been generated!  Obviously, the
# proof attempt has failed.
#
# ])
#
#
# ACL2 Error in ( DEFUN BIN-TO-NAT ...):  The proof of the measure conjecture
# for BIN-TO-NAT has failed.
#
#
#
# Summary
# Form:  ( DEFUN BIN-TO-NAT ...)
# Rules: ((:DEFINITION ACL2-COUNT)
#         (:DEFINITION EQ)
#         (:DEFINITION O-FINP)
#         (:DEFINITION O<)
#         (:ELIM CAR-CDR-ELIM)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART ACL2-COUNT)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-LINEAR-EQUALITIES NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION ACL2-COUNT)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DEFAULT-CDR)
#         (:TYPE-PRESCRIPTION ACL2-COUNT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  1296
#
# ---
# The key checkpoint goals, below, may help you to debug this failure.
# See :DOC failure and see :DOC set-checkpoint-summary-limit.
# ---
#
# *** Key checkpoint at the top level: ***
#
# Goal''
# (IMPLIES (NOT (EQUAL B 'Z))
#          (< (ACL2-COUNT (CDR B)) (ACL2-COUNT B)))
#
# *** Key checkpoint under a top-level induction
#     before generating a goal of NIL (see :DOC nil-goal): ***
#
# Subgoal *1/13'
# (IMPLIES (AND (NOT (CONSP B))
#               (NOT (RATIONALP B))
#               (NOT (COMPLEX-RATIONALP B))
#               (NOT (STRINGP B)))
#          (EQUAL B 'Z))
#
# ACL2 Error [Failure] in ( DEFUN BIN-TO-NAT ...):  The proof of the
# measure conjecture for BIN-TO-NAT has failed.  See :DOC failure.
#
# ******** FAILED ********

# %%
(defun nat-to-bin (n)
  "Convert natural number to binary"
  (declare (xargs :guard (natp n)))
  (if (zp n)
      'Z
    (bin-incr (nat-to-bin (- n 1)))))
# Out:
# ACL2 Error [Translate] in ( DEFUN NAT-TO-BIN ...):  The symbol BIN-INCR
# (in package "ACL2") has neither a function nor macro definition in
# ACL2.  Please define it.  See :DOC near-misses.  Note:  this error
# occurred in the context (BIN-INCR (NAT-TO-BIN (- N 1))).
#
#
# Summary
# Form:  ( DEFUN NAT-TO-BIN ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Error [Failure] in ( DEFUN NAT-TO-BIN ...):  See :DOC failure.
#
# ******** FAILED ********

# %%
(defun bin-normalize (b)
  "Remove leading zeros from binary number"
  (declare (xargs :guard (binp b)))
  (if (eq b 'Z)
      'Z
    (let ((bit (car b))
          (rest (cdr b)))
      (if (eq (bin-normalize rest) 'Z)
          (if (eq bit 'B0)
              'Z
            '(B1 . Z))
        (cons bit (bin-normalize rest))))))
# Out:
# For the admission of BIN-NORMALIZE we will use the relation O< (which
# is known to be well-founded on the domain recognized by O-P) and the
# measure (ACL2-COUNT B).  The non-trivial part of the measure conjecture
# is
#
# Goal
# (IMPLIES (NOT (EQ B 'Z))
#          (O< (ACL2-COUNT (CDR B))
#              (ACL2-COUNT B))).
# Goal'
# Goal''
# Subgoal 2
# Subgoal 2'
# Subgoal 2''
#
# ([ A key checkpoint:
#
# Goal''
# (IMPLIES (NOT (EQUAL B 'Z))
#          (< (ACL2-COUNT (CDR B)) (ACL2-COUNT B)))
#
# *1 (Subgoal 2'') is pushed for proof by induction:
# (IMPLIES (AND (EQUAL (ACL2-COUNT B) 0)
#               (NOT (CONSP B)))
#          (EQUAL B 'Z)).
# Subgoal 1
# Subgoal 1'
#
# ])
#
# Perhaps we can prove *1 by induction.  One induction scheme is suggested
# by this conjecture.
#
# We will induct according to a scheme suggested by (ACL2-COUNT B).
#
# This suggestion was produced using the :induction rule ACL2-COUNT.
# If we let (:P B) denote *1 above then the induction scheme we'll use
# is
# (AND (IMPLIES (AND (NOT (CONSP B))
#                    (NOT (RATIONALP B))
#                    (NOT (COMPLEX-RATIONALP B))
#                    (NOT (STRINGP B)))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (NOT (RATIONALP B))
#                    (NOT (COMPLEX-RATIONALP B))
#                    (STRINGP B))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (NOT (RATIONALP B))
#                    (COMPLEX-RATIONALP B)
#                    (:P (REALPART B))
#                    (:P (IMAGPART B)))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (RATIONALP B)
#                    (NOT (INTEGERP B)))
#               (:P B))
#      (IMPLIES (AND (NOT (CONSP B))
#                    (RATIONALP B)
#                    (INTEGERP B))
#               (:P B))
#      (IMPLIES (AND (CONSP B)
#                    (:P (CAR B))
#                    (:P (CDR B)))
#               (:P B))).
# This induction is justified by the same argument used to admit ACL2-COUNT.
# When applied to the goal at hand the above induction scheme produces
# thirteen nontautological subgoals.
# Subgoal *1/13
# Subgoal *1/13'
# Subgoal *1/13''
#
# ([ A key checkpoint while proving *1 (descended from Goal''):
#
# Subgoal *1/13'
# (IMPLIES (AND (NOT (CONSP B))
#               (NOT (RATIONALP B))
#               (NOT (COMPLEX-RATIONALP B))
#               (NOT (STRINGP B)))
#          (EQUAL B 'Z))
#
# A goal of NIL, Subgoal *1/13'', has been generated!  Obviously, the
# proof attempt has failed.
#
# ])
#
#
# ACL2 Error in ( DEFUN BIN-NORMALIZE ...):  The proof of the measure
# conjecture for BIN-NORMALIZE has failed.
#
#
#
# Summary
# Form:  ( DEFUN BIN-NORMALIZE ...)
# Rules: ((:DEFINITION ACL2-COUNT)
#         (:DEFINITION EQ)
#         (:DEFINITION O-FINP)
#         (:DEFINITION O<)
#         (:ELIM CAR-CDR-ELIM)
#         (:EXECUTABLE-COUNTERPART <)
#         (:EXECUTABLE-COUNTERPART ACL2-COUNT)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-LINEAR-EQUALITIES NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION ACL2-COUNT)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DEFAULT-CDR)
#         (:TYPE-PRESCRIPTION ACL2-COUNT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  1296
#
# ---
# The key checkpoint goals, below, may help you to debug this failure.
# See :DOC failure and see :DOC set-checkpoint-summary-limit.
# ---
#
# *** Key checkpoint at the top level: ***
#
# Goal''
# (IMPLIES (NOT (EQUAL B 'Z))
#          (< (ACL2-COUNT (CDR B)) (ACL2-COUNT B)))
#
# *** Key checkpoint under a top-level induction
#     before generating a goal of NIL (see :DOC nil-goal): ***
#
# Subgoal *1/13'
# (IMPLIES (AND (NOT (CONSP B))
#               (NOT (RATIONALP B))
#               (NOT (COMPLEX-RATIONALP B))
#               (NOT (STRINGP B)))
#          (EQUAL B 'Z))
#
# ACL2 Error [Failure] in ( DEFUN BIN-NORMALIZE ...):  The proof of the
# measure conjecture for BIN-NORMALIZE has failed.  See :DOC failure.
#
# ******** FAILED ********

# %%
(defun bin-double (b)
  "Double a binary number (shift left)"
  (declare (xargs :guard (binp b)))
  (if (eq b 'Z)
      'Z
    (cons 'B0 b)))
# Out:
# Since BIN-DOUBLE is non-recursive, its admission is trivial.  We observe
# that the type of BIN-DOUBLE is described by the theorem
# (OR (CONSP (BIN-DOUBLE B))
#     (AND (SYMBOLP (BIN-DOUBLE B))
#          (NOT (EQUAL (BIN-DOUBLE B) T))
#          (NOT (EQUAL (BIN-DOUBLE B) NIL)))).
# We used primitive type reasoning.
#
# Computing the guard conjecture for BIN-DOUBLE....
#
# The guard conjecture for BIN-DOUBLE is trivial to prove.  BIN-DOUBLE
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN BIN-DOUBLE ...)
# Rules: ((:FAKE-RUNE-FOR-TYPE-SET NIL))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  BIN-DOUBLE

# %% [raw]
# ;; =============================================================================
# ;; CHALLENGE THEOREMS - BINARY NUMBERS
# ;; =============================================================================

# %%
;; ✓ SWF: bin_to_nat_pres_incr (★★★☆ HARD)
;; Theorem: Incrementing preserves the numeric value correctly
;;
;; Strategy hints:
;; - Will likely need lemmas about binp preservation
;; - May need arithmetic lemmas about (* 2 (+ 1 n))
;; - Induction on structure of binary number
(defthm bin-incr-correct
  (implies (binp b)
           (equal (bin-to-nat (bin-incr b))
                  (+ 1 (bin-to-nat b)))))
# Out:
# ACL2 Error [Translate] in ( DEFTHM BIN-INCR-CORRECT ...):  The symbol
# BIN-TO-NAT (in package "ACL2") has neither a function nor macro definition
# in ACL2.  Please define it.  See :DOC near-misses.  Note:  this error
# occurred in the context (BIN-TO-NAT (BIN-INCR B)).
#
#
# Summary
# Form:  ( DEFTHM BIN-INCR-CORRECT ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Error [Failure] in ( DEFTHM BIN-INCR-CORRECT ...):  See :DOC failure.
#
# ******** FAILED ********

# %%
;; ✓ SWF: nat_bin_nat (★★★★ HARD)
;; Theorem: Converting nat -> bin -> nat is identity
;;
;; Strategy hints:
;; - Requires bin-incr-correct as lemma
;; - Induction on natural number n
;; - This is easier direction than bin_nat_bin
(defthm nat-bin-nat
  (implies (natp n)
           (equal (bin-to-nat (nat-to-bin n))
                  n)))
# Out:
# ACL2 Error [Translate] in ( DEFTHM NAT-BIN-NAT ...):  The symbol BIN-TO-NAT
# (in package "ACL2") has neither a function nor macro definition in
# ACL2.  Please define it.  See :DOC near-misses.  Note:  this error
# occurred in the context (BIN-TO-NAT (NAT-TO-BIN N)).
#
#
# Summary
# Form:  ( DEFTHM NAT-BIN-NAT ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Error [Failure] in ( DEFTHM NAT-BIN-NAT ...):  See :DOC failure.
#
# ******** FAILED ********

# %%
;; ⚠ ADAPTED: Implied by SWF's double_incr_bin (★★★☆ HARD)
;; Theorem: Doubling corresponds to multiplication by 2
;;
;; Strategy hints:
;; - May need lemma about (+ x x) = (* 2 x)
;; - Consider what happens when b = Z
(defthm bin-double-correct
  (implies (binp b)
           (equal (bin-to-nat (bin-double b))
                  (* 2 (bin-to-nat b)))))
# Out:
# ACL2 Error [Translate] in ( DEFTHM BIN-DOUBLE-CORRECT ...):  The symbol
# BIN-TO-NAT (in package "ACL2") has neither a function nor macro definition
# in ACL2.  Please define it.  See :DOC near-misses.  Note:  this error
# occurred in the context (BIN-TO-NAT (BIN-DOUBLE B)).
#
#
# Summary
# Form:  ( DEFTHM BIN-DOUBLE-CORRECT ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Error [Failure] in ( DEFTHM BIN-DOUBLE-CORRECT ...):  See :DOC
# failure.
#
# ******** FAILED ********

# %%
;; ✗ INVENTED: Useful helper lemma (★★★☆ MODERATE)
;; Theorem: Normalization preserves numeric value
;;
;; Strategy hints:
;; - Induction on structure of b
;; - Need to reason about what happens when rest normalizes to Z
;; - Consider cases: bit is B0 vs B1
(defthm bin-normalize-preserves-value
  (implies (binp b)
           (equal (bin-to-nat (bin-normalize b))
                  (bin-to-nat b))))
# Out:
# ACL2 Error [Translate] in ( DEFTHM BIN-NORMALIZE-PRESERVES-VALUE ...):
# The symbol BIN-TO-NAT (in package "ACL2") has neither a function nor
# macro definition in ACL2.  Please define it.  See :DOC near-misses.
# Note:  this error occurred in the context (BIN-TO-NAT (BIN-NORMALIZE B)).
#
#
# Summary
# Form:  ( DEFTHM BIN-NORMALIZE-PRESERVES-VALUE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Error [Failure] in ( DEFTHM BIN-NORMALIZE-PRESERVES-VALUE ...):
# See :DOC failure.
#
# ******** FAILED ********

# %% [raw]
# ;; ✓ SWF: bin_nat_bin (★★★★★ VERY HARD - not required initially)
# ;; Theorem: Converting bin -> nat -> bin normalizes the binary number
# ;;
# ;; This is the hard direction! Requires all previous lemmas plus careful
# ;; reasoning about what "normalized" means structurally.
# ;;
# ;; (defthm bin-nat-bin
# ;;   (implies (binp b)
# ;;            (equal (nat-to-bin (bin-to-nat b))
# ;;                   (bin-normalize b))))

# %% [raw]
# ;; =============================================================================
# ;; CHALLENGE 2: Function Injectivity (★★★☆ MODERATE)
# ;; =============================================================================
# ;; Source: Software Foundations, Lists chapter
# ;; Difficulty: MODERATE - Requires reasoning about inverses
# ;;
# ;; Prove that certain functions are injective (one-to-one).
# ;; An injective function maps distinct inputs to distinct outputs:
# ;;   f(x1) = f(x2) → x1 = x2
# ;;
# ;; Why this is moderately challenging:
# ;; - Need to reason about function inverses
# ;; - May require helper lemmas about reverse being involutive
# ;; - Different proof strategies for specific vs general injectivity
# ;; =============================================================================

# %%
;; ✓ SWF: rev_injective (★★★☆ MODERATE)
;; Theorem: Reverse is injective
;;
;; Strategy hints:
;; - Key insight: reverse is its own inverse (involution)
;; - May need lemma: (reverse (reverse l)) = l
;; - Then: if (reverse l1) = (reverse l2),
;;   apply reverse to both sides to get l1 = l2
(defthm rev-injective
  (implies (and (true-listp l1) (true-listp l2))
           (equal (equal (reverse l1) (reverse l2))
                  (equal l1 l2))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM REV-INJECTIVE ...):  A :REWRITE
# rule generated from REV-INJECTIVE will be triggered only by terms containing
# the function symbol REVERSE, which has a non-recursive definition.
# Unless this definition is disabled, this rule is unlikely ever to be
# used.
#
# Subgoal 2
# Subgoal 2'
#
# ([ A key checkpoint:
#
# Subgoal 2'
# (IMPLIES (AND (TRUE-LISTP L1)
#               (TRUE-LISTP L2)
#               (EQUAL (REVAPPEND L1 NIL)
#                      (REVAPPEND L2 NIL)))
#          (EQUAL L1 L2))
#
# *1 (Subgoal 2') is pushed for proof by induction.
#
# ])
# Subgoal 1
#
# Perhaps we can prove *1 by induction.  Four induction schemes are suggested
# by this conjecture.  These merge into two derived induction schemes.
# We will choose arbitrarily among these.
#
# We will induct according to a scheme suggested by (REVAPPEND L1 NIL),
# while accommodating (TRUE-LISTP L1).
#
# These suggestions were produced using the :induction rules REVAPPEND
# and TRUE-LISTP.  If we let (:P L1 L2) denote *1 above then the induction
# scheme we'll use is
# (AND (IMPLIES (AND (NOT (ENDP L1)) (:P (CDR L1) L2))
#               (:P L1 L2))
#      (IMPLIES (ENDP L1) (:P L1 L2))).
# This induction is justified by the same argument used to admit REVAPPEND.
# When applied to the goal at hand the above induction scheme produces
# four nontautological subgoals.
# Subgoal *1/4
# Subgoal *1/4'
# Subgoal *1/4''
# Subgoal *1/4'''
# Subgoal *1/4'4'
#
# ([ A key checkpoint while proving *1 (descended from Subgoal 2'):
#
# Subgoal *1/4''
# (IMPLIES (AND (CONSP L1)
#               (TRUE-LISTP (CDR L1))
#               (EQUAL (REVAPPEND (CDR L1) (LIST (CAR L1)))
#                      (REVAPPEND (CDR L1) NIL)))
#          (EQUAL L1 (CDR L1)))
#
# *1.1 (Subgoal *1/4'4') is pushed for proof by induction.
#
# ])
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/3''
# Subgoal *1/3'''
# Subgoal *1/3'4'
# Subgoal *1/3'5'
# Subgoal *1/3'6'
#
# ([ A key checkpoint while proving *1 (descended from Subgoal 2'):
#
# Subgoal *1/3'''
# (IMPLIES (AND (CONSP L1)
#               (NOT (EQUAL (REVAPPEND (CDR L1) NIL)
#                           (REVAPPEND L2 NIL)))
#               (TRUE-LISTP (CDR L1))
#               (TRUE-LISTP L2)
#               (EQUAL (REVAPPEND (CDR L1) (LIST (CAR L1)))
#                      (REVAPPEND L2 NIL)))
#          (EQUAL L1 L2))
#
# *1.2 (Subgoal *1/3'6') is pushed for proof by induction.
#
# ])
# Subgoal *1/2
# Subgoal *1/1
# Subgoal *1/1'
# Subgoal *1/1''
# Subgoal *1/1'''
#
# ([ A key checkpoint while proving *1 (descended from Subgoal 2'):
#
# Subgoal *1/1'''
# (IMPLIES (AND (TRUE-LISTP L2)
#               (NOT (REVAPPEND L2 NIL)))
#          (NOT L2))
#
# *1.3 (Subgoal *1/1''') is pushed for proof by induction.
#
# ])
#
# So we now return to *1.3, which is
#
# (IMPLIES (AND (TRUE-LISTP L2)
#               (NOT (REVAPPEND L2 NIL)))
#          (NOT L2)).
# Subgoal *1.3/4
# Subgoal *1.3/4'
# Subgoal *1.3/3
# Subgoal *1.3/3'
# Subgoal *1.3/2
# Subgoal *1.3/1
#
# *1.3 is COMPLETED!
# Thus key checkpoint Subgoal *1/1''' is COMPLETED!
#
# We therefore turn our attention to *1.2, which is
#
# (IMPLIES (AND (NOT (EQUAL (REVAPPEND L4 NIL)
#                           (REVAPPEND L4 (LIST L3))))
#               (TRUE-LISTP L4)
#               (TRUE-LISTP L2))
#          (EQUAL (CONS L3 L4) L2)).
# Subgoal *1.2/4
# Subgoal *1.2/4'
# Subgoal *1.2/4''
# Subgoal *1.2/4'''
#
# A goal of NIL, Subgoal *1.2/4''', has been generated!  Obviously, the
# proof attempt has failed.
#
# Summary
# Form:  ( DEFTHM REV-INJECTIVE ...)
# Rules: ((:DEFINITION ENDP)
#         (:DEFINITION NOT)
#         (:DEFINITION REVAPPEND)
#         (:DEFINITION REVERSE)
#         (:DEFINITION TRUE-LISTP)
#         (:ELIM CAR-CDR-ELIM)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:EXECUTABLE-COUNTERPART REVAPPEND)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION REVAPPEND)
#         (:INDUCTION TRUE-LISTP)
#         (:TYPE-PRESCRIPTION REVAPPEND)
#         (:TYPE-PRESCRIPTION TRUE-LISTP-REVAPPEND-TYPE-PRESCRIPTION))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  2817
#
# ---
# The key checkpoint goals, below, may help you to debug this failure.
# See :DOC failure and see :DOC set-checkpoint-summary-limit.
# ---
#
# *** Key checkpoint at the top level: ***
#
# Subgoal 2'
# (IMPLIES (AND (TRUE-LISTP L1)
#               (TRUE-LISTP L2)
#               (EQUAL (REVAPPEND L1 NIL)
#                      (REVAPPEND L2 NIL)))
#          (EQUAL L1 L2))
#
# *** Key checkpoints under a top-level induction
#     before generating a goal of NIL (see :DOC nil-goal): ***
#
# Subgoal *1/4''
# (IMPLIES (AND (CONSP L1)
#               (TRUE-LISTP (CDR L1))
#               (EQUAL (REVAPPEND (CDR L1) (LIST (CAR L1)))
#                      (REVAPPEND (CDR L1) NIL)))
#          (EQUAL L1 (CDR L1)))
#
# Subgoal *1/3'''
# (IMPLIES (AND (CONSP L1)
#               (NOT (EQUAL (REVAPPEND (CDR L1) NIL)
#                           (REVAPPEND L2 NIL)))
#               (TRUE-LISTP (CDR L1))
#               (TRUE-LISTP L2)
#               (EQUAL (REVAPPEND (CDR L1) (LIST (CAR L1)))
#                      (REVAPPEND L2 NIL)))
#          (EQUAL L1 L2))
#
# ACL2 Error [Failure] in ( DEFTHM REV-INJECTIVE ...):  See :DOC failure.
#
# ******** FAILED ********

# %%
;; ✓ SWF: involution_injective (★★★★ HARD)
;; Theorem: Any involution is injective
;;
;; In SWF, this is a general theorem:
;;   ∀ f, (∀ n, n = f(f(n))) → (∀ n1 n2, f(n1) = f(n2) → n1 = n2)
;;
;; In ACL2, we can't quantify over functions easily, so we prove it for
;; specific functions or use functional instantiation.
;;
;; Strategy hints:
;; - For specific function (like reverse), use the involution property
;; - For general case, would need defun-sk or functional instantiation
;; - Consider proving for natural number functions first (simpler case)
;;
;; Example instantiation for reverse:
(defthm involution-injective-reverse
  (implies (and (true-listp l1)
                (true-listp l2)
                ;; Involution property as hypothesis
                (equal (reverse (reverse l1)) l1)
                (equal (reverse (reverse l2)) l2))
           ;; Injectivity conclusion
           (equal (equal (reverse l1) (reverse l2))
                  (equal l1 l2))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM INVOLUTION-INJECTIVE-REVERSE ...):
# A :REWRITE rule generated from INVOLUTION-INJECTIVE-REVERSE will be
# triggered only by terms containing the function symbol REVERSE, which
# has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# Splitter note (see :DOC splitter) for Goal (4 subgoals).
#   if-intro: ((:DEFINITION TRUE-LISTP))
#
# Subgoal 4
# Subgoal 3
# Subgoal 2
# Subgoal 1
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM INVOLUTION-INJECTIVE-REVERSE ...)
# Rules: ((:DEFINITION REVERSE)
#         (:DEFINITION TRUE-LISTP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART REVAPPEND)
#         (:EXECUTABLE-COUNTERPART REVERSE)
#         (:EXECUTABLE-COUNTERPART TRUE-LISTP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION REVERSE)
#         (:TYPE-PRESCRIPTION TRUE-LISTP-REVAPPEND-TYPE-PRESCRIPTION))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION TRUE-LISTP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  711
#  INVOLUTION-INJECTIVE-REVERSE

# %% [raw]
# ;; Note: For a general involution theorem, you might want to use defun-sk
# ;; to quantify over functions, or prove it for specific interesting cases
# ;; like reverse, complement, negate, etc.

# %% [raw]
# ;; =============================================================================
# ;; END OF CHALLENGE PROBLEMS
# ;; =============================================================================
# ;;
# ;; SUMMARY OF CHALLENGES:
# ;;
# ;; 1. Binary Numbers (4 theorems): ★★★★ HARD
# ;;    - Custom data type with complex structural reasoning
# ;;    - Requires termination proofs and measure hints
# ;;    - Round-trip conversion properties need careful setup
# ;;
# ;; 2. Function Injectivity (2 theorems): ★★★☆ MODERATE
# ;;    - Reasoning about function inverses
# ;;    - Good practice with bidirectional equality reasoning
# ;;    - Involution theorem requires insight
# ;;
# ;; TOTAL: 6 genuine challenge theorems
# ;;
# ;; LESSONS LEARNED ABOUT DIFFICULTY:
# ;; - Custom encodings DON'T automatically bypass automation!
# ;; - Peano arithmetic with custom types: Still TRIVIAL (proved automatically)
# ;; - Permutation relation: Also TRIVIAL (proved automatically)
# ;; - What matters: REASONING COMPLEXITY, not built-in vs custom types
# ;; - ACL2's induction heuristics work on ANY structurally recursive definition
# ;;
# ;; MOVED TO TRIVIAL FILE (proved automatically with 0 hints):
# ;; - Bags, Interleaving: Trivial with built-in lists
# ;; - Peano arithmetic: Trivial even with custom encoding!
# ;; - Permutation: Trivial with computational definition
# ;; See: experiments/trivial-swf-exercises.lisp
# ;;
# ;; EXCLUDED (can't encode properly in ACL2):
# ;; - Church Numerals: Requires polymorphic higher-order functions
# ;; - Currying: Requires lambdas in theorem statements
# ;;
# ;; NEXT STEPS:
# ;; 1. Attempt binary number theorems (genuinely hard)
# ;; 2. Prove reverse injectivity (good moderate challenge)
# ;; 3. Tackle involution theorem (requires insight)
# ;;
# ;; These are the REAL challenges - they require thought, helper lemmas,
# ;; and understanding of ACL2's proof strategies.
# ;; =============================================================================
