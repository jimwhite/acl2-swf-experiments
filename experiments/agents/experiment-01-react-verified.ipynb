# %% [raw]
# ; Verified ReAct Agent with Z3 Enforcement & Optimization
# ;
# ; This experiment defines a ReAct-style chain-of-thought agent where:
# ; 1. Tool permissions (file access + execute) are formally specified
# ; 2. LLM and tool costs (tokens, time, money) are constrained
# ; 3. Z3 enforces constraints AND optimizes continue-vs-respond decisions
# ; 4. Guards are verified to ensure type safety
# ;
# ; Building incrementally with guard verification at each step.

# %%
(in-package "ACL2")
# Out:
#  "ACL2"

# %% [raw]
# ;;; ==========================================================================
# ;;; Part 1: Permission Model (Orthogonal: File Access + Execute)
# ;;; ==========================================================================

# %%
; File access levels (ordered enum for comparison)
(defconst *access-none* 0)
(defconst *access-read* 1)
(defconst *access-read-write* 2)
# Out:
# Summary
# Form:  ( DEFCONST *ACCESS-NONE* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *ACCESS-NONE*
#
# Summary
# Form:  ( DEFCONST *ACCESS-READ* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *ACCESS-READ*
#
# Summary
# Form:  ( DEFCONST *ACCESS-READ-WRITE* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *ACCESS-READ-WRITE*

# %%
; Permission level predicate - guard is t (accepts anything)
(defun access-level-p (x)
  (declare (xargs :guard t))
  (and (natp x) (<= x 2)))
# Out:
# Since ACCESS-LEVEL-P is non-recursive, its admission is trivial.  We
# observe that the type of ACCESS-LEVEL-P is described by the theorem
# (OR (EQUAL (ACCESS-LEVEL-P X) T) (EQUAL (ACCESS-LEVEL-P X) NIL)).
#
# Computing the guard conjecture for ACCESS-LEVEL-P....
#
# The guard conjecture for ACCESS-LEVEL-P is trivial to prove, given
# the :compound-recognizer rule NATP-COMPOUND-RECOGNIZER.  ACCESS-LEVEL-P
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN ACCESS-LEVEL-P ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  ACCESS-LEVEL-P

# %%
; Theorem: access-level-p implies natp (useful for later guards)
(defthm access-level-p-implies-natp
  (implies (access-level-p x)
           (natp x))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM ACCESS-LEVEL-P-IMPLIES-NATP ...):  The
# :TRIGGER-TERMS for the :FORWARD-CHAINING rule ACCESS-LEVEL-P-IMPLIES-NATP
# will consist of the list containing (ACCESS-LEVEL-P X).
#
# ACL2 Warning [Non-rec] in ( DEFTHM ACCESS-LEVEL-P-IMPLIES-NATP ...):
# The term (ACCESS-LEVEL-P X) contains the function symbol ACCESS-LEVEL-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (ACCESS-LEVEL-P X) is unlikely ever to occur as a trigger for
# ACCESS-LEVEL-P-IMPLIES-NATP.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ACCESS-LEVEL-P-IMPLIES-NATP ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  29
#  ACCESS-LEVEL-P-IMPLIES-NATP

# %%
; Check if granted access is sufficient for required access
; Both inputs must be valid access levels
(defun access-sufficient-p (required granted)
  (declare (xargs :guard (and (access-level-p required)
                              (access-level-p granted))))
  (<= required granted))
# Out:
# Since ACCESS-SUFFICIENT-P is non-recursive, its admission is trivial.
# We observe that the type of ACCESS-SUFFICIENT-P is described by the
# theorem
# (OR (EQUAL (ACCESS-SUFFICIENT-P REQUIRED GRANTED)
#            T)
#     (EQUAL (ACCESS-SUFFICIENT-P REQUIRED GRANTED)
#            NIL)).
#
# Computing the guard conjecture for ACCESS-SUFFICIENT-P....
#
# The guard conjecture for ACCESS-SUFFICIENT-P is trivial to prove, given
# the :compound-recognizer rule NATP-COMPOUND-RECOGNIZER, the :forward-
# chaining rule ACCESS-LEVEL-P-IMPLIES-NATP and the :type-prescription
# rule ACCESS-LEVEL-P.  ACCESS-SUFFICIENT-P is compliant with Common
# Lisp.
#
# Summary
# Form:  ( DEFUN ACCESS-SUFFICIENT-P ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:FORWARD-CHAINING ACCESS-LEVEL-P-IMPLIES-NATP)
#         (:TYPE-PRESCRIPTION ACCESS-LEVEL-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  ACCESS-SUFFICIENT-P

# %%
; Full permission check: file access + execute
; Execute is orthogonal - tools that execute code need execute permission
(defun tool-permitted-p (required-access requires-execute granted-access execute-allowed)
  (declare (xargs :guard (and (access-level-p required-access)
                              (booleanp requires-execute)
                              (access-level-p granted-access)
                              (booleanp execute-allowed))))
  (and (access-sufficient-p required-access granted-access)
       (implies requires-execute execute-allowed)))
# Out:
# Since TOOL-PERMITTED-P is non-recursive, its admission is trivial.
# We observe that the type of TOOL-PERMITTED-P is described by the theorem
# (OR (EQUAL (TOOL-PERMITTED-P REQUIRED-ACCESS REQUIRES-EXECUTE
#                              GRANTED-ACCESS EXECUTE-ALLOWED)
#            T)
#     (EQUAL (TOOL-PERMITTED-P REQUIRED-ACCESS REQUIRES-EXECUTE
#                              GRANTED-ACCESS EXECUTE-ALLOWED)
#            NIL)).
#
# Computing the guard conjecture for TOOL-PERMITTED-P....
#
# The guard conjecture for TOOL-PERMITTED-P is trivial to prove.
# TOOL-PERMITTED-P is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN TOOL-PERMITTED-P ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TOOL-PERMITTED-P

# %% [raw]
# ;;; ==========================================================================
# ;;; Part 2: LLM Model Specification
# ;;; ==========================================================================

# %% [raw]
# ; LLM model specification as a simple list structure
# ; (name tokens-per-second cost-per-1k-input cost-per-1k-output)
# ; Using positive rationals for rates and costs

# %%
(defun llm-model-spec-p (spec)
  (declare (xargs :guard t))
  (and (true-listp spec)
       (eql (len spec) 4)
       (stringp (nth 0 spec))                          ; name
       (rationalp (nth 1 spec)) (< 0 (nth 1 spec))     ; tokens-per-second > 0
       (rationalp (nth 2 spec)) (<= 0 (nth 2 spec))    ; cost-per-1k-input >= 0
       (rationalp (nth 3 spec)) (<= 0 (nth 3 spec))))  ; cost-per-1k-output >= 0
# Out:
# Since LLM-MODEL-SPEC-P is non-recursive, its admission is trivial.
# We observe that the type of LLM-MODEL-SPEC-P is described by the theorem
# (OR (EQUAL (LLM-MODEL-SPEC-P SPEC) T) (EQUAL (LLM-MODEL-SPEC-P SPEC) NIL)).
#
# Computing the guard conjecture for LLM-MODEL-SPEC-P....
#
# The guard conjecture for LLM-MODEL-SPEC-P is trivial to prove, given
# the :executable-counterpart of EQLABLEP.  LLM-MODEL-SPEC-P is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-MODEL-SPEC-P ...)
# Rules: ((:EXECUTABLE-COUNTERPART EQLABLEP))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  LLM-MODEL-SPEC-P

# %%
; Accessors with verified guards
(defun llm-model-name (spec)
  (declare (xargs :guard (llm-model-spec-p spec)))
  (nth 0 spec))
# Out:
# Since LLM-MODEL-NAME is non-recursive, its admission is trivial.  We
# could deduce no constraints on the type of LLM-MODEL-NAME.
#
# Computing the guard conjecture for LLM-MODEL-NAME....
#
# The non-trivial part of the guard conjecture for LLM-MODEL-NAME is
#
# Goal
# (IMPLIES (LLM-MODEL-SPEC-P SPEC)
#          (TRUE-LISTP SPEC)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for LLM-MODEL-NAME.
# LLM-MODEL-NAME is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-MODEL-NAME ...)
# Rules: ((:DEFINITION LLM-MODEL-SPEC-P)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  68
#  LLM-MODEL-NAME

# %%
(defun llm-model-tps (spec)
  (declare (xargs :guard (llm-model-spec-p spec)))
  (nth 1 spec))
# Out:
# Since LLM-MODEL-TPS is non-recursive, its admission is trivial.  We
# could deduce no constraints on the type of LLM-MODEL-TPS.
#
# Computing the guard conjecture for LLM-MODEL-TPS....
#
# The non-trivial part of the guard conjecture for LLM-MODEL-TPS is
#
# Goal
# (IMPLIES (LLM-MODEL-SPEC-P SPEC)
#          (TRUE-LISTP SPEC)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for LLM-MODEL-TPS.
# LLM-MODEL-TPS is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-MODEL-TPS ...)
# Rules: ((:DEFINITION LLM-MODEL-SPEC-P)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  68
#  LLM-MODEL-TPS

# %%
(defun llm-model-cost-input (spec)
  (declare (xargs :guard (llm-model-spec-p spec)))
  (nth 2 spec))
# Out:
# Since LLM-MODEL-COST-INPUT is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of LLM-MODEL-COST-INPUT.
#
# Computing the guard conjecture for LLM-MODEL-COST-INPUT....
#
# The non-trivial part of the guard conjecture for LLM-MODEL-COST-INPUT
# is
#
# Goal
# (IMPLIES (LLM-MODEL-SPEC-P SPEC)
#          (TRUE-LISTP SPEC)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for LLM-MODEL-COST-INPUT.
# LLM-MODEL-COST-INPUT is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-MODEL-COST-INPUT ...)
# Rules: ((:DEFINITION LLM-MODEL-SPEC-P)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  68
#  LLM-MODEL-COST-INPUT

# %%
(defun llm-model-cost-output (spec)
  (declare (xargs :guard (llm-model-spec-p spec)))
  (nth 3 spec))
# Out:
# Since LLM-MODEL-COST-OUTPUT is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of LLM-MODEL-COST-OUTPUT.
#
# Computing the guard conjecture for LLM-MODEL-COST-OUTPUT....
#
# The non-trivial part of the guard conjecture for LLM-MODEL-COST-OUTPUT
# is
#
# Goal
# (IMPLIES (LLM-MODEL-SPEC-P SPEC)
#          (TRUE-LISTP SPEC)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for LLM-MODEL-COST-OUTPUT.
# LLM-MODEL-COST-OUTPUT is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-MODEL-COST-OUTPUT ...)
# Rules: ((:DEFINITION LLM-MODEL-SPEC-P)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  68
#  LLM-MODEL-COST-OUTPUT

# %%
; Theorems about accessor return types (for downstream guard proofs)
(defthm llm-model-tps-positive
  (implies (llm-model-spec-p spec)
           (and (rationalp (llm-model-tps spec))
                (< 0 (llm-model-tps spec))))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM LLM-MODEL-TPS-POSITIVE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule LLM-MODEL-TPS-POSITIVE will consist
# of the list containing (LLM-MODEL-SPEC-P SPEC).
#
# ACL2 Warning [Non-rec] in ( DEFTHM LLM-MODEL-TPS-POSITIVE ...):  The
# term (LLM-MODEL-SPEC-P SPEC) contains the function symbol LLM-MODEL-SPEC-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (LLM-MODEL-SPEC-P SPEC) is unlikely ever to occur as a trigger for
# LLM-MODEL-TPS-POSITIVE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM LLM-MODEL-TPS-POSITIVE ...)
# Rules: ((:DEFINITION LLM-MODEL-SPEC-P)
#         (:DEFINITION LLM-MODEL-TPS)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  78
#  LLM-MODEL-TPS-POSITIVE

# %%
(defthm llm-model-cost-input-rational
  (implies (llm-model-spec-p spec)
           (and (rationalp (llm-model-cost-input spec))
                (<= 0 (llm-model-cost-input spec))))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM LLM-MODEL-COST-INPUT-RATIONAL ...):  The
# :TRIGGER-TERMS for the :FORWARD-CHAINING rule LLM-MODEL-COST-INPUT-RATIONAL
# will consist of the list containing (LLM-MODEL-SPEC-P SPEC).
#
# ACL2 Warning [Non-rec] in ( DEFTHM LLM-MODEL-COST-INPUT-RATIONAL ...):
# The term (LLM-MODEL-SPEC-P SPEC) contains the function symbol
# LLM-MODEL-SPEC-P, which has a non-recursive definition.  Unless this
# definition is disabled, (LLM-MODEL-SPEC-P SPEC) is unlikely ever to
# occur as a trigger for LLM-MODEL-COST-INPUT-RATIONAL.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM LLM-MODEL-COST-INPUT-RATIONAL ...)
# Rules: ((:DEFINITION LLM-MODEL-COST-INPUT)
#         (:DEFINITION LLM-MODEL-SPEC-P)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  79
#  LLM-MODEL-COST-INPUT-RATIONAL

# %%
(defthm llm-model-cost-output-rational
  (implies (llm-model-spec-p spec)
           (and (rationalp (llm-model-cost-output spec))
                (<= 0 (llm-model-cost-output spec))))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM LLM-MODEL-COST-OUTPUT-RATIONAL ...):
# The :TRIGGER-TERMS for the :FORWARD-CHAINING rule
# LLM-MODEL-COST-OUTPUT-RATIONAL will consist of the list containing
# (LLM-MODEL-SPEC-P SPEC).
#
# ACL2 Warning [Non-rec] in ( DEFTHM LLM-MODEL-COST-OUTPUT-RATIONAL ...):
# The term (LLM-MODEL-SPEC-P SPEC) contains the function symbol
# LLM-MODEL-SPEC-P, which has a non-recursive definition.  Unless this
# definition is disabled, (LLM-MODEL-SPEC-P SPEC) is unlikely ever to
# occur as a trigger for LLM-MODEL-COST-OUTPUT-RATIONAL.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM LLM-MODEL-COST-OUTPUT-RATIONAL ...)
# Rules: ((:DEFINITION LLM-MODEL-COST-OUTPUT)
#         (:DEFINITION LLM-MODEL-SPEC-P)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  79
#  LLM-MODEL-COST-OUTPUT-RATIONAL

# %% [raw]
# ;;; ==========================================================================
# ;;; Part 3: LLM Cost Calculations
# ;;; ==========================================================================

# %%
; Calculate LLM call cost in millicents
; Returns a non-negative rational
(defun llm-call-cost (spec input-tokens output-tokens)
  (declare (xargs :guard (and (llm-model-spec-p spec)
                              (natp input-tokens)
                              (natp output-tokens))))
  (+ (* (/ input-tokens 1000) (llm-model-cost-input spec))
     (* (/ output-tokens 1000) (llm-model-cost-output spec))))
# Out:
# Since LLM-CALL-COST is non-recursive, its admission is trivial.  We
# observe that the type of LLM-CALL-COST is described by the theorem
# (ACL2-NUMBERP (LLM-CALL-COST SPEC INPUT-TOKENS OUTPUT-TOKENS)).  We
# used primitive type reasoning.
#
# Computing the guard conjecture for LLM-CALL-COST....
#
# The guard conjecture for LLM-CALL-COST is trivial to prove, given the
# :compound-recognizer rule NATP-COMPOUND-RECOGNIZER, primitive type
# reasoning, the :forward-chaining rules LLM-MODEL-COST-INPUT-RATIONAL
# and LLM-MODEL-COST-OUTPUT-RATIONAL and the :type-prescription rule
# LLM-MODEL-SPEC-P.  LLM-CALL-COST is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-CALL-COST ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:FORWARD-CHAINING LLM-MODEL-COST-INPUT-RATIONAL)
#         (:FORWARD-CHAINING LLM-MODEL-COST-OUTPUT-RATIONAL)
#         (:TYPE-PRESCRIPTION LLM-MODEL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  LLM-CALL-COST

# %%
; Calculate LLM call time in milliseconds
; Returns a non-negative rational
(defun llm-call-time-ms (spec input-tokens output-tokens)
  (declare (xargs :guard (and (llm-model-spec-p spec)
                              (natp input-tokens)
                              (natp output-tokens))))
  (* 1000 (/ (+ input-tokens output-tokens) (llm-model-tps spec))))
# Out:
# Since LLM-CALL-TIME-MS is non-recursive, its admission is trivial.
# We observe that the type of LLM-CALL-TIME-MS is described by the theorem
# (ACL2-NUMBERP (LLM-CALL-TIME-MS SPEC INPUT-TOKENS OUTPUT-TOKENS)).
# We used primitive type reasoning.
#
# Computing the guard conjecture for LLM-CALL-TIME-MS....
#
# The guard conjecture for LLM-CALL-TIME-MS is trivial to prove, given
# the :compound-recognizer rule NATP-COMPOUND-RECOGNIZER, primitive type
# reasoning, the :forward-chaining rule LLM-MODEL-TPS-POSITIVE and the
# :type-prescription rule LLM-MODEL-SPEC-P.  LLM-CALL-TIME-MS is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN LLM-CALL-TIME-MS ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:FORWARD-CHAINING LLM-MODEL-TPS-POSITIVE)
#         (:TYPE-PRESCRIPTION LLM-MODEL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  LLM-CALL-TIME-MS

# %%
; Theorems about cost calculation return types
(defthm llm-call-cost-rational
  (implies (and (llm-model-spec-p spec)
                (natp input-tokens)
                (natp output-tokens))
           (and (rationalp (llm-call-cost spec input-tokens output-tokens))
                (<= 0 (llm-call-cost spec input-tokens output-tokens))))
  :hints (("Goal" :in-theory (enable llm-call-cost))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM LLM-CALL-COST-RATIONAL ...):  A
# :REWRITE rule generated from LLM-CALL-COST-RATIONAL will be triggered
# only by terms containing the function symbol LLM-CALL-COST, which has
# a non-recursive definition.  Unless this definition is disabled, this
# rule is unlikely ever to be used.
#
#
# ACL2 Warning [Non-rec] in ( DEFTHM LLM-CALL-COST-RATIONAL ...):  A
# :REWRITE rule generated from LLM-CALL-COST-RATIONAL will be triggered
# only by terms containing the function symbol LLM-CALL-COST, which has
# a non-recursive definition.  Unless this definition is disabled, this
# rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM LLM-CALL-COST-RATIONAL ...)
# Rules: ((:DEFINITION LLM-CALL-COST)
#         (:DEFINITION LLM-MODEL-COST-INPUT)
#         (:DEFINITION LLM-MODEL-COST-OUTPUT)
#         (:DEFINITION LLM-MODEL-SPEC-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION NTH)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE COMMUTATIVITY-OF-*))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  531
#  LLM-CALL-COST-RATIONAL

# %%
(defthm llm-call-time-ms-rational
  (implies (and (llm-model-spec-p spec)
                (natp input-tokens)
                (natp output-tokens))
           (and (rationalp (llm-call-time-ms spec input-tokens output-tokens))
                (<= 0 (llm-call-time-ms spec input-tokens output-tokens))))
  :hints (("Goal" :in-theory (enable llm-call-time-ms))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM LLM-CALL-TIME-MS-RATIONAL ...):
# A :REWRITE rule generated from LLM-CALL-TIME-MS-RATIONAL will be triggered
# only by terms containing the function symbol LLM-CALL-TIME-MS, which
# has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# ACL2 Warning [Non-rec] in ( DEFTHM LLM-CALL-TIME-MS-RATIONAL ...):
# A :REWRITE rule generated from LLM-CALL-TIME-MS-RATIONAL will be triggered
# only by terms containing the function symbol LLM-CALL-TIME-MS, which
# has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM LLM-CALL-TIME-MS-RATIONAL ...)
# Rules: ((:DEFINITION LLM-CALL-TIME-MS)
#         (:DEFINITION LLM-MODEL-SPEC-P)
#         (:DEFINITION LLM-MODEL-TPS)
#         (:DEFINITION NATP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  129
#  LLM-CALL-TIME-MS-RATIONAL

# %% [raw]
# ;;; ==========================================================================
# ;;; Part 4: Tool Specification
# ;;; ==========================================================================

# %% [raw]
# ; Tool specification as a simple list structure
# ; (name required-access requires-execute base-cost time-estimate token-estimate)

# %%
(defun tool-spec-p (spec)
  (declare (xargs :guard t))
  (and (true-listp spec)
       (eql (len spec) 6)
       (stringp (nth 0 spec))           ; name
       (access-level-p (nth 1 spec))    ; required-file-access
       (booleanp (nth 2 spec))          ; requires-execute
       (natp (nth 3 spec))              ; base-cost (millicents)
       (natp (nth 4 spec))              ; time-estimate-ms
       (natp (nth 5 spec))))            ; token-estimate
# Out:
# Since TOOL-SPEC-P is non-recursive, its admission is trivial.  We observe
# that the type of TOOL-SPEC-P is described by the theorem
# (OR (EQUAL (TOOL-SPEC-P SPEC) T) (EQUAL (TOOL-SPEC-P SPEC) NIL)).
# We used the :compound-recognizer rule NATP-COMPOUND-RECOGNIZER.
#
# Computing the guard conjecture for TOOL-SPEC-P....
#
# The guard conjecture for TOOL-SPEC-P is trivial to prove, given the
# :executable-counterpart of EQLABLEP.  TOOL-SPEC-P is compliant with
# Common Lisp.
#
# Summary
# Form:  ( DEFUN TOOL-SPEC-P ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:EXECUTABLE-COUNTERPART EQLABLEP))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TOOL-SPEC-P

# %%
; Accessors with verified guards
(defun tool-name (spec)
  (declare (xargs :guard (tool-spec-p spec)))
  (nth 0 spec))
# Out:
# Since TOOL-NAME is non-recursive, its admission is trivial.  We could
# deduce no constraints on the type of TOOL-NAME.
#
# Computing the guard conjecture for TOOL-NAME....
#
# The non-trivial part of the guard conjecture for TOOL-NAME is
#
# Goal
# (IMPLIES (TOOL-SPEC-P SPEC)
#          (TRUE-LISTP SPEC)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for TOOL-NAME.  TOOL-NAME
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN TOOL-NAME ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION TOOL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  126
#  TOOL-NAME

# %%
(defun tool-required-access (spec)
  (declare (xargs :guard (tool-spec-p spec)))
  (nth 1 spec))
# Out:
# Since TOOL-REQUIRED-ACCESS is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of TOOL-REQUIRED-ACCESS.
#
# Computing the guard conjecture for TOOL-REQUIRED-ACCESS....
#
# The non-trivial part of the guard conjecture for TOOL-REQUIRED-ACCESS
# is
#
# Goal
# (IMPLIES (TOOL-SPEC-P SPEC)
#          (TRUE-LISTP SPEC)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for TOOL-REQUIRED-ACCESS.
# TOOL-REQUIRED-ACCESS is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN TOOL-REQUIRED-ACCESS ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION TOOL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  126
#  TOOL-REQUIRED-ACCESS

# %%
(defun tool-requires-execute (spec)
  (declare (xargs :guard (tool-spec-p spec)))
  (nth 2 spec))
# Out:
# Since TOOL-REQUIRES-EXECUTE is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of TOOL-REQUIRES-EXECUTE.
#
# Computing the guard conjecture for TOOL-REQUIRES-EXECUTE....
#
# The non-trivial part of the guard conjecture for TOOL-REQUIRES-EXECUTE
# is
#
# Goal
# (IMPLIES (TOOL-SPEC-P SPEC)
#          (TRUE-LISTP SPEC)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for TOOL-REQUIRES-EXECUTE.
# TOOL-REQUIRES-EXECUTE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN TOOL-REQUIRES-EXECUTE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION TOOL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  126
#  TOOL-REQUIRES-EXECUTE

# %%
(defun tool-base-cost (spec)
  (declare (xargs :guard (tool-spec-p spec)))
  (nth 3 spec))
# Out:
# Since TOOL-BASE-COST is non-recursive, its admission is trivial.  We
# could deduce no constraints on the type of TOOL-BASE-COST.
#
# Computing the guard conjecture for TOOL-BASE-COST....
#
# The non-trivial part of the guard conjecture for TOOL-BASE-COST is
#
# Goal
# (IMPLIES (TOOL-SPEC-P SPEC)
#          (TRUE-LISTP SPEC)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for TOOL-BASE-COST.
# TOOL-BASE-COST is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN TOOL-BASE-COST ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION TOOL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  126
#  TOOL-BASE-COST

# %%
(defun tool-time-estimate (spec)
  (declare (xargs :guard (tool-spec-p spec)))
  (nth 4 spec))
# Out:
# Since TOOL-TIME-ESTIMATE is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of TOOL-TIME-ESTIMATE.
#
# Computing the guard conjecture for TOOL-TIME-ESTIMATE....
#
# The non-trivial part of the guard conjecture for TOOL-TIME-ESTIMATE
# is
#
# Goal
# (IMPLIES (TOOL-SPEC-P SPEC)
#          (TRUE-LISTP SPEC)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for TOOL-TIME-ESTIMATE.
# TOOL-TIME-ESTIMATE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN TOOL-TIME-ESTIMATE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION TOOL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  126
#  TOOL-TIME-ESTIMATE

# %%
(defun tool-token-estimate (spec)
  (declare (xargs :guard (tool-spec-p spec)))
  (nth 5 spec))
# Out:
# Since TOOL-TOKEN-ESTIMATE is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of TOOL-TOKEN-ESTIMATE.
#
# Computing the guard conjecture for TOOL-TOKEN-ESTIMATE....
#
# The non-trivial part of the guard conjecture for TOOL-TOKEN-ESTIMATE
# is
#
# Goal
# (IMPLIES (TOOL-SPEC-P SPEC)
#          (TRUE-LISTP SPEC)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for TOOL-TOKEN-ESTIMATE.
# TOOL-TOKEN-ESTIMATE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN TOOL-TOKEN-ESTIMATE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION TOOL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  126
#  TOOL-TOKEN-ESTIMATE

# %%
; Return type theorems for tool accessors
(defthm tool-required-access-type
  (implies (tool-spec-p spec)
           (access-level-p (tool-required-access spec)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM TOOL-REQUIRED-ACCESS-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule TOOL-REQUIRED-ACCESS-TYPE will
# consist of the list containing (TOOL-SPEC-P SPEC).
#
# ACL2 Warning [Non-rec] in ( DEFTHM TOOL-REQUIRED-ACCESS-TYPE ...):
# The term (TOOL-SPEC-P SPEC) contains the function symbol TOOL-SPEC-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (TOOL-SPEC-P SPEC) is unlikely ever to occur as a trigger for
# TOOL-REQUIRED-ACCESS-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM TOOL-REQUIRED-ACCESS-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION TOOL-REQUIRED-ACCESS)
#         (:DEFINITION TOOL-SPEC-P)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  127
#  TOOL-REQUIRED-ACCESS-TYPE

# %%
(defthm tool-requires-execute-type
  (implies (tool-spec-p spec)
           (booleanp (tool-requires-execute spec)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM TOOL-REQUIRES-EXECUTE-TYPE ...):  The
# :TRIGGER-TERMS for the :FORWARD-CHAINING rule TOOL-REQUIRES-EXECUTE-TYPE
# will consist of the list containing (TOOL-SPEC-P SPEC).
#
# ACL2 Warning [Non-rec] in ( DEFTHM TOOL-REQUIRES-EXECUTE-TYPE ...):
# The term (TOOL-SPEC-P SPEC) contains the function symbol TOOL-SPEC-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (TOOL-SPEC-P SPEC) is unlikely ever to occur as a trigger for
# TOOL-REQUIRES-EXECUTE-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM TOOL-REQUIRES-EXECUTE-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION TOOL-REQUIRES-EXECUTE)
#         (:DEFINITION TOOL-SPEC-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  127
#  TOOL-REQUIRES-EXECUTE-TYPE

# %%
(defthm tool-base-cost-type
  (implies (tool-spec-p spec)
           (natp (tool-base-cost spec)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM TOOL-BASE-COST-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule TOOL-BASE-COST-TYPE will consist
# of the list containing (TOOL-SPEC-P SPEC).
#
# ACL2 Warning [Non-rec] in ( DEFTHM TOOL-BASE-COST-TYPE ...):  The term
# (TOOL-SPEC-P SPEC) contains the function symbol TOOL-SPEC-P, which
# has a non-recursive definition.  Unless this definition is disabled,
# (TOOL-SPEC-P SPEC) is unlikely ever to occur as a trigger for
# TOOL-BASE-COST-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM TOOL-BASE-COST-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION TOOL-BASE-COST)
#         (:DEFINITION TOOL-SPEC-P)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  127
#  TOOL-BASE-COST-TYPE

# %%
(defthm tool-time-estimate-type
  (implies (tool-spec-p spec)
           (natp (tool-time-estimate spec)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM TOOL-TIME-ESTIMATE-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule TOOL-TIME-ESTIMATE-TYPE will consist
# of the list containing (TOOL-SPEC-P SPEC).
#
# ACL2 Warning [Non-rec] in ( DEFTHM TOOL-TIME-ESTIMATE-TYPE ...):  The
# term (TOOL-SPEC-P SPEC) contains the function symbol TOOL-SPEC-P, which
# has a non-recursive definition.  Unless this definition is disabled,
# (TOOL-SPEC-P SPEC) is unlikely ever to occur as a trigger for
# TOOL-TIME-ESTIMATE-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM TOOL-TIME-ESTIMATE-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION TOOL-SPEC-P)
#         (:DEFINITION TOOL-TIME-ESTIMATE)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  127
#  TOOL-TIME-ESTIMATE-TYPE

# %%
(defthm tool-token-estimate-type
  (implies (tool-spec-p spec)
           (natp (tool-token-estimate spec)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM TOOL-TOKEN-ESTIMATE-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule TOOL-TOKEN-ESTIMATE-TYPE will
# consist of the list containing (TOOL-SPEC-P SPEC).
#
# ACL2 Warning [Non-rec] in ( DEFTHM TOOL-TOKEN-ESTIMATE-TYPE ...):
# The term (TOOL-SPEC-P SPEC) contains the function symbol TOOL-SPEC-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (TOOL-SPEC-P SPEC) is unlikely ever to occur as a trigger for
# TOOL-TOKEN-ESTIMATE-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM TOOL-TOKEN-ESTIMATE-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION TOOL-SPEC-P)
#         (:DEFINITION TOOL-TOKEN-ESTIMATE)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  127
#  TOOL-TOKEN-ESTIMATE-TYPE

# %% [raw]
# ;;; ==========================================================================
# ;;; Part 5: Agent State
# ;;; ==========================================================================

# %% [raw]
# ; Agent state as a list structure
# ; (iteration max-iterations token-budget cost-budget time-budget
# ;  file-access execute-allowed satisfaction done)

# %%
(defun agent-state-p (st)
  (declare (xargs :guard t))
  (and (true-listp st)
       (eql (len st) 9)
       (natp (nth 0 st))              ; iteration
       (natp (nth 1 st))              ; max-iterations
       (natp (nth 2 st))              ; token-budget-remaining
       (natp (nth 3 st))              ; cost-budget-remaining (millicents)
       (natp (nth 4 st))              ; time-budget-remaining-ms
       (access-level-p (nth 5 st))    ; granted-file-access
       (booleanp (nth 6 st))          ; execute-allowed
       (rationalp (nth 7 st))         ; satisfaction-score
       (<= 0 (nth 7 st))
       (<= (nth 7 st) 1)
       (booleanp (nth 8 st))))        ; done
# Out:
# Since AGENT-STATE-P is non-recursive, its admission is trivial.  We
# observe that the type of AGENT-STATE-P is described by the theorem
# (OR (EQUAL (AGENT-STATE-P ST) T) (EQUAL (AGENT-STATE-P ST) NIL)).
# We used the :compound-recognizer rule BOOLEANP-COMPOUND-RECOGNIZER.
#
# Computing the guard conjecture for AGENT-STATE-P....
#
# The guard conjecture for AGENT-STATE-P is trivial to prove, given the
# :executable-counterpart of EQLABLEP.  AGENT-STATE-P is compliant with
# Common Lisp.
#
# Summary
# Form:  ( DEFUN AGENT-STATE-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:EXECUTABLE-COUNTERPART EQLABLEP))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  AGENT-STATE-P

# %%
; Accessors
(defun agent-iteration (st)
  (declare (xargs :guard (agent-state-p st)))
  (nth 0 st))
# Out:
# Since AGENT-ITERATION is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of AGENT-ITERATION.
#
# Computing the guard conjecture for AGENT-ITERATION....
#
# The non-trivial part of the guard conjecture for AGENT-ITERATION is
#
# Goal
# (IMPLIES (AGENT-STATE-P ST)
#          (TRUE-LISTP ST)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for AGENT-ITERATION.
# AGENT-ITERATION is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN AGENT-ITERATION ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  186
#  AGENT-ITERATION

# %%
(defun agent-max-iterations (st)
  (declare (xargs :guard (agent-state-p st)))
  (nth 1 st))
# Out:
# Since AGENT-MAX-ITERATIONS is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of AGENT-MAX-ITERATIONS.
#
# Computing the guard conjecture for AGENT-MAX-ITERATIONS....
#
# The non-trivial part of the guard conjecture for AGENT-MAX-ITERATIONS
# is
#
# Goal
# (IMPLIES (AGENT-STATE-P ST)
#          (TRUE-LISTP ST)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for AGENT-MAX-ITERATIONS.
# AGENT-MAX-ITERATIONS is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN AGENT-MAX-ITERATIONS ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  186
#  AGENT-MAX-ITERATIONS

# %%
(defun agent-token-budget (st)
  (declare (xargs :guard (agent-state-p st)))
  (nth 2 st))
# Out:
# Since AGENT-TOKEN-BUDGET is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of AGENT-TOKEN-BUDGET.
#
# Computing the guard conjecture for AGENT-TOKEN-BUDGET....
#
# The non-trivial part of the guard conjecture for AGENT-TOKEN-BUDGET
# is
#
# Goal
# (IMPLIES (AGENT-STATE-P ST)
#          (TRUE-LISTP ST)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for AGENT-TOKEN-BUDGET.
# AGENT-TOKEN-BUDGET is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN AGENT-TOKEN-BUDGET ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  186
#  AGENT-TOKEN-BUDGET

# %%
(defun agent-cost-budget (st)
  (declare (xargs :guard (agent-state-p st)))
  (nth 3 st))
# Out:
# Since AGENT-COST-BUDGET is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of AGENT-COST-BUDGET.
#
# Computing the guard conjecture for AGENT-COST-BUDGET....
#
# The non-trivial part of the guard conjecture for AGENT-COST-BUDGET
# is
#
# Goal
# (IMPLIES (AGENT-STATE-P ST)
#          (TRUE-LISTP ST)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for AGENT-COST-BUDGET.
# AGENT-COST-BUDGET is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN AGENT-COST-BUDGET ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  186
#  AGENT-COST-BUDGET

# %%
(defun agent-time-budget (st)
  (declare (xargs :guard (agent-state-p st)))
  (nth 4 st))
# Out:
# Since AGENT-TIME-BUDGET is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of AGENT-TIME-BUDGET.
#
# Computing the guard conjecture for AGENT-TIME-BUDGET....
#
# The non-trivial part of the guard conjecture for AGENT-TIME-BUDGET
# is
#
# Goal
# (IMPLIES (AGENT-STATE-P ST)
#          (TRUE-LISTP ST)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for AGENT-TIME-BUDGET.
# AGENT-TIME-BUDGET is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN AGENT-TIME-BUDGET ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  186
#  AGENT-TIME-BUDGET

# %%
(defun agent-file-access (st)
  (declare (xargs :guard (agent-state-p st)))
  (nth 5 st))
# Out:
# Since AGENT-FILE-ACCESS is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of AGENT-FILE-ACCESS.
#
# Computing the guard conjecture for AGENT-FILE-ACCESS....
#
# The non-trivial part of the guard conjecture for AGENT-FILE-ACCESS
# is
#
# Goal
# (IMPLIES (AGENT-STATE-P ST)
#          (TRUE-LISTP ST)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for AGENT-FILE-ACCESS.
# AGENT-FILE-ACCESS is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN AGENT-FILE-ACCESS ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  186
#  AGENT-FILE-ACCESS

# %%
(defun agent-execute-allowed (st)
  (declare (xargs :guard (agent-state-p st)))
  (nth 6 st))
# Out:
# Since AGENT-EXECUTE-ALLOWED is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of AGENT-EXECUTE-ALLOWED.
#
# Computing the guard conjecture for AGENT-EXECUTE-ALLOWED....
#
# The non-trivial part of the guard conjecture for AGENT-EXECUTE-ALLOWED
# is
#
# Goal
# (IMPLIES (AGENT-STATE-P ST)
#          (TRUE-LISTP ST)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for AGENT-EXECUTE-ALLOWED.
# AGENT-EXECUTE-ALLOWED is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN AGENT-EXECUTE-ALLOWED ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  186
#  AGENT-EXECUTE-ALLOWED

# %%
(defun agent-satisfaction (st)
  (declare (xargs :guard (agent-state-p st)))
  (nth 7 st))
# Out:
# Since AGENT-SATISFACTION is non-recursive, its admission is trivial.
# We could deduce no constraints on the type of AGENT-SATISFACTION.
#
# Computing the guard conjecture for AGENT-SATISFACTION....
#
# The non-trivial part of the guard conjecture for AGENT-SATISFACTION
# is
#
# Goal
# (IMPLIES (AGENT-STATE-P ST)
#          (TRUE-LISTP ST)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for AGENT-SATISFACTION.
# AGENT-SATISFACTION is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN AGENT-SATISFACTION ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  186
#  AGENT-SATISFACTION

# %%
(defun agent-done (st)
  (declare (xargs :guard (agent-state-p st)))
  (nth 8 st))
# Out:
# Since AGENT-DONE is non-recursive, its admission is trivial.  We could
# deduce no constraints on the type of AGENT-DONE.
#
# Computing the guard conjecture for AGENT-DONE....
#
# The non-trivial part of the guard conjecture for AGENT-DONE is
#
# Goal
# (IMPLIES (AGENT-STATE-P ST)
#          (TRUE-LISTP ST)).
#
# Q.E.D.
#
# That completes the proof of the guard theorem for AGENT-DONE.  AGENT-DONE
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN AGENT-DONE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  186
#  AGENT-DONE

# %%
; Return type theorems for agent accessors
(defthm agent-iteration-type
  (implies (agent-state-p st)
           (natp (agent-iteration st)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM AGENT-ITERATION-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule AGENT-ITERATION-TYPE will consist
# of the list containing (AGENT-STATE-P ST).
#
# ACL2 Warning [Non-rec] in ( DEFTHM AGENT-ITERATION-TYPE ...):  The
# term (AGENT-STATE-P ST) contains the function symbol AGENT-STATE-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (AGENT-STATE-P ST) is unlikely ever to occur as a trigger for
# AGENT-ITERATION-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM AGENT-ITERATION-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-ITERATION)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  187
#  AGENT-ITERATION-TYPE

# %%
(defthm agent-max-iterations-type
  (implies (agent-state-p st)
           (natp (agent-max-iterations st)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM AGENT-MAX-ITERATIONS-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule AGENT-MAX-ITERATIONS-TYPE will
# consist of the list containing (AGENT-STATE-P ST).
#
# ACL2 Warning [Non-rec] in ( DEFTHM AGENT-MAX-ITERATIONS-TYPE ...):
# The term (AGENT-STATE-P ST) contains the function symbol AGENT-STATE-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (AGENT-STATE-P ST) is unlikely ever to occur as a trigger for
# AGENT-MAX-ITERATIONS-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM AGENT-MAX-ITERATIONS-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-MAX-ITERATIONS)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  187
#  AGENT-MAX-ITERATIONS-TYPE

# %%
(defthm agent-token-budget-type
  (implies (agent-state-p st)
           (natp (agent-token-budget st)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM AGENT-TOKEN-BUDGET-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule AGENT-TOKEN-BUDGET-TYPE will consist
# of the list containing (AGENT-STATE-P ST).
#
# ACL2 Warning [Non-rec] in ( DEFTHM AGENT-TOKEN-BUDGET-TYPE ...):  The
# term (AGENT-STATE-P ST) contains the function symbol AGENT-STATE-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (AGENT-STATE-P ST) is unlikely ever to occur as a trigger for
# AGENT-TOKEN-BUDGET-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM AGENT-TOKEN-BUDGET-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION AGENT-TOKEN-BUDGET)
#         (:DEFINITION NATP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  187
#  AGENT-TOKEN-BUDGET-TYPE

# %%
(defthm agent-cost-budget-type
  (implies (agent-state-p st)
           (natp (agent-cost-budget st)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM AGENT-COST-BUDGET-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule AGENT-COST-BUDGET-TYPE will consist
# of the list containing (AGENT-STATE-P ST).
#
# ACL2 Warning [Non-rec] in ( DEFTHM AGENT-COST-BUDGET-TYPE ...):  The
# term (AGENT-STATE-P ST) contains the function symbol AGENT-STATE-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (AGENT-STATE-P ST) is unlikely ever to occur as a trigger for
# AGENT-COST-BUDGET-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM AGENT-COST-BUDGET-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-COST-BUDGET)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  187
#  AGENT-COST-BUDGET-TYPE

# %%
(defthm agent-time-budget-type
  (implies (agent-state-p st)
           (natp (agent-time-budget st)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM AGENT-TIME-BUDGET-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule AGENT-TIME-BUDGET-TYPE will consist
# of the list containing (AGENT-STATE-P ST).
#
# ACL2 Warning [Non-rec] in ( DEFTHM AGENT-TIME-BUDGET-TYPE ...):  The
# term (AGENT-STATE-P ST) contains the function symbol AGENT-STATE-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (AGENT-STATE-P ST) is unlikely ever to occur as a trigger for
# AGENT-TIME-BUDGET-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM AGENT-TIME-BUDGET-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION AGENT-TIME-BUDGET)
#         (:DEFINITION NATP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  187
#  AGENT-TIME-BUDGET-TYPE

# %%
(defthm agent-file-access-type
  (implies (agent-state-p st)
           (access-level-p (agent-file-access st)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM AGENT-FILE-ACCESS-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule AGENT-FILE-ACCESS-TYPE will consist
# of the list containing (AGENT-STATE-P ST).
#
# ACL2 Warning [Non-rec] in ( DEFTHM AGENT-FILE-ACCESS-TYPE ...):  The
# term (AGENT-STATE-P ST) contains the function symbol AGENT-STATE-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (AGENT-STATE-P ST) is unlikely ever to occur as a trigger for
# AGENT-FILE-ACCESS-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM AGENT-FILE-ACCESS-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-FILE-ACCESS)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  187
#  AGENT-FILE-ACCESS-TYPE

# %%
(defthm agent-execute-allowed-type
  (implies (agent-state-p st)
           (booleanp (agent-execute-allowed st)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM AGENT-EXECUTE-ALLOWED-TYPE ...):  The
# :TRIGGER-TERMS for the :FORWARD-CHAINING rule AGENT-EXECUTE-ALLOWED-TYPE
# will consist of the list containing (AGENT-STATE-P ST).
#
# ACL2 Warning [Non-rec] in ( DEFTHM AGENT-EXECUTE-ALLOWED-TYPE ...):
# The term (AGENT-STATE-P ST) contains the function symbol AGENT-STATE-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (AGENT-STATE-P ST) is unlikely ever to occur as a trigger for
# AGENT-EXECUTE-ALLOWED-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM AGENT-EXECUTE-ALLOWED-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-EXECUTE-ALLOWED)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  187
#  AGENT-EXECUTE-ALLOWED-TYPE

# %%
(defthm agent-satisfaction-type
  (implies (agent-state-p st)
           (and (rationalp (agent-satisfaction st))
                (<= 0 (agent-satisfaction st))
                (<= (agent-satisfaction st) 1)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM AGENT-SATISFACTION-TYPE ...):  The :TRIGGER-
# TERMS for the :FORWARD-CHAINING rule AGENT-SATISFACTION-TYPE will consist
# of the list containing (AGENT-STATE-P ST).
#
# ACL2 Warning [Non-rec] in ( DEFTHM AGENT-SATISFACTION-TYPE ...):  The
# term (AGENT-STATE-P ST) contains the function symbol AGENT-STATE-P,
# which has a non-recursive definition.  Unless this definition is disabled,
# (AGENT-STATE-P ST) is unlikely ever to occur as a trigger for
# AGENT-SATISFACTION-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM AGENT-SATISFACTION-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-SATISFACTION)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  207
#  AGENT-SATISFACTION-TYPE

# %%
(defthm agent-done-type
  (implies (agent-state-p st)
           (booleanp (agent-done st)))
  :rule-classes :forward-chaining)
# Out:
# ACL2 Observation in ( DEFTHM AGENT-DONE-TYPE ...):  The :TRIGGER-TERMS
# for the :FORWARD-CHAINING rule AGENT-DONE-TYPE will consist of the
# list containing (AGENT-STATE-P ST).
#
# ACL2 Warning [Non-rec] in ( DEFTHM AGENT-DONE-TYPE ...):  The term
# (AGENT-STATE-P ST) contains the function symbol AGENT-STATE-P, which
# has a non-recursive definition.  Unless this definition is disabled,
# (AGENT-STATE-P ST) is unlikely ever to occur as a trigger for
# AGENT-DONE-TYPE.
#
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM AGENT-DONE-TYPE ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-DONE)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION NATP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  187
#  AGENT-DONE-TYPE

# %%
; Constructor
(defun make-agent-state (iter max-iter tokens cost time-ms access exec sat done)
  (declare (xargs :guard (and (natp iter)
                              (natp max-iter)
                              (natp tokens)
                              (natp cost)
                              (natp time-ms)
                              (access-level-p access)
                              (booleanp exec)
                              (rationalp sat)
                              (<= 0 sat)
                              (<= sat 1)
                              (booleanp done))))
  (list iter max-iter tokens cost time-ms access exec sat done))
# Out:
# Since MAKE-AGENT-STATE is non-recursive, its admission is trivial.
# We observe that the type of MAKE-AGENT-STATE is described by the theorem
# (AND (CONSP (MAKE-AGENT-STATE ITER MAX-ITER TOKENS
#                               COST TIME-MS ACCESS EXEC SAT DONE))
#      (TRUE-LISTP (MAKE-AGENT-STATE ITER MAX-ITER TOKENS
#                                    COST TIME-MS ACCESS EXEC SAT DONE))).
# We used primitive type reasoning.
#
# Computing the guard conjecture for MAKE-AGENT-STATE....
#
# The guard conjecture for MAKE-AGENT-STATE is trivial to prove.
# MAKE-AGENT-STATE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MAKE-AGENT-STATE ...)
# Rules: ((:FAKE-RUNE-FOR-TYPE-SET NIL))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MAKE-AGENT-STATE

# %%
; Constructor produces valid state
(defthm make-agent-state-valid
  (implies (and (natp iter)
                (natp max-iter)
                (natp tokens)
                (natp cost)
                (natp time-ms)
                (access-level-p access)
                (booleanp exec)
                (rationalp sat)
                (<= 0 sat)
                (<= sat 1)
                (booleanp done))
           (agent-state-p (make-agent-state iter max-iter tokens cost time-ms access exec sat done))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM MAKE-AGENT-STATE-VALID ...):  A
# :REWRITE rule generated from MAKE-AGENT-STATE-VALID will be triggered
# only by terms containing the function symbols AGENT-STATE-P and
# MAKE-AGENT-STATE, which have non-recursive definitions.  Unless these
# definitions are disabled, this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of MAKE-AGENT-STATE-VALID depends upon the :type-prescription
# rule AGENT-STATE-P.
#
# Summary
# Form:  ( DEFTHM MAKE-AGENT-STATE-VALID ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION LEN)
#         (:DEFINITION MAKE-AGENT-STATE)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART LEN)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE CDR-CONS)
#         (:REWRITE NTH-0-CONS)
#         (:REWRITE NTH-ADD1)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  801
#  MAKE-AGENT-STATE-VALID

# %% [raw]
# ;;; ==========================================================================
# ;;; Part 6: Budget Checking
# ;;; ==========================================================================

# %%
; Check if there's sufficient budget for a tool call
(defun tool-budget-sufficient-p (st tool)
  (declare (xargs :guard (and (agent-state-p st)
                              (tool-spec-p tool))))
  (and (<= (tool-base-cost tool) (agent-cost-budget st))
       (<= (tool-time-estimate tool) (agent-time-budget st))
       (<= (tool-token-estimate tool) (agent-token-budget st))))
# Out:
# Since TOOL-BUDGET-SUFFICIENT-P is non-recursive, its admission is trivial.
# We observe that the type of TOOL-BUDGET-SUFFICIENT-P is described by
# the theorem
# (OR (EQUAL (TOOL-BUDGET-SUFFICIENT-P ST TOOL)
#            T)
#     (EQUAL (TOOL-BUDGET-SUFFICIENT-P ST TOOL)
#            NIL)).
#
# Computing the guard conjecture for TOOL-BUDGET-SUFFICIENT-P....
#
# The guard conjecture for TOOL-BUDGET-SUFFICIENT-P is trivial to prove,
# given the :compound-recognizer rule NATP-COMPOUND-RECOGNIZER, the :forward-
# chaining rules AGENT-COST-BUDGET-TYPE, AGENT-TIME-BUDGET-TYPE,
# AGENT-TOKEN-BUDGET-TYPE, TOOL-BASE-COST-TYPE, TOOL-TIME-ESTIMATE-TYPE
# and TOOL-TOKEN-ESTIMATE-TYPE and the :type-prescription rules AGENT-STATE-P
# and TOOL-SPEC-P.  TOOL-BUDGET-SUFFICIENT-P is compliant with Common
# Lisp.
#
# Summary
# Form:  ( DEFUN TOOL-BUDGET-SUFFICIENT-P ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:FORWARD-CHAINING AGENT-COST-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-TIME-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-TOKEN-BUDGET-TYPE)
#         (:FORWARD-CHAINING TOOL-BASE-COST-TYPE)
#         (:FORWARD-CHAINING TOOL-TIME-ESTIMATE-TYPE)
#         (:FORWARD-CHAINING TOOL-TOKEN-ESTIMATE-TYPE)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P)
#         (:TYPE-PRESCRIPTION TOOL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TOOL-BUDGET-SUFFICIENT-P

# %%
; Check if tool is both permitted and within budget
(defun can-invoke-tool-p (st tool)
  (declare (xargs :guard (and (agent-state-p st)
                              (tool-spec-p tool))))
  (and (tool-permitted-p (tool-required-access tool)
                         (tool-requires-execute tool)
                         (agent-file-access st)
                         (agent-execute-allowed st))
       (tool-budget-sufficient-p st tool)))
# Out:
# Since CAN-INVOKE-TOOL-P is non-recursive, its admission is trivial.
# We observe that the type of CAN-INVOKE-TOOL-P is described by the theorem
# (OR (EQUAL (CAN-INVOKE-TOOL-P ST TOOL) T)
#     (EQUAL (CAN-INVOKE-TOOL-P ST TOOL)
#            NIL)).
# We used the :type-prescription rule TOOL-BUDGET-SUFFICIENT-P.
#
# Computing the guard conjecture for CAN-INVOKE-TOOL-P....
#
# The guard conjecture for CAN-INVOKE-TOOL-P is trivial to prove, given
# the :compound-recognizer rule BOOLEANP-COMPOUND-RECOGNIZER, the :forward-
# chaining rules AGENT-EXECUTE-ALLOWED-TYPE, AGENT-FILE-ACCESS-TYPE,
# TOOL-REQUIRED-ACCESS-TYPE and TOOL-REQUIRES-EXECUTE-TYPE and the :type-
# prescription rules AGENT-STATE-P and TOOL-SPEC-P.  CAN-INVOKE-TOOL-P
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN CAN-INVOKE-TOOL-P ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:FORWARD-CHAINING AGENT-EXECUTE-ALLOWED-TYPE)
#         (:FORWARD-CHAINING AGENT-FILE-ACCESS-TYPE)
#         (:FORWARD-CHAINING TOOL-REQUIRED-ACCESS-TYPE)
#         (:FORWARD-CHAINING TOOL-REQUIRES-EXECUTE-TYPE)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P)
#         (:TYPE-PRESCRIPTION TOOL-BUDGET-SUFFICIENT-P)
#         (:TYPE-PRESCRIPTION TOOL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  CAN-INVOKE-TOOL-P

# %% [raw]
# ;;; ==========================================================================
# ;;; Part 7: State Transitions
# ;;; ==========================================================================

# %%
; Deduct tool call costs from state
(defun deduct-tool-cost (st tool)
  (declare (xargs :guard (and (agent-state-p st)
                              (tool-spec-p tool))))
  (make-agent-state
   (agent-iteration st)
   (agent-max-iterations st)
   (nfix (- (agent-token-budget st) (tool-token-estimate tool)))
   (nfix (- (agent-cost-budget st) (tool-base-cost tool)))
   (nfix (- (agent-time-budget st) (tool-time-estimate tool)))
   (agent-file-access st)
   (agent-execute-allowed st)
   (agent-satisfaction st)
   (agent-done st)))
# Out:
# Since DEDUCT-TOOL-COST is non-recursive, its admission is trivial.
# We observe that the type of DEDUCT-TOOL-COST is described by the theorem
# (AND (CONSP (DEDUCT-TOOL-COST ST TOOL))
#      (TRUE-LISTP (DEDUCT-TOOL-COST ST TOOL))).
# We used the :type-prescription rule MAKE-AGENT-STATE.
#
# Computing the guard conjecture for DEDUCT-TOOL-COST....
#
# The guard conjecture for DEDUCT-TOOL-COST is trivial to prove, given
# the :compound-recognizer rules BOOLEANP-COMPOUND-RECOGNIZER and
# NATP-COMPOUND-RECOGNIZER, the :forward-chaining rules AGENT-COST-BUDGET-TYPE,
# AGENT-DONE-TYPE, AGENT-EXECUTE-ALLOWED-TYPE, AGENT-FILE-ACCESS-TYPE,
# AGENT-ITERATION-TYPE, AGENT-MAX-ITERATIONS-TYPE, AGENT-SATISFACTION-TYPE,
# AGENT-TIME-BUDGET-TYPE, AGENT-TOKEN-BUDGET-TYPE, TOOL-BASE-COST-TYPE,
# TOOL-TIME-ESTIMATE-TYPE and TOOL-TOKEN-ESTIMATE-TYPE and the :type-
# prescription rules AGENT-STATE-P, NFIX and TOOL-SPEC-P.  DEDUCT-TOOL-COST
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN DEDUCT-TOOL-COST ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:FORWARD-CHAINING AGENT-COST-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-DONE-TYPE)
#         (:FORWARD-CHAINING AGENT-EXECUTE-ALLOWED-TYPE)
#         (:FORWARD-CHAINING AGENT-FILE-ACCESS-TYPE)
#         (:FORWARD-CHAINING AGENT-ITERATION-TYPE)
#         (:FORWARD-CHAINING AGENT-MAX-ITERATIONS-TYPE)
#         (:FORWARD-CHAINING AGENT-SATISFACTION-TYPE)
#         (:FORWARD-CHAINING AGENT-TIME-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-TOKEN-BUDGET-TYPE)
#         (:FORWARD-CHAINING TOOL-BASE-COST-TYPE)
#         (:FORWARD-CHAINING TOOL-TIME-ESTIMATE-TYPE)
#         (:FORWARD-CHAINING TOOL-TOKEN-ESTIMATE-TYPE)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P)
#         (:TYPE-PRESCRIPTION MAKE-AGENT-STATE)
#         (:TYPE-PRESCRIPTION NFIX)
#         (:TYPE-PRESCRIPTION TOOL-SPEC-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  DEDUCT-TOOL-COST

# %%
; Deduct-tool-cost preserves state validity
(defthm deduct-tool-cost-valid
  (implies (and (agent-state-p st)
                (tool-spec-p tool))
           (agent-state-p (deduct-tool-cost st tool))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM DEDUCT-TOOL-COST-VALID ...):  A
# :REWRITE rule generated from DEDUCT-TOOL-COST-VALID will be triggered
# only by terms containing the function symbols AGENT-STATE-P and
# DEDUCT-TOOL-COST, which have non-recursive definitions.  Unless these
# definitions are disabled, this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of DEDUCT-TOOL-COST-VALID depends upon the :type-prescription
# rule AGENT-STATE-P.
#
# Summary
# Form:  ( DEFTHM DEDUCT-TOOL-COST-VALID ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-COST-BUDGET)
#         (:DEFINITION AGENT-DONE)
#         (:DEFINITION AGENT-EXECUTE-ALLOWED)
#         (:DEFINITION AGENT-FILE-ACCESS)
#         (:DEFINITION AGENT-ITERATION)
#         (:DEFINITION AGENT-MAX-ITERATIONS)
#         (:DEFINITION AGENT-SATISFACTION)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION AGENT-TIME-BUDGET)
#         (:DEFINITION AGENT-TOKEN-BUDGET)
#         (:DEFINITION DEDUCT-TOOL-COST)
#         (:DEFINITION LEN)
#         (:DEFINITION MAKE-AGENT-STATE)
#         (:DEFINITION NATP)
#         (:DEFINITION NFIX)
#         (:DEFINITION NTH)
#         (:DEFINITION TOOL-BASE-COST)
#         (:DEFINITION TOOL-SPEC-P)
#         (:DEFINITION TOOL-TIME-ESTIMATE)
#         (:DEFINITION TOOL-TOKEN-ESTIMATE)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART LEN)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE CDR-CONS)
#         (:REWRITE NTH-0-CONS)
#         (:REWRITE NTH-ADD1)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  2838
#  DEDUCT-TOOL-COST-VALID

# %%
; Update satisfaction score (from LLM-as-judge)
(defun update-satisfaction (st new-score)
  (declare (xargs :guard (and (agent-state-p st)
                              (rationalp new-score)
                              (<= 0 new-score)
                              (<= new-score 1))))
  (make-agent-state
   (agent-iteration st)
   (agent-max-iterations st)
   (agent-token-budget st)
   (agent-cost-budget st)
   (agent-time-budget st)
   (agent-file-access st)
   (agent-execute-allowed st)
   new-score
   (agent-done st)))
# Out:
# Since UPDATE-SATISFACTION is non-recursive, its admission is trivial.
# We observe that the type of UPDATE-SATISFACTION is described by the
# theorem
# (AND (CONSP (UPDATE-SATISFACTION ST NEW-SCORE))
#      (TRUE-LISTP (UPDATE-SATISFACTION ST NEW-SCORE))).
# We used the :type-prescription rule MAKE-AGENT-STATE.
#
# Computing the guard conjecture for UPDATE-SATISFACTION....
#
# The guard conjecture for UPDATE-SATISFACTION is trivial to prove, given
# the :compound-recognizer rules BOOLEANP-COMPOUND-RECOGNIZER and
# NATP-COMPOUND-RECOGNIZER, the :forward-chaining rules AGENT-COST-BUDGET-TYPE,
# AGENT-DONE-TYPE, AGENT-EXECUTE-ALLOWED-TYPE, AGENT-FILE-ACCESS-TYPE,
# AGENT-ITERATION-TYPE, AGENT-MAX-ITERATIONS-TYPE, AGENT-TIME-BUDGET-TYPE
# and AGENT-TOKEN-BUDGET-TYPE and the :type-prescription rule AGENT-STATE-P.
# UPDATE-SATISFACTION is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN UPDATE-SATISFACTION ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:FORWARD-CHAINING AGENT-COST-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-DONE-TYPE)
#         (:FORWARD-CHAINING AGENT-EXECUTE-ALLOWED-TYPE)
#         (:FORWARD-CHAINING AGENT-FILE-ACCESS-TYPE)
#         (:FORWARD-CHAINING AGENT-ITERATION-TYPE)
#         (:FORWARD-CHAINING AGENT-MAX-ITERATIONS-TYPE)
#         (:FORWARD-CHAINING AGENT-TIME-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-TOKEN-BUDGET-TYPE)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P)
#         (:TYPE-PRESCRIPTION MAKE-AGENT-STATE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  UPDATE-SATISFACTION

# %%
(defthm update-satisfaction-valid
  (implies (and (agent-state-p st)
                (rationalp new-score)
                (<= 0 new-score)
                (<= new-score 1))
           (agent-state-p (update-satisfaction st new-score))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM UPDATE-SATISFACTION-VALID ...):
# A :REWRITE rule generated from UPDATE-SATISFACTION-VALID will be triggered
# only by terms containing the function symbols AGENT-STATE-P and
# UPDATE-SATISFACTION, which have non-recursive definitions.  Unless
# these definitions are disabled, this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of UPDATE-SATISFACTION-VALID depends upon the :type-prescription
# rule AGENT-STATE-P.
#
# Summary
# Form:  ( DEFTHM UPDATE-SATISFACTION-VALID ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-COST-BUDGET)
#         (:DEFINITION AGENT-DONE)
#         (:DEFINITION AGENT-EXECUTE-ALLOWED)
#         (:DEFINITION AGENT-FILE-ACCESS)
#         (:DEFINITION AGENT-ITERATION)
#         (:DEFINITION AGENT-MAX-ITERATIONS)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION AGENT-TIME-BUDGET)
#         (:DEFINITION AGENT-TOKEN-BUDGET)
#         (:DEFINITION LEN)
#         (:DEFINITION MAKE-AGENT-STATE)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION NTH)
#         (:DEFINITION UPDATE-SATISFACTION)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART LEN)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE CDR-CONS)
#         (:REWRITE NTH-0-CONS)
#         (:REWRITE NTH-ADD1)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  1753
#  UPDATE-SATISFACTION-VALID

# %%
; Mark agent as done
(defun mark-done (st)
  (declare (xargs :guard (agent-state-p st)))
  (make-agent-state
   (agent-iteration st)
   (agent-max-iterations st)
   (agent-token-budget st)
   (agent-cost-budget st)
   (agent-time-budget st)
   (agent-file-access st)
   (agent-execute-allowed st)
   (agent-satisfaction st)
   t))
# Out:
# Since MARK-DONE is non-recursive, its admission is trivial.  We observe
# that the type of MARK-DONE is described by the theorem
# (AND (CONSP (MARK-DONE ST)) (TRUE-LISTP (MARK-DONE ST))).  We used
# the :type-prescription rule MAKE-AGENT-STATE.
#
# Computing the guard conjecture for MARK-DONE....
#
# The guard conjecture for MARK-DONE is trivial to prove, given the :compound-
# recognizer rules BOOLEANP-COMPOUND-RECOGNIZER and NATP-COMPOUND-RECOGNIZER,
# the :executable-counterpart of BOOLEANP, the :forward-chaining rules
# AGENT-COST-BUDGET-TYPE, AGENT-EXECUTE-ALLOWED-TYPE, AGENT-FILE-ACCESS-TYPE,
# AGENT-ITERATION-TYPE, AGENT-MAX-ITERATIONS-TYPE, AGENT-SATISFACTION-TYPE,
# AGENT-TIME-BUDGET-TYPE and AGENT-TOKEN-BUDGET-TYPE and the :type-prescription
# rule AGENT-STATE-P.  MARK-DONE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MARK-DONE ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:EXECUTABLE-COUNTERPART BOOLEANP)
#         (:FORWARD-CHAINING AGENT-COST-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-EXECUTE-ALLOWED-TYPE)
#         (:FORWARD-CHAINING AGENT-FILE-ACCESS-TYPE)
#         (:FORWARD-CHAINING AGENT-ITERATION-TYPE)
#         (:FORWARD-CHAINING AGENT-MAX-ITERATIONS-TYPE)
#         (:FORWARD-CHAINING AGENT-SATISFACTION-TYPE)
#         (:FORWARD-CHAINING AGENT-TIME-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-TOKEN-BUDGET-TYPE)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P)
#         (:TYPE-PRESCRIPTION MAKE-AGENT-STATE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MARK-DONE

# %%
(defthm mark-done-valid
  (implies (agent-state-p st)
           (agent-state-p (mark-done st))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM MARK-DONE-VALID ...):  A :REWRITE
# rule generated from MARK-DONE-VALID will be triggered only by terms
# containing the function symbols AGENT-STATE-P and MARK-DONE, which
# have non-recursive definitions.  Unless these definitions are disabled,
# this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of MARK-DONE-VALID depends upon the :type-prescription
# rule AGENT-STATE-P.
#
# Summary
# Form:  ( DEFTHM MARK-DONE-VALID ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-COST-BUDGET)
#         (:DEFINITION AGENT-EXECUTE-ALLOWED)
#         (:DEFINITION AGENT-FILE-ACCESS)
#         (:DEFINITION AGENT-ITERATION)
#         (:DEFINITION AGENT-MAX-ITERATIONS)
#         (:DEFINITION AGENT-SATISFACTION)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION AGENT-TIME-BUDGET)
#         (:DEFINITION AGENT-TOKEN-BUDGET)
#         (:DEFINITION LEN)
#         (:DEFINITION MAKE-AGENT-STATE)
#         (:DEFINITION MARK-DONE)
#         (:DEFINITION NATP)
#         (:DEFINITION NTH)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART BOOLEANP)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART LEN)
#         (:EXECUTABLE-COUNTERPART NTH)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE CDR-CONS)
#         (:REWRITE NTH-0-CONS)
#         (:REWRITE NTH-ADD1)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  1650
#  MARK-DONE-VALID

# %%
; Increment iteration (after LLM call)
(defun increment-iteration (st)
  (declare (xargs :guard (agent-state-p st)))
  (make-agent-state
   (1+ (agent-iteration st))
   (agent-max-iterations st)
   (agent-token-budget st)
   (agent-cost-budget st)
   (agent-time-budget st)
   (agent-file-access st)
   (agent-execute-allowed st)
   (agent-satisfaction st)
   (agent-done st)))
# Out:
# Since INCREMENT-ITERATION is non-recursive, its admission is trivial.
# We observe that the type of INCREMENT-ITERATION is described by the
# theorem
# (AND (CONSP (INCREMENT-ITERATION ST)) (TRUE-LISTP (INCREMENT-ITERATION ST))).
# We used the :type-prescription rule MAKE-AGENT-STATE.
#
# Computing the guard conjecture for INCREMENT-ITERATION....
#
# The guard conjecture for INCREMENT-ITERATION is trivial to prove, given
# the :compound-recognizer rules BOOLEANP-COMPOUND-RECOGNIZER and
# NATP-COMPOUND-RECOGNIZER, primitive type reasoning, the :forward-chaining
# rules AGENT-COST-BUDGET-TYPE, AGENT-DONE-TYPE, AGENT-EXECUTE-ALLOWED-TYPE,
# AGENT-FILE-ACCESS-TYPE, AGENT-ITERATION-TYPE, AGENT-MAX-ITERATIONS-TYPE,
# AGENT-SATISFACTION-TYPE, AGENT-TIME-BUDGET-TYPE and AGENT-TOKEN-BUDGET-TYPE
# and the :type-prescription rule AGENT-STATE-P.  INCREMENT-ITERATION
# is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN INCREMENT-ITERATION ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:FORWARD-CHAINING AGENT-COST-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-DONE-TYPE)
#         (:FORWARD-CHAINING AGENT-EXECUTE-ALLOWED-TYPE)
#         (:FORWARD-CHAINING AGENT-FILE-ACCESS-TYPE)
#         (:FORWARD-CHAINING AGENT-ITERATION-TYPE)
#         (:FORWARD-CHAINING AGENT-MAX-ITERATIONS-TYPE)
#         (:FORWARD-CHAINING AGENT-SATISFACTION-TYPE)
#         (:FORWARD-CHAINING AGENT-TIME-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-TOKEN-BUDGET-TYPE)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P)
#         (:TYPE-PRESCRIPTION MAKE-AGENT-STATE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  INCREMENT-ITERATION

# %%
(defthm increment-iteration-valid
  (implies (agent-state-p st)
           (agent-state-p (increment-iteration st))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM INCREMENT-ITERATION-VALID ...):
# A :REWRITE rule generated from INCREMENT-ITERATION-VALID will be triggered
# only by terms containing the function symbols AGENT-STATE-P and
# INCREMENT-ITERATION, which have non-recursive definitions.  Unless
# these definitions are disabled, this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of INCREMENT-ITERATION-VALID depends upon the :type-prescription
# rule AGENT-STATE-P.
#
# Summary
# Form:  ( DEFTHM INCREMENT-ITERATION-VALID ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-COST-BUDGET)
#         (:DEFINITION AGENT-DONE)
#         (:DEFINITION AGENT-EXECUTE-ALLOWED)
#         (:DEFINITION AGENT-FILE-ACCESS)
#         (:DEFINITION AGENT-ITERATION)
#         (:DEFINITION AGENT-MAX-ITERATIONS)
#         (:DEFINITION AGENT-SATISFACTION)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION AGENT-TIME-BUDGET)
#         (:DEFINITION AGENT-TOKEN-BUDGET)
#         (:DEFINITION INCREMENT-ITERATION)
#         (:DEFINITION LEN)
#         (:DEFINITION MAKE-AGENT-STATE)
#         (:DEFINITION NATP)
#         (:DEFINITION NTH)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART LEN)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE CDR-CONS)
#         (:REWRITE NTH-0-CONS)
#         (:REWRITE NTH-ADD1)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  1810
#  INCREMENT-ITERATION-VALID

# %%
(defthm increment-iteration-increases
  (implies (agent-state-p st)
           (< (agent-iteration st)
              (agent-iteration (increment-iteration st)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM INCREMENT-ITERATION-INCREASES ...):
# A :REWRITE rule generated from INCREMENT-ITERATION-INCREASES will be
# triggered only by terms containing the function symbols AGENT-ITERATION
# and INCREMENT-ITERATION, which have non-recursive definitions.  Unless
# these definitions are disabled, this rule is unlikely ever to be used.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM INCREMENT-ITERATION-INCREASES ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-COST-BUDGET)
#         (:DEFINITION AGENT-DONE)
#         (:DEFINITION AGENT-EXECUTE-ALLOWED)
#         (:DEFINITION AGENT-FILE-ACCESS)
#         (:DEFINITION AGENT-ITERATION)
#         (:DEFINITION AGENT-MAX-ITERATIONS)
#         (:DEFINITION AGENT-SATISFACTION)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION AGENT-TIME-BUDGET)
#         (:DEFINITION AGENT-TOKEN-BUDGET)
#         (:DEFINITION INCREMENT-ITERATION)
#         (:DEFINITION MAKE-AGENT-STATE)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION NTH)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:REWRITE NTH-0-CONS))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  1143
#  INCREMENT-ITERATION-INCREASES

# %% [raw]
# ;;; ==========================================================================
# ;;; Part 8: Continue vs Respond Decision
# ;;; ==========================================================================

# %%
; Minimum budget thresholds
(defconst *min-llm-tokens* 100)
(defconst *min-iteration-cost* 10)
(defconst *min-iteration-time* 1000)
(defconst *satisfaction-threshold* 9/10)
# Out:
# Summary
# Form:  ( DEFCONST *MIN-LLM-TOKENS* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *MIN-LLM-TOKENS*
#
# Summary
# Form:  ( DEFCONST *MIN-ITERATION-COST* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *MIN-ITERATION-COST*
#
# Summary
# Form:  ( DEFCONST *MIN-ITERATION-TIME* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *MIN-ITERATION-TIME*
#
# Summary
# Form:  ( DEFCONST *SATISFACTION-THRESHOLD* ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  *SATISFACTION-THRESHOLD*

# %%
; Must respond: no budget for another iteration OR done OR max iterations
(defun must-respond-p (st)
  (declare (xargs :guard (agent-state-p st)))
  (or (agent-done st)
      (>= (agent-iteration st) (agent-max-iterations st))
      (< (agent-token-budget st) *min-llm-tokens*)
      (< (agent-cost-budget st) *min-iteration-cost*)
      (< (agent-time-budget st) *min-iteration-time*)))
# Out:
# Since MUST-RESPOND-P is non-recursive, its admission is trivial.  We
# could deduce no constraints on the type of MUST-RESPOND-P.
#
# Computing the guard conjecture for MUST-RESPOND-P....
#
# The guard conjecture for MUST-RESPOND-P is trivial to prove, given
# the :compound-recognizer rule NATP-COMPOUND-RECOGNIZER, the :forward-
# chaining rules AGENT-COST-BUDGET-TYPE, AGENT-ITERATION-TYPE,
# AGENT-MAX-ITERATIONS-TYPE, AGENT-TIME-BUDGET-TYPE and AGENT-TOKEN-BUDGET-TYPE
# and the :type-prescription rule AGENT-STATE-P.  MUST-RESPOND-P is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN MUST-RESPOND-P ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:FORWARD-CHAINING AGENT-COST-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-ITERATION-TYPE)
#         (:FORWARD-CHAINING AGENT-MAX-ITERATIONS-TYPE)
#         (:FORWARD-CHAINING AGENT-TIME-BUDGET-TYPE)
#         (:FORWARD-CHAINING AGENT-TOKEN-BUDGET-TYPE)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MUST-RESPOND-P

# %%
; Should continue: has budget and below satisfaction threshold
(defun should-continue-p (st)
  (declare (xargs :guard (agent-state-p st)))
  (and (not (must-respond-p st))
       (< (agent-satisfaction st) *satisfaction-threshold*)))
# Out:
# Since SHOULD-CONTINUE-P is non-recursive, its admission is trivial.
# We observe that the type of SHOULD-CONTINUE-P is described by the theorem
# (OR (EQUAL (SHOULD-CONTINUE-P ST) T) (EQUAL (SHOULD-CONTINUE-P ST) NIL)).
#
# Computing the guard conjecture for SHOULD-CONTINUE-P....
#
# The guard conjecture for SHOULD-CONTINUE-P is trivial to prove, given
# the :forward-chaining rule AGENT-SATISFACTION-TYPE and the :type-prescription
# rule AGENT-STATE-P.  SHOULD-CONTINUE-P is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SHOULD-CONTINUE-P ...)
# Rules: ((:FORWARD-CHAINING AGENT-SATISFACTION-TYPE)
#         (:TYPE-PRESCRIPTION AGENT-STATE-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  SHOULD-CONTINUE-P

# %% [raw]
# ;;; ==========================================================================
# ;;; Part 9: Key Theorems
# ;;; ==========================================================================

# %%
; Theorem: Permission safety - can-invoke-tool-p implies tool-permitted-p
(defthm permission-safety
  (implies (and (agent-state-p st)
                (tool-spec-p tool)
                (can-invoke-tool-p st tool))
           (tool-permitted-p (tool-required-access tool)
                             (tool-requires-execute tool)
                             (agent-file-access st)
                             (agent-execute-allowed st))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM PERMISSION-SAFETY ...):  A :REWRITE
# rule generated from PERMISSION-SAFETY will be triggered only by terms
# containing the function symbols TOOL-PERMITTED-P, TOOL-REQUIRED-ACCESS,
# TOOL-REQUIRES-EXECUTE, AGENT-FILE-ACCESS and AGENT-EXECUTE-ALLOWED,
# which have non-recursive definitions.  Unless these definitions are
# disabled, this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of PERMISSION-SAFETY depends upon the :type-prescription
# rule TOOL-PERMITTED-P.
#
# Summary
# Form:  ( DEFTHM PERMISSION-SAFETY ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION ACCESS-SUFFICIENT-P)
#         (:DEFINITION AGENT-COST-BUDGET)
#         (:DEFINITION AGENT-EXECUTE-ALLOWED)
#         (:DEFINITION AGENT-FILE-ACCESS)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION AGENT-TIME-BUDGET)
#         (:DEFINITION AGENT-TOKEN-BUDGET)
#         (:DEFINITION CAN-INVOKE-TOOL-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NTH)
#         (:DEFINITION TOOL-BASE-COST)
#         (:DEFINITION TOOL-BUDGET-SUFFICIENT-P)
#         (:DEFINITION TOOL-PERMITTED-P)
#         (:DEFINITION TOOL-REQUIRED-ACCESS)
#         (:DEFINITION TOOL-REQUIRES-EXECUTE)
#         (:DEFINITION TOOL-SPEC-P)
#         (:DEFINITION TOOL-TIME-ESTIMATE)
#         (:DEFINITION TOOL-TOKEN-ESTIMATE)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:TYPE-PRESCRIPTION TOOL-PERMITTED-P))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  1762
#  PERMISSION-SAFETY

# %%
; Theorem: Budget non-negativity after tool deduction
(defthm tool-deduction-preserves-budget-nonneg
  (implies (and (agent-state-p st)
                (tool-spec-p tool))
           (and (natp (agent-token-budget (deduct-tool-cost st tool)))
                (natp (agent-cost-budget (deduct-tool-cost st tool)))
                (natp (agent-time-budget (deduct-tool-cost st tool))))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM TOOL-DEDUCTION-PRESERVES-BUDGET-NONNEG
# ...):  A :REWRITE rule generated from TOOL-DEDUCTION-PRESERVES-BUDGET-NONNEG
# will be triggered only by terms containing the function symbols NATP,
# AGENT-TOKEN-BUDGET and DEDUCT-TOOL-COST, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
#
# ACL2 Warning [Non-rec] in ( DEFTHM TOOL-DEDUCTION-PRESERVES-BUDGET-NONNEG
# ...):  A :REWRITE rule generated from TOOL-DEDUCTION-PRESERVES-BUDGET-NONNEG
# will be triggered only by terms containing the function symbols NATP,
# AGENT-COST-BUDGET and DEDUCT-TOOL-COST, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
#
# ACL2 Warning [Non-rec] in ( DEFTHM TOOL-DEDUCTION-PRESERVES-BUDGET-NONNEG
# ...):  A :REWRITE rule generated from TOOL-DEDUCTION-PRESERVES-BUDGET-NONNEG
# will be triggered only by terms containing the function symbols NATP,
# AGENT-TIME-BUDGET and DEDUCT-TOOL-COST, which have non-recursive definitions.
# Unless these definitions are disabled, this rule is unlikely ever to
# be used.
#
# Goal'
#
# Q.E.D.
#
# The storage of TOOL-DEDUCTION-PRESERVES-BUDGET-NONNEG depends upon
# the :compound-recognizer rule NATP-COMPOUND-RECOGNIZER and the :type-
# prescription rule NATP.
#
# Summary
# Form:  ( DEFTHM TOOL-DEDUCTION-PRESERVES-BUDGET-NONNEG ...)
# Rules: ((:COMPOUND-RECOGNIZER NATP-COMPOUND-RECOGNIZER)
#         (:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-COST-BUDGET)
#         (:DEFINITION AGENT-DONE)
#         (:DEFINITION AGENT-EXECUTE-ALLOWED)
#         (:DEFINITION AGENT-FILE-ACCESS)
#         (:DEFINITION AGENT-ITERATION)
#         (:DEFINITION AGENT-MAX-ITERATIONS)
#         (:DEFINITION AGENT-SATISFACTION)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION AGENT-TIME-BUDGET)
#         (:DEFINITION AGENT-TOKEN-BUDGET)
#         (:DEFINITION DEDUCT-TOOL-COST)
#         (:DEFINITION MAKE-AGENT-STATE)
#         (:DEFINITION NATP)
#         (:DEFINITION NFIX)
#         (:DEFINITION NTH)
#         (:DEFINITION TOOL-BASE-COST)
#         (:DEFINITION TOOL-SPEC-P)
#         (:DEFINITION TOOL-TIME-ESTIMATE)
#         (:DEFINITION TOOL-TOKEN-ESTIMATE)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE NTH-0-CONS)
#         (:REWRITE NTH-ADD1)
#         (:TYPE-PRESCRIPTION NATP))
# Warnings:  Non-rec
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# Prover steps counted:  2039
#  TOOL-DEDUCTION-PRESERVES-BUDGET-NONNEG

# %%
; Theorem: Iteration strictly increases
(defthm iteration-increases
  (implies (agent-state-p st)
           (< (agent-iteration st)
              (agent-iteration (increment-iteration st)))))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM ITERATION-INCREASES ...):  A :REWRITE
# rule generated from ITERATION-INCREASES will be triggered only by terms
# containing the function symbols AGENT-ITERATION and INCREMENT-ITERATION,
# which have non-recursive definitions.  Unless these definitions are
# disabled, this rule is unlikely ever to be used.
#
#
# ACL2 Warning [Subsume] in ( DEFTHM ITERATION-INCREASES ...):  A newly
# proposed :REWRITE rule generated from ITERATION-INCREASES probably
# subsumes the previously added :REWRITE rule INCREMENT-ITERATION-INCREASES,
# in the sense that the new rule will now probably be applied whenever
# the old rule would have been.
#
#
# ACL2 Warning [Subsume] in ( DEFTHM ITERATION-INCREASES ...):  The previously
# added rule INCREMENT-ITERATION-INCREASES subsumes a newly proposed
# :REWRITE rule generated from ITERATION-INCREASES, in the sense that
# the old rule rewrites a more general target.  Because the new rule
# will be tried first, it may nonetheless find application.
#
# Goal'
# Goal''
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM ITERATION-INCREASES ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-COST-BUDGET)
#         (:DEFINITION AGENT-DONE)
#         (:DEFINITION AGENT-EXECUTE-ALLOWED)
#         (:DEFINITION AGENT-FILE-ACCESS)
#         (:DEFINITION AGENT-ITERATION)
#         (:DEFINITION AGENT-MAX-ITERATIONS)
#         (:DEFINITION AGENT-SATISFACTION)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION AGENT-TIME-BUDGET)
#         (:DEFINITION AGENT-TOKEN-BUDGET)
#         (:DEFINITION INCREMENT-ITERATION)
#         (:DEFINITION MAKE-AGENT-STATE)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION NTH)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:EXECUTABLE-COUNTERPART ZP)
#         (:REWRITE NTH-0-CONS))
# Warnings:  Subsume and Non-rec
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  1143
#  ITERATION-INCREASES

# %%
; Theorem: After enough iterations, must-respond becomes true
; (Termination guarantee via iteration bound)
(defthm termination-by-iteration
  (implies (and (agent-state-p st)
                (>= (agent-iteration st) (agent-max-iterations st)))
           (must-respond-p st)))
# Out:
# ACL2 Warning [Non-rec] in ( DEFTHM TERMINATION-BY-ITERATION ...):
# A :REWRITE rule generated from TERMINATION-BY-ITERATION will be triggered
# only by terms containing the function symbol MUST-RESPOND-P, which
# has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM TERMINATION-BY-ITERATION ...)
# Rules: ((:DEFINITION ACCESS-LEVEL-P)
#         (:DEFINITION AGENT-DONE)
#         (:DEFINITION AGENT-ITERATION)
#         (:DEFINITION AGENT-MAX-ITERATIONS)
#         (:DEFINITION AGENT-STATE-P)
#         (:DEFINITION MUST-RESPOND-P)
#         (:DEFINITION NATP)
#         (:DEFINITION NOT)
#         (:DEFINITION NTH)
#         (:EXECUTABLE-COUNTERPART ZP))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  825
#  TERMINATION-BY-ITERATION
