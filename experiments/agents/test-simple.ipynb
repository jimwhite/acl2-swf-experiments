# %% [raw]
# ; Simple test file for acl2-mcp certification with FTY and SMTLink

# %%
(in-package "ACL2")
# Out:
#  "ACL2"

# %%
(include-book "centaur/fty/top" :dir :system)
(include-book "projects/smtlink/top" :dir :system :ttags :all)
# Out:
# Summary
# Form:  ( INCLUDE-BOOK "centaur/fty/top" ...)
# Rules: NIL
# Time:  0.44 seconds (prove: 0.00, print: 0.00, other: 0.44)
#  "/home/acl2/books/centaur/fty/top.lisp"
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP from book /home/acl2/books/quicklisp/base.
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP.SHELLPOOL from book /home/acl2/books/quicklisp/shellpool.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/projects/smtlink/trusted/run.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/projects/smtlink/trusted/write.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/projects/smtlink/trusted/prove.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/centaur/misc/tshell.
#
# TTAG NOTE (for included book): Adding ttag :READ-STRING from book /home/acl2/books/projects/smtlink/trusted/run.
#
# TTAG NOTE (for included book): Adding ttag :READ-STRING from book /home/acl2/books/std/io/read-string.
#
# TTAG NOTE (for included book): Adding ttag :WRITES-OKP from book /home/acl2/books/projects/smtlink/trusted/write.
#
# TTAG NOTE (for included book): Adding ttag :SMTLINK from book /home/acl2/books/projects/smtlink/trusted/trusted-cp.
#
# TTAG NOTE (for included book): Adding ttag :SMTLINK-CUSTOM from book /home/acl2/books/projects/smtlink/trusted/trusted-cp.
#
# Summary
# Form:  ( INCLUDE-BOOK "projects/smtlink/top" ...)
# Rules: NIL
# Time:  1.31 seconds (prove: 0.00, print: 0.00, other: 1.31)
#  "/home/acl2/books/projects/smtlink/top.lisp"

# %%
(value-triple (tshell-ensure))
# Out:
#  NIL

# %%
; Define a simple FTY product type
(fty::defprod point
  ((x-coord integerp :default 0)
   (y-coord integerp :default 0)))
# Out:
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TMP-DEFTYPES-INTEGERP-OF-IFIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM TMP-DEFTYPES-IFIX-WHEN-INTEGERP ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 5
# Subgoal 4
# Subgoal 4.2
# Subgoal 4.2.2
# Subgoal 4.2.2'
# Subgoal 4.2.1
# Subgoal 4.1
# Subgoal 4.1'
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Subgoal 1'
# Form:  ( DEFUN POINT-P ...)
# Time:  0.06 seconds (prove: 0.06, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CONSP-WHEN-POINT-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO POINT-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN POINT-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM POINT-P-OF-POINT-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM POINT-P-OF-POINT-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM POINT-FIX-WHEN-POINT-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
# Form:  ( VERIFY-GUARDS POINT-FIX$INLINE ...)
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (FTY::DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.03 seconds (prove: 0.02, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO POINT->X-COORD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN POINT->X-COORD$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM INTEGERP-OF-POINT->X-COORD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM INTEGERP-OF-POINT->X-COORD ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM POINT->X-COORD$INLINE-OF-POINT-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV POINT->X-COORD ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO POINT->Y-COORD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN POINT->Y-COORD$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM INTEGERP-OF-POINT->Y-COORD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM INTEGERP-OF-POINT->Y-COORD ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM POINT->Y-COORD$INLINE-OF-POINT-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV POINT->Y-COORD ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN POINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM POINT-P-OF-POINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM POINT-P-OF-POINT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM POINT->X-COORD-OF-POINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM POINT->Y-COORD-OF-POINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM POINT-OF-FIELDS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM POINT-FIX-WHEN-POINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 4
# Subgoal 4'
# Subgoal 4''
# Subgoal 4'''
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM EQUAL-OF-POINT ...)
# Time:  0.03 seconds (prove: 0.01, print: 0.00, other: 0.02)
# Goal'
# Form:  ( DEFTHM POINT-OF-IFIX-X-COORD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM POINT-OF-IFIX-Y-COORD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFMACRO PATBIND-POINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-POINT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-POINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-POINT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM POINT->X-COORD-OF-POINT ...) ...)
# Time:  0.04 seconds (prove: 0.02, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM POINT-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC POINT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC POINT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.23 seconds (prove: 0.10, print: 0.00, other: 0.13)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.24 seconds (prove: 0.10, print: 0.00, other: 0.14)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFPROD-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.24 seconds (prove: 0.10, print: 0.00, other: 0.14)
# Prover steps counted:  6156
#  T

# %%
; A simple function on points
(define point-sum ((p point-p))
  :returns (sum integerp)
  (+ (point->x-coord p) (point->y-coord p)))
# Out:
# Since POINT-SUM is non-recursive, its admission is trivial.  We observe
# that the type of POINT-SUM is described by the theorem
# (INTEGERP (POINT-SUM P)).  We used primitive type reasoning and the
# :type-prescription rules POINT->X-COORD$INLINE and POINT->Y-COORD$INLINE.
#
# Computing the guard conjecture for POINT-SUM....
#
# The guard conjecture for POINT-SUM is trivial to prove, given the :compound-
# recognizer rule CONSP-WHEN-POINT-P and the :type-prescription rules
# POINT->X-COORD$INLINE and POINT->Y-COORD$INLINE.  POINT-SUM is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN POINT-SUM ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-POINT-P)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION POINT->X-COORD$INLINE)
#         (:TYPE-PRESCRIPTION POINT->Y-COORD$INLINE))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# ACL2 !>>(DEFTHM INTEGERP-OF-POINT-SUM
#           (B* ((SUM (POINT-SUM P)))
#             (INTEGERP SUM))
#           :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'POINT-SUM
#                                                         ID WORLD))
#           :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM INTEGERP-OF-POINT-SUM ...):  A :REWRITE
# rule generated from INTEGERP-OF-POINT-SUM will be triggered only by
# terms containing the function symbol POINT-SUM, which has a non-recursive
# definition.  Unless this definition is disabled, this rule is unlikely
# ever to be used.
#
#
# Q.E.D.
#
# The storage of INTEGERP-OF-POINT-SUM depends upon the :type-prescription
# rule POINT-SUM.
#
# Summary
# Form:  ( DEFTHM INTEGERP-OF-POINT-SUM ...)
# Rules: ((:TYPE-PRESCRIPTION POINT-SUM))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# INTEGERP-OF-POINT-SUM
#
# Summary
# Form:  ( PROGN (DEFTHM INTEGERP-OF-POINT-SUM ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  POINT-SUM

# %%
; A simple theorem (pure ACL2)
(defthm point-sum-type
  (implies (point-p p)
           (integerp (point-sum p))))
# Out:
# ACL2 Warning [Subsume] in ( DEFTHM POINT-SUM-TYPE ...):  The previously
# added rule INTEGERP-OF-POINT-SUM subsumes a newly proposed :REWRITE
# rule generated from POINT-SUM-TYPE, in the sense that the old rule
# rewrites a more general target.  Because the new rule will be tried
# first, it may nonetheless find application.
#
#
# Q.E.D.
#
# The storage of POINT-SUM-TYPE depends upon the :type-prescription rule
# POINT-SUM.
#
# Summary
# Form:  ( DEFTHM POINT-SUM-TYPE ...)
# Rules: ((:TYPE-PRESCRIPTION POINT-SUM))
# Warnings:  Subsume
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  POINT-SUM-TYPE

# %%
; A simple theorem using SMTLink
(defthm simple-arithmetic-smt
  (implies (and (integerp x)
                (integerp y)
                (< 0 x)
                (< 0 y))
           (< 0 (+ x y)))
  :hints (("Goal" :smtlink nil)))
# Out:
# Using clause-processor Smtlink
# Goal'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM SIMPLE-ARITHMETIC-SMT ...)
# Rules: ((:FAKE-RUNE-FOR-TYPE-SET NIL))
# Hint-events: ((:CLAUSE-PROCESSOR SMT::PROCESS-HINT))
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  SIMPLE-ARITHMETIC-SMT
