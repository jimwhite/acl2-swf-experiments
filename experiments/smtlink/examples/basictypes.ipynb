# %% [raw]
# ;; Copyright (C) 2015, University of British Columbia
# ;; Written by Yan Peng (May 2019)
# ;;
# ;; License: A 3-clause BSD license.
# ;; See the LICENSE file distributed with ACL2

# %%
(in-package "SMT")
(include-book "centaur/fty/top" :dir :system)
(include-book "centaur/sv/tutorial/support" :dir :system)
# Out:
#  "SMT"
#
# Summary
# Form:  ( INCLUDE-BOOK "centaur/fty/top" ...)
# Rules: NIL
# Time:  0.43 seconds (prove: 0.00, print: 0.00, other: 0.42)
#  "/home/acl2/books/centaur/fty/top.lisp"
#
# The event ( INCLUDE-BOOK "centaur/sv/tutorial/support" ...) is redundant.
# See :DOC redundant-events.
#
# Summary
# Form:  ( INCLUDE-BOOK "centaur/sv/tutorial/support" ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  :REDUNDANT

# %%
; Matt K. mod: Avoid ACL2(p) failure ("Exit code from ACL2 is 0")
(set-waterfall-parallelism nil)
# Out:
# ACL2 Observation in SET-WATERFALL-PARALLELISM:  Ignoring call to set-
# waterfall-parallelism since the new value is the same as the current
# value.
#
#  :IGNORED

# %% [raw]
# ;; BOZO: All basic FTY type definitions in the examples directory should
# ;; eventually be moved to this file.

# %%
(def-saved-event maybe-integer-example
  (defoption maybe-integer integerp
    :parents (tutorial))
  )
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'MAYBE-INTEGER-EXAMPLE
#          '(DEFOPTION MAYBE-INTEGER INTEGERP
#                      :PARENTS (TUTORIAL)))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFOPTION MAYBE-INTEGER INTEGERP
#                   :PARENTS (TUTORIAL))
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-INTEGERP-OF-IFIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-IFIX-WHEN-INTEGERP ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ACL2::ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MAYBE-INTEGER-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 2
# Subgoal 2'
# Form:  ( DEFTHM CONSP-WHEN-MAYBE-INTEGER-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# *** Note: No checkpoints to print. ***
#
# ACL2 Error [Failure] in ( DEFTHM CONSP-WHEN-MAYBE-INTEGER-P ...):
# See :DOC failure.
#
# ******** FAILED ********
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MAYBE-INTEGER-P-WHEN-INTEGERP ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM INTEGERP-WHEN-MAYBE-INTEGER-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAYBE-INTEGER-CASE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAYBE-INTEGER-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MAYBE-INTEGER-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM MAYBE-INTEGER-P-OF-MAYBE-INTEGER-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MAYBE-INTEGER-P-OF-MAYBE-INTEGER-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM MAYBE-INTEGER-FIX-WHEN-MAYBE-INTEGER-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS MAYBE-INTEGER-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (DEFFIXTYPE ... T) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( DEFTHM ACL2::DEFOPTION-LEMMA-IFIX-NONNIL
# ...):  The :DEFINITION rule for the built-in function CONS-WITH-HINT
# is disabled by the theory expression '((INTEGERP)), but some expansions
# of its calls may still occur.  See :DOC theories-and-primitives.
#
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM ACL2::DEFOPTION-LEMMA-IFIX-NONNIL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MAYBE-INTEGER-FIX-UNDER-IFF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MAYBE-INTEGER-EQUIV-REFINES-INT-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (ACL2::DEFREFINEMENT-FORM ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN MAYBE-INTEGER-NONE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM RETURN-TYPE-OF-MAYBE-INTEGER-NONE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-MAYBE-INTEGER-NONE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MAYBE-INTEGER-FIX-WHEN-NONE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Form:  ( DEFTHM EQUAL-OF-MAYBE-INTEGER-NONE ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFMACRO PATBIND-MAYBE-INTEGER-NONE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-MAYBE-INTEGER-NONE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-MAYBE-INTEGER-NONE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-MAYBE-INTEGER-NONE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MAYBE-INTEGER-FIX-WHEN-NONE ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAYBE-INTEGER-SOME->VAL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MAYBE-INTEGER-SOME->VAL$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM INTEGERP-OF-MAYBE-INTEGER-SOME->VAL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM INTEGERP-OF-MAYBE-INTEGER-SOME->VAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MAYBE-INTEGER-SOME->VAL$INLINE-OF-MAYBE-INTEGER-FIX-X
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM MAYBE-INTEGER-SOME->VAL-WHEN-WRONG-KIND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (FTY::DEFFIXEQUIV MAYBE-INTEGER-SOME->VAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN MAYBE-INTEGER-SOME ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM RETURN-TYPE-OF-MAYBE-INTEGER-SOME ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM RETURN-TYPE-OF-MAYBE-INTEGER-SOME ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM MAYBE-INTEGER-SOME->VAL-OF-MAYBE-INTEGER-SOME ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MAYBE-INTEGER-SOME-OF-FIELDS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MAYBE-INTEGER-FIX-WHEN-SOME ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 4
# Subgoal 3
# Subgoal 3'
# Subgoal 3''
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM EQUAL-OF-MAYBE-INTEGER-SOME ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MAYBE-INTEGER-SOME-OF-IFIX-VAL ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFMACRO PATBIND-MAYBE-INTEGER-SOME ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-MAYBE-INTEGER-SOME ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-MAYBE-INTEGER-SOME ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-MAYBE-INTEGER-SOME ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM MAYBE-INTEGER-SOME->VAL-OF-MAYBE-INTEGER-SOME
# ...) ...)
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM MAYBE-INTEGER-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC MAYBE-INTEGER ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC MAYBE-INTEGER ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE ACL2::XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.10 seconds (prove: 0.02, print: 0.00, other: 0.08)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.11 seconds (prove: 0.02, print: 0.00, other: 0.09)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFOPTION-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.11 seconds (prove: 0.02, print: 0.00, other: 0.09)
# Prover steps counted:  1714
# T
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Warnings:  Theory
# Time:  0.11 seconds (prove: 0.02, print: 0.00, other: 0.09)
# Prover steps counted:  1714
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.11 seconds (prove: 0.02, print: 0.00, other: 0.09)
# Prover steps counted:  1714
#  T
