# %% [raw]
# ;; Copyright (C) 2015, University of British Columbia
# ;; Written (originally) by Yan Peng (August 2nd 2016)
# ;;
# ;; License: A 3-clause BSD license.
# ;; See the LICENSE file distributed with ACL2

# %%
(in-package "SMT")
(include-book "projects/smtlink/top" :dir :system :ttags :all)
(include-book "centaur/sv/tutorial/support" :dir :system)
;; def-saved-event is a wrapper that is used by the documentation system,
;; and can be ignored by the reader.
;; Check the book centaur/sv/tutorial/support.lisp for detailed explanation.
(include-book "basictypes")
# Out:
#  "SMT"
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP from book /home/acl2/books/quicklisp/base.
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP.SHELLPOOL from book /home/acl2/books/quicklisp/shellpool.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/projects/smtlink/trusted/run.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/projects/smtlink/trusted/write.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/projects/smtlink/trusted/prove.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/centaur/misc/tshell.
#
# TTAG NOTE (for included book): Adding ttag :READ-STRING from book /home/acl2/books/projects/smtlink/trusted/run.
#
# TTAG NOTE (for included book): Adding ttag :READ-STRING from book /home/acl2/books/std/io/read-string.
#
# TTAG NOTE (for included book): Adding ttag :WRITES-OKP from book /home/acl2/books/projects/smtlink/trusted/write.
#
# TTAG NOTE (for included book): Adding ttag :SMTLINK from book /home/acl2/books/projects/smtlink/trusted/trusted-cp.
#
# TTAG NOTE (for included book): Adding ttag :SMTLINK-CUSTOM from book /home/acl2/books/projects/smtlink/trusted/trusted-cp.
#
# Summary
# Form:  ( INCLUDE-BOOK "projects/smtlink/top" ...)
# Rules: NIL
# Time:  1.47 seconds (prove: 0.00, print: 0.00, other: 1.47)
#  "/home/acl2/books/projects/smtlink/top.lisp"
#
# The event ( INCLUDE-BOOK "centaur/sv/tutorial/support" ...) is redundant.
# See :DOC redundant-events.
#
# Summary
# Form:  ( INCLUDE-BOOK "centaur/sv/tutorial/support" ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  :REDUNDANT
#
# ACL2 Warning [Compiled file] in ( INCLUDE-BOOK "basictypes" ...):
# Unable to load compiled file for book
#   /workspaces/acl2-swf-experiments/experiments/smtlink/examples/basictypes.lis\
# p
# because that book is not certified.  See :DOC include-book.  No load
# was in progress for any parent book.
#
#
# ACL2 Warning [Uncertified] in ( INCLUDE-BOOK "basictypes" ...):  There
# is no certificate on file for
# "/workspaces/acl2-swf-experiments/experiments/smtlink/examples/basictypes.lisp".
# See :DOC uncertified-books.
#
#
# ACL2 Observation in ( DEFTHM CONSP-WHEN-MAYBE-INTEGER-P ...):  When
# (MAYBE-INTEGER-P ACL2::X) is assumed true, CONSP-WHEN-MAYBE-INTEGER-P
# will allow us to deduce (CONSP ACL2::X).  When (MAYBE-INTEGER-P ACL2::X)
# is assumed false, CONSP-WHEN-MAYBE-INTEGER-P will allow us to deduce
# nothing about the type of X.  Note that (MAYBE-INTEGER-P ACL2::X) is
# not a strong compound recognizer, according to this rule.  See doc
# :compound-recognizer if these observations surprise you.  These particular
# expressions of the type information are based on trivial observations.
# Goal'
# Subgoal 2
# Subgoal 2'
#
# *** Note: No checkpoints to print. ***
#
# ACL2 Error [Failure] in ( DEFTHM CONSP-WHEN-MAYBE-INTEGER-P ...):
# See :DOC failure.
#
# ******** FAILED ********
#
# Summary
# Form:  ( INCLUDE-BOOK "basictypes" ...)
# Rules: NIL
# Warnings:  Uncertified and Compiled file
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Prover steps counted:  56
#  "/workspaces/acl2-swf-experiments/experiments/smtlink/examples/basictypes.lisp"

# %% [raw]
# ; cert_param: (uses-smtlink)

# %%
(value-triple (tshell-ensure))
(add-default-hints '((SMT::SMT-computed-hint clause)))
# Out:
#  NIL
#  ((SMT-COMPUTED-HINT CLAUSE)
#   (SET::PICK-A-POINT-SUBSET-HINT ID CLAUSE
#                                  WORLD STABLE-UNDER-SIMPLIFICATIONP))

# %%
;; Example 1
(def-saved-event x^2-y^2
  (defun x^2-y^2 (x y) (- (* x x) (* y y))))
(def-saved-event x^2+y^2
  (defun x^2+y^2 (x y) (+ (* x x) (* y y))))
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'X^2-Y^2
#          '(DEFUN X^2-Y^2 (X Y)
#             (- (* X X) (* Y Y))))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFUN X^2-Y^2 (X Y)
#          (- (* X X) (* Y Y)))
#
# Since X^2-Y^2 is non-recursive, its admission is trivial.  We observe
# that the type of X^2-Y^2 is described by the theorem
# (ACL2-NUMBERP (X^2-Y^2 X Y)).  We used primitive type reasoning.
#
# Summary
# Form:  ( DEFUN X^2-Y^2 ...)
# Rules: ((:FAKE-RUNE-FOR-TYPE-SET NIL))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# X^2-Y^2
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  X^2-Y^2
#
#
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'X^2+Y^2
#          '(DEFUN X^2+Y^2 (X Y)
#             (+ (* X X) (* Y Y))))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFUN X^2+Y^2 (X Y)
#          (+ (* X X) (* Y Y)))
#
# Since X^2+Y^2 is non-recursive, its admission is trivial.  We observe
# that the type of X^2+Y^2 is described by the theorem
# (ACL2-NUMBERP (X^2+Y^2 X Y)).  We used primitive type reasoning.
#
# Summary
# Form:  ( DEFUN X^2+Y^2 ...)
# Rules: ((:FAKE-RUNE-FOR-TYPE-SET NIL))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# X^2+Y^2
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  X^2+Y^2

# %%
(def-saved-event poly-ineq
  (defthm poly-ineq-example
    (implies (and (real/rationalp x) (real/rationalp y)
                  (<= (+ (* (/ 9 8) x x) (* y y)) 1)
                  (<=  (x^2-y^2 x y) 1))
             (< y (- (* 3 (- x (/ 17 8)) (- x (/ 17 8))) 3)))
    :hints(("Goal"
            :smtlink nil)))
  )
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'POLY-INEQ
#          '(DEFTHM POLY-INEQ-EXAMPLE
#             (IMPLIES (AND (REAL/RATIONALP X)
#                           (REAL/RATIONALP Y)
#                           (<= (+ (* (/ 9 8) X X) (* Y Y)) 1)
#                           (<= (X^2-Y^2 X Y) 1))
#                      (< Y
#                         (- (* 3 (- X (/ 17 8)) (- X (/ 17 8)))
#                            3)))
#             :HINTS (("Goal" :SMTLINK NIL))))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFTHM POLY-INEQ-EXAMPLE
#          (IMPLIES (AND (REAL/RATIONALP X)
#                        (REAL/RATIONALP Y)
#                        (<= (+ (* (/ 9 8) X X) (* Y Y)) 1)
#                        (<= (X^2-Y^2 X Y) 1))
#                   (< Y
#                      (- (* 3 (- X (/ 17 8)) (- X (/ 17 8)))
#                         3)))
#          :HINTS (("Goal" :SMTLINK NIL)))
#
#
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
# Using default SMT-trusted-cp...
# ; SMT solver: `python /tmp/py_file/smtlink.U0zbT`: 0.07 sec, 65,616 bytes
# Proved!
# Subgoal 2.2'4'
# Subgoal 2.2'5'
# Subgoal 2.1
# Subgoal 2.1'
# Subgoal 2.1''
# Subgoal 2.1'''
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM POLY-INEQ-EXAMPLE ...)
# Rules: ((:DEFINITION HIDE)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:DEFINITION TYPE-HYP)
#         (:DEFINITION X^2-Y^2)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART ACL2::BOOLEAN-LIST-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:EXECUTABLE-COUNTERPART UNARY-/)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE ASSOCIATIVITY-OF-+)
#         (:REWRITE ACL2::COMMUTATIVITY-2-OF-+)
#         (:REWRITE COMMUTATIVITY-OF-*)
#         (:REWRITE COMMUTATIVITY-OF-+)
#         (:REWRITE DISTRIBUTIVITY)
#         (:REWRITE ACL2::FOLD-CONSTS-IN-+))
# Hint-events: ((:CLAUSE-PROCESSOR ADD-HYPO-CP)
#               (:CLAUSE-PROCESSOR EXPAND-CP-FN)
#               (:CLAUSE-PROCESSOR PROCESS-HINT)
#               (:CLAUSE-PROCESSOR REMOVE-HINT-PLEASE)
#               (:CLAUSE-PROCESSOR SMT-TRUSTED-CP)
#               (:CLAUSE-PROCESSOR TYPE-EXTRACT-FN)
#               (:CLAUSE-PROCESSOR UNINTERPRETED-FN-CP))
# Time:  0.07 seconds (prove: 0.07, print: 0.00, other: 0.00)
# Prover steps counted:  1383
# POLY-INEQ-EXAMPLE
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Time:  0.08 seconds (prove: 0.07, print: 0.00, other: 0.00)
# Prover steps counted:  1383
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Time:  0.08 seconds (prove: 0.07, print: 0.00, other: 0.00)
# Prover steps counted:  1383
#  POLY-INEQ-EXAMPLE

# %%
(deftutorial Example-1
  :parents (Tutorial)
  :short "Example 1: the basics"
  :long "<h3>Example 1</h3>
<p>Prerequisite read for this tutorial example is @(tsee tutorial).</p>
<p>The first example is a basic polynomial inequality.  Let's say we want to
prove below theorem:</p>

<box>
<p>
<b><color rgb='#323cbe'>Theorem 1.</color></b>
@($\\forall x\\in R$) and @($\\forall y \\in R$), if @($ \\frac{9x^2}{8}+y^2 \\le 1$) and
@($ x^2-y^2 \\le 1$), then @($ y < 3(x-\\frac{17}{8})^2 - 3$).
</p>
</box>

<p>Suppose we've defined a function called @('x^2-y^2') like below:</p>

@(`(:code ($ x^2-y^2))`)

<p>We define our theorem as:</p>

@(`(:code ($ poly-ineq))`)

<p>Smtlink should just prove this inequality without any problem.</p>
<p>Like is shown in the example, @(':smtlink') can be provided as a hint in the
standard @(see acl2::hints) in ACL2.  In the most basic cases where Smtlink
handles everything, no @(see smt-hint) are required to be provided, Hence
@(':smtlink nil').</p>

<p>The output of this defthm should look similar to:</p>

@({
Using clause-processor Smtlink
Goal'
Goal''
SMT-goal-generator=>Expanding ... X^2-Y^2
Subgoal 2
Subgoal 2.2
Subgoal 2.2'
Using default SMT-trusted-cp...
; SMT solver: `python /tmp/py_file/smtlink.w59zR`: 0.52 sec, 7,904 bytes
Proved!
Subgoal 2.2''
Subgoal 2.1
Subgoal 2.1'
Subgoal 1
Subgoal 1'

Summary
Form:  ( DEFTHM POLY-INEQ-EXAMPLE ...)
Rules: ((:DEFINITION HIDE)
        (:DEFINITION HINT-PLEASE)
        (:DEFINITION NOT)
        (:DEFINITION TYPE-HYP)
        (:DEFINITION X^2-Y^2)
        (:EXECUTABLE-COUNTERPART BINARY-*)
        (:EXECUTABLE-COUNTERPART ACL2::BOOLEAN-LIST-FIX$INLINE)
        (:EXECUTABLE-COUNTERPART CAR)
        (:EXECUTABLE-COUNTERPART CDR)
        (:EXECUTABLE-COUNTERPART CONS)
        (:EXECUTABLE-COUNTERPART CONSP)
        (:EXECUTABLE-COUNTERPART UNARY--)
        (:EXECUTABLE-COUNTERPART UNARY-/)
        (:FAKE-RUNE-FOR-TYPE-SET NIL)
        (:REWRITE ASSOCIATIVITY-OF-+)
        (:REWRITE ACL2::COMMUTATIVITY-2-OF-+)
        (:REWRITE COMMUTATIVITY-OF-*)
        (:REWRITE COMMUTATIVITY-OF-+)
        (:REWRITE DISTRIBUTIVITY)
        (:TYPE-PRESCRIPTION NONNEGATIVE-PRODUCT))
Hint-events: ((:CLAUSE-PROCESSOR ADD-HYPO-CP)
              (:CLAUSE-PROCESSOR EXPAND-CP-FN)
              (:CLAUSE-PROCESSOR PROCESS-HINT)
              (:CLAUSE-PROCESSOR SMT-TRUSTED-CP)
              (:CLAUSE-PROCESSOR TYPE-EXTRACT-FN)
              (:CLAUSE-PROCESSOR UNINTERPRETED-FN-CP))
Time:  0.60 seconds (prove: 0.60, print: 0.00, other: 0.00)
Prover steps counted:  1440
POLY-INEQ-EXAMPLE

})

<p>Smtlink is a sequence of clause processors controlled by a computed hint.
Calling smtlink from the @(':hints') put the theorem clause though a clause
processor looking for syntax errors in the @(see smt-hint).  If nothing wrong,
it will generate a term to be recognized by the computed-hint
@('SMT::SMT-computed-hint').  The computed-hint then installs the next-to-be
clause processor to work on the clause.  The next is the verified clause
processor for adding hypotheses. After that is the verified clause processor
for function expansion.</p>

<p>@('SMT-goal-generator=>Expanding ... X^2-Y^2') shows function expansion is
being conducted. </p>

<p>In this example, several subgoals are generated as a result of this clause
processor.  The first subgoal is the goal to be sent to the trusted clause
processor that transliterates the term into the corresponding SMT form and
writes it out to a file.  An SMT solver is called upon the file and results are
read back into ACL2.  Below are the outputs from this clause processor called
@('SMT-trusted-cp').
</p>

@({
Using default SMT-trusted-cp...
; SMT solver: `python /tmp/py_file/smtlink.w59zR`: 0.52 sec, 7,904 bytes
Proved!
})

<p>The second line tells the user what command is run to execute the SMT
solving.  \"Proved!\" indicates the SMT solver has successfully proved the
theorem.  When a theorem failed, a possible counter-example might be
provided in the form:</p>
@({
Possible counter-example found: ((X ...) (Y ...))
One can access it through global variable SMT-cex by doing (@ SMT-
cex).
})

<p>Other subgoals are auxiliary clauses generated by the verified
clause-processors. They help ensure the soundness of Smtlink.</p>
")

# %%
(def-saved-event smtconf-expt-tutorial
  (defun my-smtlink-expt-config ()
    (declare (xargs :guard t))
    (change-smtlink-config (default-smt-cnf)
                           :smt-module    "RewriteExpt"
                           :smt-class     "to_smt_w_expt")))
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'SMTCONF-EXPT-TUTORIAL
#          '(DEFUN MY-SMTLINK-EXPT-CONFIG NIL
#             (DECLARE (XARGS :GUARD T))
#             (CHANGE-SMTLINK-CONFIG (DEFAULT-SMT-CNF)
#                                    :SMT-MODULE "RewriteExpt"
#                                    :SMT-CLASS "to_smt_w_expt")))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFUN MY-SMTLINK-EXPT-CONFIG NIL
#          (DECLARE (XARGS :GUARD T))
#          (CHANGE-SMTLINK-CONFIG (DEFAULT-SMT-CNF)
#                                 :SMT-MODULE "RewriteExpt"
#                                 :SMT-CLASS "to_smt_w_expt"))
#
# Since MY-SMTLINK-EXPT-CONFIG is non-recursive, its admission is trivial.
# We observe that the type of MY-SMTLINK-EXPT-CONFIG is described by
# the theorem
# (AND (CONSP (MY-SMTLINK-EXPT-CONFIG)) (TRUE-LISTP (MY-SMTLINK-EXPT-CONFIG))).
# We used the :type-prescription rule SMTLINK-CONFIG.
#
# Computing the guard conjecture for MY-SMTLINK-EXPT-CONFIG....
#
# The guard conjecture for MY-SMTLINK-EXPT-CONFIG is trivial to prove,
# given the :executable-counterparts of DEFAULT-SMT-CNF,
# SMTLINK-CONFIG->INTERFACE-DIR$INLINE, SMTLINK-CONFIG->PYTHONPATH$INLINE,
# SMTLINK-CONFIG->SMT-CMD$INLINE, SMTLINK-CONFIG-P and STRINGP.
# MY-SMTLINK-EXPT-CONFIG is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN MY-SMTLINK-EXPT-CONFIG ...)
# Rules: ((:EXECUTABLE-COUNTERPART DEFAULT-SMT-CNF)
#         (:EXECUTABLE-COUNTERPART SMTLINK-CONFIG->INTERFACE-DIR$INLINE)
#         (:EXECUTABLE-COUNTERPART SMTLINK-CONFIG->PYTHONPATH$INLINE)
#         (:EXECUTABLE-COUNTERPART SMTLINK-CONFIG->SMT-CMD$INLINE)
#         (:EXECUTABLE-COUNTERPART SMTLINK-CONFIG-P)
#         (:EXECUTABLE-COUNTERPART STRINGP)
#         (:TYPE-PRESCRIPTION SMTLINK-CONFIG))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# MY-SMTLINK-EXPT-CONFIG
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  MY-SMTLINK-EXPT-CONFIG

# %%
(def-saved-event smtconf-expt-defattach-tutorial
  (defattach custom-smt-cnf my-smtlink-expt-config))
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'SMTCONF-EXPT-DEFATTACH-TUTORIAL
#          '(DEFATTACH CUSTOM-SMT-CNF MY-SMTLINK-EXPT-CONFIG))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFATTACH CUSTOM-SMT-CNF MY-SMTLINK-EXPT-CONFIG)
#
# The guard proof obligation is
#
# (IMPLIES T T).
#
# Q.E.D.
#
# This concludes the guard proof.
#
#
# We now prove that the attachment satisfies the required constraint.
# The goal to prove is
#
# (SMTLINK-CONFIG-P (MY-SMTLINK-EXPT-CONFIG)).
#
# Q.E.D.
#
# ACL2 Observation in ( DEFATTACH CUSTOM-SMT-CNF MY-SMTLINK-EXPT-CONFIG):
# The pre-existing attachment is being removed for function CUSTOM-SMT-CNF,
# before adding the requested attachment.
#
# Summary
# Form:  ( DEFATTACH CUSTOM-SMT-CNF MY-SMTLINK-EXPT-CONFIG)
# Rules: ((:EXECUTABLE-COUNTERPART MY-SMTLINK-EXPT-CONFIG)
#         (:EXECUTABLE-COUNTERPART SMTLINK-CONFIG-P))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  2
# :ATTACHMENTS-RECORDED
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  2
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  2
#  :ATTACHMENTS-RECORDED

# %%
;; Example 2
(def-saved-event poly-of-expt-example
  (encapsulate ()
    (local (include-book "arithmetic-5/top" :dir :system))
    (defthm poly-of-expt-example
      (implies (and (real/rationalp x) (real/rationalp y) (real/rationalp z)
                    (integerp m) (integerp n)
                    (< 0 z) (< z 1) (< 0 m) (< m n))
               (<= (* 2 (expt z n) x y)
                   (* (expt z m) (x^2+y^2 x y))))
      :hints (("Goal"
               :smtlink-custom (:functions ((expt :formals ((r real/rationalp)
                                                            (i real/rationalp))
                                                  :returns ((ex real/rationalp))
                                                  :level 0))
                                :hypotheses (((< (expt z n) (expt z m)))
                                             ((< 0 (expt z m)))
                                             ((< 0 (expt z n))))
                                :int-to-rat t)
      )))))
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#         'POLY-OF-EXPT-EXAMPLE
#         '(ENCAPSULATE NIL
#           (LOCAL (INCLUDE-BOOK "arithmetic-5/top"
#                                :DIR :SYSTEM))
#           (DEFTHM POLY-OF-EXPT-EXAMPLE
#            (IMPLIES (AND (REAL/RATIONALP X)
#                          (REAL/RATIONALP Y)
#                          (REAL/RATIONALP Z)
#                          (INTEGERP M)
#                          (INTEGERP N)
#                          (< 0 Z)
#                          (< Z 1)
#                          (< 0 M)
#                          (< M N))
#                     (<= (* 2 (EXPT Z N) X Y)
#                         (* (EXPT Z M) (X^2+Y^2 X Y))))
#            :HINTS
#            (("Goal"
#                  :SMTLINK-CUSTOM
#                  (:FUNCTIONS
#                       ((EXPT :FORMALS ((R REAL/RATIONALP) (I REAL/RATIONALP))
#                              :RETURNS ((EX REAL/RATIONALP))
#                              :LEVEL 0))
#                       :HYPOTHESES (((< (EXPT Z N) (EXPT Z M)))
#                                    ((< 0 (EXPT Z M)))
#                                    ((< 0 (EXPT Z N))))
#                       :INT-TO-RAT T))))))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(ENCAPSULATE NIL
#          (LOCAL (INCLUDE-BOOK "arithmetic-5/top"
#                               :DIR :SYSTEM))
#          (DEFTHM POLY-OF-EXPT-EXAMPLE
#            (IMPLIES (AND (REAL/RATIONALP X)
#                          (REAL/RATIONALP Y)
#                          (REAL/RATIONALP Z)
#                          (INTEGERP M)
#                          (INTEGERP N)
#                          (< 0 Z)
#                          (< Z 1)
#                          (< 0 M)
#                          (< M N))
#                     (<= (* 2 (EXPT Z N) X Y)
#                         (* (EXPT Z M) (X^2+Y^2 X Y))))
#            :HINTS
#            (("Goal"
#                  :SMTLINK-CUSTOM
#                  (:FUNCTIONS
#                       ((EXPT :FORMALS ((R REAL/RATIONALP) (I REAL/RATIONALP))
#                              :RETURNS ((EX REAL/RATIONALP))
#                              :LEVEL 0))
#                       :HYPOTHESES (((< (EXPT Z N) (EXPT Z M)))
#                                    ((< 0 (EXPT Z M)))
#                                    ((< 0 (EXPT Z N))))
#                       :INT-TO-RAT T)))))
#
# To verify that the two encapsulated events correctly extend the current
# theory we will evaluate them.  The theory thus constructed is only
# ephemeral.
#
# Encapsulated Events:
#
#
# SMT !>>(LOCAL (INCLUDE-BOOK "arithmetic-5/top"
#                             :DIR :SYSTEM))
#
# ACL2 Observation in NON-LINEAR-ARITHMETIC:  To turn on non-linear arithmetic,
# execute :
#
# (SET-DEFAULT-HINTS '((NONLINEARP-DEFAULT-HINT STABLE-UNDER-SIMPLIFICATIONP
#                                               HIST PSPV)))
#
# or :
#
# (SET-DEFAULT-HINTS
#      '((NONLINEARP-DEFAULT-HINT++ ID
#                                   STABLE-UNDER-SIMPLIFICATIONP HIST NIL)))
#
# See the README for more about non-linear arithmetic and general information
# about using this library.
#
# Summary
# Form:  ( INCLUDE-BOOK "arithmetic-5/top" ...)
# Rules: NIL
# Time:  0.19 seconds (prove: 0.00, print: 0.00, other: 0.19)
# "/home/acl2/books/arithmetic-5/top.lisp"
#
#
# SMT !>>(DEFTHM POLY-OF-EXPT-EXAMPLE
#         (IMPLIES (AND (REAL/RATIONALP X)
#                       (REAL/RATIONALP Y)
#                       (REAL/RATIONALP Z)
#                       (INTEGERP M)
#                       (INTEGERP N)
#                       (< 0 Z)
#                       (< Z 1)
#                       (< 0 M)
#                       (< M N))
#                  (<= (* 2 (EXPT Z N) X Y)
#                      (* (EXPT Z M) (X^2+Y^2 X Y))))
#         :HINTS
#         (("Goal"
#           :SMTLINK-CUSTOM
#           (:FUNCTIONS ((EXPT :FORMALS ((R REAL/RATIONALP) (I REAL/RATIONALP))
#                              :RETURNS ((EX REAL/RATIONALP))
#                              :LEVEL 0))
#                       :HYPOTHESES (((< (EXPT Z N) (EXPT Z M)))
#                                    ((< 0 (EXPT Z M)))
#                                    ((< 0 (EXPT Z N))))
#                       :INT-TO-RAT T))))
#
# ACL2 Warning [Non-rec] in ( DEFTHM POLY-OF-EXPT-EXAMPLE ...):  A :REWRITE
# rule generated from POLY-OF-EXPT-EXAMPLE will be triggered only by
# terms containing the function symbol X^2+Y^2, which has a non-recursive
# definition.  Unless this definition is disabled, this rule is unlikely
# ever to be used.
#
#
#
# Using clause-processor Smtlink (customized)
# Goal'
# Goal''
# Subgoal 4
# Subgoal 4'
# Subgoal 4.2
# Subgoal 4.2'
# Subgoal 4.2.2
# Subgoal 4.2.2'
# Subgoal 4.2.2.7
# Subgoal 4.2.2.7'
# Using custom SMT-trusted-cp...
# ; SMT solver: `python /tmp/py_file/smtlink.XiKi9`: 0.08 sec, 0 bytes
# Proved!
# Subgoal 4.2.2.7''
# Subgoal 4.2.2.7'''
# Subgoal 4.2.2.6
# Subgoal 4.2.2.6'
# Subgoal 4.2.2.6''
# Subgoal 4.2.2.6'''
# Subgoal 4.2.2.5
# Subgoal 4.2.2.5'
# Subgoal 4.2.2.5''
# Subgoal 4.2.2.5'''
# Subgoal 4.2.2.4
# Subgoal 4.2.2.4'
# Subgoal 4.2.2.4''
# Subgoal 4.2.2.4'''
# Subgoal 4.2.2.3
# Subgoal 4.2.2.3'
# Subgoal 4.2.2.3''
# Subgoal 4.2.2.3'''
# Subgoal 4.2.2.2
# Subgoal 4.2.2.2'
# Subgoal 4.2.2.2''
# Subgoal 4.2.2.2'''
# Subgoal 4.2.2.1
# Subgoal 4.2.2.1'
# Subgoal 4.2.2.1''
# Subgoal 4.2.2.1'''
# Subgoal 4.2.1
# Subgoal 4.2.1'
# Subgoal 4.2.1''
# Subgoal 4.2.1'''
# Subgoal 4.1
# Subgoal 4.1'
# Subgoal 4.1''
# Subgoal 4.1'''
# Subgoal 3
# Subgoal 3'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM POLY-OF-EXPT-EXAMPLE ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:CONGRUENCE ACL2::IFF-IMPLIES-EQUAL-BOOL-FIX-1)
#         (:DEFINITION HIDE)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:DEFINITION TYPE-HYP)
#         (:DEFINITION X^2+Y^2)
#         (:EXECUTABLE-COUNTERPART ACL2::BOOL-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART ACL2::BOOLEAN-LIST-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:LINEAR ACL2::EXPT-IS-DECREASING-FOR-POS-BASE-<-1)
#         (:REWRITE ACL2::|(* (expt x m) (expt x n))|)
#         (:REWRITE ACL2::|(* 1 x)|)
#         (:REWRITE ACL2::|(* x (+ y z))|)
#         (:REWRITE ACL2::|(* x x)|)
#         (:REWRITE ACL2::|(* y (* x z))|)
#         (:REWRITE ACL2::|(* y x)|)
#         (:REWRITE ACL2::|(+ x (- x))|)
#         (:REWRITE ACL2::|(expt x 0)|)
#         (:REWRITE ACL2::BOOL-FIX-WHEN-BOOLEANP)
#         (:REWRITE ACL2::BOOLEAN-LIST-FIX-OF-CONS)
#         (:REWRITE ACL2::BUBBLE-DOWN-*-MATCH-1)
#         (:REWRITE ACL2::BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE ACL2::DEFAULT-EXPT-2)
#         (:REWRITE ACL2::EXPT-IS-DECREASING-FOR-POS-BASE-<-1)
#         (:REWRITE ACL2::NORMALIZE-ADDENDS)
#         (:REWRITE ACL2::NORMALIZE-FACTORS-GATHER-EXPONENTS)
#         (:REWRITE ACL2::REMOVE-STRICT-INEQUALITIES)
#         (:REWRITE ACL2::SIMPLIFY-PRODUCTS-GATHER-EXPONENTS-<)
#         (:TYPE-PRESCRIPTION EXPT)
#         (:TYPE-PRESCRIPTION ACL2::EXPT-TYPE-PRESCRIPTION-NONNEGATIVE-BASE)
#         (:TYPE-PRESCRIPTION ACL2::EXPT-TYPE-PRESCRIPTION-POSITIVE-BASE)
#         (:TYPE-PRESCRIPTION ACL2::EXPT-TYPE-PRESCRIPTION-RATIONALP-BASE))
# Hint-events: ((:CLAUSE-PROCESSOR ADD-HYPO-CP)
#               (:CLAUSE-PROCESSOR EXPAND-CP-FN)
#               (:CLAUSE-PROCESSOR PROCESS-HINT)
#               (:CLAUSE-PROCESSOR REMOVE-HINT-PLEASE)
#               (:CLAUSE-PROCESSOR SMT-TRUSTED-CP-CUSTOM)
#               (:CLAUSE-PROCESSOR TYPE-EXTRACT-FN)
#               (:CLAUSE-PROCESSOR UNINTERPRETED-FN-CP))
# Warnings:  Non-rec
# Time:  0.32 seconds (prove: 0.32, print: 0.00, other: 0.00)
# Prover steps counted:  7776
# POLY-OF-EXPT-EXAMPLE
#
# End of Encapsulated Events.
#
# Having verified that the encapsulated events validate the signatures
# of the ENCAPSULATE event, we discard the ephemeral theory and extend
# the original theory as directed by the signatures and the non-LOCAL
# events.
#
#
# Summary
# Form:  ( ENCAPSULATE NIL (LOCAL ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.52 seconds (prove: 0.32, print: 0.00, other: 0.20)
# Prover steps counted:  7776
# T
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.52 seconds (prove: 0.32, print: 0.00, other: 0.20)
# Prover steps counted:  7776
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.52 seconds (prove: 0.32, print: 0.00, other: 0.20)
# Prover steps counted:  7776
#  T

# %%
(deftutorial Example-2
  :parents (Tutorial)
  :short "Example 2: something wild"
  :long "<h3>Example 2</h3>
<p>Prerequisite read for this tutorial example is @(tsee tutorial).</p>
<p>Smtlink is extensible, with the user's understanding that the extended part
is not verified and therefore is the user's responsibility to ensure its
soundness.  A different trust tag is installed if this customized Smtlink is
used.  Such ability makes Smtlink very powerful.  Here's an example to show the
usage.</p>
<p>Let's say we want to prove the theorem:</p>

<box>
<p>
<b><color rgb='#323cbe'>Theorem 2.</color></b>
@($\\forall x,y,z\\in R$), and @($\\forall m,n \\in Z$), if @($ 0 \\le z \\le 1$) and
@($ 0 \\le m \\le n $), then @($ 2xy\\cdot z^n \\le (x^2+y^2)z^m$).
</p>
</box>

<p>In @('smtlink/z3_interface/'), file @('RewriteExpt.py') is a Python class
extending from the default class in ACL2_to_Z3.py.  One could imaging defining
one's own file that does magical things in the SMT solver.  What
@('RewriteExpt.py') does is that it uses basic rewrite lemmas about @('expt')
to help the SMT solver to solve.  In order to make Smtlink uses the custom
version instead of the default, one needs to define and attach a new
configuration:</p>

@(`(:code ($ smtconf-expt-tutorial))`)
@(`(:code ($ smtconf-expt-defattach-tutorial))`)

<p>Defining the function @('x^2+y^2')</p>
@(`(:code ($ ||x^2+y^2||))`)

<p>Then define the theorem to prove:</p>
@(`(:code ($ poly-of-expt-example))`)

<p>Notice the @(':hints') keyword used this time is @(':smtlink-custom').  It
allows the customized version of Smtlink to be applied to the current
clause.  Take a read in @(see smt-hint) for a detailed description of each
keyword.  Here we will only describe what's used in this example.</p>

<p>In the hints, @(':function') tells Smtlink to treat @('expt') as an
uninterpreted function.  @(':formals') tells us the input argument types of the
uninterpreted function and @(':returns') tells us the output argument type.
@(':levels') specifies an expansion level of 0, making the function an
uninterpreted function.</p>

<p>@(':hypotheses') provides a list of hypotheses that the user believes to be
true and can help with the proof. The hypotheses will be insert into the
hypotheses when generating the SMT problem. They will be proved correctness
as part of the returned clauses from the verified clause processor. </p>

<p>@(':int-to-rat') tells Smtlink to raise integers to rationals when
translating the clause into a SMT problem. This is because of the limitation in
Z3. Integers mixed with real numbers are hard for Z3. We prove the given
theorem by proving a more general statement in the SMT solver.</p>

<p>Another observation is that, we are including the arithmetic-5 book for
proving the returned auxiliary clauses, which requires arithmetic
reasoning.</p>
")
# Out:
# SMT !>>(LOCAL (TABLE SV::TUTORIAL-ORDERING-TABLE
#                 'TUTORIAL
#                 (LET* ((TABLE (TABLE-ALIST 'SV::TUTORIAL-ORDERING-TABLE
#                                            WORLD)
# )
#                        (SV::TOPICS (CDR (ASSOC 'TUTORIAL TABLE))))
#                   (CONS 'EXAMPLE-2 SV::TOPICS))))
#
# Summary
# Form:  ( TABLE SV::TUTORIAL-ORDERING-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::TUTORIAL-ORDERING-TABLE
#
#
# SMT !>>(DEFXDOC EXAMPLE-2
#         :PARENTS (TUTORIAL)
#         :SHORT "Example 2: something wild"
#         :LONG
#         "<h3>Example 2</h3> <p>Prerequisite read for this tutorial example is @(tsee tutorial).</p> <p>Smtlink is extensible, with the user's understanding that the extended part is not verified and therefore is the user's responsibility to ensure its soundness.  A different trust tag is installed if this customized Smtlink is used.  Such ability makes Smtlink very powerful.  Here's an example to show the usage.</p> <p>Let's say we want to prove the theorem:</p>  <box> <p> <b><color rgb='#323cbe'>Theorem 2.</color></b> @($\\forall x,y,z\\in R$), and @($\\forall m,n \\in Z$), if @($ 0 \\le z \\le 1$) and @($ 0 \\le m \\le n $), then @($ 2xy\\cdot z^n \\le (x^2+y^2)z^m$). </p> </box>  <p>In @('smtlink/z3_interface/'), file @('RewriteExpt.py') is a Python class extending from the default class in ACL2_to_Z3.py.  One could imaging defining one's own file that does magical things in the SMT solver.  What @('RewriteExpt.py') does is that it uses basic rewrite lemmas about @('expt') to help the SMT solver to solve.  In order to make Smtlink uses the custom version instead of the default, one needs to define and attach a new configuration:</p>  @(`(:code ($ smtconf-expt-tutorial))`) @(`(:code ($ smtconf-expt-defattach-tutorial))`)  <p>Defining the function @('x^2+y^2')</p> @(`(:code ($ ||x^2+y^2||))`)  <p>Then define the theorem to prove:</p> @(`(:code ($ poly-of-expt-example))`)  <p>Notice the @(':hints') keyword used this time is @(':smtlink-custom').  It allows the customized version of Smtlink to be applied to the current clause.  Take a read in @(see smt-hint) for a detailed description of each keyword.  Here we will only describe what's used in this example.</p>  <p>In the hints, @(':function') tells Smtlink to treat @('expt') as an uninterpreted function.  @(':formals') tells us the input argument types of the uninterpreted function and @(':returns') tells us the output argument type. @(':levels') specifies an expansion level of 0, making the function an uninterpreted function.</p>  <p>@(':hypotheses') provides a list of hypotheses that the user believes to be true and can help with the proof. The hypotheses will be insert into the hypotheses when generating the SMT problem. They will be proved correctness as part of the returned clauses from the verified clause processor. </p>  <p>@(':int-to-rat') tells Smtlink to raise integers to rationals when translating the clause into a SMT problem. This is because of the limitation in Z3. Integers mixed with real numbers are hard for Z3. We prove the given theorem by proving a more general statement in the SMT solver.</p>  <p>Another observation is that, we are including the arithmetic-5 book for proving the returned auxiliary clauses, which requires arithmetic reasoning.</p> ")
# (DEFXDOC EXAMPLE-2)
#
# Summary
# Form:  ( PROGN (LOCAL ...) ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  (DEFXDOC EXAMPLE-2)

# %%
;; Buggy example
(def-saved-event non-theorem-example
  (acl2::must-fail
   (defthm non-theorem
     (implies (and (real/rationalp x)
                   (real/rationalp y)
                   (integerp (/ x y)))
              (not (equal y 0)))
     :hints(("Goal"
             :smtlink nil))
     :rule-classes nil)))
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'NON-THEOREM-EXAMPLE
#          '(ACL2::MUST-FAIL (DEFTHM NON-THEOREM
#                              (IMPLIES (AND (REAL/RATIONALP X)
#                                            (REAL/RATIONALP Y)
#                                            (INTEGERP (/ X Y)))
#                                       (NOT (EQUAL Y 0)))
#                              :HINTS (("Goal" :SMTLINK NIL))
#                              :RULE-CLASSES NIL)))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(ACL2::MUST-FAIL (DEFTHM NON-THEOREM
#                           (IMPLIES (AND (REAL/RATIONALP X)
#                                         (REAL/RATIONALP Y)
#                                         (INTEGERP (/ X Y)))
#                                    (NOT (EQUAL Y 0)))
#                           :HINTS (("Goal" :SMTLINK NIL))
#                           :RULE-CLASSES NIL))
#
#
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
#
# HARD ACL2 ERROR in SMT-TRANSLATOR=>TRANSLATE-FUNCTION:  Not a basic
# SMT function: INTEGERP
#
#
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
# T
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
#  T

# %%
(deftutorial Example-3
  :parents (Tutorial)
  :short "Example 3: defense against evil"
  :long "<h3>Example 3</h3>
<p>Prerequisite read for this tutorial example is @(tsee tutorial).</p>
<p>The third evil example is from one of the reviews we get when we first
published our paper in @(see Smtlink). </p>

@(`(:code ($ non-theorem-example))`)

<p>This is an evil theorem because we know below is a theorem in ACL2:</p>

@({
(thm (equal (/ x 0) 0))
})

<p>Therefore if Smtlink falsely prove @('non-theorem'), it will introduce
contradiction into ACL2.</p>

<p>Smtlink fails to prove the @('non-theorem') with error message:</p>

@({
HARD ACL2 ERROR in SMT-TRANSLATOR=>TRANSLATE-FUNCTION:  Not a basic
SMT function: INTEGERP
})

<p>This is because ACL2 treats @('integerp')'s as type declarations in Z3.  But
here in this theorem, @('(integerp (/ x y))') is a constraint/hypotheses rather
than a type declaration. When ACL2 tried to translate it as a constraint, it
finds out @('integerp') is not a supported function.</p>
")
# Out:
# SMT !>>(LOCAL (TABLE SV::TUTORIAL-ORDERING-TABLE
#                 'TUTORIAL
#                 (LET* ((TABLE (TABLE-ALIST 'SV::TUTORIAL-ORDERING-TABLE
#                                            WORLD)
# )
#                        (SV::TOPICS (CDR (ASSOC 'TUTORIAL TABLE))))
#                   (CONS 'EXAMPLE-3 SV::TOPICS))))
#
# Summary
# Form:  ( TABLE SV::TUTORIAL-ORDERING-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::TUTORIAL-ORDERING-TABLE
#
#
# SMT !>>(DEFXDOC EXAMPLE-3
#         :PARENTS (TUTORIAL)
#         :SHORT "Example 3: defense against evil"
#         :LONG
#         "<h3>Example 3</h3> <p>Prerequisite read for this tutorial example is @(tsee tutorial).</p> <p>The third evil example is from one of the reviews we get when we first published our paper in @(see Smtlink). </p>  @(`(:code ($ non-theorem-example))`)  <p>This is an evil theorem because we know below is a theorem in ACL2:</p>  @({ (thm (equal (/ x 0) 0)) })  <p>Therefore if Smtlink falsely prove @('non-theorem'), it will introduce contradiction into ACL2.</p>  <p>Smtlink fails to prove the @('non-theorem') with error message:</p>  @({ HARD ACL2 ERROR in SMT-TRANSLATOR=>TRANSLATE-FUNCTION:  Not a basic SMT function: INTEGERP })  <p>This is because ACL2 treats @('integerp')'s as type declarations in Z3.  But here in this theorem, @('(integerp (/ x y))') is a constraint/hypotheses rather than a type declaration. When ACL2 tried to translate it as a constraint, it finds out @('integerp') is not a supported function.</p> ")
# (DEFXDOC EXAMPLE-3)
#
# Summary
# Form:  ( PROGN (LOCAL ...) ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  (DEFXDOC EXAMPLE-3)

# %%
(define foo ((x real/rationalp))
  :returns (rx real/rationalp)
  (b* ((x (realfix x)))
    (+ (* x x) 1)))
# Out:
# Since FOO is non-recursive, its admission is trivial.  We observe that
# the type of FOO is described by the theorem
# (AND (RATIONALP (FOO X)) (< 0 (FOO X))).  We used primitive type reasoning
# and the :type-prescription rules NONNEGATIVE-PRODUCT and REALFIX.
#
# Computing the guard conjecture for FOO....
#
# The guard conjecture for FOO is trivial to prove, given the :type-
# prescription rules NONNEGATIVE-PRODUCT and REALFIX.  FOO is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN FOO ...)
# Rules: ((:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION NONNEGATIVE-PRODUCT)
#         (:TYPE-PRESCRIPTION REALFIX))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# SMT !>>(DEFTHM REAL/RATIONALP-OF-FOO
#          (B* ((RX (FOO X))) (REAL/RATIONALP RX))
#          :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'FOO
#                                                        ID WORLD))
#          :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM REAL/RATIONALP-OF-FOO ...):  A :REWRITE
# rule generated from REAL/RATIONALP-OF-FOO will be triggered only by
# terms containing the function symbol FOO, which has a non-recursive
# definition.  Unless this definition is disabled, this rule is unlikely
# ever to be used.
#
#
# Q.E.D.
#
# The storage of REAL/RATIONALP-OF-FOO depends upon the :type-prescription
# rule FOO.
#
# Summary
# Form:  ( DEFTHM REAL/RATIONALP-OF-FOO ...)
# Rules: ((:TYPE-PRESCRIPTION FOO))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# REAL/RATIONALP-OF-FOO
#
# Summary
# Form:  ( PROGN (DEFTHM REAL/RATIONALP-OF-FOO ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  FOO

# %%
(in-theory (disable (:type-prescription foo)))
# Out:
# Summary
# Form:  ( IN-THEORY (DISABLE ...))
# Rules: NIL
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#  (:NUMBER-OF-ENABLED-RUNES 16381)

# %%
(defthm poly-ineq-example-functions
  (implies (and (real/rationalp x))
           (< 0 (* 2 (foo x))))
  :hints(("Goal"
          :smtlink
          (:functions ((foo :formals ((x real/rationalp))
                            :returns ((rx real/rationalp))
                            :level 0))
           :hypotheses (((<= 1 (foo x))
                         :hints (:in-theory (enable foo))))
          ))))
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2.2
# Subgoal 2.2.2'
# Subgoal 2.2.2.3
# Subgoal 2.2.2.3'
# Using default SMT-trusted-cp...
# ; SMT solver: `python /tmp/py_file/smtlink.bBxAF`: 0.07 sec, 0 bytes
# Proved!
# Subgoal 2.2.2.3''
# Subgoal 2.2.2.3'''
# Subgoal 2.2.2.2
# Subgoal 2.2.2.2'
# Subgoal 2.2.2.2''
# Subgoal 2.2.2.2'''
# Subgoal 2.2.2.1
# Subgoal 2.2.2.1'
# Subgoal 2.2.2.1''
# Subgoal 2.2.2.1'''
# Subgoal 2.2.1
# Subgoal 2.2.1'
# Subgoal 2.2.1''
# Subgoal 2.2.1'''
# Subgoal 2.1
# Subgoal 2.1'
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM POLY-INEQ-EXAMPLE-FUNCTIONS ...)
# Rules: ((:DEFINITION FOO)
#         (:DEFINITION NOT)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION NONNEGATIVE-PRODUCT)
#         (:TYPE-PRESCRIPTION REALFIX))
# Hint-events: ((:CLAUSE-PROCESSOR ADD-HYPO-CP)
#               (:CLAUSE-PROCESSOR EXPAND-CP-FN)
#               (:CLAUSE-PROCESSOR PROCESS-HINT)
#               (:CLAUSE-PROCESSOR REMOVE-HINT-PLEASE)
#               (:CLAUSE-PROCESSOR SMT-TRUSTED-CP)
#               (:CLAUSE-PROCESSOR TYPE-EXTRACT-FN)
#               (:CLAUSE-PROCESSOR UNINTERPRETED-FN-CP))
# Time:  0.14 seconds (prove: 0.13, print: 0.00, other: 0.00)
# Prover steps counted:  347
#  POLY-INEQ-EXAMPLE-FUNCTIONS

# %%
(def-saved-event fty-deflist-theorem-example
  (defthm fty-deflist-theorem
    (implies (and (integer-listp l)
                  (consp (acl2::integer-list-fix l))
                  (consp (acl2::integer-list-fix (cdr (acl2::integer-list-fix l)))))
             (>= (x^2+y^2 (car (acl2::integer-list-fix l))
                          (car (acl2::integer-list-fix
                                (cdr (acl2::integer-list-fix l)))))
                 0))
    :hints(("Goal"
            :smtlink
            (:fty (acl2::integer-list))))
    :rule-classes nil))
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#         'FTY-DEFLIST-THEOREM-EXAMPLE
#         '(DEFTHM FTY-DEFLIST-THEOREM
#           (IMPLIES
#            (AND
#              (INTEGER-LISTP L)
#              (CONSP (ACL2::INTEGER-LIST-FIX L))
#              (CONSP
#                   (ACL2::INTEGER-LIST-FIX (CDR (ACL2::INTEGER-LIST-FIX L)))))
#            (>=
#             (X^2+Y^2
#              (CAR (ACL2::INTEGER-LIST-FIX L))
#              (CAR (ACL2::INTEGER-LIST-FIX (CDR (ACL2::INTEGER-LIST-FIX L)))))
#             0))
#           :HINTS (("Goal" :SMTLINK (:FTY (ACL2::INTEGER-LIST))))
#           :RULE-CLASSES NIL))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFTHM FTY-DEFLIST-THEOREM
#         (IMPLIES
#          (AND
#            (INTEGER-LISTP L)
#            (CONSP (ACL2::INTEGER-LIST-FIX L))
#            (CONSP (ACL2::INTEGER-LIST-FIX (CDR (ACL2::INTEGER-LIST-FIX L)))))
#          (>=
#           (X^2+Y^2
#              (CAR (ACL2::INTEGER-LIST-FIX L))
#              (CAR (ACL2::INTEGER-LIST-FIX (CDR (ACL2::INTEGER-LIST-FIX L)))))
#           0))
#         :HINTS (("Goal" :SMTLINK (:FTY (ACL2::INTEGER-LIST))))
#         :RULE-CLASSES NIL)
#
#
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
# Using default SMT-trusted-cp...
# ; SMT solver: `python /tmp/py_file/smtlink.f0Q4X`: 0.07 sec, 54,048 bytes
# Proved!
# Subgoal 2.2'4'
# Subgoal 2.2'5'
# Subgoal 2.2'6'
# Subgoal 2.2'7'
# Subgoal 2.1
# Subgoal 2.1'
# Subgoal 2.1''
# Subgoal 2.1'''
# Subgoal 2.1'4'
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
# Subgoal 1'4'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM FTY-DEFLIST-THEOREM ...)
# Rules: ((:COMPOUND-RECOGNIZER
#              ACL2::TRUE-LISTP-WHEN-INTEGER-LISTP-COMPOUND-RECOGNIZER)
#         (:CONGRUENCE
#          ACL2::CDR-INTEGER-LIST-EQUIV-CONGRUENCE-ON-X-UNDER-INTEGER-LIST-EQUIV)
#         (:DEFINITION DOUBLE-REWRITE)
#         (:DEFINITION HIDE)
#         (:DEFINITION INTEGER-LISTP)
#         (:DEFINITION NOT)
#         (:DEFINITION TYPE-HYP)
#         (:DEFINITION X^2+Y^2)
#         (:EXECUTABLE-COUNTERPART ACL2::BOOLEAN-LIST-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:EXECUTABLE-COUNTERPART IF)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE ACL2::CONSP-OF-INTEGER-LIST-FIX)
#         (:REWRITE ACL2::INTEGER-LIST-FIX-UNDER-INTEGER-LIST-EQUIV)
#         (:REWRITE ACL2::INTEGER-LIST-FIX-WHEN-INTEGER-LISTP)
#         (:REWRITE ACL2::INTEGER-LISTP-OF-CDR-WHEN-INTEGER-LISTP)
#         (:REWRITE ACL2::INTEGERP-OF-CAR-WHEN-INTEGER-LISTP)
#         (:TYPE-PRESCRIPTION INTEGER-LISTP))
# Hint-events: ((:CLAUSE-PROCESSOR ADD-HYPO-CP)
#               (:CLAUSE-PROCESSOR EXPAND-CP-FN)
#               (:CLAUSE-PROCESSOR PROCESS-HINT)
#               (:CLAUSE-PROCESSOR REMOVE-HINT-PLEASE)
#               (:CLAUSE-PROCESSOR SMT-TRUSTED-CP)
#               (:CLAUSE-PROCESSOR TYPE-EXTRACT-FN)
#               (:CLAUSE-PROCESSOR UNINTERPRETED-FN-CP))
# Time:  0.09 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  2620
# FTY-DEFLIST-THEOREM
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Time:  0.09 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  2620
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Time:  0.09 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  2620
#  FTY-DEFLIST-THEOREM

# %%
(acl2::must-fail
(defthm fty-deflist-theorem-fail
  (implies (and (integer-listp l)
                (consp (acl2::integer-list-fix l))
                (consp (acl2::integer-list-fix (cdr (acl2::integer-list-fix l)))))
           (>= (x^2+y^2 (car (acl2::integer-list-fix l))
                        (car (acl2::integer-list-fix
                              (cdr (acl2::integer-list-fix l)))))
               1))
  :hints(("Goal"
          :smtlink
          (:fty (acl2::integer-list))))
  :rule-classes nil)
)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  T

# %%
(def-saved-event symbol-integer-example
  (defalist symbol-integer-alist
    :key-type symbolp
    :val-type integerp
    :true-listp t)
)
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'SYMBOL-INTEGER-EXAMPLE
#          '(DEFALIST SYMBOL-INTEGER-ALIST
#                     :KEY-TYPE SYMBOLP
#                     :VAL-TYPE INTEGERP
#                     :TRUE-LISTP T))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFALIST SYMBOL-INTEGER-ALIST
#                  :KEY-TYPE SYMBOLP
#                  :VAL-TYPE INTEGERP
#                  :TRUE-LISTP T)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-SYMBOLP-OF-SYMBOL-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-INTEGERP-OF-IFIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-IFIX-WHEN-INTEGERP ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ACL2::ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN SYMBOL-INTEGER-ALIST-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Disable] in ( IN-THEORY (THEORY ...)):  Forcing has transitioned
# from disabled to enabled.
# See :DOC force.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOL-INTEGER-ALIST-P-OF-UPDATE-NTH ...):  In a :REWRITE rule generated
# from SYMBOL-INTEGER-ALIST-P-OF-UPDATE-NTH, equivalence relations
# ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at two problematic
# occurrences of variable ACL2::Y in the right-hand side, but not at
# any binding occurrence of ACL2::Y.  Consider replacing those two occurrences
# of ACL2::Y in the right-hand side with (DOUBLE-REWRITE ACL2::Y).  See
# :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOL-INTEGER-ALIST-P-OF-UPDATE-NTH ...):  In a :REWRITE rule generated
# from SYMBOL-INTEGER-ALIST-P-OF-UPDATE-NTH, equivalence relations
# STR::ICHARLISTEQV, STR::CHARLISTEQV$INLINE and ACL2::LIST-EQUIV are
# maintained at two problematic occurrences of variable ACL2::X in the
# right-hand side, but not at any binding occurrence of ACL2::X.  Consider
# replacing those two occurrences of ACL2::X in the right-hand side with
# (DOUBLE-REWRITE ACL2::X).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOL-INTEGER-ALIST-P-OF-UPDATE-NTH ...):  In a :REWRITE rule generated
# from SYMBOL-INTEGER-ALIST-P-OF-UPDATE-NTH, equivalence relation
# ACL2::NAT-EQUIV$INLINE is maintained at two problematic occurrences
# of variable ACL2::N in the right-hand side, but not at any binding
# occurrence of ACL2::N.  Consider replacing those two occurrences of
# ACL2::N in the right-hand side with (DOUBLE-REWRITE ACL2::N).  See
# :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM SYMBOL-INTEGER-ALIST-P-OF-REPEAT
# ...):  In a :REWRITE rule generated from SYMBOL-INTEGER-ALIST-P-OF-REPEAT,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at four problematic occurrences of variable ACL2::X in the right-hand
# side, but not at any binding occurrence of ACL2::X.  Consider replacing
# those four occurrences of ACL2::X in the right-hand side with
# (DOUBLE-REWRITE ACL2::X).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM SYMBOL-INTEGER-ALIST-P-OF-TAKE
# ...):  In a :REWRITE rule generated from SYMBOL-INTEGER-ALIST-P-OF-TAKE,
# equivalence relations STR::ICHARLISTEQV and STR::CHARLISTEQV$INLINE
# are maintained at one problematic occurrence of variable ACL2::X in
# the right-hand side, but not at any binding occurrence of ACL2::X.
# Consider replacing that occurrence of ACL2::X in the right-hand side
# with (DOUBLE-REWRITE ACL2::X).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM SYMBOL-INTEGER-ALIST-P-OF-TAKE
# ...):  In a :REWRITE rule generated from SYMBOL-INTEGER-ALIST-P-OF-TAKE,
# equivalence relation ACL2::NAT-EQUIV$INLINE is maintained at one problematic
# occurrence of variable ACL2::N in the right-hand side, but not at any
# binding occurrence of ACL2::N.  Consider replacing that occurrence
# of ACL2::N in the right-hand side with (DOUBLE-REWRITE ACL2::N).  See
# :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOL-INTEGER-ALIST-P-OF-UNION-EQUAL ...):  In a :REWRITE rule generated
# from SYMBOL-INTEGER-ALIST-P-OF-UNION-EQUAL, equivalence relation
# ACL2::LIST-EQUIV is maintained at one problematic occurrence of variable
# ACL2::X in the right-hand side, but not at any binding occurrence of
# ACL2::X.  Consider replacing that occurrence of ACL2::X in the right-
# hand side with (DOUBLE-REWRITE ACL2::X).  See :doc double-rewrite for
# more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOL-INTEGER-ALIST-P-WHEN-SUBSETP-EQUAL ...):  In a :REWRITE rule
# generated from SYMBOL-INTEGER-ALIST-P-WHEN-SUBSETP-EQUAL, equivalence
# relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at one
# problematic occurrence of variable ACL2::X in the first hypothesis,
# but not at any binding occurrence of ACL2::X.  Consider replacing that
# occurrence of ACL2::X in the first hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOL-INTEGER-ALIST-P-WHEN-SUBSETP-EQUAL ...):  In a :REWRITE rule
# generated from SYMBOL-INTEGER-ALIST-P-WHEN-SUBSETP-EQUAL, equivalence
# relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at one
# problematic occurrence of variable ACL2::X in the second hypothesis,
# but not at any binding occurrence of ACL2::X.  Consider replacing that
# occurrence of ACL2::X in the second hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOL-INTEGER-ALIST-P-WHEN-SUBSETP-EQUAL ...):  In a :REWRITE rule
# generated from SYMBOL-INTEGER-ALIST-P-WHEN-SUBSETP-EQUAL, equivalence
# relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at one
# problematic occurrence of variable ACL2::Y in the second hypothesis,
# but not at any binding occurrence of ACL2::Y.  Consider replacing that
# occurrence of ACL2::Y in the second hypothesis with (DOUBLE-REWRITE ACL2::Y).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM SYMBOL-INTEGER-ALIST-P-OF-RCONS
# ...):  In a :REWRITE rule generated from SYMBOL-INTEGER-ALIST-P-OF-RCONS,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at two problematic occurrences of variable ACL2::A in the right-hand
# side, but not at any binding occurrence of ACL2::A.  Consider replacing
# those two occurrences of ACL2::A in the right-hand side with
# (DOUBLE-REWRITE ACL2::A).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM SYMBOL-INTEGER-ALIST-P-OF-REV
# ...):  In a :REWRITE rule generated from SYMBOL-INTEGER-ALIST-P-OF-REV,
# equivalence relation ACL2::LIST-EQUIV is maintained at one problematic
# occurrence of variable ACL2::X in the right-hand side, but not at any
# binding occurrence of ACL2::X.  Consider replacing that occurrence
# of ACL2::X in the right-hand side with (DOUBLE-REWRITE ACL2::X).  See
# :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM SYMBOL-INTEGER-ALIST-P-OF-INSERT
# ...):  In a :REWRITE rule generated from SYMBOL-INTEGER-ALIST-P-OF-INSERT,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at two problematic occurrences of variable ACL2::A in the right-hand
# side, but not at any binding occurrence of ACL2::A.  Consider replacing
# those two occurrences of ACL2::A in the right-hand side with
# (DOUBLE-REWRITE ACL2::A).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOL-INTEGER-ALIST-P-WHEN-NOT-CONSP ...):  In a :REWRITE rule generated
# from SYMBOL-INTEGER-ALIST-P-WHEN-NOT-CONSP, equivalence relations
# ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at one problematic
# occurrence of variable ACL2::X in the first hypothesis, but not at
# any binding occurrence of ACL2::X.  Consider replacing that occurrence
# of ACL2::X in the first hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOL-INTEGER-ALIST-P-WHEN-NOT-CONSP ...):  In a :REWRITE rule generated
# from SYMBOL-INTEGER-ALIST-P-WHEN-NOT-CONSP, equivalence relation IFF
# is maintained at one problematic occurrence of variable ACL2::X in
# the right-hand side, but not at any binding occurrence of ACL2::X.
# Consider replacing that occurrence of ACL2::X in the right-hand side
# with (DOUBLE-REWRITE ACL2::X).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM SYMBOL-INTEGER-ALIST-P-OF-CONS
# ...):  In a :REWRITE rule generated from SYMBOL-INTEGER-ALIST-P-OF-CONS,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at two problematic occurrences of variable ACL2::A in the right-hand
# side, but not at any binding occurrence of ACL2::A.  Consider replacing
# those two occurrences of ACL2::A in the right-hand side with
# (DOUBLE-REWRITE ACL2::A).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# INTEGERP-OF-CDR-WHEN-MEMBER-EQUAL-OF-SYMBOL-INTEGER-ALIST-P ...):
# In a :REWRITE rule generated from
# INTEGERP-OF-CDR-WHEN-MEMBER-EQUAL-OF-SYMBOL-INTEGER-ALIST-P, equivalence
# relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at one
# problematic occurrence of variable ACL2::X in the second hypothesis,
# but not at any binding occurrence of ACL2::X.  Consider replacing that
# occurrence of ACL2::X in the second hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOLP-OF-CAR-WHEN-MEMBER-EQUAL-OF-SYMBOL-INTEGER-ALIST-P ...):  In
# a :REWRITE rule generated from
# SYMBOLP-OF-CAR-WHEN-MEMBER-EQUAL-OF-SYMBOL-INTEGER-ALIST-P, equivalence
# relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at one
# problematic occurrence of variable ACL2::X in the second hypothesis,
# but not at any binding occurrence of ACL2::X.  Consider replacing that
# occurrence of ACL2::X in the second hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# CONSP-WHEN-MEMBER-EQUAL-OF-SYMBOL-INTEGER-ALIST-P ...):  In a :REWRITE
# rule generated from CONSP-WHEN-MEMBER-EQUAL-OF-SYMBOL-INTEGER-ALIST-P,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at one problematic occurrence of variable ACL2::X in the second hypothesis,
# but not at any binding occurrence of ACL2::X.  Consider replacing that
# occurrence of ACL2::X in the second hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# INTEGERP-OF-CDAR-WHEN-SYMBOL-INTEGER-ALIST-P ...):  In a :REWRITE rule
# generated from INTEGERP-OF-CDAR-WHEN-SYMBOL-INTEGER-ALIST-P, equivalence
# relation ACL2::SET-EQUIV is maintained at two problematic occurrences
# of variable ACL2::X in the right-hand side, but not at any binding
# occurrence of ACL2::X.  Consider replacing those two occurrences of
# ACL2::X in the right-hand side with (DOUBLE-REWRITE ACL2::X).  See
# :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SYMBOLP-OF-CAAR-WHEN-SYMBOL-INTEGER-ALIST-P ...):  In a :REWRITE rule
# generated from SYMBOLP-OF-CAAR-WHEN-SYMBOL-INTEGER-ALIST-P, equivalence
# relation ACL2::SET-EQUIV is maintained at two problematic occurrences
# of variable ACL2::X in the right-hand side, but not at any binding
# occurrence of ACL2::X.  Consider replacing those two occurrences of
# ACL2::X in the right-hand side with (DOUBLE-REWRITE ACL2::X).  See
# :doc double-rewrite for more information on this issue.
#
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SYMBOL-INTEGER-ALIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN SYMBOL-INTEGER-ALIST-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 3
# Subgoal 2
# Subgoal 2'
# Subgoal 2''
# Subgoal 2'''
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SYMBOL-INTEGER-ALIST-P-OF-SYMBOL-INTEGER-ALIST-FIX
# ...)
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SYMBOL-INTEGER-ALIST-P-OF-SYMBOL-INTEGER-ALIST-FIX
# ...) ...)
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SYMBOL-INTEGER-ALIST-FIX-WHEN-SYMBOL-INTEGER-ALIST-P
# ...)
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS SYMBOL-INTEGER-ALIST-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (DEFFIXTYPE ... T) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CONS-OF-SYMBOL-FIX-K-UNDER-SYMBOL-INTEGER-ALIST-EQUIV
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-IFIX-V-UNDER-SYMBOL-INTEGER-ALIST-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM
# CONS-OF-SYMBOL-INTEGER-ALIST-FIX-Y-UNDER-SYMBOL-INTEGER-ALIST-EQUIV
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SYMBOL-INTEGER-ALIST-FIX-OF-ACONS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Form:  ( DEFTHM SYMBOL-INTEGER-ALIST-FIX-OF-APPEND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Subgoal *1/1'
# Subgoal *1/1''
# Form:  ( DEFTHM CONSP-CAR-OF-SYMBOL-INTEGER-ALIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.05 seconds (prove: 0.04, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SYMBOL-INTEGER-ALIST ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SYMBOL-INTEGER-ALIST ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE ACL2::XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.19 seconds (prove: 0.07, print: 0.00, other: 0.12)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.21 seconds (prove: 0.07, print: 0.00, other: 0.14)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFALIST-FN ...))
# Rules: NIL
# Warnings:  Double-rewrite, Disable and Theory
# Time:  0.21 seconds (prove: 0.07, print: 0.00, other: 0.14)
# Prover steps counted:  5708
# T
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Warnings:  Double-rewrite, Disable and Theory
# Time:  0.21 seconds (prove: 0.07, print: 0.00, other: 0.14)
# Prover steps counted:  5708
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Warnings:  Double-rewrite, Disable and Theory
# Time:  0.21 seconds (prove: 0.07, print: 0.00, other: 0.14)
# Prover steps counted:  5708
#  T

# %%
(def-saved-event fty-defalist-theorem-example
  (defthm fty-defalist-theorem
    (implies (and (symbol-integer-alist-p l)
                  (symbolp s1)
                  (symbolp s2)
                  (not (equal (assoc-equal s1 (symbol-integer-alist-fix l))
                              (smt::magic-fix 'symbolp_integerp nil)))
                  (not (equal (assoc-equal s2 (symbol-integer-alist-fix l))
                              (smt::magic-fix 'symbolp_integerp nil))))
             (>= (x^2+y^2
                  (cdr (smt::magic-fix 'symbolp_integerp
                                       (assoc-equal s1 (symbol-integer-alist-fix l))))
                  (cdr (smt::magic-fix 'symbolp_integerp
                                       (assoc-equal s2 (symbol-integer-alist-fix l)))))
                 0))
    :hints(("Goal"
            :smtlink
            (:fty (symbol-integer-alist))))
    :rule-classes nil)
  )
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#         'FTY-DEFALIST-THEOREM-EXAMPLE
#         '(DEFTHM FTY-DEFALIST-THEOREM
#           (IMPLIES
#            (AND (SYMBOL-INTEGER-ALIST-P L)
#                 (SYMBOLP S1)
#                 (SYMBOLP S2)
#                 (NOT (EQUAL (ASSOC-EQUAL S1 (SYMBOL-INTEGER-ALIST-FIX L))
#                             (MAGIC-FIX 'SYMBOLP_INTEGERP NIL)))
#                 (NOT (EQUAL (ASSOC-EQUAL S2 (SYMBOL-INTEGER-ALIST-FIX L))
#                             (MAGIC-FIX 'SYMBOLP_INTEGERP NIL))))
#            (>=
#             (X^2+Y^2
#              (CDR (MAGIC-FIX 'SYMBOLP_INTEGERP
#                              (ASSOC-EQUAL S1 (SYMBOL-INTEGER-ALIST-FIX L))))
#              (CDR (MAGIC-FIX 'SYMBOLP_INTEGERP
#                              (ASSOC-EQUAL S2 (SYMBOL-INTEGER-ALIST-FIX L)))))
#             0))
#           :HINTS (("Goal" :SMTLINK (:FTY (SYMBOL-INTEGER-ALIST))))
#           :RULE-CLASSES NIL))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFTHM FTY-DEFALIST-THEOREM
#         (IMPLIES
#          (AND (SYMBOL-INTEGER-ALIST-P L)
#               (SYMBOLP S1)
#               (SYMBOLP S2)
#               (NOT (EQUAL (ASSOC-EQUAL S1 (SYMBOL-INTEGER-ALIST-FIX L))
#                           (MAGIC-FIX 'SYMBOLP_INTEGERP NIL)))
#               (NOT (EQUAL (ASSOC-EQUAL S2 (SYMBOL-INTEGER-ALIST-FIX L))
#                           (MAGIC-FIX 'SYMBOLP_INTEGERP NIL))))
#          (>=
#           (X^2+Y^2
#              (CDR (MAGIC-FIX 'SYMBOLP_INTEGERP
#                              (ASSOC-EQUAL S1 (SYMBOL-INTEGER-ALIST-FIX L))))
#              (CDR (MAGIC-FIX 'SYMBOLP_INTEGERP
#                              (ASSOC-EQUAL S2 (SYMBOL-INTEGER-ALIST-FIX L)))))
#           0))
#         :HINTS (("Goal" :SMTLINK (:FTY (SYMBOL-INTEGER-ALIST))))
#         :RULE-CLASSES NIL)
#
#
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
# Using default SMT-trusted-cp...
# ; SMT solver: `python /tmp/py_file/smtlink.cNRjJ`: 0.07 sec, 0 bytes
# Proved!
# Subgoal 2.2'4'
# Subgoal 2.2'5'
# Subgoal 2.2'6'
# Subgoal 2.2'7'
# Subgoal 2.1
# Subgoal 2.1'
# Subgoal 2.1''
# Subgoal 2.1'''
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM FTY-DEFALIST-THEOREM ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-SYMBOL-INTEGER-ALIST-P-COMPOUND-RECOGNIZER)
#         (:DEFINITION HIDE)
#         (:DEFINITION MAGIC-FIX)
#         (:DEFINITION NOT)
#         (:DEFINITION TYPE-HYP)
#         (:DEFINITION X^2+Y^2)
#         (:EXECUTABLE-COUNTERPART ACL2::BOOL-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART ACL2::BOOLEAN-LIST-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART IF)
#         (:EXECUTABLE-COUNTERPART MAGIC-FIX)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE ACL2::BOOL-FIX-WHEN-BOOLEANP)
#         (:REWRITE ACL2::BOOLEAN-LIST-FIX-OF-CONS)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE SUBSETP-IF-TRUE-SET-EQUIV)
#         (:REWRITE SYMBOL-INTEGER-ALIST-FIX-WHEN-SYMBOL-INTEGER-ALIST-P)
#         (:REWRITE SYMBOL-INTEGER-ALIST-P-WHEN-SUBSETP-EQUAL)
#         (:TYPE-PRESCRIPTION SYMBOL-INTEGER-ALIST-P))
# Hint-events: ((:CLAUSE-PROCESSOR ADD-HYPO-CP)
#               (:CLAUSE-PROCESSOR EXPAND-CP-FN)
#               (:CLAUSE-PROCESSOR PROCESS-HINT)
#               (:CLAUSE-PROCESSOR REMOVE-HINT-PLEASE)
#               (:CLAUSE-PROCESSOR SMT-TRUSTED-CP)
#               (:CLAUSE-PROCESSOR TYPE-EXTRACT-FN)
#               (:CLAUSE-PROCESSOR UNINTERPRETED-FN-CP))
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  2725
# FTY-DEFALIST-THEOREM
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  2725
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  2725
#  FTY-DEFALIST-THEOREM

# %%
(defthm fty-defalist-theorem-acons
  (implies (and (symbol-integer-alist-p l)
                (symbolp s1)
                (symbolp s2)
                (not (equal (assoc-equal s1 (symbol-integer-alist-fix
                                             (acons 'x 1
                                                    (symbol-integer-alist-fix l))))
                            (smt::magic-fix 'symbolp_integerp nil)))
                (not (equal (assoc-equal s2 (symbol-integer-alist-fix l))
                            (smt::magic-fix 'symbolp_integerp nil))))
           (>= (x^2+y^2
                (cdr (smt::magic-fix
                      'symbolp_integerp
                      (assoc-equal s1 (symbol-integer-alist-fix
                                       (acons 'x 1
                                              (symbol-integer-alist-fix l))))))
                (cdr (smt::magic-fix 'symbolp_integerp
                                     (assoc-equal s2 (symbol-integer-alist-fix l)))))
               0))
  :hints(("Goal"
          :smtlink
          (:fty (symbol-integer-alist))))
  :rule-classes nil)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
# Using default SMT-trusted-cp...
# ; SMT solver: `python /tmp/py_file/smtlink.InGhq`: 0.07 sec, 0 bytes
# Proved!
# Subgoal 2.2'4'
# Subgoal 2.2'5'
# Subgoal 2.2'6'
# Subgoal 2.2'7'
# Subgoal 2.1
# Subgoal 2.1'
# Subgoal 2.1''
# Subgoal 2.1'''
#
# Splitter note (see :DOC splitter) for Subgoal 2.1''' (2 subgoals).
#   if-intro: ((:DEFINITION ASSOC-EQUAL)
#              (:DEFINITION NOT))
#
# Subgoal 2.1.2
# Subgoal 2.1.1
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
#
# Splitter note (see :DOC splitter) for Subgoal 1''' (2 subgoals).
#   if-intro: ((:DEFINITION ASSOC-EQUAL)
#              (:DEFINITION NOT))
#
# Subgoal 1.2
# Subgoal 1.1
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM FTY-DEFALIST-THEOREM-ACONS ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-SYMBOL-INTEGER-ALIST-P-COMPOUND-RECOGNIZER)
#         (:CONGRUENCE
#          SYMBOL-INTEGER-ALIST-EQUIV-IMPLIES-EQUAL-SYMBOL-INTEGER-ALIST-FIX-1)
#         (:DEFINITION ACONS)
#         (:DEFINITION ASSOC-EQUAL)
#         (:DEFINITION HIDE)
#         (:DEFINITION MAGIC-FIX)
#         (:DEFINITION NOT)
#         (:DEFINITION TYPE-HYP)
#         (:DEFINITION X^2+Y^2)
#         (:EXECUTABLE-COUNTERPART BINARY-*)
#         (:EXECUTABLE-COUNTERPART ACL2::BOOL-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART ACL2::BOOLEAN-LIST-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART IF)
#         (:EXECUTABLE-COUNTERPART IFIX)
#         (:EXECUTABLE-COUNTERPART INTEGERP)
#         (:EXECUTABLE-COUNTERPART MAGIC-FIX)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART SYMBOL-FIX)
#         (:EXECUTABLE-COUNTERPART SYMBOLP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE ACL2::BOOL-FIX-WHEN-BOOLEANP)
#         (:REWRITE ACL2::BOOLEAN-LIST-FIX-OF-CONS)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE
#          CONS-OF-SYMBOL-INTEGER-ALIST-FIX-Y-UNDER-SYMBOL-INTEGER-ALIST-EQUIV)
#         (:REWRITE SUBSETP-IF-TRUE-SET-EQUIV)
#         (:REWRITE SYMBOL-INTEGER-ALIST-FIX-OF-ACONS)
#         (:REWRITE SYMBOL-INTEGER-ALIST-FIX-WHEN-SYMBOL-INTEGER-ALIST-P)
#         (:REWRITE SYMBOL-INTEGER-ALIST-P-OF-CONS)
#         (:REWRITE SYMBOL-INTEGER-ALIST-P-OF-SYMBOL-INTEGER-ALIST-FIX)
#         (:REWRITE SYMBOL-INTEGER-ALIST-P-WHEN-SUBSETP-EQUAL)
#         (:TYPE-PRESCRIPTION SYMBOL-INTEGER-ALIST-P))
# Hint-events: ((:CLAUSE-PROCESSOR ADD-HYPO-CP)
#               (:CLAUSE-PROCESSOR EXPAND-CP-FN)
#               (:CLAUSE-PROCESSOR PROCESS-HINT)
#               (:CLAUSE-PROCESSOR REMOVE-HINT-PLEASE)
#               (:CLAUSE-PROCESSOR SMT-TRUSTED-CP)
#               (:CLAUSE-PROCESSOR TYPE-EXTRACT-FN)
#               (:CLAUSE-PROCESSOR UNINTERPRETED-FN-CP))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION ASSOC-EQUAL)
#              (:DEFINITION NOT))
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  4529
#  FTY-DEFALIST-THEOREM-ACONS

# %%
(acl2::must-fail
(defthm fty-defalist-theorem-fail
  (implies (and (symbol-integer-alist-p l)
                (symbolp s1)
                (symbolp s2)
                (not (equal (assoc-equal s1 (symbol-integer-alist-fix l))
                            (smt::magic-fix 'symbolp_integerp nil)))
                (not (equal (assoc-equal s2 (symbol-integer-alist-fix l))
                            (smt::magic-fix 'symbolp_integerp nil))))
           (>= (x^2+y^2
                (cdr (smt::magic-fix 'symbolp_integerp
                                     (assoc-equal s1 (symbol-integer-alist-fix l))))
                (cdr (smt::magic-fix 'symbolp_integerp
                                     (assoc-equal s2 (symbol-integer-alist-fix l)))))
               1))
  :hints(("Goal"
          :smtlink
          (:fty (symbol-integer-alist))))
  :rule-classes nil)
)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  T

# %%
(def-saved-event sandwich-example
  (defprod sandwich
    ((bread integerp)
     (fillings symbolp)))
  )
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'SANDWICH-EXAMPLE
#          '(DEFPROD SANDWICH
#                    ((BREAD INTEGERP) (FILLINGS SYMBOLP))))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFPROD SANDWICH
#                 ((BREAD INTEGERP) (FILLINGS SYMBOLP)))
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-INTEGERP-OF-IFIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-IFIX-WHEN-INTEGERP ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-SYMBOLP-OF-SYMBOL-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ACL2::ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 5
# Subgoal 4
# Subgoal 4.2
# Subgoal 4.2.2
# Subgoal 4.2.2'
# Subgoal 4.2.1
# Subgoal 4.1
# Subgoal 4.1'
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Subgoal 1'
# Form:  ( DEFUN SANDWICH-P ...)
# Time:  0.08 seconds (prove: 0.07, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CONSP-WHEN-SANDWICH-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SANDWICH-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN SANDWICH-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM SANDWICH-P-OF-SANDWICH-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SANDWICH-P-OF-SANDWICH-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SANDWICH-FIX-WHEN-SANDWICH-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
# Form:  ( VERIFY-GUARDS SANDWICH-FIX$INLINE ...)
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (DEFFIXTYPE ... T) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.04 seconds (prove: 0.03, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SANDWICH->BREAD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN SANDWICH->BREAD$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM INTEGERP-OF-SANDWICH->BREAD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM INTEGERP-OF-SANDWICH->BREAD ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SANDWICH->BREAD$INLINE-OF-SANDWICH-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV SANDWICH->BREAD ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SANDWICH->FILLINGS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN SANDWICH->FILLINGS$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SYMBOLP-OF-SANDWICH->FILLINGS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SYMBOLP-OF-SANDWICH->FILLINGS ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SANDWICH->FILLINGS$INLINE-OF-SANDWICH-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV SANDWICH->FILLINGS ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN SANDWICH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM SANDWICH-P-OF-SANDWICH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SANDWICH-P-OF-SANDWICH ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM SANDWICH->BREAD-OF-SANDWICH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM SANDWICH->FILLINGS-OF-SANDWICH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SANDWICH-OF-FIELDS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SANDWICH-FIX-WHEN-SANDWICH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 4
# Subgoal 4'
# Subgoal 4''
# Subgoal 4'''
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM EQUAL-OF-SANDWICH ...)
# Time:  0.06 seconds (prove: 0.04, print: 0.00, other: 0.02)
# Goal'
# Form:  ( DEFTHM SANDWICH-OF-IFIX-BREAD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM SANDWICH-OF-SYMBOL-FIX-FILLINGS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFMACRO PATBIND-SANDWICH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-SANDWICH ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-SANDWICH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-SANDWICH ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SANDWICH->BREAD-OF-SANDWICH ...) ...)
# Time:  0.07 seconds (prove: 0.05, print: 0.00, other: 0.03)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SANDWICH-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SANDWICH ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SANDWICH ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE ACL2::XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.31 seconds (prove: 0.16, print: 0.00, other: 0.15)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.32 seconds (prove: 0.16, print: 0.00, other: 0.16)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFPROD-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.32 seconds (prove: 0.16, print: 0.00, other: 0.16)
# Prover steps counted:  6933
# T
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Warnings:  Theory
# Time:  0.32 seconds (prove: 0.16, print: 0.00, other: 0.16)
# Prover steps counted:  6933
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.32 seconds (prove: 0.16, print: 0.00, other: 0.16)
# Prover steps counted:  6933
#  T

# %%
(def-saved-event fty-defprod-theorem-example
  (defthm fty-defprod-theorem
    (implies (and (sandwich-p s1)
                  (sandwich-p s2))
             (>= (x^2+y^2
                  (sandwich->bread s1)
                  (sandwich->bread s2))
                 0))
    :hints(("Goal"
            :smtlink
            (:fty (sandwich))))
    :rule-classes nil)
  )
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'FTY-DEFPROD-THEOREM-EXAMPLE
#          '(DEFTHM FTY-DEFPROD-THEOREM
#             (IMPLIES (AND (SANDWICH-P S1) (SANDWICH-P S2))
#                      (>= (X^2+Y^2 (SANDWICH->BREAD S1)
#                                   (SANDWICH->BREAD S2))
#                          0))
#             :HINTS (("Goal" :SMTLINK (:FTY (SANDWICH))))
#             :RULE-CLASSES NIL))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFTHM FTY-DEFPROD-THEOREM
#          (IMPLIES (AND (SANDWICH-P S1) (SANDWICH-P S2))
#                   (>= (X^2+Y^2 (SANDWICH->BREAD S1)
#                                (SANDWICH->BREAD S2))
#                       0))
#          :HINTS (("Goal" :SMTLINK (:FTY (SANDWICH))))
#          :RULE-CLASSES NIL)
#
#
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
# Using default SMT-trusted-cp...
# ; SMT solver: `python /tmp/py_file/smtlink.Kmw52`: 0.07 sec, 0 bytes
# Proved!
# Subgoal 2.2'4'
# Subgoal 2.2'5'
# Subgoal 2.1
# Subgoal 2.1'
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
# Subgoal 1'4'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM FTY-DEFPROD-THEOREM ...)
# Rules: ((:COMPOUND-RECOGNIZER CONSP-WHEN-SANDWICH-P)
#         (:DEFINITION NOT)
#         (:DEFINITION X^2+Y^2)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:TYPE-PRESCRIPTION NONNEGATIVE-PRODUCT)
#         (:TYPE-PRESCRIPTION SANDWICH->BREAD$INLINE))
# Hint-events: ((:CLAUSE-PROCESSOR ADD-HYPO-CP)
#               (:CLAUSE-PROCESSOR EXPAND-CP-FN)
#               (:CLAUSE-PROCESSOR PROCESS-HINT)
#               (:CLAUSE-PROCESSOR REMOVE-HINT-PLEASE)
#               (:CLAUSE-PROCESSOR SMT-TRUSTED-CP)
#               (:CLAUSE-PROCESSOR TYPE-EXTRACT-FN)
#               (:CLAUSE-PROCESSOR UNINTERPRETED-FN-CP))
# Time:  0.07 seconds (prove: 0.07, print: 0.00, other: 0.00)
# Prover steps counted:  259
# FTY-DEFPROD-THEOREM
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Time:  0.07 seconds (prove: 0.07, print: 0.00, other: 0.00)
# Prover steps counted:  259
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Time:  0.07 seconds (prove: 0.07, print: 0.00, other: 0.00)
# Prover steps counted:  259
#  FTY-DEFPROD-THEOREM

# %%
(acl2::must-fail
(defthm fty-defprod-theorem-fail
  (implies (and (sandwich-p s1)
                (sandwich-p s2))
           (>= (x^2+y^2
                (sandwich->bread (sandwich-fix s1))
                (sandwich->bread (sandwich-fix s2)))
               1))
  :hints(("Goal"
          :smtlink
          (:fty (sandwich))))
  :rule-classes nil)
)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  T

# %%
(def-saved-event x^2+y^2-fixed-example
  (define x^2+y^2-fixed ((x maybe-integer-p)
                         (y maybe-integer-p))
    :returns (res maybe-integer-p)
    (b* ((x (maybe-integer-fix x))
         (y (maybe-integer-fix y))
         ((if (equal x (maybe-integer-fix nil)))
          (maybe-integer-fix nil))
         ((if (equal y (maybe-integer-fix nil)))
          (maybe-integer-fix nil)))
      (maybe-integer-some
       (+ (* (maybe-integer-some->val x)
             (maybe-integer-some->val x))
          (* (maybe-integer-some->val y)
             (maybe-integer-some->val y))))))
  )
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'X^2+Y^2-FIXED-EXAMPLE
#          '(DEFINE X^2+Y^2-FIXED ((X MAYBE-INTEGER-P)
#                                  (Y MAYBE-INTEGER-P))
#             :RETURNS (RES MAYBE-INTEGER-P)
#             (B* ((X (MAYBE-INTEGER-FIX X))
#                  (Y (MAYBE-INTEGER-FIX Y))
#                  ((IF (EQUAL X (MAYBE-INTEGER-FIX NIL)))
#                   (MAYBE-INTEGER-FIX NIL))
#                  ((IF (EQUAL Y (MAYBE-INTEGER-FIX NIL)))
#                   (MAYBE-INTEGER-FIX NIL)))
#               (MAYBE-INTEGER-SOME (+ (* (MAYBE-INTEGER-SOME->VAL X)
#                                         (MAYBE-INTEGER-SOME->VAL X))
#                                      (* (MAYBE-INTEGER-SOME->VAL Y)
#                                         (MAYBE-INTEGER-SOME->VAL Y)))))))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFINE X^2+Y^2-FIXED ((X MAYBE-INTEGER-P)
#                               (Y MAYBE-INTEGER-P))
#          :RETURNS (RES MAYBE-INTEGER-P)
#          (B* ((X (MAYBE-INTEGER-FIX X))
#               (Y (MAYBE-INTEGER-FIX Y))
#               ((IF (EQUAL X (MAYBE-INTEGER-FIX NIL)))
#                (MAYBE-INTEGER-FIX NIL))
#               ((IF (EQUAL Y (MAYBE-INTEGER-FIX NIL)))
#                (MAYBE-INTEGER-FIX NIL)))
#            (MAYBE-INTEGER-SOME (+ (* (MAYBE-INTEGER-SOME->VAL X)
#                                      (MAYBE-INTEGER-SOME->VAL X))
#                                   (* (MAYBE-INTEGER-SOME->VAL Y)
#                                      (MAYBE-INTEGER-SOME->VAL Y))))))
#
# Since X^2+Y^2-FIXED is non-recursive, its admission is trivial.  We
# observe that the type of X^2+Y^2-FIXED is described by the theorem
# (OR (INTEGERP (X^2+Y^2-FIXED X Y)) (EQUAL (X^2+Y^2-FIXED X Y) NIL)).
# We used the :type-prescription rules MAYBE-INTEGER-FIX$INLINE and
# MAYBE-INTEGER-SOME.
#
# Computing the guard conjecture for X^2+Y^2-FIXED....
#
# The non-trivial part of the guard conjecture for X^2+Y^2-FIXED, given
# the :executable-counterparts of MAYBE-INTEGER-FIX$INLINE and MAYBE-INTEGER-P,
# is
#
# Goal
# (IMPLIES
#  (AND (MAYBE-INTEGER-P Y)
#       (MAYBE-INTEGER-P X))
#  (AND
#      (MAYBE-INTEGER-P X)
#      (LET ((X (MAYBE-INTEGER-FIX X)))
#        (AND (MAYBE-INTEGER-P Y)
#             (LET ((Y (MAYBE-INTEGER-FIX Y)))
#               (AND (OR (EQUAL X NIL)
#                        (EQUAL Y NIL)
#                        (MAYBE-INTEGER-P X))
#                    (OR (EQUAL X NIL) (EQUAL Y NIL) X)
#                    (OR (EQUAL X NIL)
#                        (EQUAL Y NIL)
#                        (ACL2-NUMBERP (MAYBE-INTEGER-SOME->VAL X)))
#                    (OR (EQUAL X NIL)
#                        (EQUAL Y NIL)
#                        (MAYBE-INTEGER-P Y))
#                    (OR (EQUAL X NIL) (EQUAL Y NIL) Y)
#                    (OR (EQUAL X NIL)
#                        (EQUAL Y NIL)
#                        (ACL2-NUMBERP (MAYBE-INTEGER-SOME->VAL Y)))
#                    (OR (EQUAL X NIL)
#                        (EQUAL Y NIL)
#                        (ACL2-NUMBERP (* (MAYBE-INTEGER-SOME->VAL X)
#                                         (MAYBE-INTEGER-SOME->VAL X))))
#                    (OR (EQUAL X NIL)
#                        (EQUAL Y NIL)
#                        (ACL2-NUMBERP (* (MAYBE-INTEGER-SOME->VAL Y)
#                                         (MAYBE-INTEGER-SOME->VAL Y))))
#                    (OR (EQUAL X NIL)
#                        (EQUAL Y NIL)
#                        (INTEGERP (+ (* (MAYBE-INTEGER-SOME->VAL X)
#                                        (MAYBE-INTEGER-SOME->VAL X))
#                                     (* (MAYBE-INTEGER-SOME->VAL Y)
#                                        (MAYBE-INTEGER-SOME->VAL Y))))))))))).
# Goal'
#
# Q.E.D.
#
# That completes the proof of the guard theorem for X^2+Y^2-FIXED.
# X^2+Y^2-FIXED is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN X^2+Y^2-FIXED ...)
# Rules: ((:DEFINITION NOT)
#         (:EXECUTABLE-COUNTERPART MAYBE-INTEGER-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART MAYBE-INTEGER-P)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE INTEGERP-WHEN-MAYBE-INTEGER-P)
#         (:REWRITE MAYBE-INTEGER-FIX-WHEN-MAYBE-INTEGER-P)
#         (:REWRITE MAYBE-INTEGER-P-WHEN-INTEGERP)
#         (:TYPE-PRESCRIPTION MAYBE-INTEGER-FIX$INLINE)
#         (:TYPE-PRESCRIPTION MAYBE-INTEGER-P)
#         (:TYPE-PRESCRIPTION MAYBE-INTEGER-SOME)
#         (:TYPE-PRESCRIPTION MAYBE-INTEGER-SOME->VAL$INLINE)
#         (:TYPE-PRESCRIPTION NONNEGATIVE-PRODUCT))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  536
#
#
# SMT !>>(DEFTHM MAYBE-INTEGER-P-OF-X^2+Y^2-FIXED
#          (B* ((RES (X^2+Y^2-FIXED X Y)))
#            (MAYBE-INTEGER-P RES))
#          :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'X^2+Y^2-FIXED
#                                                        ID WORLD))
#          :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM MAYBE-INTEGER-P-OF-X^2+Y^2-FIXED
# ...):  A :REWRITE rule generated from MAYBE-INTEGER-P-OF-X^2+Y^2-FIXED
# will be triggered only by terms containing the function symbol X^2+Y^2-FIXED,
# which has a non-recursive definition.  Unless this definition is disabled,
# this rule is unlikely ever to be used.
#
#
# Q.E.D.
#
# The storage of MAYBE-INTEGER-P-OF-X^2+Y^2-FIXED depends upon the :type-
# prescription rule MAYBE-INTEGER-P.
#
# Summary
# Form:  ( DEFTHM MAYBE-INTEGER-P-OF-X^2+Y^2-FIXED ...)
# Rules: ((:DEFINITION X^2+Y^2-FIXED)
#         (:EXECUTABLE-COUNTERPART MAYBE-INTEGER-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:TYPE-PRESCRIPTION MAYBE-INTEGER-P))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  44
# MAYBE-INTEGER-P-OF-X^2+Y^2-FIXED
#
# Summary
# Form:  ( PROGN (DEFTHM MAYBE-INTEGER-P-OF-X^2+Y^2-FIXED ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Prover steps counted:  44
# X^2+Y^2-FIXED
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.02 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Prover steps counted:  580
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.02 seconds (prove: 0.01, print: 0.00, other: 0.01)
# Prover steps counted:  580
#  X^2+Y^2-FIXED

# %%
(def-saved-event fty-defoption-theorem-example
  (defthm fty-defoption-theorem
    (implies (and (maybe-integer-p m1)
                  (maybe-integer-p m2)
                  (not (equal m1 (maybe-integer-fix nil)))
                  (not (equal m2 (maybe-integer-fix nil))))
             (>= (maybe-integer-some->val (x^2+y^2-fixed m1 m2))
               0))
    :hints(("Goal"
            :smtlink
            (:fty (maybe-integer))))
    :rule-classes nil)
  )
# Out:
# SMT !>>(TABLE SV::SAVED-FORMS-TABLE
#          'FTY-DEFOPTION-THEOREM-EXAMPLE
#          '(DEFTHM FTY-DEFOPTION-THEOREM
#             (IMPLIES (AND (MAYBE-INTEGER-P M1)
#                           (MAYBE-INTEGER-P M2)
#                           (NOT (EQUAL M1 (MAYBE-INTEGER-FIX NIL)))
#                           (NOT (EQUAL M2 (MAYBE-INTEGER-FIX NIL))))
#                      (>= (MAYBE-INTEGER-SOME->VAL (X^2+Y^2-FIXED M1 M2))
#                          0))
#             :HINTS (("Goal" :SMTLINK (:FTY (MAYBE-INTEGER))))
#             :RULE-CLASSES NIL))
#
# Summary
# Form:  ( TABLE SV::SAVED-FORMS-TABLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# SV::SAVED-FORMS-TABLE
#
#
# SMT !>>(DEFTHM FTY-DEFOPTION-THEOREM
#          (IMPLIES (AND (MAYBE-INTEGER-P M1)
#                        (MAYBE-INTEGER-P M2)
#                        (NOT (EQUAL M1 (MAYBE-INTEGER-FIX NIL)))
#                        (NOT (EQUAL M2 (MAYBE-INTEGER-FIX NIL))))
#                   (>= (MAYBE-INTEGER-SOME->VAL (X^2+Y^2-FIXED M1 M2))
#                       0))
#          :HINTS (("Goal" :SMTLINK (:FTY (MAYBE-INTEGER))))
#          :RULE-CLASSES NIL)
#
#
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
# Using default SMT-trusted-cp...
# ; SMT solver: `python /tmp/py_file/smtlink.De7D4`: 0.07 sec, 0 bytes
# Proved!
# Subgoal 2.2'4'
# Subgoal 2.2'5'
# Subgoal 2.2'6'
# Subgoal 2.2'7'
# Subgoal 2.1
# Subgoal 2.1'
# Subgoal 2.1''
# Subgoal 2.1'''
# Subgoal 2.1'4'
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM FTY-DEFOPTION-THEOREM ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:DEFINITION HIDE)
#         (:DEFINITION IFIX)
#         (:DEFINITION NOT)
#         (:DEFINITION TYPE-HYP)
#         (:DEFINITION X^2+Y^2-FIXED)
#         (:EXECUTABLE-COUNTERPART ACL2::BOOL-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART ACL2::BOOLEAN-LIST-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART CDR)
#         (:EXECUTABLE-COUNTERPART CONS)
#         (:EXECUTABLE-COUNTERPART CONSP)
#         (:EXECUTABLE-COUNTERPART IF)
#         (:EXECUTABLE-COUNTERPART MAYBE-INTEGER-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART MAYBE-INTEGER-P)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE ACL2::BOOL-FIX-WHEN-BOOLEANP)
#         (:REWRITE ACL2::BOOLEAN-LIST-FIX-OF-CONS)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE INTEGERP-WHEN-MAYBE-INTEGER-P)
#         (:REWRITE MAYBE-INTEGER-FIX-WHEN-MAYBE-INTEGER-P)
#         (:REWRITE MAYBE-INTEGER-P-WHEN-INTEGERP)
#         (:REWRITE MAYBE-INTEGER-SOME->VAL-OF-MAYBE-INTEGER-SOME)
#         (:TYPE-PRESCRIPTION MAYBE-INTEGER-P)
#         (:TYPE-PRESCRIPTION MAYBE-INTEGER-SOME->VAL$INLINE)
#         (:TYPE-PRESCRIPTION NONNEGATIVE-PRODUCT))
# Hint-events: ((:CLAUSE-PROCESSOR ADD-HYPO-CP)
#               (:CLAUSE-PROCESSOR EXPAND-CP-FN)
#               (:CLAUSE-PROCESSOR PROCESS-HINT)
#               (:CLAUSE-PROCESSOR REMOVE-HINT-PLEASE)
#               (:CLAUSE-PROCESSOR SMT-TRUSTED-CP)
#               (:CLAUSE-PROCESSOR TYPE-EXTRACT-FN)
#               (:CLAUSE-PROCESSOR UNINTERPRETED-FN-CP))
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  1489
# FTY-DEFOPTION-THEOREM
#
# Summary
# Form:  ( PROGN (TABLE SV::SAVED-FORMS-TABLE ...) ...)
# Rules: NIL
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  1489
#
# Summary
# Form:  ( MAKE-EVENT (LET* ...))
# Rules: NIL
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  1489
#  FTY-DEFOPTION-THEOREM

# %%
(acl2::must-fail
(defthm fty-defoption-theorem-fail
  (implies (and (maybe-integer-p m1)
                (maybe-integer-p m2)
                (not (equal m1 (maybe-integer-fix nil)))
                (not (equal m2 (maybe-integer-fix nil))))
           (>= (maybe-integer-some->val (x^2+y^2-fixed m1 m2))
               1))
  :hints(("Goal"
          :smtlink
          (:fty (maybe-integer))))
  :rule-classes nil)
)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  T

# %%
(acl2::must-fail
(defthm bogus-revised
  (implies (and (symbolp symx) (symbolp symy))
           (or (eq (symbol-fix symx) 'sym1) (eq (symbol-fix symx) 'sym2)
               (eq (symbol-fix symx) 'sym3)
               (eq (symbol-fix symy) 'sym1) (eq (symbol-fix symy) 'sym2)
               (eq (symbol-fix symy) 'sym3)
               (eq (symbol-fix symx)
                   (symbol-fix symy))))
  :hints (("Goal" :smtlink nil)))
)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
#
# HARD ACL2 ERROR in SMT-TRANSLATOR=>TRANSLATE-FUNCTION:  Not a basic
# SMT function: SYMBOLP
#
#
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
#  T

# %%
(acl2::must-fail
(defthm bogus-revised-still-bogus
  (implies (and (symbolp symx) (symbolp symy))
           (or (eq symx 'symx) (eq symx 'sym2)
               (eq symx 'sym3)
               (eq symy 'symx) (eq symy 'sym2)
               (eq symy 'sym3)
               (eq symx symy)))
  :hints (("Goal" :smtlink nil)))
)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.01, print: 0.00, other: 0.00)
#  T

# %%
(defprod sym-prod
  ((sym symbolp)))
# Out:
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-SYMBOLP-OF-SYMBOL-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ACL2::ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 4
# Subgoal 3
# Subgoal 3.2
# Subgoal 3.2.2
# Subgoal 3.2.2'
# Subgoal 3.2.1
# Subgoal 3.1
# Subgoal 3.1'
# Subgoal 2
# Subgoal 1
# Form:  ( DEFUN SYM-PROD-P ...)
# Time:  0.08 seconds (prove: 0.07, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CONSP-WHEN-SYM-PROD-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SYM-PROD-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN SYM-PROD-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM SYM-PROD-P-OF-SYM-PROD-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SYM-PROD-P-OF-SYM-PROD-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SYM-PROD-FIX-WHEN-SYM-PROD-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS SYM-PROD-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (DEFFIXTYPE ... T) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SYM-PROD->SYM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN SYM-PROD->SYM$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SYMBOLP-OF-SYM-PROD->SYM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SYMBOLP-OF-SYM-PROD->SYM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SYM-PROD->SYM$INLINE-OF-SYM-PROD-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV SYM-PROD->SYM ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN SYM-PROD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM SYM-PROD-P-OF-SYM-PROD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SYM-PROD-P-OF-SYM-PROD ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM SYM-PROD->SYM-OF-SYM-PROD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SYM-PROD-OF-FIELDS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SYM-PROD-FIX-WHEN-SYM-PROD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 3
# Subgoal 3'
# Subgoal 3''
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM EQUAL-OF-SYM-PROD ...)
# Time:  0.05 seconds (prove: 0.02, print: 0.00, other: 0.02)
# Goal'
# Form:  ( DEFTHM SYM-PROD-OF-SYMBOL-FIX-SYM ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFMACRO PATBIND-SYM-PROD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-SYM-PROD ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-SYM-PROD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-SYM-PROD ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SYM-PROD->SYM-OF-SYM-PROD ...) ...)
# Time:  0.05 seconds (prove: 0.03, print: 0.00, other: 0.03)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SYM-PROD-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SYM-PROD ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SYM-PROD ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE ACL2::XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.25 seconds (prove: 0.11, print: 0.00, other: 0.14)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.26 seconds (prove: 0.11, print: 0.00, other: 0.15)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFPROD-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.26 seconds (prove: 0.11, print: 0.00, other: 0.15)
# Prover steps counted:  2675
#  T

# %%
(acl2::must-fail
(defthm bogus-revised-still-bogus-prod
  (implies (and (sym-prod-p x) (sym-prod-p y))
           (or (eq (sym-prod->sym x) 'sym1) (eq (sym-prod->sym x) 'sym2)
               (eq (sym-prod->sym x) 'sym3)
               (eq (sym-prod->sym y) 'sym1) (eq (sym-prod->sym y) 'sym2)
               (eq (sym-prod->sym y) 'sym3)
               (eq (sym-prod->sym x) (sym-prod->sym y))))
  :hints (("Goal" :smtlink (:fty (sym-prod)))))
)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  T

# %%
(acl2::must-fail
 (defthm check-guard
   (implies (acl2::integer-listp x)
            (equal (1+ (1- (car (acl2::integer-list-fix x))))
                   (car (acl2::integer-list-fix x))))
   :hints (("Goal" :smtlink (:fty (acl2::integer-list)))))
)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
# Subgoal 2.2'4'
# Subgoal 2.2'5'
# Subgoal 2.2'6'
# Subgoal 2.2'7'
# Subgoal 2.2'8'
# Subgoal 2.2'9'
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Prover steps counted:  267
#  T

# %%
(acl2::must-fail
 (defthm check-guard-2
   (implies (and (symbol-integer-alist-p l)
                 (symbolp x))
            (equal (1+ (1- (cdr
                            (magic-fix 'symbolp_integerp
                                       (assoc-equal x (symbol-integer-alist-fix
                                                       l))))))
                   (cdr (magic-fix 'symbolp_integerp
                                   (assoc-equal x (symbol-integer-alist-fix l))))))
   :hints (("Goal" :smtlink (:fty (symbol-integer-alist)))))
 )
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
# Subgoal 2.2'4'
# Subgoal 2.2'5'
# Subgoal 2.2'6'
# Subgoal 2.2'7'
# Subgoal 2.2'8'
# Subgoal 2.2'9'
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Prover steps counted:  667
#  T

# %%
(defthm check-guard-3
  (implies (maybe-integer-p x)
           (equal (1+ (1- (maybe-integer-some->val
                           (maybe-integer-fix x))))
                  (maybe-integer-some->val
                   (maybe-integer-fix x))))
  :hints (("Goal" :smtlink (:fty (maybe-integer))))
  )
# Out:
# ACL2 Warning [Subsume] in ( DEFTHM CHECK-GUARD-3 ...):  The previously
# added rules ACL2::COMMUTATIVITY-2-OF-+ and COMMUTATIVITY-OF-+ subsume
# a newly proposed :REWRITE rule generated from CHECK-GUARD-3, in the
# sense that the old rules rewrite more general targets.  Because the
# new rule will be tried first, it may nonetheless find application.
#
#
#
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
# Using default SMT-trusted-cp...
# ; SMT solver: `python /tmp/py_file/smtlink.Kwt1V`: 0.07 sec, 0 bytes
# Proved!
# Subgoal 2.2'4'
# Subgoal 2.2'5'
# Subgoal 2.2'6'
# Subgoal 2.2'7'
# Subgoal 2.1
# Subgoal 2.1'
# Subgoal 2.1''
# Subgoal 2.1'''
# Subgoal 1
# Subgoal 1'
#
# Q.E.D.
#
# Summary
# Form:  ( DEFTHM CHECK-GUARD-3 ...)
# Rules: ((:CONGRUENCE
#           MAYBE-INTEGER-SOME->VAL$INLINE-MAYBE-INTEGER-EQUIV-CONGRUENCE-ON-X)
#         (:DEFINITION NOT)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:REWRITE MAYBE-INTEGER-FIX-UNDER-MAYBE-INTEGER-EQUIV)
#         (:TYPE-PRESCRIPTION MAYBE-INTEGER-SOME->VAL$INLINE))
# Hint-events: ((:CLAUSE-PROCESSOR ADD-HYPO-CP)
#               (:CLAUSE-PROCESSOR EXPAND-CP-FN)
#               (:CLAUSE-PROCESSOR PROCESS-HINT)
#               (:CLAUSE-PROCESSOR REMOVE-HINT-PLEASE)
#               (:CLAUSE-PROCESSOR SMT-TRUSTED-CP)
#               (:CLAUSE-PROCESSOR TYPE-EXTRACT-FN)
#               (:CLAUSE-PROCESSOR UNINTERPRETED-FN-CP))
# Warnings:  Subsume
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Prover steps counted:  199
#  CHECK-GUARD-3

# %%
(acl2::must-fail
 (defthm check-guard-3-fail
   (implies (maybe-integer-p x)
            (equal (1+ (1- (maybe-integer-fix x)))
                   (maybe-integer-fix x)))
   :hints (("Goal" :smtlink (:fty (maybe-integer))))
   )
 )
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
#
# HARD ACL2 ERROR in SMT-RUN=>SMT-INTERPRET:  Z3 failure: ("Traceback (most recent call last):"
#                                                          "File \"/tmp/py_file/smtlink.muJPA\", line 14, in <module>"
#                                                          "theorem = _SMT_.equal(_SMT_.plus(1,_SMT_.plus(-1,x)),x)"
#                                                          "^^^^^^^^^^^^^^^^"
#                                                          "File \"/home/acl2/books/projects/smtlink/z3_interface/ACL2_to_Z3.py\", line 91, in plus"
#                                                          "def plus(self, *args): return reduce(lambda x, y: x+y, args)"
#                                                          "^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^"
#                                                          ...)
# (See :DOC set-iprint to be able to see elided values in this message.)
#
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  T

# %%
(acl2::must-fail
(defthm check-rational-cex
  (implies (rationalp x)
           (not (equal x 1/4)))
  :hints (("Goal" :smtlink (:fty (maybe-integer))))
  )
)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  T

# %%
(acl2::must-fail
 (defthm check-boolean-cex
   (implies (booleanp x)
            (not (equal x nil)))
   :hints (("Goal" :smtlink (:fty (maybe-integer))))
   )
 )
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  T

# %%
(acl2::must-fail
 (defthm check-symbol-cex
   (implies (symbolp x)
            (not (equal x 'arbitrary-sym)))
   :hints (("Goal" :smtlink (:fty (maybe-integer))))
   )
 )
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  T

# %%
;; algebraic counter-example example by Carl Kwan
(acl2::must-fail
(defthm poly-sat-7
  (implies (and (real/rationalp x)
                (equal (* (+ x -1) (+ x 1) (+ x 2)) 0)
                (< x 0)
                (real/rationalp y)
                (equal (* y y) 2))
           (and (equal x -1)
                (< y 0)))
  :rule-classes nil
  :hints (("Goal"
		       :smtlink nil)))
)
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.01 seconds (prove: 0.01, print: 0.00, other: 0.00)
#  T

# %%
(deftutorial FTY-examples
  :parents (Tutorial)
  :short "A list of FTY examples"
  :long "<h3>FTY examples</h3>
<p>Prerequisite read for this tutorial example is @(tsee tutorial).</p>
<p>Smtlink supports types defined by @(tsee acl2::FTY) macros @(tsee defprod), @(tsee
  deflist), @(tsee defalist) and @(tsee defoption). We show here an example for
  each type.</p>

<h4>defprod</h4>
<p>Define the function @('x^2+y^2')</p>
@(`(:code ($ ||x^2+y^2||))`)

<p>Define the defprod @('sandwich')</p>
@(`(:code ($ sandwich))`)

<p>Then define the theorem to prove:</p>
@(`(:code ($ fty-defprod-theorem-example))`)

<p>This theorem says, given two @('sandwich-p'), then the square sum of the
bread field of the two sandwiches should be non-negative. This example doesn't
quite make sense.  Here we use this as an example to show how @('defprod')
defined types can be used in a theorem to be discharged by Smtlink.</p>

<p>We notice the @(':fty') hint is used to tell Smtlink which set of FTY types
we will use in proving this theorem. Here, we use the FTY type
@('sandwich'). Smtlink will check @('fty::flextypes-table') for information
about this FTY type.</p>

<p>Counter-examples for defprods like like:</p>
@({
Possible counter-example found:
((S2 (SANDWICH 0 (SYM 2))) (S1 (SANDWICH 0 (SYM 1))))
})


<h4>deflist</h4>
<p>Define the theorem to prove:</p>
@(`(:code ($ fty-deflist-theorem-example))`)

<p>This theorem says, given a list of integers, if there are at least two
elements, then the square sum of the two elements should be non-negative.</p>

<p>First, Smtlink only allows types defined by deflist that are @(tsee
true-listp).  We notice the @(':fty') hint is used to tell Smtlink which set of
FTY types we will use in proving this theorem. Here, we use the FTY type
@('acl2::integer-list'). Smtlink will check @('fty::flextypes-table') to make
sure the given deflist type is a true-listp.</p>

<p>Second, we notice extra fixing functions @(tsee acl2::integer-list-fix)
functions are added. This is because Z3 lists are typed. The polymorphic
functions like @('car') when translated into Z3, also become typed. Therefore
we need to inference which @('car') we want to apply here. Currently Smtlink
doesn't have type inference ability, therefore it requires the user to add
fixing functions for telling it the types.</p>

<p>Counter-examples for deflists like like:</p>
@({
Possible counter-example found: ((L (CONS 0 (CONS 0 NIL))))
})

<h4>defalist</h4>
<p>Define the defalist @('symbol-integer-alist')</p>
@(`(:code ($ symbol-integer-example))`)

<p>Then define the theorem to prove:</p>
@(`(:code ($ fty-defalist-theorem-example))`)

<p>This theorem says, given a symbol-integer-alist l, two symbols s1 and s2, if
one can find both s1 and s2 in the alist l, then the values satisfy that their
square sum is non-negative. I hope the square sum example hasn't bored you yet
at this point.</p>

<p>Similar to deflists, we notice extra fixing functions
@('symbol-integer-alist-fix') functions are added due to similar reasons. In
addition, we notice ACL2 doesn't have a type specification for the thing
returned by an assoc-equal. To make sure @('cdr') knows what its argument type
is, we add a @('magic-fix') function.</p>

<p>Counter-examples for defalists like like:</p>
@({
((S2 (SYM 2)) (L (K SYMBOL (SOME 0))) (S1 (SYM 1)))
})

<p>Here, the counter-example for alist l is</p>
 @({(K SYMBOL (SOME 0))})
<p>This means in Z3 a constant array mapping from symbols to the maybe integer
 0. Also, @('SYM') stands for generated symbols for symbol
 counter-examples.</p>

<h4>defoption</h4>
<p>Define the defoption @('maybe-integer')</p>
@(`(:code ($ maybe-integer-example))`)

<p>Define the fixed version of @('x^2+y^2')</p>
@(`(:code ($ x^2+y^2-fixed-example))`)

<p>Then define the theorem to prove:</p>
@(`(:code ($ fty-defoption-theorem-example))`)

<p>This theorem says, given a maybe-integer m1 and a maybe-integer m2, if they
are not nils, then the square sum of their values is non-negative.</p>

<p>Similar to deflists and defalists, we notice extra fixing functions
@('maybe-integer-fix') functions are added due to similar reasons. In addition,
we notice in definition of function @('x^2+y^2-fixed'), even when one knows x
and y are not nil, they are still maybe-integers. Therefore, field-accessors
and constructors are required.</p>

<p>Counter-examples for defalists like like:</p>
@({
Possible counter-example found: ((M2 (SOME 0)) (M1 (SOME 0)))
})

")

# %%
(defthm poly-ineq-example-with-prog2$
  (implies (and (real/rationalp x) (real/rationalp y)
                (<= (+ (* (/ 9 8) x x) (* y y)) 1)
                (<= (prog2$ (cw "I'm here!~%")
                            (x^2-y^2 x y))
                    1))
           (< y (- (* 3 (- x (/ 17 8)) (- x (/ 17 8))) 3)))
  :hints(("Goal"
          :smtlink nil)))
# Out:
# The event ( DEFTHM POLY-INEQ-EXAMPLE-WITH-PROG2$ ...) is redundant.
# See :DOC redundant-events.
#
# Summary
# Form:  ( DEFTHM POLY-INEQ-EXAMPLE-WITH-PROG2$ ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  :REDUNDANT

# %%
;; Abstract datatype example
(encapsulate
  (((abstract-p *) => *))
  (local
   (defun abstract-p (x)
       (acl2::any-p x))))
# Out:
# The event ( ENCAPSULATE (((ABSTRACT-P * ...) ...) ...) ...) is redundant.
# See :DOC redundant-events.
#
# Summary
# Form:  ( ENCAPSULATE (((ABSTRACT-P * ...) ...) ...) ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  :REDUNDANT

# %%
(defthm abstract-example
  (implies (abstract-p x)
           (equal x x))
  :hints(("Goal"
          :smtlink (:abstract (abstract-p))))
  :rule-classes nil)
# Out:
# The event ( DEFTHM ABSTRACT-EXAMPLE ...) is redundant.  See :DOC redundant-
# events.
#
# Summary
# Form:  ( DEFTHM ABSTRACT-EXAMPLE ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  :REDUNDANT

# %%
;; Thanks to Andrew Walter and Pete Manolios for providing this bug example.
;; In this example, it used to be that unary-/ is translated to be integer
;; division in Z3. Since unary-/ is interpreted as integer division and x >=
;; 10, 1/x is 0, which makes y 0. We fixed this problem by casting the input of
;; unary-/ to be real. Check the reciprocal function in ACL2_to_Z3.py for
;; detail.
(acl2::must-fail
 (defthm smt-not-integer-division
   (implies (and (integerp x)
                 (integerp y)
                 (integerp z)
                 (>= x 10)
                 (= y (* (unary-/ x) z)))
            (= y 0))
   :hints (("goal" :smtlink nil))
   :rule-classes nil)
 )
# Out:
# Using clause-processor Smtlink
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal 2
# Subgoal 2'
# Subgoal 2.2
# Subgoal 2.2'
# Subgoal 2.2''
# Subgoal 2.2'''
#
# Summary
# Form:  ( MAKE-EVENT (QUOTE ...) ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
#  T
