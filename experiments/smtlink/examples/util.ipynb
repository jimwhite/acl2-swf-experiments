# %% [raw]
# ;; Copyright (C) 2015, University of British Columbia
# ;; Written by Yan Peng (May 2019)
# ;;
# ;; License: A 3-clause BSD license.
# ;; See the LICENSE file distributed with ACL2

# %%
(in-package "SMT")
(include-book "std/util/define" :dir :system)
(include-book "std/util/bstar" :dir :system)
(include-book "centaur/fty/top" :dir :system) ; for defalist, etc.
(include-book "projects/smtlink/top" :dir :system :ttags :all)
(include-book "basictypes")
# Out:
#  "SMT"
#
# Summary
# Form:  ( INCLUDE-BOOK "std/util/define" ...)
# Rules: NIL
# Time:  0.05 seconds (prove: 0.00, print: 0.00, other: 0.05)
#  "/home/acl2/books/std/util/define.lisp"
#
# The event ( INCLUDE-BOOK "std/util/bstar" ...) is redundant.  See :DOC
# redundant-events.
#
# Summary
# Form:  ( INCLUDE-BOOK "std/util/bstar" ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  :REDUNDANT
#
# Summary
# Form:  ( INCLUDE-BOOK "centaur/fty/top" ...)
# Rules: NIL
# Time:  0.40 seconds (prove: 0.00, print: 0.00, other: 0.40)
#  "/home/acl2/books/centaur/fty/top.lisp"
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP from book /home/acl2/books/quicklisp/base.
#
# TTAG NOTE (for included book): Adding ttag :QUICKLISP.SHELLPOOL from book /home/acl2/books/quicklisp/shellpool.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/projects/smtlink/trusted/run.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/projects/smtlink/trusted/write.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/projects/smtlink/trusted/prove.
#
# TTAG NOTE (for included book): Adding ttag :TSHELL from book /home/acl2/books/centaur/misc/tshell.
#
# TTAG NOTE (for included book): Adding ttag :READ-STRING from book /home/acl2/books/projects/smtlink/trusted/run.
#
# TTAG NOTE (for included book): Adding ttag :READ-STRING from book /home/acl2/books/std/io/read-string.
#
# TTAG NOTE (for included book): Adding ttag :WRITES-OKP from book /home/acl2/books/projects/smtlink/trusted/write.
#
# TTAG NOTE (for included book): Adding ttag :SMTLINK from book /home/acl2/books/projects/smtlink/trusted/trusted-cp.
#
# TTAG NOTE (for included book): Adding ttag :SMTLINK-CUSTOM from book /home/acl2/books/projects/smtlink/trusted/trusted-cp.
#
# Summary
# Form:  ( INCLUDE-BOOK "projects/smtlink/top" ...)
# Rules: NIL
# Time:  1.14 seconds (prove: 0.00, print: 0.00, other: 1.14)
#  "/home/acl2/books/projects/smtlink/top.lisp"
#
# Summary
# Form:  ( INCLUDE-BOOK "basictypes" ...)
# Rules: NIL
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
#  "/workspaces/acl2-swf-experiments/experiments/smtlink/examples/basictypes.lisp"

# %%
(defprod sig
  ((module symbolp)
   (index integerp)))
# Out:
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-SYMBOLP-OF-SYMBOL-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-INTEGERP-OF-IFIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-IFIX-WHEN-INTEGERP ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ACL2::ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 5
# Subgoal 4
# Subgoal 4.2
# Subgoal 4.2.2
# Subgoal 4.2.2'
# Subgoal 4.2.1
# Subgoal 4.1
# Subgoal 4.1'
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Subgoal 1'
# Form:  ( DEFUN SIG-P ...)
# Time:  0.07 seconds (prove: 0.07, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CONSP-WHEN-SIG-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (MAKE-EVENT ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SIG-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN SIG-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM SIG-P-OF-SIG-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SIG-P-OF-SIG-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SIG-FIX-WHEN-SIG-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Subgoal 1'
# Subgoal 1''
# Subgoal 1'''
# Form:  ( VERIFY-GUARDS SIG-FIX$INLINE ...)
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (DEFFIXTYPE ... T) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.04 seconds (prove: 0.03, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SIG->MODULE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN SIG->MODULE$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SYMBOLP-OF-SIG->MODULE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SYMBOLP-OF-SIG->MODULE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SIG->MODULE$INLINE-OF-SIG-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV SIG->MODULE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SIG->INDEX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFUN SIG->INDEX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM INTEGERP-OF-SIG->INDEX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM INTEGERP-OF-SIG->INDEX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SIG->INDEX$INLINE-OF-SIG-FIX-X ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( PROGN (FTY::DEFFIXEQUIV SIG->INDEX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFUN SIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM SIG-P-OF-SIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SIG-P-OF-SIG ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM SIG->MODULE-OF-SIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Form:  ( DEFTHM SIG->INDEX-OF-SIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SIG-OF-FIELDS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SIG-FIX-WHEN-SIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 4
# Subgoal 4'
# Subgoal 4''
# Subgoal 4'''
# Subgoal 3
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM EQUAL-OF-SIG ...)
# Time:  0.05 seconds (prove: 0.03, print: 0.00, other: 0.02)
# Goal'
# Form:  ( DEFTHM SIG-OF-SYMBOL-FIX-MODULE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM SIG-OF-IFIX-INDEX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFMACRO PATBIND-SIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::B*-BINDER-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFMACRO PATBIND-SIG ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO MAKE-SIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO CHANGE-SIG ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SIG->MODULE-OF-SIG ...) ...)
# Time:  0.06 seconds (prove: 0.04, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SIG-FIX-REDEF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SIG ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SIG ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE ACL2::XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.29 seconds (prove: 0.14, print: 0.00, other: 0.14)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.30 seconds (prove: 0.14, print: 0.00, other: 0.15)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFPROD-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.30 seconds (prove: 0.14, print: 0.00, other: 0.15)
# Prover steps counted:  6565
#  T

# %%
(deflist sig-path
  :elt-type sig-p
  :true-listp t)
# Out:
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ACL2::ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN SIG-PATH-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# Deflist: attempting to show, using your current theory, that (SIG-P X)
# is always Boolean valued.
#
# Deflist: introducing SIG-PATH-P and proving deflist theorems.
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SIG-PATH-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN SIG-PATH-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-P-OF-SIG-PATH-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SIG-PATH-P-OF-SIG-PATH-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-FIX-WHEN-SIG-PATH-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS SIG-PATH-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (DEFFIXTYPE ... T) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Form:  ( DEFTHM CAR-OF-SIG-PATH-FIX-X-UNDER-SIG-EQUIV ...)
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
# Form:  ( DEFTHM CDR-OF-SIG-PATH-FIX-X-UNDER-SIG-PATH-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-SIG-FIX-X-UNDER-SIG-PATH-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-SIG-PATH-FIX-Y-UNDER-SIG-PATH-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM CONSP-OF-SIG-PATH-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SIG-PATH-FIX-UNDER-IFF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SIG-PATH-FIX-OF-CONS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM LEN-OF-SIG-PATH-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM SIG-PATH-FIX-OF-APPEND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM SIG-PATH-FIX-OF-REPEAT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/4
# Subgoal *1/4'
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM LIST-EQUIV-REFINES-SIG-PATH-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/3
# Subgoal *1/3.9
# Subgoal *1/3.9'
# Subgoal *1/3.9''
# Subgoal *1/3.9'''
# Subgoal *1/3.8
# Subgoal *1/3.7
# Subgoal *1/3.6
# Subgoal *1/3.5
# Subgoal *1/3.4
# Subgoal *1/3.3
# Subgoal *1/3.3'
# Subgoal *1/3.3''
# Subgoal *1/3.3'''
# Subgoal *1/3.2
# Subgoal *1/3.2'
# Subgoal *1/3.2''
# Subgoal *1/3.2'''
# Subgoal *1/3.1
# Subgoal *1/3.1'
# Subgoal *1/3.1''
# Subgoal *1/3.1'''
# Subgoal *1/2
# Subgoal *1/2.3
# Subgoal *1/2.3'
# Subgoal *1/2.2
# Subgoal *1/2.2'
# Subgoal *1/2.2''
# Subgoal *1/2.2'''
# Subgoal *1/2.1
# Subgoal *1/2.1'
# Subgoal *1/1
# Form:  ( DEFTHM NTH-OF-SIG-PATH-FIX ...)
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-EQUIV-IMPLIES-SIG-PATH-EQUIV-APPEND-1 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-EQUIV-IMPLIES-SIG-PATH-EQUIV-APPEND-2 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-EQUIV-IMPLIES-SIG-PATH-EQUIV-NTHCDR-2 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (ACL2::DEFCONG-FORM ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-EQUIV-IMPLIES-SIG-PATH-EQUIV-TAKE-2 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (ACL2::DEFCONG-FORM ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.14 seconds (prove: 0.12, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SIG-PATH ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SIG-PATH ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE ACL2::XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.23 seconds (prove: 0.13, print: 0.00, other: 0.10)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.25 seconds (prove: 0.13, print: 0.00, other: 0.12)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFLIST-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.25 seconds (prove: 0.13, print: 0.00, other: 0.12)
# Prover steps counted:  9644
#  T

# %%
(deflist sig-path-list
  :elt-type sig-path
  :pred sig-path-listp
  :true-listp t)
# Out:
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ACL2::ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN SIG-PATH-LISTP ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# Deflist: attempting to show, using your current theory, that (SIG-PATH-P X)
# is always Boolean valued.
#
# Deflist: introducing SIG-PATH-LISTP and proving deflist theorems.
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO SIG-PATH-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN SIG-PATH-LIST-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-LISTP-OF-SIG-PATH-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM SIG-PATH-LISTP-OF-SIG-PATH-LIST-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-LIST-FIX-WHEN-SIG-PATH-LISTP ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS SIG-PATH-LIST-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (DEFFIXTYPE ... T) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Form:  ( DEFTHM CAR-OF-SIG-PATH-LIST-FIX-X-UNDER-SIG-PATH-EQUIV ...)
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
# Form:  ( DEFTHM CDR-OF-SIG-PATH-LIST-FIX-X-UNDER-SIG-PATH-LIST-EQUIV
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-SIG-PATH-FIX-X-UNDER-SIG-PATH-LIST-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-SIG-PATH-LIST-FIX-Y-UNDER-SIG-PATH-LIST-EQUIV
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM CONSP-OF-SIG-PATH-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM SIG-PATH-LIST-FIX-UNDER-IFF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM SIG-PATH-LIST-FIX-OF-CONS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM LEN-OF-SIG-PATH-LIST-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM SIG-PATH-LIST-FIX-OF-APPEND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM SIG-PATH-LIST-FIX-OF-REPEAT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/4
# Subgoal *1/4'
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM LIST-EQUIV-REFINES-SIG-PATH-LIST-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/3
# Subgoal *1/3.9
# Subgoal *1/3.9'
# Subgoal *1/3.9''
# Subgoal *1/3.8
# Subgoal *1/3.7
# Subgoal *1/3.6
# Subgoal *1/3.5
# Subgoal *1/3.4
# Subgoal *1/3.3
# Subgoal *1/3.3'
# Subgoal *1/3.3''
# Subgoal *1/3.2
# Subgoal *1/3.2'
# Subgoal *1/3.2''
# Subgoal *1/3.1
# Subgoal *1/3.1'
# Subgoal *1/3.1''
# Subgoal *1/2
# Subgoal *1/2.3
# Subgoal *1/2.3'
# Subgoal *1/2.2
# Subgoal *1/2.2'
# Subgoal *1/2.2''
# Subgoal *1/2.2'''
# Subgoal *1/2.1
# Subgoal *1/2.1'
# Subgoal *1/1
# Form:  ( DEFTHM NTH-OF-SIG-PATH-LIST-FIX ...)
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-LIST-EQUIV-IMPLIES-SIG-PATH-LIST-EQUIV-APPEND-1
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-LIST-EQUIV-IMPLIES-SIG-PATH-LIST-EQUIV-APPEND-2
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-LIST-EQUIV-IMPLIES-SIG-PATH-LIST-EQUIV-NTHCDR-2
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (ACL2::DEFCONG-FORM ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM SIG-PATH-LIST-EQUIV-IMPLIES-SIG-PATH-LIST-EQUIV-TAKE-2
# ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (ACL2::DEFCONG-FORM ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.15 seconds (prove: 0.13, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SIG-PATH-LIST ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC SIG-PATH-LIST ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE ACL2::XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.24 seconds (prove: 0.13, print: 0.00, other: 0.11)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.26 seconds (prove: 0.13, print: 0.00, other: 0.13)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFLIST-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.26 seconds (prove: 0.13, print: 0.00, other: 0.13)
# Prover steps counted:  9628
#  T

# %%
(defalist any-table
  :key-type sig-path-p
  :val-type booleanp
  :true-listp t)
# Out:
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ACL2::TMP-DEFTYPES-BOOLEANP-OF-BOOL-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (QUOTE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ACL2::ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN ANY-TABLE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Disable] in ( IN-THEORY (THEORY ...)):  Forcing has transitioned
# from disabled to enabled.
# See :DOC force.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-UPDATE-NTH
# ...):  In a :REWRITE rule generated from ANY-TABLE-P-OF-UPDATE-NTH,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at two problematic occurrences of variable ACL2::Y in the right-hand
# side, but not at any binding occurrence of ACL2::Y.  Consider replacing
# those two occurrences of ACL2::Y in the right-hand side with
# (DOUBLE-REWRITE ACL2::Y).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-UPDATE-NTH
# ...):  In a :REWRITE rule generated from ANY-TABLE-P-OF-UPDATE-NTH,
# equivalence relations STR::ICHARLISTEQV, STR::CHARLISTEQV$INLINE and
# ACL2::LIST-EQUIV are maintained at two problematic occurrences of variable
# ACL2::X in the right-hand side, but not at any binding occurrence of
# ACL2::X.  Consider replacing those two occurrences of ACL2::X in the
# right-hand side with (DOUBLE-REWRITE ACL2::X).  See :doc double-rewrite
# for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-UPDATE-NTH
# ...):  In a :REWRITE rule generated from ANY-TABLE-P-OF-UPDATE-NTH,
# equivalence relation ACL2::NAT-EQUIV$INLINE is maintained at two problematic
# occurrences of variable ACL2::N in the right-hand side, but not at
# any binding occurrence of ACL2::N.  Consider replacing those two occurrences
# of ACL2::N in the right-hand side with (DOUBLE-REWRITE ACL2::N).  See
# :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-REPEAT ...):
# In a :REWRITE rule generated from ANY-TABLE-P-OF-REPEAT, equivalence
# relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at four
# problematic occurrences of variable ACL2::X in the right-hand side,
# but not at any binding occurrence of ACL2::X.  Consider replacing those
# four occurrences of ACL2::X in the right-hand side with
# (DOUBLE-REWRITE ACL2::X).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-TAKE ...):
# In a :REWRITE rule generated from ANY-TABLE-P-OF-TAKE, equivalence
# relations STR::ICHARLISTEQV and STR::CHARLISTEQV$INLINE are maintained
# at one problematic occurrence of variable ACL2::X in the right-hand
# side, but not at any binding occurrence of ACL2::X.  Consider replacing
# that occurrence of ACL2::X in the right-hand side with
# (DOUBLE-REWRITE ACL2::X).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-TAKE ...):
# In a :REWRITE rule generated from ANY-TABLE-P-OF-TAKE, equivalence
# relation ACL2::NAT-EQUIV$INLINE is maintained at one problematic occurrence
# of variable ACL2::N in the right-hand side, but not at any binding
# occurrence of ACL2::N.  Consider replacing that occurrence of ACL2::N
# in the right-hand side with (DOUBLE-REWRITE ACL2::N).  See :doc double-
# rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-UNION-EQUAL
# ...):  In a :REWRITE rule generated from ANY-TABLE-P-OF-UNION-EQUAL,
# equivalence relation ACL2::LIST-EQUIV is maintained at one problematic
# occurrence of variable ACL2::X in the right-hand side, but not at any
# binding occurrence of ACL2::X.  Consider replacing that occurrence
# of ACL2::X in the right-hand side with (DOUBLE-REWRITE ACL2::X).  See
# :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-WHEN-SUBSETP-EQUAL
# ...):  In a :REWRITE rule generated from ANY-TABLE-P-WHEN-SUBSETP-EQUAL,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at one problematic occurrence of variable ACL2::X in the first hypothesis,
# but not at any binding occurrence of ACL2::X.  Consider replacing that
# occurrence of ACL2::X in the first hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-WHEN-SUBSETP-EQUAL
# ...):  In a :REWRITE rule generated from ANY-TABLE-P-WHEN-SUBSETP-EQUAL,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at one problematic occurrence of variable ACL2::X in the second hypothesis,
# but not at any binding occurrence of ACL2::X.  Consider replacing that
# occurrence of ACL2::X in the second hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-WHEN-SUBSETP-EQUAL
# ...):  In a :REWRITE rule generated from ANY-TABLE-P-WHEN-SUBSETP-EQUAL,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at one problematic occurrence of variable ACL2::Y in the second hypothesis,
# but not at any binding occurrence of ACL2::Y.  Consider replacing that
# occurrence of ACL2::Y in the second hypothesis with (DOUBLE-REWRITE ACL2::Y).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-RCONS ...):
# In a :REWRITE rule generated from ANY-TABLE-P-OF-RCONS, equivalence
# relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at two
# problematic occurrences of variable ACL2::A in the right-hand side,
# but not at any binding occurrence of ACL2::A.  Consider replacing those
# two occurrences of ACL2::A in the right-hand side with
# (DOUBLE-REWRITE ACL2::A).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-REV ...):
# In a :REWRITE rule generated from ANY-TABLE-P-OF-REV, equivalence relation
# ACL2::LIST-EQUIV is maintained at one problematic occurrence of variable
# ACL2::X in the right-hand side, but not at any binding occurrence of
# ACL2::X.  Consider replacing that occurrence of ACL2::X in the right-
# hand side with (DOUBLE-REWRITE ACL2::X).  See :doc double-rewrite for
# more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-INSERT ...):
# In a :REWRITE rule generated from ANY-TABLE-P-OF-INSERT, equivalence
# relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at two
# problematic occurrences of variable ACL2::A in the right-hand side,
# but not at any binding occurrence of ACL2::A.  Consider replacing those
# two occurrences of ACL2::A in the right-hand side with
# (DOUBLE-REWRITE ACL2::A).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-WHEN-NOT-CONSP
# ...):  In a :REWRITE rule generated from ANY-TABLE-P-WHEN-NOT-CONSP,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at one problematic occurrence of variable ACL2::X in the first hypothesis,
# but not at any binding occurrence of ACL2::X.  Consider replacing that
# occurrence of ACL2::X in the first hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-WHEN-NOT-CONSP
# ...):  In a :REWRITE rule generated from ANY-TABLE-P-WHEN-NOT-CONSP,
# equivalence relation IFF is maintained at one problematic occurrence
# of variable ACL2::X in the right-hand side, but not at any binding
# occurrence of ACL2::X.  Consider replacing that occurrence of ACL2::X
# in the right-hand side with (DOUBLE-REWRITE ACL2::X).  See :doc double-
# rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM ANY-TABLE-P-OF-CONS ...):
# In a :REWRITE rule generated from ANY-TABLE-P-OF-CONS, equivalence
# relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at two
# problematic occurrences of variable ACL2::A in the right-hand side,
# but not at any binding occurrence of ACL2::A.  Consider replacing those
# two occurrences of ACL2::A in the right-hand side with
# (DOUBLE-REWRITE ACL2::A).  See :doc double-rewrite for more information
# on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# BOOLEANP-OF-CDR-WHEN-MEMBER-EQUAL-OF-ANY-TABLE-P ...):  In a :REWRITE
# rule generated from BOOLEANP-OF-CDR-WHEN-MEMBER-EQUAL-OF-ANY-TABLE-P,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at one problematic occurrence of variable ACL2::X in the second hypothesis,
# but not at any binding occurrence of ACL2::X.  Consider replacing that
# occurrence of ACL2::X in the second hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# SIG-PATH-P-OF-CAR-WHEN-MEMBER-EQUAL-OF-ANY-TABLE-P ...):  In a :REWRITE
# rule generated from SIG-PATH-P-OF-CAR-WHEN-MEMBER-EQUAL-OF-ANY-TABLE-P,
# equivalence relations ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained
# at one problematic occurrence of variable ACL2::X in the second hypothesis,
# but not at any binding occurrence of ACL2::X.  Consider replacing that
# occurrence of ACL2::X in the second hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM
# CONSP-WHEN-MEMBER-EQUAL-OF-ANY-TABLE-P ...):  In a :REWRITE rule generated
# from CONSP-WHEN-MEMBER-EQUAL-OF-ANY-TABLE-P, equivalence relations
# ACL2::SET-EQUIV and ACL2::LIST-EQUIV are maintained at one problematic
# occurrence of variable ACL2::X in the second hypothesis, but not at
# any binding occurrence of ACL2::X.  Consider replacing that occurrence
# of ACL2::X in the second hypothesis with (DOUBLE-REWRITE ACL2::X).
# See :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM BOOLEANP-OF-CDAR-WHEN-ANY-TABLE-P
# ...):  In a :REWRITE rule generated from BOOLEANP-OF-CDAR-WHEN-ANY-TABLE-P,
# equivalence relation ACL2::SET-EQUIV is maintained at two problematic
# occurrences of variable ACL2::X in the right-hand side, but not at
# any binding occurrence of ACL2::X.  Consider replacing those two occurrences
# of ACL2::X in the right-hand side with (DOUBLE-REWRITE ACL2::X).  See
# :doc double-rewrite for more information on this issue.
#
#
# ACL2 Warning [Double-rewrite] in ( DEFTHM SIG-PATH-P-OF-CAAR-WHEN-ANY-TABLE-P
# ...):  In a :REWRITE rule generated from SIG-PATH-P-OF-CAAR-WHEN-ANY-TABLE-P,
# equivalence relation ACL2::SET-EQUIV is maintained at two problematic
# occurrences of variable ACL2::X in the right-hand side, but not at
# any binding occurrence of ACL2::X.  Consider replacing those two occurrences
# of ACL2::X in the right-hand side with (DOUBLE-REWRITE ACL2::X).  See
# :doc double-rewrite for more information on this issue.
#
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO ANY-TABLE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN ANY-TABLE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 3
# Subgoal 2
# Subgoal 2'
# Subgoal 2''
# Subgoal 2'''
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM ANY-TABLE-P-OF-ANY-TABLE-FIX ...)
# Time:  0.03 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM ANY-TABLE-P-OF-ANY-TABLE-FIX ...) ...)
# Time:  0.03 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'''
# Goal'4'
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM ANY-TABLE-FIX-WHEN-ANY-TABLE-P ...)
# Time:  0.03 seconds (prove: 0.03, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS ANY-TABLE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (DEFFIXTYPE ... T) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM CONS-OF-SIG-PATH-FIX-K-UNDER-ANY-TABLE-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-BOOL-FIX-V-UNDER-ANY-TABLE-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal''
# Goal'
# Form:  ( DEFTHM CONS-OF-ANY-TABLE-FIX-Y-UNDER-ANY-TABLE-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM ANY-TABLE-FIX-OF-ACONS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Form:  ( DEFTHM ANY-TABLE-FIX-OF-APPEND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Subgoal *1/1'
# Subgoal *1/1''
# Form:  ( DEFTHM CONSP-CAR-OF-ANY-TABLE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.05 seconds (prove: 0.04, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC ANY-TABLE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC ANY-TABLE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE ACL2::XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.17 seconds (prove: 0.06, print: 0.00, other: 0.10)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.19 seconds (prove: 0.06, print: 0.00, other: 0.12)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFALIST-FN ...))
# Rules: NIL
# Warnings:  Double-rewrite, Disable and Theory
# Time:  0.19 seconds (prove: 0.06, print: 0.00, other: 0.12)
# Prover steps counted:  5510
#  T

# %%
(deflist any-trace
  :elt-type any-table
  :true-listp t)
# Out:
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE STD::DEFAULT-HINTS-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-ORIG-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TYPE-THEORY ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (CONS ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( DEFLABEL FTY::DEFTYPES-BEFORE-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHEORY FTY::DEFTYPES-TEMP-THMS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :DEFINITION
# rules for the built-in functions DOUBLE-REWRITE, THE-CHECK, CONS-WITH-HINT,
# IFF, FROM-DF, WORMHOLE-EVAL, MV-LIST, MINUSP, PLUSP, ZEROP, LISTP,
# SYNP, CASE-SPLIT, FORCE, /=, =, RETURN-LAST, NULL, ENDP, ATOM, EQL,
# NOT, IMPLIES and EQ are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some expansions of their calls
# may still occur.  See :DOC theories-and-primitives.
#
#
# ACL2 Warning [Theory] in ( IN-THEORY (DISABLE ...)):  The :EXECUTABLE-
# COUNTERPART rules for the built-in functions NOT, SYMBOLP,
# SYMBOL-PACKAGE-NAME, SYMBOL-NAME, STRINGP, REALPART, RATIONALP, PKG-WITNESS,
# PKG-IMPORTS, NUMERATOR, INTERN-IN-PACKAGE-OF-SYMBOL, INTEGERP, IMAGPART,
# IF, EQUAL, DENOMINATOR, CONSP, CONS, COERCE, COMPLEX-RATIONALP, COMPLEX,
# CODE-CHAR, CHARACTERP, CHAR-CODE, CDR, CAR, <, UNARY-/, UNARY--, BINARY-+,
# BINARY-* and ACL2-NUMBERP are disabled by the theory expression
# (DISABLE FTY::DEFTYPES-ORIG-THEORY), but some evaluations of their
# calls may still occur.  See :DOC theories-and-primitives.
#
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ACL2::ENABLE* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE DEFINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN ANY-TRACE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
# Deflist: attempting to show, using your current theory, that (ANY-TABLE-P X)
# is always Boolean valued.
#
# Deflist: introducing ANY-TRACE-P and proving deflist theorems.
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.01)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFMACRO ANY-TRACE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFUN ANY-TRACE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM ANY-TRACE-P-OF-ANY-TRACE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFTHM ANY-TRACE-P-OF-ANY-TRACE-FIX ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM ANY-TRACE-FIX-WHEN-ANY-TRACE-P ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( VERIFY-GUARDS ANY-TRACE-FIX$INLINE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (LET* ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM FTY::TMP-DEFFIXTYPE-IDEMPOTENT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 1
# Goal'
# Form:  ( ENCAPSULATE NIL (DEFFIXTYPE ... T) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Form:  ( DEFTHM CAR-OF-ANY-TRACE-FIX-X-UNDER-ANY-TABLE-EQUIV ...)
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Subgoal 2
# Subgoal 2'
# Subgoal 1
# Subgoal 1'
# Form:  ( DEFTHM CDR-OF-ANY-TRACE-FIX-X-UNDER-ANY-TRACE-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-ANY-TABLE-FIX-X-UNDER-ANY-TRACE-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Goal'
# Form:  ( DEFTHM CONS-OF-ANY-TRACE-FIX-Y-UNDER-ANY-TRACE-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Subgoal 2
# Subgoal 1
# Form:  ( DEFTHM CONSP-OF-ANY-TRACE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Goal'
# Form:  ( DEFTHM ANY-TRACE-FIX-UNDER-IFF ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( DEFTHM ANY-TRACE-FIX-OF-CONS ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM LEN-OF-ANY-TRACE-FIX ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM ANY-TRACE-FIX-OF-APPEND ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/1
# Form:  ( DEFTHM ANY-TRACE-FIX-OF-REPEAT ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/4
# Subgoal *1/4'
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM LIST-EQUIV-REFINES-ANY-TRACE-EQUIV ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/3
# Subgoal *1/3.9
# Subgoal *1/3.9'
# Subgoal *1/3.9''
# Subgoal *1/3.8
# Subgoal *1/3.7
# Subgoal *1/3.6
# Subgoal *1/3.5
# Subgoal *1/3.4
# Subgoal *1/3.3
# Subgoal *1/3.3'
# Subgoal *1/3.3''
# Subgoal *1/3.2
# Subgoal *1/3.2'
# Subgoal *1/3.2''
# Subgoal *1/3.1
# Subgoal *1/3.1'
# Subgoal *1/3.1''
# Subgoal *1/2
# Subgoal *1/2.3
# Subgoal *1/2.3'
# Subgoal *1/2.2
# Subgoal *1/2.2'
# Subgoal *1/2.2''
# Subgoal *1/2.2'''
# Subgoal *1/2.1
# Subgoal *1/2.1'
# Subgoal *1/1
# Form:  ( DEFTHM NTH-OF-ANY-TRACE-FIX ...)
# Time:  0.09 seconds (prove: 0.09, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM ANY-TRACE-EQUIV-IMPLIES-ANY-TRACE-EQUIV-APPEND-1 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM ANY-TRACE-EQUIV-IMPLIES-ANY-TRACE-EQUIV-APPEND-2 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM ANY-TRACE-EQUIV-IMPLIES-ANY-TRACE-EQUIV-NTHCDR-2 ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (ACL2::DEFCONG-FORM ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/1
# Subgoal *1/1'
# Form:  ( DEFTHM ANY-TRACE-EQUIV-IMPLIES-ANY-TRACE-EQUIV-TAKE-2 ...)
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (ACL2::DEFCONG-FORM ...))
# Time:  0.01 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.15 seconds (prove: 0.13, print: 0.00, other: 0.02)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (DISABLE ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( IN-THEORY (ENABLE ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( TABLE FTY::FLEXTYPES-TABLE ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC ANY-TRACE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( TABLE ACL2::XDOC ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (DEFXDOC ANY-TRACE ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (B* ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (TABLE ACL2::XDOC ...) ...)
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( MAKE-EVENT (FTY::FLEXTYPES-FINAL-XDOC-FN ...))
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# Form:  ( PROGN (LOCAL ...) ...)
# Time:  0.24 seconds (prove: 0.14, print: 0.00, other: 0.11)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :SUMMARY-OFF ...) ...)
# Time:  0.27 seconds (prove: 0.14, print: 0.00, other: 0.13)
#
# Summary
# Form:  ( MAKE-EVENT (FTY::DEFLIST-FN ...))
# Rules: NIL
# Warnings:  Theory
# Time:  0.27 seconds (prove: 0.14, print: 0.00, other: 0.13)
# Prover steps counted:  9554
#  T

# %%
(define sigs-in-bool-table ((sigs sig-path-listp)
                            (st any-table-p))
  :returns (ok booleanp)
  :measure (len sigs)
  :hints (("Goal" :in-theory (enable sig-path-list-fix)))
  (b* ((sigs (sig-path-list-fix sigs))
       (st (any-table-fix st))
       ((unless (consp (sig-path-list-fix sigs))) t)
       (first (car (sig-path-list-fix sigs)))
       (rest (cdr (sig-path-list-fix sigs)))
       (first-v (assoc-equal first (any-table-fix st)))
       ((unless (consp (smt::magic-fix 'sig-path_booleanp first-v)))
        nil))
    (sigs-in-bool-table rest st)))
# Out:
# For the admission of SIGS-IN-BOOL-TABLE we will use the relation O<
# (which is known to be well-founded on the domain recognized by O-P)
# and the measure (LEN SIGS).  The non-trivial part of the measure conjecture
# is
#
# Goal
# (AND
#  (O-P (LEN SIGS))
#  (IMPLIES
#   (AND
#     (CONSP (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#     (CONSP
#          (MAGIC-FIX
#               'SIG-PATH_BOOLEANP
#               (ASSOC-EQUAL (CAR (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#                            (ANY-TABLE-FIX (ANY-TABLE-FIX ST))))))
#   (O< (LEN (CDR (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS))))
#       (LEN SIGS)))).
# Goal'
#
# ([ A key checkpoint:
#
# Goal'
# (IMPLIES (AND (CONSP SIGS)
#               (CONSP (ASSOC-EQUAL (CAR (SIG-PATH-LIST-FIX SIGS))
#                                   (ANY-TABLE-FIX ST))))
#          (O< (LEN (CDR (SIG-PATH-LIST-FIX SIGS)))
#              (LEN SIGS)))
#
# *1 (Goal') is pushed for proof by induction.
#
# ])
#
# Perhaps we can prove *1 by induction.  Three induction schemes are
# suggested by this conjecture.  Subsumption reduces that number to two.
# These merge into one derived induction scheme.
#
# We will induct according to a scheme suggested by (LEN SIGS), while
# accommodating (SIG-PATH-LIST-FIX SIGS).
#
# These suggestions were produced using the :induction rules LEN and
# SIG-PATH-LIST-FIX$INLINE.  If we let (:P SIGS ST) denote *1 above then
# the induction scheme we'll use is
# (AND (IMPLIES (NOT (CONSP SIGS))
#               (:P SIGS ST))
#      (IMPLIES (AND (CONSP SIGS) (:P (CDR SIGS) ST))
#               (:P SIGS ST))).
# This induction is justified by the same argument used to admit LEN.
# When applied to the goal at hand the above induction scheme produces
# three nontautological subgoals.
# Subgoal *1/3
# Subgoal *1/2
# Subgoal *1/1
#
# *1 is COMPLETED!
# Thus key checkpoint Goal' is COMPLETED!
#
# Q.E.D.
#
# That completes the proof of the measure theorem for SIGS-IN-BOOL-TABLE.
# Thus, we admit this function under the principle of definition.  We
# observe that the type of SIGS-IN-BOOL-TABLE is described by the theorem
# (OR (EQUAL (SIGS-IN-BOOL-TABLE SIGS ST) T)
#     (EQUAL (SIGS-IN-BOOL-TABLE SIGS ST)
#            NIL)).
#
# Computing the guard conjecture for SIGS-IN-BOOL-TABLE....
#
# The non-trivial part of the guard conjecture for SIGS-IN-BOOL-TABLE
# is
#
# Goal
# (IMPLIES
#  (AND (ANY-TABLE-P ST)
#       (SIG-PATH-LISTP SIGS))
#  (AND
#   (SIG-PATH-LISTP SIGS)
#   (LET ((SIGS (SIG-PATH-LIST-FIX SIGS)))
#    (AND
#     (ANY-TABLE-P ST)
#     (LET ((ST (ANY-TABLE-FIX ST)))
#      (AND
#       (SIG-PATH-LISTP SIGS)
#       (OR (NOT (CONSP (SIG-PATH-LIST-FIX SIGS)))
#           (SIG-PATH-LISTP SIGS))
#       (OR
#        (NOT (CONSP (SIG-PATH-LIST-FIX SIGS)))
#        (LET ((FIRST (CAR (SIG-PATH-LIST-FIX SIGS))))
#         (AND
#          (SIG-PATH-LISTP SIGS)
#          (OR (CONSP (SIG-PATH-LIST-FIX SIGS))
#              (EQUAL (SIG-PATH-LIST-FIX SIGS) NIL))
#          (LET ((REST (CDR (SIG-PATH-LIST-FIX SIGS))))
#           (AND
#               (ANY-TABLE-P ST)
#               (ALISTP (ANY-TABLE-FIX ST))
#               (LET ((FIRST-V (ASSOC-EQUAL FIRST (ANY-TABLE-FIX ST))))
#                 (AND (OR (NOT (CONSP (MAGIC-FIX 'SIG-PATH_BOOLEANP FIRST-V)))
#                          (SIG-PATH-LISTP REST))
#                      (OR (NOT (CONSP (MAGIC-FIX 'SIG-PATH_BOOLEANP FIRST-V)))
#                          (ANY-TABLE-P ST))))))))))))))).
# Goal'
# Goal''
#
# Q.E.D.
#
# That completes the proof of the guard theorem for SIGS-IN-BOOL-TABLE.
# SIGS-IN-BOOL-TABLE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SIGS-IN-BOOL-TABLE ...)
# Rules: ((:COMPOUND-RECOGNIZER ACL2::O-FINP-CR)
#         (:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-ANY-TABLE-P-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-SIG-PATH-LISTP-COMPOUND-RECOGNIZER)
#         (:CONGRUENCE ANY-TABLE-EQUIV-IMPLIES-EQUAL-ANY-TABLE-FIX-1)
#         (:CONGRUENCE SIG-PATH-LIST-EQUIV-IMPLIES-EQUAL-SIG-PATH-LIST-FIX-1)
#         (:DEFINITION LEN)
#         (:DEFINITION MAGIC-FIX)
#         (:DEFINITION NOT)
#         (:DEFINITION SIG-PATH-LIST-FIX$INLINE)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:FORWARD-CHAINING ACL2::O-FINP-<-FC)
#         (:INDUCTION LEN)
#         (:INDUCTION SIG-PATH-LIST-FIX$INLINE)
#         (:REWRITE ANY-TABLE-FIX-UNDER-ANY-TABLE-EQUIV)
#         (:REWRITE ANY-TABLE-FIX-WHEN-ANY-TABLE-P)
#         (:REWRITE ANY-TABLE-P-WHEN-SUBSETP-EQUAL)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE CONSP-OF-SIG-PATH-LIST-FIX)
#         (:REWRITE LEN-OF-SIG-PATH-LIST-FIX)
#         (:REWRITE ACL2::O-FINP-<)
#         (:REWRITE SIG-PATH-LIST-FIX-UNDER-SIG-PATH-LIST-EQUIV)
#         (:REWRITE SIG-PATH-LIST-FIX-WHEN-SIG-PATH-LISTP)
#         (:REWRITE SIG-PATH-LISTP-WHEN-SUBSETP-EQUAL)
#         (:REWRITE SUBSETP-IF-TRUE-SET-EQUIV)
#         (:REWRITE ACL2::SUBSETP-OF-CDR)
#         (:TYPE-PRESCRIPTION ALISTP)
#         (:TYPE-PRESCRIPTION LEN)
#         (:TYPE-PRESCRIPTION O<))
# Time:  0.04 seconds (prove: 0.02, print: 0.00, other: 0.01)
# Prover steps counted:  1593
#
#
# SMT !>>(DEFTHM BOOLEANP-OF-SIGS-IN-BOOL-TABLE
#          (B* ((OK (SIGS-IN-BOOL-TABLE SIGS ST)))
#            (BOOLEANP OK))
#          :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'SIGS-IN-BOOL-TABLE
#                                                        ID WORLD))
#          :RULE-CLASSES :REWRITE)
#
# *1 (the initial Goal, a key checkpoint) is pushed for proof by induction.
#
# We have been told to use induction.  One induction scheme is suggested
# by the induction hint.
#
# We will induct according to a scheme suggested by
# (SIGS-IN-BOOL-TABLE SIGS ST).
#
# This suggestion was produced using the :induction rule SIGS-IN-BOOL-TABLE.
# If we let (:P SIGS ST) denote *1 above then the induction scheme we'll
# use is
# (AND
#  (IMPLIES (NOT (CONSP (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS))))
#           (:P SIGS ST))
#  (IMPLIES
#   (AND
#    (CONSP (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#    (NOT
#     (CONSP
#          (MAGIC-FIX
#               'SIG-PATH_BOOLEANP
#               (ASSOC-EQUAL (CAR (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#                            (ANY-TABLE-FIX (ANY-TABLE-FIX ST)))))))
#   (:P SIGS ST))
#  (IMPLIES
#   (AND
#     (CONSP (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#     (CONSP
#          (MAGIC-FIX
#               'SIG-PATH_BOOLEANP
#               (ASSOC-EQUAL (CAR (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#                            (ANY-TABLE-FIX (ANY-TABLE-FIX ST)))))
#     (:P (CDR (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#         (ANY-TABLE-FIX ST)))
#   (:P SIGS ST))).
# This induction is justified by the same argument used to admit
# SIGS-IN-BOOL-TABLE.  Note, however, that the unmeasured variable ST
# is being instantiated.  When applied to the goal at hand the above
# induction scheme produces three nontautological subgoals.
# Subgoal *1/3
# Subgoal *1/2
# Subgoal *1/1
#
# *1 is COMPLETED!
# Thus key checkpoint Goal is COMPLETED!
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-SIGS-IN-BOOL-TABLE depends upon the :compound-
# recognizer rule BOOLEANP-COMPOUND-RECOGNIZER and the :type-prescription
# rule SIGS-IN-BOOL-TABLE.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-SIGS-IN-BOOL-TABLE ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:INDUCTION SIGS-IN-BOOL-TABLE)
#         (:TYPE-PRESCRIPTION SIGS-IN-BOOL-TABLE))
# Time:  0.07 seconds (prove: 0.06, print: 0.00, other: 0.00)
# BOOLEANP-OF-SIGS-IN-BOOL-TABLE
#
# Summary
# Form:  ( PROGN (DEFTHM BOOLEANP-OF-SIGS-IN-BOOL-TABLE ...) ...)
# Rules: NIL
# Time:  0.07 seconds (prove: 0.06, print: 0.00, other: 0.00)
#  SIGS-IN-BOOL-TABLE

# %%
(define sigs-in-bool-trace ((sigs sig-path-listp)
                            (tr any-trace-p))
  :returns (ok booleanp)
  :measure (len tr)
  (b* ((sigs (sig-path-list-fix sigs))
       (tr (any-trace-fix tr))
       ((unless (consp (sig-path-list-fix sigs))) t)
       ((unless (consp (any-trace-fix tr))) t)
       (first (car (any-trace-fix tr)))
       (rest (cdr (any-trace-fix tr)))
       ((unless (sigs-in-bool-table sigs first)) nil))
    (sigs-in-bool-trace sigs rest)))
# Out:
# For the admission of SIGS-IN-BOOL-TRACE we will use the relation O<
# (which is known to be well-founded on the domain recognized by O-P)
# and the measure (LEN TR).  The non-trivial part of the measure conjecture
# is
#
# Goal
# (AND
#  (O-P (LEN TR))
#  (IMPLIES (AND (CONSP (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#                (CONSP (ANY-TRACE-FIX (ANY-TRACE-FIX TR)))
#                (SIGS-IN-BOOL-TABLE (SIG-PATH-LIST-FIX SIGS)
#                                    (CAR (ANY-TRACE-FIX (ANY-TRACE-FIX TR)))))
#           (O< (LEN (CDR (ANY-TRACE-FIX (ANY-TRACE-FIX TR))))
#               (LEN TR)))).
# Goal'
#
# ([ A key checkpoint:
#
# Goal'
# (IMPLIES (AND (CONSP SIGS)
#               (CONSP TR)
#               (SIGS-IN-BOOL-TABLE (SIG-PATH-LIST-FIX SIGS)
#                                   (CAR (ANY-TRACE-FIX TR))))
#          (O< (LEN (CDR (ANY-TRACE-FIX TR)))
#              (LEN TR)))
#
# *1 (Goal') is pushed for proof by induction.
#
# ])
#
# Perhaps we can prove *1 by induction.  One induction scheme is suggested
# by this conjecture.
#
# We will induct according to a scheme suggested by (LEN TR).
#
# This suggestion was produced using the :induction rule LEN.  If we
# let (:P SIGS TR) denote *1 above then the induction scheme we'll use
# is
# (AND (IMPLIES (NOT (CONSP TR)) (:P SIGS TR))
#      (IMPLIES (AND (CONSP TR) (:P SIGS (CDR TR)))
#               (:P SIGS TR))).
# This induction is justified by the same argument used to admit LEN.
# When applied to the goal at hand the above induction scheme produces
# three nontautological subgoals.
# Subgoal *1/3
# Subgoal *1/3'
# Subgoal *1/3''
# Subgoal *1/3'''
# Subgoal *1/2
# Subgoal *1/2'
# Subgoal *1/2''
# Subgoal *1/2'''
# Subgoal *1/1
# Subgoal *1/1'
# Subgoal *1/1''
# Subgoal *1/1'''
# Subgoal *1/1'4'
#
# *1 is COMPLETED!
# Thus key checkpoint Goal' is COMPLETED!
#
# Q.E.D.
#
# That completes the proof of the measure theorem for SIGS-IN-BOOL-TRACE.
# Thus, we admit this function under the principle of definition.  We
# observe that the type of SIGS-IN-BOOL-TRACE is described by the theorem
# (OR (EQUAL (SIGS-IN-BOOL-TRACE SIGS TR) T)
#     (EQUAL (SIGS-IN-BOOL-TRACE SIGS TR)
#            NIL)).
#
# Computing the guard conjecture for SIGS-IN-BOOL-TRACE....
#
# The non-trivial part of the guard conjecture for SIGS-IN-BOOL-TRACE
# is
#
# Goal
# (IMPLIES
#  (AND (ANY-TRACE-P TR)
#       (SIG-PATH-LISTP SIGS))
#  (AND
#     (SIG-PATH-LISTP SIGS)
#     (LET ((SIGS (SIG-PATH-LIST-FIX SIGS)))
#       (AND (ANY-TRACE-P TR)
#            (LET ((TR (ANY-TRACE-FIX TR)))
#              (AND (SIG-PATH-LISTP SIGS)
#                   (OR (NOT (CONSP (SIG-PATH-LIST-FIX SIGS)))
#                       (ANY-TRACE-P TR))
#                   (OR (NOT (CONSP (SIG-PATH-LIST-FIX SIGS)))
#                       (NOT (CONSP (ANY-TRACE-FIX TR)))
#                       (ANY-TRACE-P TR))
#                   (OR (NOT (CONSP (SIG-PATH-LIST-FIX SIGS)))
#                       (NOT (CONSP (ANY-TRACE-FIX TR)))
#                       (LET ((FIRST (CAR (ANY-TRACE-FIX TR))))
#                         (AND (ANY-TRACE-P TR)
#                              (OR (CONSP (ANY-TRACE-FIX TR))
#                                  (EQUAL (ANY-TRACE-FIX TR) NIL))
#                              (LET ((REST (CDR (ANY-TRACE-FIX TR))))
#                                (AND (SIG-PATH-LISTP SIGS)
#                                     (ANY-TABLE-P FIRST)
#                                     (OR (NOT (SIGS-IN-BOOL-TABLE SIGS FIRST))
#                                         (SIG-PATH-LISTP SIGS))
#                                     (OR (NOT (SIGS-IN-BOOL-TABLE SIGS FIRST))
#                                         (ANY-TRACE-P REST))))))))))))).
# Goal'
#
# Q.E.D.
#
# That completes the proof of the guard theorem for SIGS-IN-BOOL-TRACE.
# SIGS-IN-BOOL-TRACE is compliant with Common Lisp.
#
# Summary
# Form:  ( DEFUN SIGS-IN-BOOL-TRACE ...)
# Rules: ((:COMPOUND-RECOGNIZER ACL2::O-FINP-CR)
#         (:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-ANY-TRACE-P-COMPOUND-RECOGNIZER)
#         (:COMPOUND-RECOGNIZER
#              TRUE-LISTP-WHEN-SIG-PATH-LISTP-COMPOUND-RECOGNIZER)
#         (:CONGRUENCE ANY-TRACE-EQUIV-IMPLIES-EQUAL-ANY-TRACE-FIX-1)
#         (:CONGRUENCE SIG-PATH-LIST-EQUIV-IMPLIES-EQUAL-SIG-PATH-LIST-FIX-1)
#         (:DEFINITION LEN)
#         (:DEFINITION NOT)
#         (:ELIM CAR-CDR-ELIM)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART O<)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:FAKE-RUNE-FOR-LINEAR NIL)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:FORWARD-CHAINING ACL2::O-FINP-<-FC)
#         (:INDUCTION LEN)
#         (:REWRITE ANY-TABLE-P-WHEN-MEMBER-EQUAL-OF-ANY-TRACE-P)
#         (:REWRITE ANY-TRACE-FIX-OF-CONS)
#         (:REWRITE ANY-TRACE-FIX-UNDER-ANY-TRACE-EQUIV)
#         (:REWRITE ANY-TRACE-FIX-WHEN-ANY-TRACE-P)
#         (:REWRITE ANY-TRACE-P-WHEN-SUBSETP-EQUAL)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE CONSP-OF-ANY-TRACE-FIX)
#         (:REWRITE CONSP-OF-SIG-PATH-LIST-FIX)
#         (:REWRITE LEN-OF-ANY-TRACE-FIX)
#         (:REWRITE ACL2::O-FINP-<)
#         (:REWRITE SIG-PATH-LIST-FIX-UNDER-SIG-PATH-LIST-EQUIV)
#         (:REWRITE SIG-PATH-LIST-FIX-WHEN-SIG-PATH-LISTP)
#         (:REWRITE SIG-PATH-LISTP-WHEN-SUBSETP-EQUAL)
#         (:REWRITE ACL2::SUBSETP-CAR-MEMBER)
#         (:REWRITE SUBSETP-IF-TRUE-SET-EQUIV)
#         (:REWRITE ACL2::SUBSETP-OF-CDR)
#         (:TYPE-PRESCRIPTION LEN)
#         (:TYPE-PRESCRIPTION O<))
# Time:  0.02 seconds (prove: 0.02, print: 0.00, other: 0.00)
# Prover steps counted:  3092
#
#
# SMT !>>(DEFTHM BOOLEANP-OF-SIGS-IN-BOOL-TRACE
#          (B* ((OK (SIGS-IN-BOOL-TRACE SIGS TR)))
#            (BOOLEANP OK))
#          :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'SIGS-IN-BOOL-TRACE
#                                                        ID WORLD))
#          :RULE-CLASSES :REWRITE)
#
# *1 (the initial Goal, a key checkpoint) is pushed for proof by induction.
#
# We have been told to use induction.  One induction scheme is suggested
# by the induction hint.
#
# We will induct according to a scheme suggested by
# (SIGS-IN-BOOL-TRACE SIGS TR).
#
# This suggestion was produced using the :induction rule SIGS-IN-BOOL-TRACE.
# If we let (:P SIGS TR) denote *1 above then the induction scheme we'll
# use is
# (AND
#  (IMPLIES (NOT (CONSP (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS))))
#           (:P SIGS TR))
#  (IMPLIES (AND (CONSP (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#                (NOT (CONSP (ANY-TRACE-FIX (ANY-TRACE-FIX TR)))))
#           (:P SIGS TR))
#  (IMPLIES
#     (AND (CONSP (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#          (CONSP (ANY-TRACE-FIX (ANY-TRACE-FIX TR)))
#          (NOT (SIGS-IN-BOOL-TABLE (SIG-PATH-LIST-FIX SIGS)
#                                   (CAR (ANY-TRACE-FIX (ANY-TRACE-FIX TR))))))
#     (:P SIGS TR))
#  (IMPLIES (AND (CONSP (SIG-PATH-LIST-FIX (SIG-PATH-LIST-FIX SIGS)))
#                (CONSP (ANY-TRACE-FIX (ANY-TRACE-FIX TR)))
#                (SIGS-IN-BOOL-TABLE (SIG-PATH-LIST-FIX SIGS)
#                                    (CAR (ANY-TRACE-FIX (ANY-TRACE-FIX TR))))
#                (:P (SIG-PATH-LIST-FIX SIGS)
#                    (CDR (ANY-TRACE-FIX (ANY-TRACE-FIX TR)))))
#           (:P SIGS TR))).
# This induction is justified by the same argument used to admit
# SIGS-IN-BOOL-TRACE.  Note, however, that the unmeasured variable SIGS
# is being instantiated.  When applied to the goal at hand the above
# induction scheme produces four nontautological subgoals.
# Subgoal *1/4
# Subgoal *1/3
# Subgoal *1/2
# Subgoal *1/1
#
# *1 is COMPLETED!
# Thus key checkpoint Goal is COMPLETED!
#
# Q.E.D.
#
# The storage of BOOLEANP-OF-SIGS-IN-BOOL-TRACE depends upon the :compound-
# recognizer rule BOOLEANP-COMPOUND-RECOGNIZER and the :type-prescription
# rule SIGS-IN-BOOL-TRACE.
#
# Summary
# Form:  ( DEFTHM BOOLEANP-OF-SIGS-IN-BOOL-TRACE ...)
# Rules: ((:COMPOUND-RECOGNIZER BOOLEANP-COMPOUND-RECOGNIZER)
#         (:INDUCTION SIGS-IN-BOOL-TRACE)
#         (:TYPE-PRESCRIPTION SIGS-IN-BOOL-TRACE))
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
# BOOLEANP-OF-SIGS-IN-BOOL-TRACE
#
# Summary
# Form:  ( PROGN (DEFTHM BOOLEANP-OF-SIGS-IN-BOOL-TRACE ...) ...)
# Rules: NIL
# Time:  0.08 seconds (prove: 0.08, print: 0.00, other: 0.00)
#  SIGS-IN-BOOL-TRACE

# %%
(define boolval ((bit booleanp))
  :returns (n integerp)
  (if (equal bit nil)
      0
    1))
# Out:
# Since BOOLVAL is non-recursive, its admission is trivial.  We observe
# that the type of BOOLVAL is described by the theorem
# (OR (EQUAL (BOOLVAL BIT) 0) (EQUAL (BOOLVAL BIT) 1)).
#
# Computing the guard conjecture for BOOLVAL....
#
# The guard conjecture for BOOLVAL is trivial to prove.  BOOLVAL is compliant
# with Common Lisp.
#
# Summary
# Form:  ( DEFUN BOOLVAL ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#
#
# SMT !>>(DEFTHM INTEGERP-OF-BOOLVAL
#          (B* ((N (BOOLVAL BIT))) (INTEGERP N))
#          :HINTS ((STD::RETURNSPEC-DEFAULT-DEFAULT-HINT 'BOOLVAL
#                                                        ID WORLD))
#          :RULE-CLASSES :REWRITE)
#
# ACL2 Warning [Non-rec] in ( DEFTHM INTEGERP-OF-BOOLVAL ...):  A :REWRITE
# rule generated from INTEGERP-OF-BOOLVAL will be triggered only by terms
# containing the function symbol BOOLVAL, which has a non-recursive definition.
# Unless this definition is disabled, this rule is unlikely ever to be
# used.
#
#
# Q.E.D.
#
# The storage of INTEGERP-OF-BOOLVAL depends upon the :type-prescription
# rule BOOLVAL.
#
# Summary
# Form:  ( DEFTHM INTEGERP-OF-BOOLVAL ...)
# Rules: ((:TYPE-PRESCRIPTION BOOLVAL))
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
# INTEGERP-OF-BOOLVAL
#
# Summary
# Form:  ( PROGN (DEFTHM INTEGERP-OF-BOOLVAL ...) ...)
# Rules: NIL
# Warnings:  Non-rec
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  BOOLVAL
